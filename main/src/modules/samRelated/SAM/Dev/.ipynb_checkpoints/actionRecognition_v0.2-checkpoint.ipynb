# %%
jointMu = 0
jointSig = 0.0000001

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import readline
import GPy
from SAM.SAM_Core import SAMCore
from SAM.SAM_Core import SAMDriver
import pylab as pb
import sys 
from sys import executable
import subprocess
from subprocess import Popen, PIPE
import pickle
import os
from os import listdir, walk, system
from os.path import isfile, join, isdir
import time
import operator
import numpy

import numpy as np
import numpy.ma as ma
np.set_printoptions(threshold=numpy.nan)
import datetime
import yarp
import copy
from itertools import combinations 
from ConfigParser import SafeConfigParser
from scipy.spatial import distance
from numpy.linalg import inv
import math
import ipyparallel as ipp
import random
from SAM.SAM_Core import staticPose

dataSetFolder = '/home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld'
dataFolderList = ['lift-drop-right_arm', 
                  'lift-drop-left_arm', 
                  'push-pull-left_arm', 
                  'push-pull-right_arm']

dataFolders = []
labelFolders = []
#check folders in list actually exist
for j in dataFolderList:
    t = join(dataSetFolder,j,'data')
    m = join(dataSetFolder,j,'labels')
    if(isdir(t) and isdir(m)):
        dataFolders.append(t)
        labelFolders.append(m)
print '\n'.join(dataFolders)
print
print '\n'.join(labelFolders)
#subDirFolderList = ['camera/left', 'camera/right', 'data', 'kinect/rgb', 'labels']
# Out:
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld/lift-drop-right_arm/data
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld/lift-drop-left_arm/data
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld/push-pull-left_arm/data
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld/push-pull-right_arm/data
#
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld/lift-drop-right_arm/labels
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld/lift-drop-left_arm/labels
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld/push-pull-left_arm/labels
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDatasetOld/push-pull-right_arm/labels

# %%
def distEuc(a,b):
    temp = a-b
    temp = np.square(temp)
    temp = np.sum(temp,1)
    return np.sqrt(temp)

def qtc_2D(k,l,q,thresh):
    
    d1 = distEuc(k[:-2],l[1:-1])
    d2 = distEuc(k[1:-1],l[1:-1])
    d3 = distEuc(k[2:],l[1:-1])
    
    for i in range(len(d1)):
        #threshold distance moved
        diff1 = d2[i]-d1[i]
        if(np.abs(diff1) < thresh):
            diff1 = 0

        diff2 = d3[i]-d2[i]
        if(np.abs(diff2) < thresh):
            diff2 = 0

        #convert to qtc
        if(diff1 > 0 and diff2 > 0):
            q[i] = -1
        elif(diff1 < 0 and diff2 < 0):
            q[i] = +1
        else:
            q[i] = 0
    
    return d2

def frenetFrame(arr):
    t_num = np.diff(arr,axis=0)
    t = (t_num/np.abs(t_num)).astype(int)

    b_num = np.cross(t[:-1],t[1:])
    b = b_num/np.abs(b_num)
    t = t[1:]

    n = np.cross(b,t)

    frameArr = np.concatenate((t,n,b),axis=1).T
    fArr = frameArr.reshape((3,3,-1),order = 'F')
    return fArr

def qtc_3D(k, l, thresh, q3, q4, q5):
    fFrameK = frenetFrame(k)
    fFrameL = frenetFrame(l)
    alpArr = np.zeros(q3.shape)
    betArr = np.zeros(q3.shape)
    gamArr = np.zeros(q3.shape)
    
    for g in range(fFrameK.shape[2]):
        fKinv = np.linalg.pinv(fFrameK[:,:,g])
        R = np.dot(fFrameL[:,:,g],fKinv)
        
        alpha = np.arctan(R[1,0]/R[0,0])
        den = np.sqrt(pow(R[2,1],2) + pow(R[2,2],2))
        
        beta = np.arctan(-R[2,0]/den)
        gamma = np.arctan(R[2,1]/R[2,2])

        #threshold angles
        if(np.abs(alpha) < thresh or math.isnan(alpha)):
            alpha = 0
        if(np.abs(beta) < thresh or math.isnan(beta)):
            beta = 0
        if(np.abs(gamma) < thresh or math.isnan(gamma)):
            gamma = 0
        alpArr[g] = alpha
        betArr[g] = beta
        gamArr[g] = gamma
        
        q3[g] = np.sign(alpha)
        q4[g] = np.sign(beta)
        q5[g] = np.sign(gamma)
    
    return [alpArr,betArr,gamArr]
            
def checkQTC(qtcArr):
    #array of shape x by 11 with 0 to 4 of 11 being the ones that unique must apply to
    tArr = copy.deepcopy(qtcArr)
    for i in range(1,tArr.shape[0]):
        if(i != 0):
            currRow = tArr[i,:]
            Mod = False
            for q in range(tArr.shape[1]):
                r = tArr[i,q] - tArr[i-1,q]
                if(r == -2 or r == 2):
                    Mod = True
                    currRow[q] = 0
            if(Mod):    
                qtcArr = np.insert(qtcArr,i,currRow,axis=0)    
                Mod = False
    return qtcArr

def uniqueQTC(currQTC):
    #array of shape x by 11 with 0 to 4 of 11 being the ones that unique must apply to
    i = 0
    del1 = False
    del2 = False
    
    while(i < currQTC.shape[0]-2):
        if(i!=0):
            if(np.array_equal(currQTC[i,:5],currQTC[i-1,:5])):
                del1 = True
            if(np.array_equal(currQTC[i+1,:5],currQTC[i-1,:5])):
                del2 = True
        
        if(del1 and not del2):
            currQTC = np.delete(currQTC,i,0)
        elif(del2):
            currQTC = np.delete(currQTC,i,0)
            currQTC = np.delete(currQTC,i+1,0)
            
        i+=1
    return currQTC

# %%
#load kinect skeleton data for all folders in dataFolderList
numJoints = 9
data = dict()
firstPass = True
jointsList = []
objectsList = []
labelsList = []
numFolders = len(dataFolders)

for j in dataFolders:
    k = dataFolders.index(j)
    dataFile = open(join(dataFolders[k],'data.log'),'r')
    labelFile = open(join(labelFolders[k],'data.log'),'r')
    
    #number of lines in dataFile
    for i, l in enumerate(dataFile):
            pass
    lenDataFile = i+1
    
    #number of lines in labelFile
    for i, l in enumerate(labelFile):
            pass
    lenLabelFile = i+1
    dataFile.close()
    labelFile.close()
    
    
    if(lenLabelFile != lenDataFile):
        raise ValueError('Files not of same lenght')
    else:
        dataFile = open(join(dataFolders[k],'data.log'),'r')
        labelFile = open(join(labelFolders[k],'data.log'),'r')
        labelsList.append([])
        
        for curr in range(lenDataFile):
            line = dataFile.readline()
            labelLine = labelFile.readline()
            
            t = line.replace('(','').replace(')','').split(' ')
            del t[0:4]
           
            v = labelLine.split(' ')[2].replace('\n','').replace('(','').replace(')','')
            if(v == ''):
                v = 'unknown'
            labelsList[k].append(v)
            
            #parse skeleton data which has 9 sections by (x,y,z)
            for i in range(numJoints):
                a = i*4
                if(t[a] == 'shoulderCenter'):
                    t[a] = 'chest'
                
                if(firstPass):
                    data[t[a]] = [None]*numFolders
                    data[t[a]][k] = (np.array([float(t[a+1]), float(t[a+2]), float(t[a+3])]))
                    jointsList.append(t[a])
                else:
                    arr =  np.array([float(t[a+1]), float(t[a+2]), float(t[a+3])])
                    if(data[t[a]][k] != None):
                        data[t[a]][k] = np.vstack((data[t[a]][k],arr))
                    else:
                        data[t[a]][k] = arr

            currIdx = (numJoints*4 -1)
            numObjs = (len(t) - currIdx)/5

            for i in range(numObjs):
                a = currIdx + 1 + (i*5)
                if(t[a] in data):
                    arr = np.array([float(t[a+1]), float(t[a+2]), float(t[a+3])])
                    if(data[t[a]][k] != None):
                        data[t[a]][k] =  np.vstack((data[t[a]][k],arr))
                    else:
                        data[t[a]][k] = arr
                else:
                    data[t[a]] = [None]*(numFolders)
                    data[t[a]][k] = np.array([float(t[a+1]), float(t[a+2]), float(t[a+3])])
                    objectsList.append(t[a])

            firstPass = False
            
        dataFile.close()
        labelFile.close()
# Out:
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:59: FutureWarning:comparison to `None` will result in an elementwise object comparison in the future.
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:71: FutureWarning:comparison to `None` will result in an elementwise object comparison in the future.

# %%
print 'data has length = ' + str(len(data)) + ' joints'
strl =  'each joint has ' + str(len(data['head'])) + ' arrays of shape: '

for i in data['head']:
    strl += str(i.shape) + ', '
print strl

strl = 'labelsList has length = ' + str(len(labelsList)) + ' with sizes: '
for i in labelsList:
    strl += str(len(i)) + ', '
print strl
# Out:
# data has length = 12 joints
# each joint has 4 arrays of shape: (4637, 3), (4907, 3), (5914, 3), (5440, 3),
# labelsList has length = 4 with sizes: 4637, 4907, 5914, 5440,

# %%
#compile a list of all unique labels
setList = []
for x in labelsList:
    setList.append(list(set(x)))
flattenedList = [val for sublist in setList for val in sublist]
labels = list(set(flattenedList))
labels.sort()
for k in range(0,len(labels)):
    print str(k) + '  ' + labels[k]
# Out:
# 0  agent_entry
# 1  agent_exit
# 2  arms_lowered
# 3  arms_raised
# 4  carry_object_car_hand_left
# 5  carry_object_car_hand_left_no
# 6  carry_object_car_hand_right
# 7  carry_object_car_hand_right_no
# 8  drop_object_car_hand_left
# 9  drop_object_car_hand_left_no
# 10  drop_object_car_hand_right
# 11  drop_object_car_hand_right_no
# 12  dropping_arms
# 13  lift_object_car_hand_left
# 14  lift_object_car_hand_left_no
# 15  lift_object_car_hand_right_no
# 16  no_agent
# 17  pull_object_car_hand_left
# 18  pull_object_car_hand_left_no
# 19  pull_object_car_hand_right
# 20  pull_object_car_hand_right_no
# 21  pull_object_octopus_hand_left
# 22  pull_object_octopus_hand_left_no
# 23  pull_object_octopus_hand_right
# 24  push_object_car_hand_left
# 25  push_object_car_hand_left_no
# 26  push_object_car_hand_right
# 27  push_object_car_hand_right_no
# 28  push_object_octopus_hand_left
# 29  push_object_octopus_hand_left_no
# 30  push_object_octopus_hand_right
# 31  push_object_octopus_hand_right_no
# 32  raising_arms
# 33  reach_object_car_hand_left
# 34  reach_object_car_hand_left_no
# 35  reach_object_car_hand_right
# 36  reach_object_car_hand_right_no
# 37  reach_object_octopus_hand_left
# 38  reach_object_octopus_hand_left_no
# 39  reach_object_octopus_hand_right
# 40  reach_object_octopus_hand_right_no
# 41  retract_hand
# 42  touch_octopus_hand_left
# 43  unknown

# %%
print range(len(dataFolderList))
print len(dataFolderList)
print dataFolderList[3:4]
# Out:
# [0, 1, 2, 3]
# 4
# ['push-pull-right_arm']

# %%
dataStruct = []
verbose = True
for arr in range(len(dataFolderList)):
    for label in labels:
        if(verbose):
            print
            print 'current dataset = ' + str(dataFolderList[arr])
            print 'curent label: ' + str(label)
            print
        idxs = [i for i in range(len(labelsList[arr])) if labelsList[arr][i] == label]
        actionBlocks = []
        startIdx = 0
        if(len(idxs) > 5):
            for idxIndex in range(len(idxs)):
                if(idxIndex != 0):
                    if(idxs[idxIndex] - idxs[idxIndex-1] != 1):
                        if(idxIndex-startIdx > 5):
                            for joint in jointsList+objectsList[1:]:
                                actionData = data[joint][arr][idxs[startIdx:idxIndex]]
                                dataStruct.append([joint, label, arr, actionData.shape[0], actionData])
                                if(verbose):
                                    print '[%s]' % ', '.join(map(str, dataStruct[-1][:-1]))
                            startIdx = idxIndex

                    if(idxIndex+2 > len(idxs)):
                        if(idxs[idxIndex] - idxs[idxIndex-1] != 1):
                            for joint in jointsList+objectsList[1:]:
                                actionData = data[joint][arr][idxs[startIdx:idxIndex+1]]
                                dataStruct.append([joint, label, arr, actionData.shape[0], actionData])
                                if(verbose):
                                    print '[%s]' % ', '.join(map(str, dataStruct[-1][:-1]))
            print '------------------------------------------------------------------------'
# Out:
# current dataset = lift-drop-right_arm
# curent label: agent_entry
#
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: agent_exit
#
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: arms_lowered
#
# [elbowLeft, arms_lowered, 0, 31]
# [elbowRight, arms_lowered, 0, 31]
# [handLeft, arms_lowered, 0, 31]
# [handRight, arms_lowered, 0, 31]
# [head, arms_lowered, 0, 31]
# [chest, arms_lowered, 0, 31]
# [shoulderLeft, arms_lowered, 0, 31]
# [shoulderRight, arms_lowered, 0, 31]
# [spine, arms_lowered, 0, 31]
# [car, arms_lowered, 0, 31]
# [octopus, arms_lowered, 0, 31]
# [elbowLeft, arms_lowered, 0, 17]
# [elbowRight, arms_lowered, 0, 17]
# [handLeft, arms_lowered, 0, 17]
# [handRight, arms_lowered, 0, 17]
# [head, arms_lowered, 0, 17]
# [chest, arms_lowered, 0, 17]
# [shoulderLeft, arms_lowered, 0, 17]
# [shoulderRight, arms_lowered, 0, 17]
# [spine, arms_lowered, 0, 17]
# [car, arms_lowered, 0, 17]
# [octopus, arms_lowered, 0, 17]
# [elbowLeft, arms_lowered, 0, 29]
# [elbowRight, arms_lowered, 0, 29]
# [handLeft, arms_lowered, 0, 29]
# [handRight, arms_lowered, 0, 29]
# [head, arms_lowered, 0, 29]
# [chest, arms_lowered, 0, 29]
# [shoulderLeft, arms_lowered, 0, 29]
# [shoulderRight, arms_lowered, 0, 29]
# [spine, arms_lowered, 0, 29]
# [car, arms_lowered, 0, 29]
# [octopus, arms_lowered, 0, 29]
# [elbowLeft, arms_lowered, 0, 49]
# [elbowRight, arms_lowered, 0, 49]
# [handLeft, arms_lowered, 0, 49]
# [handRight, arms_lowered, 0, 49]
# [head, arms_lowered, 0, 49]
# [chest, arms_lowered, 0, 49]
# [shoulderLeft, arms_lowered, 0, 49]
# [shoulderRight, arms_lowered, 0, 49]
# [spine, arms_lowered, 0, 49]
# [car, arms_lowered, 0, 49]
# [octopus, arms_lowered, 0, 49]
# [elbowLeft, arms_lowered, 0, 24]
# [elbowRight, arms_lowered, 0, 24]
# [handLeft, arms_lowered, 0, 24]
# [handRight, arms_lowered, 0, 24]
# [head, arms_lowered, 0, 24]
# [chest, arms_lowered, 0, 24]
# [shoulderLeft, arms_lowered, 0, 24]
# [shoulderRight, arms_lowered, 0, 24]
# [spine, arms_lowered, 0, 24]
# [car, arms_lowered, 0, 24]
# [octopus, arms_lowered, 0, 24]
# [elbowLeft, arms_lowered, 0, 34]
# [elbowRight, arms_lowered, 0, 34]
# [handLeft, arms_lowered, 0, 34]
# [handRight, arms_lowered, 0, 34]
# [head, arms_lowered, 0, 34]
# [chest, arms_lowered, 0, 34]
# [shoulderLeft, arms_lowered, 0, 34]
# [shoulderRight, arms_lowered, 0, 34]
# [spine, arms_lowered, 0, 34]
# [car, arms_lowered, 0, 34]
# [octopus, arms_lowered, 0, 34]
# [elbowLeft, arms_lowered, 0, 56]
# [elbowRight, arms_lowered, 0, 56]
# [handLeft, arms_lowered, 0, 56]
# [handRight, arms_lowered, 0, 56]
# [head, arms_lowered, 0, 56]
# [chest, arms_lowered, 0, 56]
# [shoulderLeft, arms_lowered, 0, 56]
# [shoulderRight, arms_lowered, 0, 56]
# [spine, arms_lowered, 0, 56]
# [car, arms_lowered, 0, 56]
# [octopus, arms_lowered, 0, 56]
# [elbowLeft, arms_lowered, 0, 20]
# [elbowRight, arms_lowered, 0, 20]
# [handLeft, arms_lowered, 0, 20]
# [handRight, arms_lowered, 0, 20]
# [head, arms_lowered, 0, 20]
# [chest, arms_lowered, 0, 20]
# [shoulderLeft, arms_lowered, 0, 20]
# [shoulderRight, arms_lowered, 0, 20]
# [spine, arms_lowered, 0, 20]
# [car, arms_lowered, 0, 20]
# [octopus, arms_lowered, 0, 20]
# [elbowLeft, arms_lowered, 0, 76]
# [elbowRight, arms_lowered, 0, 76]
# [handLeft, arms_lowered, 0, 76]
# [handRight, arms_lowered, 0, 76]
# [head, arms_lowered, 0, 76]
# [chest, arms_lowered, 0, 76]
# [shoulderLeft, arms_lowered, 0, 76]
# [shoulderRight, arms_lowered, 0, 76]
# [spine, arms_lowered, 0, 76]
# [car, arms_lowered, 0, 76]
# [octopus, arms_lowered, 0, 76]
# [elbowLeft, arms_lowered, 0, 51]
# [elbowRight, arms_lowered, 0, 51]
# [handLeft, arms_lowered, 0, 51]
# [handRight, arms_lowered, 0, 51]
# [head, arms_lowered, 0, 51]
# [chest, arms_lowered, 0, 51]
# [shoulderLeft, arms_lowered, 0, 51]
# [shoulderRight, arms_lowered, 0, 51]
# [spine, arms_lowered, 0, 51]
# [car, arms_lowered, 0, 51]
# [octopus, arms_lowered, 0, 51]
# [elbowLeft, arms_lowered, 0, 55]
# [elbowRight, arms_lowered, 0, 55]
# [handLeft, arms_lowered, 0, 55]
# [handRight, arms_lowered, 0, 55]
# [head, arms_lowered, 0, 55]
# [chest, arms_lowered, 0, 55]
# [shoulderLeft, arms_lowered, 0, 55]
# [shoulderRight, arms_lowered, 0, 55]
# [spine, arms_lowered, 0, 55]
# [car, arms_lowered, 0, 55]
# [octopus, arms_lowered, 0, 55]
# [elbowLeft, arms_lowered, 0, 17]
# [elbowRight, arms_lowered, 0, 17]
# [handLeft, arms_lowered, 0, 17]
# [handRight, arms_lowered, 0, 17]
# [head, arms_lowered, 0, 17]
# [chest, arms_lowered, 0, 17]
# [shoulderLeft, arms_lowered, 0, 17]
# [shoulderRight, arms_lowered, 0, 17]
# [spine, arms_lowered, 0, 17]
# [car, arms_lowered, 0, 17]
# [octopus, arms_lowered, 0, 17]
# [elbowLeft, arms_lowered, 0, 32]
# [elbowRight, arms_lowered, 0, 32]
# [handLeft, arms_lowered, 0, 32]
# [handRight, arms_lowered, 0, 32]
# [head, arms_lowered, 0, 32]
# [chest, arms_lowered, 0, 32]
# [shoulderLeft, arms_lowered, 0, 32]
# [shoulderRight, arms_lowered, 0, 32]
# [spine, arms_lowered, 0, 32]
# [car, arms_lowered, 0, 32]
# [octopus, arms_lowered, 0, 32]
# [elbowLeft, arms_lowered, 0, 40]
# [elbowRight, arms_lowered, 0, 40]
# [handLeft, arms_lowered, 0, 40]
# [handRight, arms_lowered, 0, 40]
# [head, arms_lowered, 0, 40]
# [chest, arms_lowered, 0, 40]
# [shoulderLeft, arms_lowered, 0, 40]
# [shoulderRight, arms_lowered, 0, 40]
# [spine, arms_lowered, 0, 40]
# [car, arms_lowered, 0, 40]
# [octopus, arms_lowered, 0, 40]
# [elbowLeft, arms_lowered, 0, 65]
# [elbowRight, arms_lowered, 0, 65]
# [handLeft, arms_lowered, 0, 65]
# [handRight, arms_lowered, 0, 65]
# [head, arms_lowered, 0, 65]
# [chest, arms_lowered, 0, 65]
# [shoulderLeft, arms_lowered, 0, 65]
# [shoulderRight, arms_lowered, 0, 65]
# [spine, arms_lowered, 0, 65]
# [car, arms_lowered, 0, 65]
# [octopus, arms_lowered, 0, 65]
# [elbowLeft, arms_lowered, 0, 37]
# [elbowRight, arms_lowered, 0, 37]
# [handLeft, arms_lowered, 0, 37]
# [handRight, arms_lowered, 0, 37]
# [head, arms_lowered, 0, 37]
# [chest, arms_lowered, 0, 37]
# [shoulderLeft, arms_lowered, 0, 37]
# [shoulderRight, arms_lowered, 0, 37]
# [spine, arms_lowered, 0, 37]
# [car, arms_lowered, 0, 37]
# [octopus, arms_lowered, 0, 37]
# [elbowLeft, arms_lowered, 0, 148]
# [elbowRight, arms_lowered, 0, 148]
# [handLeft, arms_lowered, 0, 148]
# [handRight, arms_lowered, 0, 148]
# [head, arms_lowered, 0, 148]
# [chest, arms_lowered, 0, 148]
# [shoulderLeft, arms_lowered, 0, 148]
# [shoulderRight, arms_lowered, 0, 148]
# [spine, arms_lowered, 0, 148]
# [car, arms_lowered, 0, 148]
# [octopus, arms_lowered, 0, 148]
# [elbowLeft, arms_lowered, 0, 92]
# [elbowRight, arms_lowered, 0, 92]
# [handLeft, arms_lowered, 0, 92]
# [handRight, arms_lowered, 0, 92]
# [head, arms_lowered, 0, 92]
# [chest, arms_lowered, 0, 92]
# [shoulderLeft, arms_lowered, 0, 92]
# [shoulderRight, arms_lowered, 0, 92]
# [spine, arms_lowered, 0, 92]
# [car, arms_lowered, 0, 92]
# [octopus, arms_lowered, 0, 92]
# [elbowLeft, arms_lowered, 0, 33]
# [elbowRight, arms_lowered, 0, 33]
# [handLeft, arms_lowered, 0, 33]
# [handRight, arms_lowered, 0, 33]
# [head, arms_lowered, 0, 33]
# [chest, arms_lowered, 0, 33]
# [shoulderLeft, arms_lowered, 0, 33]
# [shoulderRight, arms_lowered, 0, 33]
# [spine, arms_lowered, 0, 33]
# [car, arms_lowered, 0, 33]
# [octopus, arms_lowered, 0, 33]
# [elbowLeft, arms_lowered, 0, 37]
# [elbowRight, arms_lowered, 0, 37]
# [handLeft, arms_lowered, 0, 37]
# [handRight, arms_lowered, 0, 37]
# [head, arms_lowered, 0, 37]
# [chest, arms_lowered, 0, 37]
# [shoulderLeft, arms_lowered, 0, 37]
# [shoulderRight, arms_lowered, 0, 37]
# [spine, arms_lowered, 0, 37]
# [car, arms_lowered, 0, 37]
# [octopus, arms_lowered, 0, 37]
# [elbowLeft, arms_lowered, 0, 46]
# [elbowRight, arms_lowered, 0, 46]
# [handLeft, arms_lowered, 0, 46]
# [handRight, arms_lowered, 0, 46]
# [head, arms_lowered, 0, 46]
# [chest, arms_lowered, 0, 46]
# [shoulderLeft, arms_lowered, 0, 46]
# [shoulderRight, arms_lowered, 0, 46]
# [spine, arms_lowered, 0, 46]
# [car, arms_lowered, 0, 46]
# [octopus, arms_lowered, 0, 46]
# [elbowLeft, arms_lowered, 0, 41]
# [elbowRight, arms_lowered, 0, 41]
# [handLeft, arms_lowered, 0, 41]
# [handRight, arms_lowered, 0, 41]
# [head, arms_lowered, 0, 41]
# [chest, arms_lowered, 0, 41]
# [shoulderLeft, arms_lowered, 0, 41]
# [shoulderRight, arms_lowered, 0, 41]
# [spine, arms_lowered, 0, 41]
# [car, arms_lowered, 0, 41]
# [octopus, arms_lowered, 0, 41]
# [elbowLeft, arms_lowered, 0, 56]
# [elbowRight, arms_lowered, 0, 56]
# [handLeft, arms_lowered, 0, 56]
# [handRight, arms_lowered, 0, 56]
# [head, arms_lowered, 0, 56]
# [chest, arms_lowered, 0, 56]
# [shoulderLeft, arms_lowered, 0, 56]
# [shoulderRight, arms_lowered, 0, 56]
# [spine, arms_lowered, 0, 56]
# [car, arms_lowered, 0, 56]
# [octopus, arms_lowered, 0, 56]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: arms_raised
#
# [elbowLeft, arms_raised, 0, 129]
# [elbowRight, arms_raised, 0, 129]
# [handLeft, arms_raised, 0, 129]
# [handRight, arms_raised, 0, 129]
# [head, arms_raised, 0, 129]
# [chest, arms_raised, 0, 129]
# [shoulderLeft, arms_raised, 0, 129]
# [shoulderRight, arms_raised, 0, 129]
# [spine, arms_raised, 0, 129]
# [car, arms_raised, 0, 129]
# [octopus, arms_raised, 0, 129]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: carry_object_car_hand_left
#
#
# current dataset = lift-drop-right_arm
# curent label: carry_object_car_hand_left_no
#
#
# current dataset = lift-drop-right_arm
# curent label: carry_object_car_hand_right
#
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: carry_object_car_hand_right_no
#
# [elbowLeft, carry_object_car_hand_right_no, 0, 30]
# [elbowRight, carry_object_car_hand_right_no, 0, 30]
# [handLeft, carry_object_car_hand_right_no, 0, 30]
# [handRight, carry_object_car_hand_right_no, 0, 30]
# [head, carry_object_car_hand_right_no, 0, 30]
# [chest, carry_object_car_hand_right_no, 0, 30]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 30]
# [shoulderRight, carry_object_car_hand_right_no, 0, 30]
# [spine, carry_object_car_hand_right_no, 0, 30]
# [car, carry_object_car_hand_right_no, 0, 30]
# [octopus, carry_object_car_hand_right_no, 0, 30]
# [elbowLeft, carry_object_car_hand_right_no, 0, 45]
# [elbowRight, carry_object_car_hand_right_no, 0, 45]
# [handLeft, carry_object_car_hand_right_no, 0, 45]
# [handRight, carry_object_car_hand_right_no, 0, 45]
# [head, carry_object_car_hand_right_no, 0, 45]
# [chest, carry_object_car_hand_right_no, 0, 45]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 45]
# [shoulderRight, carry_object_car_hand_right_no, 0, 45]
# [spine, carry_object_car_hand_right_no, 0, 45]
# [car, carry_object_car_hand_right_no, 0, 45]
# [octopus, carry_object_car_hand_right_no, 0, 45]
# [elbowLeft, carry_object_car_hand_right_no, 0, 40]
# [elbowRight, carry_object_car_hand_right_no, 0, 40]
# [handLeft, carry_object_car_hand_right_no, 0, 40]
# [handRight, carry_object_car_hand_right_no, 0, 40]
# [head, carry_object_car_hand_right_no, 0, 40]
# [chest, carry_object_car_hand_right_no, 0, 40]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 40]
# [shoulderRight, carry_object_car_hand_right_no, 0, 40]
# [spine, carry_object_car_hand_right_no, 0, 40]
# [car, carry_object_car_hand_right_no, 0, 40]
# [octopus, carry_object_car_hand_right_no, 0, 40]
# [elbowLeft, carry_object_car_hand_right_no, 0, 31]
# [elbowRight, carry_object_car_hand_right_no, 0, 31]
# [handLeft, carry_object_car_hand_right_no, 0, 31]
# [handRight, carry_object_car_hand_right_no, 0, 31]
# [head, carry_object_car_hand_right_no, 0, 31]
# [chest, carry_object_car_hand_right_no, 0, 31]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 31]
# [shoulderRight, carry_object_car_hand_right_no, 0, 31]
# [spine, carry_object_car_hand_right_no, 0, 31]
# [car, carry_object_car_hand_right_no, 0, 31]
# [octopus, carry_object_car_hand_right_no, 0, 31]
# [elbowLeft, carry_object_car_hand_right_no, 0, 27]
# [elbowRight, carry_object_car_hand_right_no, 0, 27]
# [handLeft, carry_object_car_hand_right_no, 0, 27]
# [handRight, carry_object_car_hand_right_no, 0, 27]
# [head, carry_object_car_hand_right_no, 0, 27]
# [chest, carry_object_car_hand_right_no, 0, 27]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 27]
# [shoulderRight, carry_object_car_hand_right_no, 0, 27]
# [spine, carry_object_car_hand_right_no, 0, 27]
# [car, carry_object_car_hand_right_no, 0, 27]
# [octopus, carry_object_car_hand_right_no, 0, 27]
# [elbowLeft, carry_object_car_hand_right_no, 0, 34]
# [elbowRight, carry_object_car_hand_right_no, 0, 34]
# [handLeft, carry_object_car_hand_right_no, 0, 34]
# [handRight, carry_object_car_hand_right_no, 0, 34]
# [head, carry_object_car_hand_right_no, 0, 34]
# [chest, carry_object_car_hand_right_no, 0, 34]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 34]
# [shoulderRight, carry_object_car_hand_right_no, 0, 34]
# [spine, carry_object_car_hand_right_no, 0, 34]
# [car, carry_object_car_hand_right_no, 0, 34]
# [octopus, carry_object_car_hand_right_no, 0, 34]
# [elbowLeft, carry_object_car_hand_right_no, 0, 38]
# [elbowRight, carry_object_car_hand_right_no, 0, 38]
# [handLeft, carry_object_car_hand_right_no, 0, 38]
# [handRight, carry_object_car_hand_right_no, 0, 38]
# [head, carry_object_car_hand_right_no, 0, 38]
# [chest, carry_object_car_hand_right_no, 0, 38]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 38]
# [shoulderRight, carry_object_car_hand_right_no, 0, 38]
# [spine, carry_object_car_hand_right_no, 0, 38]
# [car, carry_object_car_hand_right_no, 0, 38]
# [octopus, carry_object_car_hand_right_no, 0, 38]
# [elbowLeft, carry_object_car_hand_right_no, 0, 73]
# [elbowRight, carry_object_car_hand_right_no, 0, 73]
# [handLeft, carry_object_car_hand_right_no, 0, 73]
# [handRight, carry_object_car_hand_right_no, 0, 73]
# [head, carry_object_car_hand_right_no, 0, 73]
# [chest, carry_object_car_hand_right_no, 0, 73]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 73]
# [shoulderRight, carry_object_car_hand_right_no, 0, 73]
# [spine, carry_object_car_hand_right_no, 0, 73]
# [car, carry_object_car_hand_right_no, 0, 73]
# [octopus, carry_object_car_hand_right_no, 0, 73]
# [elbowLeft, carry_object_car_hand_right_no, 0, 39]
# [elbowRight, carry_object_car_hand_right_no, 0, 39]
# [handLeft, carry_object_car_hand_right_no, 0, 39]
# [handRight, carry_object_car_hand_right_no, 0, 39]
# [head, carry_object_car_hand_right_no, 0, 39]
# [chest, carry_object_car_hand_right_no, 0, 39]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 39]
# [shoulderRight, carry_object_car_hand_right_no, 0, 39]
# [spine, carry_object_car_hand_right_no, 0, 39]
# [car, carry_object_car_hand_right_no, 0, 39]
# [octopus, carry_object_car_hand_right_no, 0, 39]
# [elbowLeft, carry_object_car_hand_right_no, 0, 33]
# [elbowRight, carry_object_car_hand_right_no, 0, 33]
# [handLeft, carry_object_car_hand_right_no, 0, 33]
# [handRight, carry_object_car_hand_right_no, 0, 33]
# [head, carry_object_car_hand_right_no, 0, 33]
# [chest, carry_object_car_hand_right_no, 0, 33]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 33]
# [shoulderRight, carry_object_car_hand_right_no, 0, 33]
# [spine, carry_object_car_hand_right_no, 0, 33]
# [car, carry_object_car_hand_right_no, 0, 33]
# [octopus, carry_object_car_hand_right_no, 0, 33]
# [elbowLeft, carry_object_car_hand_right_no, 0, 30]
# [elbowRight, carry_object_car_hand_right_no, 0, 30]
# [handLeft, carry_object_car_hand_right_no, 0, 30]
# [handRight, carry_object_car_hand_right_no, 0, 30]
# [head, carry_object_car_hand_right_no, 0, 30]
# [chest, carry_object_car_hand_right_no, 0, 30]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 30]
# [shoulderRight, carry_object_car_hand_right_no, 0, 30]
# [spine, carry_object_car_hand_right_no, 0, 30]
# [car, carry_object_car_hand_right_no, 0, 30]
# [octopus, carry_object_car_hand_right_no, 0, 30]
# [elbowLeft, carry_object_car_hand_right_no, 0, 51]
# [elbowRight, carry_object_car_hand_right_no, 0, 51]
# [handLeft, carry_object_car_hand_right_no, 0, 51]
# [handRight, carry_object_car_hand_right_no, 0, 51]
# [head, carry_object_car_hand_right_no, 0, 51]
# [chest, carry_object_car_hand_right_no, 0, 51]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 51]
# [shoulderRight, carry_object_car_hand_right_no, 0, 51]
# [spine, carry_object_car_hand_right_no, 0, 51]
# [car, carry_object_car_hand_right_no, 0, 51]
# [octopus, carry_object_car_hand_right_no, 0, 51]
# [elbowLeft, carry_object_car_hand_right_no, 0, 25]
# [elbowRight, carry_object_car_hand_right_no, 0, 25]
# [handLeft, carry_object_car_hand_right_no, 0, 25]
# [handRight, carry_object_car_hand_right_no, 0, 25]
# [head, carry_object_car_hand_right_no, 0, 25]
# [chest, carry_object_car_hand_right_no, 0, 25]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 25]
# [shoulderRight, carry_object_car_hand_right_no, 0, 25]
# [spine, carry_object_car_hand_right_no, 0, 25]
# [car, carry_object_car_hand_right_no, 0, 25]
# [octopus, carry_object_car_hand_right_no, 0, 25]
# [elbowLeft, carry_object_car_hand_right_no, 0, 55]
# [elbowRight, carry_object_car_hand_right_no, 0, 55]
# [handLeft, carry_object_car_hand_right_no, 0, 55]
# [handRight, carry_object_car_hand_right_no, 0, 55]
# [head, carry_object_car_hand_right_no, 0, 55]
# [chest, carry_object_car_hand_right_no, 0, 55]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 55]
# [shoulderRight, carry_object_car_hand_right_no, 0, 55]
# [spine, carry_object_car_hand_right_no, 0, 55]
# [car, carry_object_car_hand_right_no, 0, 55]
# [octopus, carry_object_car_hand_right_no, 0, 55]
# [elbowLeft, carry_object_car_hand_right_no, 0, 35]
# [elbowRight, carry_object_car_hand_right_no, 0, 35]
# [handLeft, carry_object_car_hand_right_no, 0, 35]
# [handRight, carry_object_car_hand_right_no, 0, 35]
# [head, carry_object_car_hand_right_no, 0, 35]
# [chest, carry_object_car_hand_right_no, 0, 35]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 35]
# [shoulderRight, carry_object_car_hand_right_no, 0, 35]
# [spine, carry_object_car_hand_right_no, 0, 35]
# [car, carry_object_car_hand_right_no, 0, 35]
# [octopus, carry_object_car_hand_right_no, 0, 35]
# [elbowLeft, carry_object_car_hand_right_no, 0, 23]
# [elbowRight, carry_object_car_hand_right_no, 0, 23]
# [handLeft, carry_object_car_hand_right_no, 0, 23]
# [handRight, carry_object_car_hand_right_no, 0, 23]
# [head, carry_object_car_hand_right_no, 0, 23]
# [chest, carry_object_car_hand_right_no, 0, 23]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 23]
# [shoulderRight, carry_object_car_hand_right_no, 0, 23]
# [spine, carry_object_car_hand_right_no, 0, 23]
# [car, carry_object_car_hand_right_no, 0, 23]
# [octopus, carry_object_car_hand_right_no, 0, 23]
# [elbowLeft, carry_object_car_hand_right_no, 0, 27]
# [elbowRight, carry_object_car_hand_right_no, 0, 27]
# [handLeft, carry_object_car_hand_right_no, 0, 27]
# [handRight, carry_object_car_hand_right_no, 0, 27]
# [head, carry_object_car_hand_right_no, 0, 27]
# [chest, carry_object_car_hand_right_no, 0, 27]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 27]
# [shoulderRight, carry_object_car_hand_right_no, 0, 27]
# [spine, carry_object_car_hand_right_no, 0, 27]
# [car, carry_object_car_hand_right_no, 0, 27]
# [octopus, carry_object_car_hand_right_no, 0, 27]
# [elbowLeft, carry_object_car_hand_right_no, 0, 33]
# [elbowRight, carry_object_car_hand_right_no, 0, 33]
# [handLeft, carry_object_car_hand_right_no, 0, 33]
# [handRight, carry_object_car_hand_right_no, 0, 33]
# [head, carry_object_car_hand_right_no, 0, 33]
# [chest, carry_object_car_hand_right_no, 0, 33]
# [shoulderLeft, carry_object_car_hand_right_no, 0, 33]
# [shoulderRight, carry_object_car_hand_right_no, 0, 33]
# [spine, carry_object_car_hand_right_no, 0, 33]
# [car, carry_object_car_hand_right_no, 0, 33]
# [octopus, carry_object_car_hand_right_no, 0, 33]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: drop_object_car_hand_left
#
#
# current dataset = lift-drop-right_arm
# curent label: drop_object_car_hand_left_no
#
#
# current dataset = lift-drop-right_arm
# curent label: drop_object_car_hand_right
#
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: drop_object_car_hand_right_no
#
# [elbowLeft, drop_object_car_hand_right_no, 0, 13]
# [elbowRight, drop_object_car_hand_right_no, 0, 13]
# [handLeft, drop_object_car_hand_right_no, 0, 13]
# [handRight, drop_object_car_hand_right_no, 0, 13]
# [head, drop_object_car_hand_right_no, 0, 13]
# [chest, drop_object_car_hand_right_no, 0, 13]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 13]
# [shoulderRight, drop_object_car_hand_right_no, 0, 13]
# [spine, drop_object_car_hand_right_no, 0, 13]
# [car, drop_object_car_hand_right_no, 0, 13]
# [octopus, drop_object_car_hand_right_no, 0, 13]
# [elbowLeft, drop_object_car_hand_right_no, 0, 31]
# [elbowRight, drop_object_car_hand_right_no, 0, 31]
# [handLeft, drop_object_car_hand_right_no, 0, 31]
# [handRight, drop_object_car_hand_right_no, 0, 31]
# [head, drop_object_car_hand_right_no, 0, 31]
# [chest, drop_object_car_hand_right_no, 0, 31]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 31]
# [shoulderRight, drop_object_car_hand_right_no, 0, 31]
# [spine, drop_object_car_hand_right_no, 0, 31]
# [car, drop_object_car_hand_right_no, 0, 31]
# [octopus, drop_object_car_hand_right_no, 0, 31]
# [elbowLeft, drop_object_car_hand_right_no, 0, 19]
# [elbowRight, drop_object_car_hand_right_no, 0, 19]
# [handLeft, drop_object_car_hand_right_no, 0, 19]
# [handRight, drop_object_car_hand_right_no, 0, 19]
# [head, drop_object_car_hand_right_no, 0, 19]
# [chest, drop_object_car_hand_right_no, 0, 19]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 19]
# [shoulderRight, drop_object_car_hand_right_no, 0, 19]
# [spine, drop_object_car_hand_right_no, 0, 19]
# [car, drop_object_car_hand_right_no, 0, 19]
# [octopus, drop_object_car_hand_right_no, 0, 19]
# [elbowLeft, drop_object_car_hand_right_no, 0, 29]
# [elbowRight, drop_object_car_hand_right_no, 0, 29]
# [handLeft, drop_object_car_hand_right_no, 0, 29]
# [handRight, drop_object_car_hand_right_no, 0, 29]
# [head, drop_object_car_hand_right_no, 0, 29]
# [chest, drop_object_car_hand_right_no, 0, 29]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 29]
# [shoulderRight, drop_object_car_hand_right_no, 0, 29]
# [spine, drop_object_car_hand_right_no, 0, 29]
# [car, drop_object_car_hand_right_no, 0, 29]
# [octopus, drop_object_car_hand_right_no, 0, 29]
# [elbowLeft, drop_object_car_hand_right_no, 0, 19]
# [elbowRight, drop_object_car_hand_right_no, 0, 19]
# [handLeft, drop_object_car_hand_right_no, 0, 19]
# [handRight, drop_object_car_hand_right_no, 0, 19]
# [head, drop_object_car_hand_right_no, 0, 19]
# [chest, drop_object_car_hand_right_no, 0, 19]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 19]
# [shoulderRight, drop_object_car_hand_right_no, 0, 19]
# [spine, drop_object_car_hand_right_no, 0, 19]
# [car, drop_object_car_hand_right_no, 0, 19]
# [octopus, drop_object_car_hand_right_no, 0, 19]
# [elbowLeft, drop_object_car_hand_right_no, 0, 29]
# [elbowRight, drop_object_car_hand_right_no, 0, 29]
# [handLeft, drop_object_car_hand_right_no, 0, 29]
# [handRight, drop_object_car_hand_right_no, 0, 29]
# [head, drop_object_car_hand_right_no, 0, 29]
# [chest, drop_object_car_hand_right_no, 0, 29]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 29]
# [shoulderRight, drop_object_car_hand_right_no, 0, 29]
# [spine, drop_object_car_hand_right_no, 0, 29]
# [car, drop_object_car_hand_right_no, 0, 29]
# [octopus, drop_object_car_hand_right_no, 0, 29]
# [elbowLeft, drop_object_car_hand_right_no, 0, 21]
# [elbowRight, drop_object_car_hand_right_no, 0, 21]
# [handLeft, drop_object_car_hand_right_no, 0, 21]
# [handRight, drop_object_car_hand_right_no, 0, 21]
# [head, drop_object_car_hand_right_no, 0, 21]
# [chest, drop_object_car_hand_right_no, 0, 21]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 21]
# [shoulderRight, drop_object_car_hand_right_no, 0, 21]
# [spine, drop_object_car_hand_right_no, 0, 21]
# [car, drop_object_car_hand_right_no, 0, 21]
# [octopus, drop_object_car_hand_right_no, 0, 21]
# [elbowLeft, drop_object_car_hand_right_no, 0, 20]
# [elbowRight, drop_object_car_hand_right_no, 0, 20]
# [handLeft, drop_object_car_hand_right_no, 0, 20]
# [handRight, drop_object_car_hand_right_no, 0, 20]
# [head, drop_object_car_hand_right_no, 0, 20]
# [chest, drop_object_car_hand_right_no, 0, 20]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 20]
# [shoulderRight, drop_object_car_hand_right_no, 0, 20]
# [spine, drop_object_car_hand_right_no, 0, 20]
# [car, drop_object_car_hand_right_no, 0, 20]
# [octopus, drop_object_car_hand_right_no, 0, 20]
# [elbowLeft, drop_object_car_hand_right_no, 0, 29]
# [elbowRight, drop_object_car_hand_right_no, 0, 29]
# [handLeft, drop_object_car_hand_right_no, 0, 29]
# [handRight, drop_object_car_hand_right_no, 0, 29]
# [head, drop_object_car_hand_right_no, 0, 29]
# [chest, drop_object_car_hand_right_no, 0, 29]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 29]
# [shoulderRight, drop_object_car_hand_right_no, 0, 29]
# [spine, drop_object_car_hand_right_no, 0, 29]
# [car, drop_object_car_hand_right_no, 0, 29]
# [octopus, drop_object_car_hand_right_no, 0, 29]
# [elbowLeft, drop_object_car_hand_right_no, 0, 29]
# [elbowRight, drop_object_car_hand_right_no, 0, 29]
# [handLeft, drop_object_car_hand_right_no, 0, 29]
# [handRight, drop_object_car_hand_right_no, 0, 29]
# [head, drop_object_car_hand_right_no, 0, 29]
# [chest, drop_object_car_hand_right_no, 0, 29]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 29]
# [shoulderRight, drop_object_car_hand_right_no, 0, 29]
# [spine, drop_object_car_hand_right_no, 0, 29]
# [car, drop_object_car_hand_right_no, 0, 29]
# [octopus, drop_object_car_hand_right_no, 0, 29]
# [elbowLeft, drop_object_car_hand_right_no, 0, 18]
# [elbowRight, drop_object_car_hand_right_no, 0, 18]
# [handLeft, drop_object_car_hand_right_no, 0, 18]
# [handRight, drop_object_car_hand_right_no, 0, 18]
# [head, drop_object_car_hand_right_no, 0, 18]
# [chest, drop_object_car_hand_right_no, 0, 18]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 18]
# [shoulderRight, drop_object_car_hand_right_no, 0, 18]
# [spine, drop_object_car_hand_right_no, 0, 18]
# [car, drop_object_car_hand_right_no, 0, 18]
# [octopus, drop_object_car_hand_right_no, 0, 18]
# [elbowLeft, drop_object_car_hand_right_no, 0, 28]
# [elbowRight, drop_object_car_hand_right_no, 0, 28]
# [handLeft, drop_object_car_hand_right_no, 0, 28]
# [handRight, drop_object_car_hand_right_no, 0, 28]
# [head, drop_object_car_hand_right_no, 0, 28]
# [chest, drop_object_car_hand_right_no, 0, 28]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 28]
# [shoulderRight, drop_object_car_hand_right_no, 0, 28]
# [spine, drop_object_car_hand_right_no, 0, 28]
# [car, drop_object_car_hand_right_no, 0, 28]
# [octopus, drop_object_car_hand_right_no, 0, 28]
# [elbowLeft, drop_object_car_hand_right_no, 0, 33]
# [elbowRight, drop_object_car_hand_right_no, 0, 33]
# [handLeft, drop_object_car_hand_right_no, 0, 33]
# [handRight, drop_object_car_hand_right_no, 0, 33]
# [head, drop_object_car_hand_right_no, 0, 33]
# [chest, drop_object_car_hand_right_no, 0, 33]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 33]
# [shoulderRight, drop_object_car_hand_right_no, 0, 33]
# [spine, drop_object_car_hand_right_no, 0, 33]
# [car, drop_object_car_hand_right_no, 0, 33]
# [octopus, drop_object_car_hand_right_no, 0, 33]
# [elbowLeft, drop_object_car_hand_right_no, 0, 16]
# [elbowRight, drop_object_car_hand_right_no, 0, 16]
# [handLeft, drop_object_car_hand_right_no, 0, 16]
# [handRight, drop_object_car_hand_right_no, 0, 16]
# [head, drop_object_car_hand_right_no, 0, 16]
# [chest, drop_object_car_hand_right_no, 0, 16]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 16]
# [shoulderRight, drop_object_car_hand_right_no, 0, 16]
# [spine, drop_object_car_hand_right_no, 0, 16]
# [car, drop_object_car_hand_right_no, 0, 16]
# [octopus, drop_object_car_hand_right_no, 0, 16]
# [elbowLeft, drop_object_car_hand_right_no, 0, 14]
# [elbowRight, drop_object_car_hand_right_no, 0, 14]
# [handLeft, drop_object_car_hand_right_no, 0, 14]
# [handRight, drop_object_car_hand_right_no, 0, 14]
# [head, drop_object_car_hand_right_no, 0, 14]
# [chest, drop_object_car_hand_right_no, 0, 14]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 14]
# [shoulderRight, drop_object_car_hand_right_no, 0, 14]
# [spine, drop_object_car_hand_right_no, 0, 14]
# [car, drop_object_car_hand_right_no, 0, 14]
# [octopus, drop_object_car_hand_right_no, 0, 14]
# [elbowLeft, drop_object_car_hand_right_no, 0, 17]
# [elbowRight, drop_object_car_hand_right_no, 0, 17]
# [handLeft, drop_object_car_hand_right_no, 0, 17]
# [handRight, drop_object_car_hand_right_no, 0, 17]
# [head, drop_object_car_hand_right_no, 0, 17]
# [chest, drop_object_car_hand_right_no, 0, 17]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 17]
# [shoulderRight, drop_object_car_hand_right_no, 0, 17]
# [spine, drop_object_car_hand_right_no, 0, 17]
# [car, drop_object_car_hand_right_no, 0, 17]
# [octopus, drop_object_car_hand_right_no, 0, 17]
# [elbowLeft, drop_object_car_hand_right_no, 0, 22]
# [elbowRight, drop_object_car_hand_right_no, 0, 22]
# [handLeft, drop_object_car_hand_right_no, 0, 22]
# [handRight, drop_object_car_hand_right_no, 0, 22]
# [head, drop_object_car_hand_right_no, 0, 22]
# [chest, drop_object_car_hand_right_no, 0, 22]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 22]
# [shoulderRight, drop_object_car_hand_right_no, 0, 22]
# [spine, drop_object_car_hand_right_no, 0, 22]
# [car, drop_object_car_hand_right_no, 0, 22]
# [octopus, drop_object_car_hand_right_no, 0, 22]
# [elbowLeft, drop_object_car_hand_right_no, 0, 19]
# [elbowRight, drop_object_car_hand_right_no, 0, 19]
# [handLeft, drop_object_car_hand_right_no, 0, 19]
# [handRight, drop_object_car_hand_right_no, 0, 19]
# [head, drop_object_car_hand_right_no, 0, 19]
# [chest, drop_object_car_hand_right_no, 0, 19]
# [shoulderLeft, drop_object_car_hand_right_no, 0, 19]
# [shoulderRight, drop_object_car_hand_right_no, 0, 19]
# [spine, drop_object_car_hand_right_no, 0, 19]
# [car, drop_object_car_hand_right_no, 0, 19]
# [octopus, drop_object_car_hand_right_no, 0, 19]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: dropping_arms
#
# [elbowLeft, dropping_arms, 0, 28]
# [elbowRight, dropping_arms, 0, 28]
# [handLeft, dropping_arms, 0, 28]
# [handRight, dropping_arms, 0, 28]
# [head, dropping_arms, 0, 28]
# [chest, dropping_arms, 0, 28]
# [shoulderLeft, dropping_arms, 0, 28]
# [shoulderRight, dropping_arms, 0, 28]
# [spine, dropping_arms, 0, 28]
# [car, dropping_arms, 0, 28]
# [octopus, dropping_arms, 0, 28]
# [elbowLeft, dropping_arms, 0, 15]
# [elbowRight, dropping_arms, 0, 15]
# [handLeft, dropping_arms, 0, 15]
# [handRight, dropping_arms, 0, 15]
# [head, dropping_arms, 0, 15]
# [chest, dropping_arms, 0, 15]
# [shoulderLeft, dropping_arms, 0, 15]
# [shoulderRight, dropping_arms, 0, 15]
# [spine, dropping_arms, 0, 15]
# [car, dropping_arms, 0, 15]
# [octopus, dropping_arms, 0, 15]
# [elbowLeft, dropping_arms, 0, 16]
# [elbowRight, dropping_arms, 0, 16]
# [handLeft, dropping_arms, 0, 16]
# [handRight, dropping_arms, 0, 16]
# [head, dropping_arms, 0, 16]
# [chest, dropping_arms, 0, 16]
# [shoulderLeft, dropping_arms, 0, 16]
# [shoulderRight, dropping_arms, 0, 16]
# [spine, dropping_arms, 0, 16]
# [car, dropping_arms, 0, 16]
# [octopus, dropping_arms, 0, 16]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: lift_object_car_hand_left
#
#
# current dataset = lift-drop-right_arm
# curent label: lift_object_car_hand_left_no
#
#
# current dataset = lift-drop-right_arm
# curent label: lift_object_car_hand_right_no
#
# [elbowLeft, lift_object_car_hand_right_no, 0, 16]
# [elbowRight, lift_object_car_hand_right_no, 0, 16]
# [handLeft, lift_object_car_hand_right_no, 0, 16]
# [handRight, lift_object_car_hand_right_no, 0, 16]
# [head, lift_object_car_hand_right_no, 0, 16]
# [chest, lift_object_car_hand_right_no, 0, 16]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 16]
# [shoulderRight, lift_object_car_hand_right_no, 0, 16]
# [spine, lift_object_car_hand_right_no, 0, 16]
# [car, lift_object_car_hand_right_no, 0, 16]
# [octopus, lift_object_car_hand_right_no, 0, 16]
# [elbowLeft, lift_object_car_hand_right_no, 0, 29]
# [elbowRight, lift_object_car_hand_right_no, 0, 29]
# [handLeft, lift_object_car_hand_right_no, 0, 29]
# [handRight, lift_object_car_hand_right_no, 0, 29]
# [head, lift_object_car_hand_right_no, 0, 29]
# [chest, lift_object_car_hand_right_no, 0, 29]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 29]
# [shoulderRight, lift_object_car_hand_right_no, 0, 29]
# [spine, lift_object_car_hand_right_no, 0, 29]
# [car, lift_object_car_hand_right_no, 0, 29]
# [octopus, lift_object_car_hand_right_no, 0, 29]
# [elbowLeft, lift_object_car_hand_right_no, 0, 24]
# [elbowRight, lift_object_car_hand_right_no, 0, 24]
# [handLeft, lift_object_car_hand_right_no, 0, 24]
# [handRight, lift_object_car_hand_right_no, 0, 24]
# [head, lift_object_car_hand_right_no, 0, 24]
# [chest, lift_object_car_hand_right_no, 0, 24]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 24]
# [shoulderRight, lift_object_car_hand_right_no, 0, 24]
# [spine, lift_object_car_hand_right_no, 0, 24]
# [car, lift_object_car_hand_right_no, 0, 24]
# [octopus, lift_object_car_hand_right_no, 0, 24]
# [elbowLeft, lift_object_car_hand_right_no, 0, 25]
# [elbowRight, lift_object_car_hand_right_no, 0, 25]
# [handLeft, lift_object_car_hand_right_no, 0, 25]
# [handRight, lift_object_car_hand_right_no, 0, 25]
# [head, lift_object_car_hand_right_no, 0, 25]
# [chest, lift_object_car_hand_right_no, 0, 25]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 25]
# [shoulderRight, lift_object_car_hand_right_no, 0, 25]
# [spine, lift_object_car_hand_right_no, 0, 25]
# [car, lift_object_car_hand_right_no, 0, 25]
# [octopus, lift_object_car_hand_right_no, 0, 25]
# [elbowLeft, lift_object_car_hand_right_no, 0, 28]
# [elbowRight, lift_object_car_hand_right_no, 0, 28]
# [handLeft, lift_object_car_hand_right_no, 0, 28]
# [handRight, lift_object_car_hand_right_no, 0, 28]
# [head, lift_object_car_hand_right_no, 0, 28]
# [chest, lift_object_car_hand_right_no, 0, 28]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 28]
# [shoulderRight, lift_object_car_hand_right_no, 0, 28]
# [spine, lift_object_car_hand_right_no, 0, 28]
# [car, lift_object_car_hand_right_no, 0, 28]
# [octopus, lift_object_car_hand_right_no, 0, 28]
# [elbowLeft, lift_object_car_hand_right_no, 0, 31]
# [elbowRight, lift_object_car_hand_right_no, 0, 31]
# [handLeft, lift_object_car_hand_right_no, 0, 31]
# [handRight, lift_object_car_hand_right_no, 0, 31]
# [head, lift_object_car_hand_right_no, 0, 31]
# [chest, lift_object_car_hand_right_no, 0, 31]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 31]
# [shoulderRight, lift_object_car_hand_right_no, 0, 31]
# [spine, lift_object_car_hand_right_no, 0, 31]
# [car, lift_object_car_hand_right_no, 0, 31]
# [octopus, lift_object_car_hand_right_no, 0, 31]
# [elbowLeft, lift_object_car_hand_right_no, 0, 24]
# [elbowRight, lift_object_car_hand_right_no, 0, 24]
# [handLeft, lift_object_car_hand_right_no, 0, 24]
# [handRight, lift_object_car_hand_right_no, 0, 24]
# [head, lift_object_car_hand_right_no, 0, 24]
# [chest, lift_object_car_hand_right_no, 0, 24]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 24]
# [shoulderRight, lift_object_car_hand_right_no, 0, 24]
# [spine, lift_object_car_hand_right_no, 0, 24]
# [car, lift_object_car_hand_right_no, 0, 24]
# [octopus, lift_object_car_hand_right_no, 0, 24]
# [elbowLeft, lift_object_car_hand_right_no, 0, 25]
# [elbowRight, lift_object_car_hand_right_no, 0, 25]
# [handLeft, lift_object_car_hand_right_no, 0, 25]
# [handRight, lift_object_car_hand_right_no, 0, 25]
# [head, lift_object_car_hand_right_no, 0, 25]
# [chest, lift_object_car_hand_right_no, 0, 25]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 25]
# [shoulderRight, lift_object_car_hand_right_no, 0, 25]
# [spine, lift_object_car_hand_right_no, 0, 25]
# [car, lift_object_car_hand_right_no, 0, 25]
# [octopus, lift_object_car_hand_right_no, 0, 25]
# [elbowLeft, lift_object_car_hand_right_no, 0, 23]
# [elbowRight, lift_object_car_hand_right_no, 0, 23]
# [handLeft, lift_object_car_hand_right_no, 0, 23]
# [handRight, lift_object_car_hand_right_no, 0, 23]
# [head, lift_object_car_hand_right_no, 0, 23]
# [chest, lift_object_car_hand_right_no, 0, 23]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 23]
# [shoulderRight, lift_object_car_hand_right_no, 0, 23]
# [spine, lift_object_car_hand_right_no, 0, 23]
# [car, lift_object_car_hand_right_no, 0, 23]
# [octopus, lift_object_car_hand_right_no, 0, 23]
# [elbowLeft, lift_object_car_hand_right_no, 0, 30]
# [elbowRight, lift_object_car_hand_right_no, 0, 30]
# [handLeft, lift_object_car_hand_right_no, 0, 30]
# [handRight, lift_object_car_hand_right_no, 0, 30]
# [head, lift_object_car_hand_right_no, 0, 30]
# [chest, lift_object_car_hand_right_no, 0, 30]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 30]
# [shoulderRight, lift_object_car_hand_right_no, 0, 30]
# [spine, lift_object_car_hand_right_no, 0, 30]
# [car, lift_object_car_hand_right_no, 0, 30]
# [octopus, lift_object_car_hand_right_no, 0, 30]
# [elbowLeft, lift_object_car_hand_right_no, 0, 35]
# [elbowRight, lift_object_car_hand_right_no, 0, 35]
# [handLeft, lift_object_car_hand_right_no, 0, 35]
# [handRight, lift_object_car_hand_right_no, 0, 35]
# [head, lift_object_car_hand_right_no, 0, 35]
# [chest, lift_object_car_hand_right_no, 0, 35]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 35]
# [shoulderRight, lift_object_car_hand_right_no, 0, 35]
# [spine, lift_object_car_hand_right_no, 0, 35]
# [car, lift_object_car_hand_right_no, 0, 35]
# [octopus, lift_object_car_hand_right_no, 0, 35]
# [elbowLeft, lift_object_car_hand_right_no, 0, 20]
# [elbowRight, lift_object_car_hand_right_no, 0, 20]
# [handLeft, lift_object_car_hand_right_no, 0, 20]
# [handRight, lift_object_car_hand_right_no, 0, 20]
# [head, lift_object_car_hand_right_no, 0, 20]
# [chest, lift_object_car_hand_right_no, 0, 20]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 20]
# [shoulderRight, lift_object_car_hand_right_no, 0, 20]
# [spine, lift_object_car_hand_right_no, 0, 20]
# [car, lift_object_car_hand_right_no, 0, 20]
# [octopus, lift_object_car_hand_right_no, 0, 20]
# [elbowLeft, lift_object_car_hand_right_no, 0, 32]
# [elbowRight, lift_object_car_hand_right_no, 0, 32]
# [handLeft, lift_object_car_hand_right_no, 0, 32]
# [handRight, lift_object_car_hand_right_no, 0, 32]
# [head, lift_object_car_hand_right_no, 0, 32]
# [chest, lift_object_car_hand_right_no, 0, 32]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 32]
# [shoulderRight, lift_object_car_hand_right_no, 0, 32]
# [spine, lift_object_car_hand_right_no, 0, 32]
# [car, lift_object_car_hand_right_no, 0, 32]
# [octopus, lift_object_car_hand_right_no, 0, 32]
# [elbowLeft, lift_object_car_hand_right_no, 0, 24]
# [elbowRight, lift_object_car_hand_right_no, 0, 24]
# [handLeft, lift_object_car_hand_right_no, 0, 24]
# [handRight, lift_object_car_hand_right_no, 0, 24]
# [head, lift_object_car_hand_right_no, 0, 24]
# [chest, lift_object_car_hand_right_no, 0, 24]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 24]
# [shoulderRight, lift_object_car_hand_right_no, 0, 24]
# [spine, lift_object_car_hand_right_no, 0, 24]
# [car, lift_object_car_hand_right_no, 0, 24]
# [octopus, lift_object_car_hand_right_no, 0, 24]
# [elbowLeft, lift_object_car_hand_right_no, 0, 24]
# [elbowRight, lift_object_car_hand_right_no, 0, 24]
# [handLeft, lift_object_car_hand_right_no, 0, 24]
# [handRight, lift_object_car_hand_right_no, 0, 24]
# [head, lift_object_car_hand_right_no, 0, 24]
# [chest, lift_object_car_hand_right_no, 0, 24]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 24]
# [shoulderRight, lift_object_car_hand_right_no, 0, 24]
# [spine, lift_object_car_hand_right_no, 0, 24]
# [car, lift_object_car_hand_right_no, 0, 24]
# [octopus, lift_object_car_hand_right_no, 0, 24]
# [elbowLeft, lift_object_car_hand_right_no, 0, 23]
# [elbowRight, lift_object_car_hand_right_no, 0, 23]
# [handLeft, lift_object_car_hand_right_no, 0, 23]
# [handRight, lift_object_car_hand_right_no, 0, 23]
# [head, lift_object_car_hand_right_no, 0, 23]
# [chest, lift_object_car_hand_right_no, 0, 23]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 23]
# [shoulderRight, lift_object_car_hand_right_no, 0, 23]
# [spine, lift_object_car_hand_right_no, 0, 23]
# [car, lift_object_car_hand_right_no, 0, 23]
# [octopus, lift_object_car_hand_right_no, 0, 23]
# [elbowLeft, lift_object_car_hand_right_no, 0, 23]
# [elbowRight, lift_object_car_hand_right_no, 0, 23]
# [handLeft, lift_object_car_hand_right_no, 0, 23]
# [handRight, lift_object_car_hand_right_no, 0, 23]
# [head, lift_object_car_hand_right_no, 0, 23]
# [chest, lift_object_car_hand_right_no, 0, 23]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 23]
# [shoulderRight, lift_object_car_hand_right_no, 0, 23]
# [spine, lift_object_car_hand_right_no, 0, 23]
# [car, lift_object_car_hand_right_no, 0, 23]
# [octopus, lift_object_car_hand_right_no, 0, 23]
# [elbowLeft, lift_object_car_hand_right_no, 0, 28]
# [elbowRight, lift_object_car_hand_right_no, 0, 28]
# [handLeft, lift_object_car_hand_right_no, 0, 28]
# [handRight, lift_object_car_hand_right_no, 0, 28]
# [head, lift_object_car_hand_right_no, 0, 28]
# [chest, lift_object_car_hand_right_no, 0, 28]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 28]
# [shoulderRight, lift_object_car_hand_right_no, 0, 28]
# [spine, lift_object_car_hand_right_no, 0, 28]
# [car, lift_object_car_hand_right_no, 0, 28]
# [octopus, lift_object_car_hand_right_no, 0, 28]
# [elbowLeft, lift_object_car_hand_right_no, 0, 30]
# [elbowRight, lift_object_car_hand_right_no, 0, 30]
# [handLeft, lift_object_car_hand_right_no, 0, 30]
# [handRight, lift_object_car_hand_right_no, 0, 30]
# [head, lift_object_car_hand_right_no, 0, 30]
# [chest, lift_object_car_hand_right_no, 0, 30]
# [shoulderLeft, lift_object_car_hand_right_no, 0, 30]
# [shoulderRight, lift_object_car_hand_right_no, 0, 30]
# [spine, lift_object_car_hand_right_no, 0, 30]
# [car, lift_object_car_hand_right_no, 0, 30]
# [octopus, lift_object_car_hand_right_no, 0, 30]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: no_agent
#
# [elbowLeft, no_agent, 0, 69]
# [elbowRight, no_agent, 0, 69]
# [handLeft, no_agent, 0, 69]
# [handRight, no_agent, 0, 69]
# [head, no_agent, 0, 69]
# [chest, no_agent, 0, 69]
# [shoulderLeft, no_agent, 0, 69]
# [shoulderRight, no_agent, 0, 69]
# [spine, no_agent, 0, 69]
# [car, no_agent, 0, 69]
# [octopus, no_agent, 0, 69]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: pull_object_car_hand_left
#
#
# current dataset = lift-drop-right_arm
# curent label: pull_object_car_hand_left_no
#
#
# current dataset = lift-drop-right_arm
# curent label: pull_object_car_hand_right
#
#
# current dataset = lift-drop-right_arm
# curent label: pull_object_car_hand_right_no
#
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: pull_object_octopus_hand_left
#
#
# current dataset = lift-drop-right_arm
# curent label: pull_object_octopus_hand_left_no
#
#
# current dataset = lift-drop-right_arm
# curent label: pull_object_octopus_hand_right
#
#
# current dataset = lift-drop-right_arm
# curent label: push_object_car_hand_left
#
#
# current dataset = lift-drop-right_arm
# curent label: push_object_car_hand_left_no
#
#
# current dataset = lift-drop-right_arm
# curent label: push_object_car_hand_right
#
#
# current dataset = lift-drop-right_arm
# curent label: push_object_car_hand_right_no
#
# [elbowLeft, push_object_car_hand_right_no, 0, 12]
# [elbowRight, push_object_car_hand_right_no, 0, 12]
# [handLeft, push_object_car_hand_right_no, 0, 12]
# [handRight, push_object_car_hand_right_no, 0, 12]
# [head, push_object_car_hand_right_no, 0, 12]
# [chest, push_object_car_hand_right_no, 0, 12]
# [shoulderLeft, push_object_car_hand_right_no, 0, 12]
# [shoulderRight, push_object_car_hand_right_no, 0, 12]
# [spine, push_object_car_hand_right_no, 0, 12]
# [car, push_object_car_hand_right_no, 0, 12]
# [octopus, push_object_car_hand_right_no, 0, 12]
# [elbowLeft, push_object_car_hand_right_no, 0, 22]
# [elbowRight, push_object_car_hand_right_no, 0, 22]
# [handLeft, push_object_car_hand_right_no, 0, 22]
# [handRight, push_object_car_hand_right_no, 0, 22]
# [head, push_object_car_hand_right_no, 0, 22]
# [chest, push_object_car_hand_right_no, 0, 22]
# [shoulderLeft, push_object_car_hand_right_no, 0, 22]
# [shoulderRight, push_object_car_hand_right_no, 0, 22]
# [spine, push_object_car_hand_right_no, 0, 22]
# [car, push_object_car_hand_right_no, 0, 22]
# [octopus, push_object_car_hand_right_no, 0, 22]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: push_object_octopus_hand_left
#
#
# current dataset = lift-drop-right_arm
# curent label: push_object_octopus_hand_left_no
#
#
# current dataset = lift-drop-right_arm
# curent label: push_object_octopus_hand_right
#
#
# current dataset = lift-drop-right_arm
# curent label: push_object_octopus_hand_right_no
#
#
# current dataset = lift-drop-right_arm
# curent label: raising_arms
#
# [elbowLeft, raising_arms, 0, 31]
# [elbowRight, raising_arms, 0, 31]
# [handLeft, raising_arms, 0, 31]
# [handRight, raising_arms, 0, 31]
# [head, raising_arms, 0, 31]
# [chest, raising_arms, 0, 31]
# [shoulderLeft, raising_arms, 0, 31]
# [shoulderRight, raising_arms, 0, 31]
# [spine, raising_arms, 0, 31]
# [car, raising_arms, 0, 31]
# [octopus, raising_arms, 0, 31]
# [elbowLeft, raising_arms, 0, 10]
# [elbowRight, raising_arms, 0, 10]
# [handLeft, raising_arms, 0, 10]
# [handRight, raising_arms, 0, 10]
# [head, raising_arms, 0, 10]
# [chest, raising_arms, 0, 10]
# [shoulderLeft, raising_arms, 0, 10]
# [shoulderRight, raising_arms, 0, 10]
# [spine, raising_arms, 0, 10]
# [car, raising_arms, 0, 10]
# [octopus, raising_arms, 0, 10]
# [elbowLeft, raising_arms, 0, 19]
# [elbowRight, raising_arms, 0, 19]
# [handLeft, raising_arms, 0, 19]
# [handRight, raising_arms, 0, 19]
# [head, raising_arms, 0, 19]
# [chest, raising_arms, 0, 19]
# [shoulderLeft, raising_arms, 0, 19]
# [shoulderRight, raising_arms, 0, 19]
# [spine, raising_arms, 0, 19]
# [car, raising_arms, 0, 19]
# [octopus, raising_arms, 0, 19]
# ------------------------------------------------------------------------
#
# current dataset = lift-drop-right_arm
# curent label: reach_object_car_hand_left
#
#
# current dataset = lift-drop-right_arm
# curent label: reach_object_car_hand_left_no
#
#
# current dataset = lift-drop-right_arm
# curent label: reach_object_car_hand_right
#
#
# current dataset = lift-drop-right_arm
# curent label: reach_object_car_hand_right_no
#
# [elbowLeft, reach_object_car_hand_right_no, 0, 18]
# [elbowRight, reach_object_car_hand_right_no, 0, 18]
# [handLeft, reach_object_car_hand_right_no, 0, 18]
# [handRight, reach_object_car_hand_right_no, 0, 18]
# [head, reach_object_car_hand_right_no, 0, 18]
# [chest, reach_object_car_hand_right_no, 0, 18]
# [shoulderLeft, reach_object_car_hand_right_no, 0, 18]
# [shoulderRight, reach_object_car_hand_right_no, 0, 18]
# [spine, reach_object_car_hand_right_no, 0, 18]
# [car, reach_object_car_hand_right_no, 0, 18]
# [octopus, reach_object_car_hand_right_no, 0, 18]
# [elbowLeft, reach_object_car_hand_right_no, 0, 31]
# [elbowRight, reach_object_car_hand_right_no, 0, 31]
# [handLeft, reach_object_car_hand_right_no, 0, 31]
# [handRight, reach_object_car_hand_right_no, 0, 31]
# [head, reach_object_car_hand_right_no, 0, 31]
# [chest, reach_object_car_hand_right_no, 0, 31]
# [shoulderLeft, reach_object_car_hand_right_no, 0, 31]
# [shoulderRight, reach_object_car_hand_right_no, 0, 31]
# [spine, reach_object_car_hand_right_no, 0, 31]
# [car, reach_object_car_hand_right_no, 0, 31]
# [octopus, reach_object_car_hand_right_no, 0, 31]
# [elbowLeft, reach_object_car_hand_right_no, 0, 36]
# [elbowRight, reach_object_car_hand_right_no, 0, 36]
# [handLeft, reach_object_car_hand_right_no, 0, 36]
# [handRight, reach_object_car_hand_right_no, 0, 36]
# [head, reach_object_car_hand_right_no, 0, 36]
# [chest, reach_object_car_hand_right_no, 0, 36]
# [shoulderLeft, reach_object_car_hand_right_no, 0, 36]
# [shoulderRight, reach_object_car_hand_right_no, 0, 36]
# [spine, reach_object_car_hand_right_no, 0, 36]
# [car, reach_object_car_hand_right_no, 0, 36]
# [octopus, reach_object_car_hand_right_no, 0, 36]
# [elbowLeft, reach_object_car_hand_right_no, 0, 31]
# [elbowRight, reach_object_car_hand_right_no, 0, 31]
# [handLeft, reach_object_car_hand_right_no, 0, 31]
# [handRight, reach_object_car_hand_right_no, 0, 31]
# [head, reach_object_car_hand_right_no, 0, 31]
# [chest, reach_object_car_hand_right_no, 0, 31]
# [shoulderLeft, reach_object_car_hand_right_no, 0, 31]
# [shoulderRight, reach_object_car_hand_right_no, 0, 31]
# [spine, reach_object_car_hand_right_no, 0, 31]
# [car, reach_object_car_hand_right_no, 0, 31]
# [octopus, reach_object_car_hand_right_no, 0, 31]
# [elbowLeft, reach_object_car_hand_right_no, 0, 25]
# [elbowRight, reach_object_car_hand_right_no, 0, 25]
# [handLeft, reach_object_car_hand_right_no, 0, 25]
# [handRight, reach_object_car_hand_right_no, 0, 25]
# [head, reach_object_car_hand_right_no, 0, 25]
# ...
# [elbowLeft, retract_hand, 3, 38]
# [elbowRight, retract_hand, 3, 38]
# [handLeft, retract_hand, 3, 38]
# [handRight, retract_hand, 3, 38]
# [head, retract_hand, 3, 38]
# [chest, retract_hand, 3, 38]
# [shoulderLeft, retract_hand, 3, 38]
# [shoulderRight, retract_hand, 3, 38]
# [spine, retract_hand, 3, 38]
# [car, retract_hand, 3, 38]
# [octopus, retract_hand, 3, 38]
# [elbowLeft, retract_hand, 3, 24]
# [elbowRight, retract_hand, 3, 24]
# [handLeft, retract_hand, 3, 24]
# [handRight, retract_hand, 3, 24]
# [head, retract_hand, 3, 24]
# [chest, retract_hand, 3, 24]
# [shoulderLeft, retract_hand, 3, 24]
# [shoulderRight, retract_hand, 3, 24]
# [spine, retract_hand, 3, 24]
# [car, retract_hand, 3, 24]
# [octopus, retract_hand, 3, 24]
# [elbowLeft, retract_hand, 3, 25]
# [elbowRight, retract_hand, 3, 25]
# [handLeft, retract_hand, 3, 25]
# [handRight, retract_hand, 3, 25]
# [head, retract_hand, 3, 25]
# [chest, retract_hand, 3, 25]
# [shoulderLeft, retract_hand, 3, 25]
# [shoulderRight, retract_hand, 3, 25]
# [spine, retract_hand, 3, 25]
# [car, retract_hand, 3, 25]
# [octopus, retract_hand, 3, 25]
# [elbowLeft, retract_hand, 3, 33]
# [elbowRight, retract_hand, 3, 33]
# [handLeft, retract_hand, 3, 33]
# [handRight, retract_hand, 3, 33]
# [head, retract_hand, 3, 33]
# [chest, retract_hand, 3, 33]
# [shoulderLeft, retract_hand, 3, 33]
# [shoulderRight, retract_hand, 3, 33]
# [spine, retract_hand, 3, 33]
# [car, retract_hand, 3, 33]
# [octopus, retract_hand, 3, 33]
# [elbowLeft, retract_hand, 3, 65]
# [elbowRight, retract_hand, 3, 65]
# [handLeft, retract_hand, 3, 65]
# [handRight, retract_hand, 3, 65]
# [head, retract_hand, 3, 65]
# [chest, retract_hand, 3, 65]
# [shoulderLeft, retract_hand, 3, 65]
# [shoulderRight, retract_hand, 3, 65]
# [spine, retract_hand, 3, 65]
# [car, retract_hand, 3, 65]
# [octopus, retract_hand, 3, 65]
# [elbowLeft, retract_hand, 3, 29]
# [elbowRight, retract_hand, 3, 29]
# [handLeft, retract_hand, 3, 29]
# [handRight, retract_hand, 3, 29]
# [head, retract_hand, 3, 29]
# [chest, retract_hand, 3, 29]
# [shoulderLeft, retract_hand, 3, 29]
# [shoulderRight, retract_hand, 3, 29]
# [spine, retract_hand, 3, 29]
# [car, retract_hand, 3, 29]
# [octopus, retract_hand, 3, 29]
# [elbowLeft, retract_hand, 3, 33]
# [elbowRight, retract_hand, 3, 33]
# [handLeft, retract_hand, 3, 33]
# [handRight, retract_hand, 3, 33]
# [head, retract_hand, 3, 33]
# [chest, retract_hand, 3, 33]
# [shoulderLeft, retract_hand, 3, 33]
# [shoulderRight, retract_hand, 3, 33]
# [spine, retract_hand, 3, 33]
# [car, retract_hand, 3, 33]
# [octopus, retract_hand, 3, 33]
# [elbowLeft, retract_hand, 3, 27]
# [elbowRight, retract_hand, 3, 27]
# [handLeft, retract_hand, 3, 27]
# [handRight, retract_hand, 3, 27]
# [head, retract_hand, 3, 27]
# [chest, retract_hand, 3, 27]
# [shoulderLeft, retract_hand, 3, 27]
# [shoulderRight, retract_hand, 3, 27]
# [spine, retract_hand, 3, 27]
# [car, retract_hand, 3, 27]
# [octopus, retract_hand, 3, 27]
# [elbowLeft, retract_hand, 3, 44]
# [elbowRight, retract_hand, 3, 44]
# [handLeft, retract_hand, 3, 44]
# [handRight, retract_hand, 3, 44]
# [head, retract_hand, 3, 44]
# [chest, retract_hand, 3, 44]
# [shoulderLeft, retract_hand, 3, 44]
# [shoulderRight, retract_hand, 3, 44]
# [spine, retract_hand, 3, 44]
# [car, retract_hand, 3, 44]
# [octopus, retract_hand, 3, 44]
# [elbowLeft, retract_hand, 3, 26]
# [elbowRight, retract_hand, 3, 26]
# [handLeft, retract_hand, 3, 26]
# [handRight, retract_hand, 3, 26]
# [head, retract_hand, 3, 26]
# [chest, retract_hand, 3, 26]
# [shoulderLeft, retract_hand, 3, 26]
# [shoulderRight, retract_hand, 3, 26]
# [spine, retract_hand, 3, 26]
# [car, retract_hand, 3, 26]
# [octopus, retract_hand, 3, 26]
# [elbowLeft, retract_hand, 3, 32]
# [elbowRight, retract_hand, 3, 32]
# [handLeft, retract_hand, 3, 32]
# [handRight, retract_hand, 3, 32]
# [head, retract_hand, 3, 32]
# [chest, retract_hand, 3, 32]
# [shoulderLeft, retract_hand, 3, 32]
# [shoulderRight, retract_hand, 3, 32]
# [spine, retract_hand, 3, 32]
# [car, retract_hand, 3, 32]
# [octopus, retract_hand, 3, 32]
# [elbowLeft, retract_hand, 3, 27]
# [elbowRight, retract_hand, 3, 27]
# [handLeft, retract_hand, 3, 27]
# [handRight, retract_hand, 3, 27]
# [head, retract_hand, 3, 27]
# [chest, retract_hand, 3, 27]
# [shoulderLeft, retract_hand, 3, 27]
# [shoulderRight, retract_hand, 3, 27]
# [spine, retract_hand, 3, 27]
# [car, retract_hand, 3, 27]
# [octopus, retract_hand, 3, 27]
# [elbowLeft, retract_hand, 3, 20]
# [elbowRight, retract_hand, 3, 20]
# [handLeft, retract_hand, 3, 20]
# [handRight, retract_hand, 3, 20]
# [head, retract_hand, 3, 20]
# [chest, retract_hand, 3, 20]
# [shoulderLeft, retract_hand, 3, 20]
# [shoulderRight, retract_hand, 3, 20]
# [spine, retract_hand, 3, 20]
# [car, retract_hand, 3, 20]
# [octopus, retract_hand, 3, 20]
# [elbowLeft, retract_hand, 3, 36]
# [elbowRight, retract_hand, 3, 36]
# [handLeft, retract_hand, 3, 36]
# [handRight, retract_hand, 3, 36]
# [head, retract_hand, 3, 36]
# [chest, retract_hand, 3, 36]
# [shoulderLeft, retract_hand, 3, 36]
# [shoulderRight, retract_hand, 3, 36]
# [spine, retract_hand, 3, 36]
# [car, retract_hand, 3, 36]
# [octopus, retract_hand, 3, 36]
# [elbowLeft, retract_hand, 3, 22]
# [elbowRight, retract_hand, 3, 22]
# [handLeft, retract_hand, 3, 22]
# [handRight, retract_hand, 3, 22]
# [head, retract_hand, 3, 22]
# [chest, retract_hand, 3, 22]
# [shoulderLeft, retract_hand, 3, 22]
# [shoulderRight, retract_hand, 3, 22]
# [spine, retract_hand, 3, 22]
# [car, retract_hand, 3, 22]
# [octopus, retract_hand, 3, 22]
# [elbowLeft, retract_hand, 3, 28]
# [elbowRight, retract_hand, 3, 28]
# [handLeft, retract_hand, 3, 28]
# [handRight, retract_hand, 3, 28]
# [head, retract_hand, 3, 28]
# [chest, retract_hand, 3, 28]
# [shoulderLeft, retract_hand, 3, 28]
# [shoulderRight, retract_hand, 3, 28]
# [spine, retract_hand, 3, 28]
# [car, retract_hand, 3, 28]
# [octopus, retract_hand, 3, 28]
# [elbowLeft, retract_hand, 3, 26]
# [elbowRight, retract_hand, 3, 26]
# [handLeft, retract_hand, 3, 26]
# [handRight, retract_hand, 3, 26]
# [head, retract_hand, 3, 26]
# [chest, retract_hand, 3, 26]
# [shoulderLeft, retract_hand, 3, 26]
# [shoulderRight, retract_hand, 3, 26]
# [spine, retract_hand, 3, 26]
# [car, retract_hand, 3, 26]
# [octopus, retract_hand, 3, 26]
# [elbowLeft, retract_hand, 3, 29]
# [elbowRight, retract_hand, 3, 29]
# [handLeft, retract_hand, 3, 29]
# [handRight, retract_hand, 3, 29]
# [head, retract_hand, 3, 29]
# [chest, retract_hand, 3, 29]
# [shoulderLeft, retract_hand, 3, 29]
# [shoulderRight, retract_hand, 3, 29]
# [spine, retract_hand, 3, 29]
# [car, retract_hand, 3, 29]
# [octopus, retract_hand, 3, 29]
# [elbowLeft, retract_hand, 3, 20]
# [elbowRight, retract_hand, 3, 20]
# [handLeft, retract_hand, 3, 20]
# [handRight, retract_hand, 3, 20]
# [head, retract_hand, 3, 20]
# [chest, retract_hand, 3, 20]
# [shoulderLeft, retract_hand, 3, 20]
# [shoulderRight, retract_hand, 3, 20]
# [spine, retract_hand, 3, 20]
# [car, retract_hand, 3, 20]
# [octopus, retract_hand, 3, 20]
# [elbowLeft, retract_hand, 3, 27]
# [elbowRight, retract_hand, 3, 27]
# [handLeft, retract_hand, 3, 27]
# [handRight, retract_hand, 3, 27]
# [head, retract_hand, 3, 27]
# [chest, retract_hand, 3, 27]
# [shoulderLeft, retract_hand, 3, 27]
# [shoulderRight, retract_hand, 3, 27]
# [spine, retract_hand, 3, 27]
# [car, retract_hand, 3, 27]
# [octopus, retract_hand, 3, 27]
# [elbowLeft, retract_hand, 3, 23]
# [elbowRight, retract_hand, 3, 23]
# [handLeft, retract_hand, 3, 23]
# [handRight, retract_hand, 3, 23]
# [head, retract_hand, 3, 23]
# [chest, retract_hand, 3, 23]
# [shoulderLeft, retract_hand, 3, 23]
# [shoulderRight, retract_hand, 3, 23]
# [spine, retract_hand, 3, 23]
# [car, retract_hand, 3, 23]
# [octopus, retract_hand, 3, 23]
# [elbowLeft, retract_hand, 3, 30]
# [elbowRight, retract_hand, 3, 30]
# [handLeft, retract_hand, 3, 30]
# [handRight, retract_hand, 3, 30]
# [head, retract_hand, 3, 30]
# [chest, retract_hand, 3, 30]
# [shoulderLeft, retract_hand, 3, 30]
# [shoulderRight, retract_hand, 3, 30]
# [spine, retract_hand, 3, 30]
# [car, retract_hand, 3, 30]
# [octopus, retract_hand, 3, 30]
# [elbowLeft, retract_hand, 3, 23]
# [elbowRight, retract_hand, 3, 23]
# [handLeft, retract_hand, 3, 23]
# [handRight, retract_hand, 3, 23]
# [head, retract_hand, 3, 23]
# [chest, retract_hand, 3, 23]
# [shoulderLeft, retract_hand, 3, 23]
# [shoulderRight, retract_hand, 3, 23]
# [spine, retract_hand, 3, 23]
# [car, retract_hand, 3, 23]
# [octopus, retract_hand, 3, 23]
# [elbowLeft, retract_hand, 3, 25]
# [elbowRight, retract_hand, 3, 25]
# [handLeft, retract_hand, 3, 25]
# [handRight, retract_hand, 3, 25]
# [head, retract_hand, 3, 25]
# [chest, retract_hand, 3, 25]
# [shoulderLeft, retract_hand, 3, 25]
# [shoulderRight, retract_hand, 3, 25]
# [spine, retract_hand, 3, 25]
# [car, retract_hand, 3, 25]
# [octopus, retract_hand, 3, 25]
# [elbowLeft, retract_hand, 3, 33]
# [elbowRight, retract_hand, 3, 33]
# [handLeft, retract_hand, 3, 33]
# [handRight, retract_hand, 3, 33]
# [head, retract_hand, 3, 33]
# [chest, retract_hand, 3, 33]
# [shoulderLeft, retract_hand, 3, 33]
# [shoulderRight, retract_hand, 3, 33]
# [spine, retract_hand, 3, 33]
# [car, retract_hand, 3, 33]
# [octopus, retract_hand, 3, 33]
# [elbowLeft, retract_hand, 3, 44]
# [elbowRight, retract_hand, 3, 44]
# [handLeft, retract_hand, 3, 44]
# [handRight, retract_hand, 3, 44]
# [head, retract_hand, 3, 44]
# [chest, retract_hand, 3, 44]
# [shoulderLeft, retract_hand, 3, 44]
# [shoulderRight, retract_hand, 3, 44]
# [spine, retract_hand, 3, 44]
# [car, retract_hand, 3, 44]
# [octopus, retract_hand, 3, 44]
# [elbowLeft, retract_hand, 3, 29]
# [elbowRight, retract_hand, 3, 29]
# [handLeft, retract_hand, 3, 29]
# [handRight, retract_hand, 3, 29]
# [head, retract_hand, 3, 29]
# [chest, retract_hand, 3, 29]
# [shoulderLeft, retract_hand, 3, 29]
# [shoulderRight, retract_hand, 3, 29]
# [spine, retract_hand, 3, 29]
# [car, retract_hand, 3, 29]
# [octopus, retract_hand, 3, 29]
# [elbowLeft, retract_hand, 3, 23]
# [elbowRight, retract_hand, 3, 23]
# [handLeft, retract_hand, 3, 23]
# [handRight, retract_hand, 3, 23]
# [head, retract_hand, 3, 23]
# [chest, retract_hand, 3, 23]
# [shoulderLeft, retract_hand, 3, 23]
# [shoulderRight, retract_hand, 3, 23]
# [spine, retract_hand, 3, 23]
# [car, retract_hand, 3, 23]
# [octopus, retract_hand, 3, 23]
# [elbowLeft, retract_hand, 3, 25]
# [elbowRight, retract_hand, 3, 25]
# [handLeft, retract_hand, 3, 25]
# [handRight, retract_hand, 3, 25]
# [head, retract_hand, 3, 25]
# [chest, retract_hand, 3, 25]
# [shoulderLeft, retract_hand, 3, 25]
# [shoulderRight, retract_hand, 3, 25]
# [spine, retract_hand, 3, 25]
# [car, retract_hand, 3, 25]
# [octopus, retract_hand, 3, 25]
# [elbowLeft, retract_hand, 3, 22]
# [elbowRight, retract_hand, 3, 22]
# [handLeft, retract_hand, 3, 22]
# [handRight, retract_hand, 3, 22]
# [head, retract_hand, 3, 22]
# [chest, retract_hand, 3, 22]
# [shoulderLeft, retract_hand, 3, 22]
# [shoulderRight, retract_hand, 3, 22]
# [spine, retract_hand, 3, 22]
# [car, retract_hand, 3, 22]
# [octopus, retract_hand, 3, 22]
# [elbowLeft, retract_hand, 3, 46]
# [elbowRight, retract_hand, 3, 46]
# [handLeft, retract_hand, 3, 46]
# [handRight, retract_hand, 3, 46]
# [head, retract_hand, 3, 46]
# [chest, retract_hand, 3, 46]
# [shoulderLeft, retract_hand, 3, 46]
# [shoulderRight, retract_hand, 3, 46]
# [spine, retract_hand, 3, 46]
# [car, retract_hand, 3, 46]
# [octopus, retract_hand, 3, 46]
# [elbowLeft, retract_hand, 3, 35]
# [elbowRight, retract_hand, 3, 35]
# [handLeft, retract_hand, 3, 35]
# [handRight, retract_hand, 3, 35]
# [head, retract_hand, 3, 35]
# [chest, retract_hand, 3, 35]
# [shoulderLeft, retract_hand, 3, 35]
# [shoulderRight, retract_hand, 3, 35]
# [spine, retract_hand, 3, 35]
# [car, retract_hand, 3, 35]
# [octopus, retract_hand, 3, 35]
# [elbowLeft, retract_hand, 3, 37]
# [elbowRight, retract_hand, 3, 37]
# [handLeft, retract_hand, 3, 37]
# [handRight, retract_hand, 3, 37]
# [head, retract_hand, 3, 37]
# [chest, retract_hand, 3, 37]
# [shoulderLeft, retract_hand, 3, 37]
# [shoulderRight, retract_hand, 3, 37]
# [spine, retract_hand, 3, 37]
# [car, retract_hand, 3, 37]
# [octopus, retract_hand, 3, 37]
# [elbowLeft, retract_hand, 3, 22]
# [elbowRight, retract_hand, 3, 22]
# [handLeft, retract_hand, 3, 22]
# [handRight, retract_hand, 3, 22]
# [head, retract_hand, 3, 22]
# [chest, retract_hand, 3, 22]
# [shoulderLeft, retract_hand, 3, 22]
# [shoulderRight, retract_hand, 3, 22]
# [spine, retract_hand, 3, 22]
# [car, retract_hand, 3, 22]
# [octopus, retract_hand, 3, 22]
# [elbowLeft, retract_hand, 3, 32]
# [elbowRight, retract_hand, 3, 32]
# [handLeft, retract_hand, 3, 32]
# [handRight, retract_hand, 3, 32]
# [head, retract_hand, 3, 32]
# [chest, retract_hand, 3, 32]
# [shoulderLeft, retract_hand, 3, 32]
# [shoulderRight, retract_hand, 3, 32]
# [spine, retract_hand, 3, 32]
# [car, retract_hand, 3, 32]
# [octopus, retract_hand, 3, 32]
# [elbowLeft, retract_hand, 3, 36]
# [elbowRight, retract_hand, 3, 36]
# [handLeft, retract_hand, 3, 36]
# [handRight, retract_hand, 3, 36]
# [head, retract_hand, 3, 36]
# [chest, retract_hand, 3, 36]
# [shoulderLeft, retract_hand, 3, 36]
# [shoulderRight, retract_hand, 3, 36]
# [spine, retract_hand, 3, 36]
# [car, retract_hand, 3, 36]
# [octopus, retract_hand, 3, 36]
# [elbowLeft, retract_hand, 3, 28]
# [elbowRight, retract_hand, 3, 28]
# [handLeft, retract_hand, 3, 28]
# [handRight, retract_hand, 3, 28]
# [head, retract_hand, 3, 28]
# [chest, retract_hand, 3, 28]
# [shoulderLeft, retract_hand, 3, 28]
# [shoulderRight, retract_hand, 3, 28]
# [spine, retract_hand, 3, 28]
# [car, retract_hand, 3, 28]
# [octopus, retract_hand, 3, 28]
# [elbowLeft, retract_hand, 3, 29]
# [elbowRight, retract_hand, 3, 29]
# [handLeft, retract_hand, 3, 29]
# [handRight, retract_hand, 3, 29]
# [head, retract_hand, 3, 29]
# [chest, retract_hand, 3, 29]
# [shoulderLeft, retract_hand, 3, 29]
# [shoulderRight, retract_hand, 3, 29]
# [spine, retract_hand, 3, 29]
# [car, retract_hand, 3, 29]
# [octopus, retract_hand, 3, 29]
# [elbowLeft, retract_hand, 3, 24]
# [elbowRight, retract_hand, 3, 24]
# [handLeft, retract_hand, 3, 24]
# [handRight, retract_hand, 3, 24]
# [head, retract_hand, 3, 24]
# [chest, retract_hand, 3, 24]
# [shoulderLeft, retract_hand, 3, 24]
# [shoulderRight, retract_hand, 3, 24]
# [spine, retract_hand, 3, 24]
# [car, retract_hand, 3, 24]
# [octopus, retract_hand, 3, 24]
# [elbowLeft, retract_hand, 3, 32]
# [elbowRight, retract_hand, 3, 32]
# [handLeft, retract_hand, 3, 32]
# [handRight, retract_hand, 3, 32]
# [head, retract_hand, 3, 32]
# [chest, retract_hand, 3, 32]
# [shoulderLeft, retract_hand, 3, 32]
# [shoulderRight, retract_hand, 3, 32]
# [spine, retract_hand, 3, 32]
# [car, retract_hand, 3, 32]
# [octopus, retract_hand, 3, 32]
# [elbowLeft, retract_hand, 3, 26]
# [elbowRight, retract_hand, 3, 26]
# [handLeft, retract_hand, 3, 26]
# [handRight, retract_hand, 3, 26]
# [head, retract_hand, 3, 26]
# [chest, retract_hand, 3, 26]
# [shoulderLeft, retract_hand, 3, 26]
# [shoulderRight, retract_hand, 3, 26]
# [spine, retract_hand, 3, 26]
# [car, retract_hand, 3, 26]
# [octopus, retract_hand, 3, 26]
# [elbowLeft, retract_hand, 3, 20]
# [elbowRight, retract_hand, 3, 20]
# [handLeft, retract_hand, 3, 20]
# [handRight, retract_hand, 3, 20]
# [head, retract_hand, 3, 20]
# [chest, retract_hand, 3, 20]
# [shoulderLeft, retract_hand, 3, 20]
# [shoulderRight, retract_hand, 3, 20]
# [spine, retract_hand, 3, 20]
# [car, retract_hand, 3, 20]
# [octopus, retract_hand, 3, 20]
# [elbowLeft, retract_hand, 3, 32]
# [elbowRight, retract_hand, 3, 32]
# [handLeft, retract_hand, 3, 32]
# [handRight, retract_hand, 3, 32]
# [head, retract_hand, 3, 32]
# [chest, retract_hand, 3, 32]
# [shoulderLeft, retract_hand, 3, 32]
# [shoulderRight, retract_hand, 3, 32]
# [spine, retract_hand, 3, 32]
# [car, retract_hand, 3, 32]
# [octopus, retract_hand, 3, 32]
# [elbowLeft, retract_hand, 3, 46]
# [elbowRight, retract_hand, 3, 46]
# [handLeft, retract_hand, 3, 46]
# [handRight, retract_hand, 3, 46]
# [head, retract_hand, 3, 46]
# [chest, retract_hand, 3, 46]
# [shoulderLeft, retract_hand, 3, 46]
# [shoulderRight, retract_hand, 3, 46]
# [spine, retract_hand, 3, 46]
# [car, retract_hand, 3, 46]
# [octopus, retract_hand, 3, 46]
# [elbowLeft, retract_hand, 3, 34]
# [elbowRight, retract_hand, 3, 34]
# [handLeft, retract_hand, 3, 34]
# [handRight, retract_hand, 3, 34]
# [head, retract_hand, 3, 34]
# [chest, retract_hand, 3, 34]
# [shoulderLeft, retract_hand, 3, 34]
# [shoulderRight, retract_hand, 3, 34]
# [spine, retract_hand, 3, 34]
# [car, retract_hand, 3, 34]
# [octopus, retract_hand, 3, 34]
# ------------------------------------------------------------------------
#
# current dataset = push-pull-right_arm
# curent label: touch_octopus_hand_left
#
#
# current dataset = push-pull-right_arm
# curent label: unknown
#
# ------------------------------------------------------------------------

# %%
joint = 0
action = 1
dataset = 2
start = 3
end = 4
for a in range(len(dataFolderList)):
    print 'Dataset ' + str(a) + ' : ' + dataFolderList[a]
    for b in range(len(labels)):
        if('no' not in labels[b]):
            y = len([i[1] for i in dataStruct if i[joint] == 'head' and i[dataset] == a and i[action] == labels[b]])
            print '\t ' + str(labels[b]).ljust(35) + ' = ' + str(y).ljust(3) + ' repetitions'
    print
# Out:
# Dataset 0 : lift-drop-right_arm
# 	 agent_entry                         = 0   repetitions
# 	 agent_exit                          = 0   repetitions
# 	 arms_lowered                        = 23  repetitions
# 	 arms_raised                         = 1   repetitions
# 	 carry_object_car_hand_left          = 0   repetitions
# 	 carry_object_car_hand_right         = 0   repetitions
# 	 drop_object_car_hand_left           = 0   repetitions
# 	 drop_object_car_hand_right          = 0   repetitions
# 	 dropping_arms                       = 3   repetitions
# 	 lift_object_car_hand_left           = 0   repetitions
# 	 pull_object_car_hand_left           = 0   repetitions
# 	 pull_object_car_hand_right          = 0   repetitions
# 	 pull_object_octopus_hand_left       = 0   repetitions
# 	 pull_object_octopus_hand_right      = 0   repetitions
# 	 push_object_car_hand_left           = 0   repetitions
# 	 push_object_car_hand_right          = 0   repetitions
# 	 push_object_octopus_hand_left       = 0   repetitions
# 	 push_object_octopus_hand_right      = 0   repetitions
# 	 raising_arms                        = 3   repetitions
# 	 reach_object_car_hand_left          = 0   repetitions
# 	 reach_object_car_hand_right         = 0   repetitions
# 	 reach_object_octopus_hand_left      = 0   repetitions
# 	 reach_object_octopus_hand_right     = 0   repetitions
# 	 retract_hand                        = 25  repetitions
# 	 touch_octopus_hand_left             = 0   repetitions
#
# Dataset 1 : lift-drop-left_arm
# 	 agent_entry                         = 0   repetitions
# 	 agent_exit                          = 0   repetitions
# 	 arms_lowered                        = 22  repetitions
# 	 arms_raised                         = 4   repetitions
# 	 carry_object_car_hand_left          = 10  repetitions
# 	 carry_object_car_hand_right         = 0   repetitions
# 	 drop_object_car_hand_left           = 11  repetitions
# 	 drop_object_car_hand_right          = 0   repetitions
# 	 dropping_arms                       = 4   repetitions
# 	 lift_object_car_hand_left           = 11  repetitions
# 	 pull_object_car_hand_left           = 0   repetitions
# 	 pull_object_car_hand_right          = 0   repetitions
# 	 pull_object_octopus_hand_left       = 0   repetitions
# 	 pull_object_octopus_hand_right      = 0   repetitions
# 	 push_object_car_hand_left           = 0   repetitions
# 	 push_object_car_hand_right          = 0   repetitions
# 	 push_object_octopus_hand_left       = 0   repetitions
# 	 push_object_octopus_hand_right      = 0   repetitions
# 	 raising_arms                        = 4   repetitions
# 	 reach_object_car_hand_left          = 10  repetitions
# 	 reach_object_car_hand_right         = 0   repetitions
# 	 reach_object_octopus_hand_left      = 0   repetitions
# 	 reach_object_octopus_hand_right     = 0   repetitions
# 	 retract_hand                        = 16  repetitions
# 	 touch_octopus_hand_left             = 0   repetitions
#
# Dataset 2 : push-pull-left_arm
# 	 agent_entry                         = 0   repetitions
# 	 agent_exit                          = 0   repetitions
# 	 arms_lowered                        = 0   repetitions
# 	 arms_raised                         = 29  repetitions
# 	 carry_object_car_hand_left          = 0   repetitions
# 	 carry_object_car_hand_right         = 0   repetitions
# 	 drop_object_car_hand_left           = 0   repetitions
# 	 drop_object_car_hand_right          = 0   repetitions
# 	 dropping_arms                       = 2   repetitions
# 	 lift_object_car_hand_left           = 0   repetitions
# 	 pull_object_car_hand_left           = 7   repetitions
# 	 pull_object_car_hand_right          = 0   repetitions
# 	 pull_object_octopus_hand_left       = 9   repetitions
# 	 pull_object_octopus_hand_right      = 0   repetitions
# 	 push_object_car_hand_left           = 12  repetitions
# 	 push_object_car_hand_right          = 0   repetitions
# 	 push_object_octopus_hand_left       = 7   repetitions
# 	 push_object_octopus_hand_right      = 0   repetitions
# 	 raising_arms                        = 0   repetitions
# 	 reach_object_car_hand_left          = 20  repetitions
# 	 reach_object_car_hand_right         = 0   repetitions
# 	 reach_object_octopus_hand_left      = 17  repetitions
# 	 reach_object_octopus_hand_right     = 0   repetitions
# 	 retract_hand                        = 48  repetitions
# 	 touch_octopus_hand_left             = 0   repetitions
#
# Dataset 3 : push-pull-right_arm
# 	 agent_entry                         = 0   repetitions
# 	 agent_exit                          = 0   repetitions
# 	 arms_lowered                        = 2   repetitions
# 	 arms_raised                         = 33  repetitions
# 	 carry_object_car_hand_left          = 0   repetitions
# 	 carry_object_car_hand_right         = 0   repetitions
# 	 drop_object_car_hand_left           = 0   repetitions
# 	 drop_object_car_hand_right          = 0   repetitions
# 	 dropping_arms                       = 1   repetitions
# 	 lift_object_car_hand_left           = 0   repetitions
# 	 pull_object_car_hand_left           = 0   repetitions
# 	 pull_object_car_hand_right          = 11  repetitions
# 	 pull_object_octopus_hand_left       = 0   repetitions
# 	 pull_object_octopus_hand_right      = 10  repetitions
# 	 push_object_car_hand_left           = 0   repetitions
# 	 push_object_car_hand_right          = 11  repetitions
# 	 push_object_octopus_hand_left       = 0   repetitions
# 	 push_object_octopus_hand_right      = 14  repetitions
# 	 raising_arms                        = 2   repetitions
# 	 reach_object_car_hand_left          = 0   repetitions
# 	 reach_object_car_hand_right         = 24  repetitions
# 	 reach_object_octopus_hand_left      = 0   repetitions
# 	 reach_object_octopus_hand_right     = 23  repetitions
# 	 retract_hand                        = 48  repetitions
# 	 touch_octopus_hand_left             = 0   repetitions

# %%
joint = 0
action = 1
dataset = 2
start = 3
end = 4

for b in range(len(labels)):
    if('no' not in labels[b]):
        y = 0
        for a in range(len(dataFolderList)):
            y += len([i[1] for i in dataStruct if i[joint] == 'head' and i[dataset] == a and i[action] == labels[b]])
        print '\t ' + str(labels[b]).ljust(35) + ' = ' + str(y).ljust(3) + ' repetitions'
# Out:
# 	 agent_entry                         = 0   repetitions
# 	 agent_exit                          = 0   repetitions
# 	 arms_lowered                        = 47  repetitions
# 	 arms_raised                         = 67  repetitions
# 	 carry_object_car_hand_left          = 10  repetitions
# 	 carry_object_car_hand_right         = 0   repetitions
# 	 drop_object_car_hand_left           = 11  repetitions
# 	 drop_object_car_hand_right          = 0   repetitions
# 	 dropping_arms                       = 10  repetitions
# 	 lift_object_car_hand_left           = 11  repetitions
# 	 pull_object_car_hand_left           = 7   repetitions
# 	 pull_object_car_hand_right          = 11  repetitions
# 	 pull_object_octopus_hand_left       = 9   repetitions
# 	 pull_object_octopus_hand_right      = 10  repetitions
# 	 push_object_car_hand_left           = 12  repetitions
# 	 push_object_car_hand_right          = 11  repetitions
# 	 push_object_octopus_hand_left       = 7   repetitions
# 	 push_object_octopus_hand_right      = 14  repetitions
# 	 raising_arms                        = 9   repetitions
# 	 reach_object_car_hand_left          = 30  repetitions
# 	 reach_object_car_hand_right         = 24  repetitions
# 	 reach_object_octopus_hand_left      = 17  repetitions
# 	 reach_object_octopus_hand_right     = 23  repetitions
# 	 retract_hand                        = 137 repetitions
# 	 touch_octopus_hand_left             = 0   repetitions

# %%
#Calibrate contact threshold
# data has length = 12 joints
# each joint has 4 arrays of shape: (4637, 3), (4907, 3), (5914, 3), (5440, 3), 
# labelsList has length = 4 with sizes: 4637, 4907, 5914, 5440, 
handPos = np.zeros((1,3))
objectPos = np.zeros((1,3))

# push_object_car_hand_right

for i in range(len(labelsList)):
    for j in range(len(labelsList[i])):
        if('object' in labelsList[i][j] and 'reach' not in labelsList[i][j] and "no" not in labelsList[i][j]):
            if('left' in labelsList[i][j]):
                handPos = np.vstack((handPos,data['handLeft'][i][j,:,None].T))
                obj = labelsList[i][j].split('_')[2]
                objectPos = np.vstack((objectPos,data[obj][i][j,:,None].T))
                
            if('right' in labelsList[i][j]):
                handPos = np.vstack((handPos,data['handRight'][i][j,:, None].T))
                obj = labelsList[i][j].split('_')[2]
                objectPos = np.vstack((objectPos,data[obj][i][j,:,None].T))

d = distEuc(handPos, objectPos)
perc = 98
print 'Mean of contact distances = ' + str(np.mean(d))
print 'Median of contact distances = '  + str(np.median(d))
print 'Max contact distance = ' + str(np.max(d))
print 'Min contact distance = ' + str(np.min(d))
print str(perc)+'% percentile contact distance = ' + str(np.percentile(d,perc))
# Out:
# Mean of contact distances = 0.11143710217
# Median of contact distances = 0.107711559875
# Max contact distance = 0.343510114671
# Min contact distance = 0.0
# 98% percentile contact distance = 0.213788154879

# %%
jointsList.sort()
modJointsListHand_R = [i for i in jointsList if i != 'elbowRight' and i != 'handRight']
modJointsListHand_L = [i for i in jointsList if i != 'elbowLeft' and i != 'handLeft']

modJointsListHand_R = []
modJointsListHand_L = []
combinationList = []

if(len(modJointsListHand_R) > 0):
    for i in range(len(modJointsListHand_R)):
        combinationList.append(['handLeft', modJointsListHand_L[i]])
        combinationList.append(['handRight', modJointsListHand_R[i]])
    del combinationList[combinationList.index(['handLeft', 'handRight'])]

for i in objectsList[1:]:
    combinationList.append(['handLeft',i])
    combinationList.append(['handRight',i])


print 'Available joint pairs for hands:'
print
for i in combinationList:
    print '\t' + str(i)
# Out:
# Available joint pairs for hands:
#
# 	['handLeft', 'car']
# 	['handRight', 'car']
# 	['handLeft', 'octopus']
# 	['handRight', 'octopus']

# %%
humanStaticLabels = []
humanStaticLabels.append('left of')
humanStaticLabels.append('right of')
humanStaticLabels.append('on top of')
humanStaticLabels.append('underneath')
humanStaticLabels.append('in front of')
humanStaticLabels.append('behind')
humanStaticLabels.append('stationary')

# %%
joint = 0
action = 1
dataset = 2
start = 3
end = 4

actionsAllowedList = ['lift_object', 'pull_object', 'push_object', 'drop_object', 'carry_object']
#actionsAllowedList = ['lift_object', 'drop_object']
actionsAllowed = []

for ac in actionsAllowedList:
    temp = [g for g in labels if ac in g and "no" not in g]
    for h in range(len(temp)):
        actionsAllowed.append(temp[h])

for b in range(len(labels)):
#     print labels[b]
    if('no' not in labels[b] and labels[b] in actionsAllowed):
        y = 0
        for a in range(len(dataFolderList)):
            y += len([i[1] for i in dataStruct if i[joint] == 'head' and i[dataset] == a and i[action] == labels[b]])
        print '\t ' + str(labels[b]).ljust(35) + ' = ' + str(y).ljust(3) + ' repetitions'
# Out:
# 	 carry_object_car_hand_left          = 10  repetitions
# 	 carry_object_car_hand_right         = 0   repetitions
# 	 drop_object_car_hand_left           = 11  repetitions
# 	 drop_object_car_hand_right          = 0   repetitions
# 	 lift_object_car_hand_left           = 11  repetitions
# 	 pull_object_car_hand_left           = 7   repetitions
# 	 pull_object_car_hand_right          = 11  repetitions
# 	 pull_object_octopus_hand_left       = 9   repetitions
# 	 pull_object_octopus_hand_right      = 10  repetitions
# 	 push_object_car_hand_left           = 12  repetitions
# 	 push_object_car_hand_right          = 11  repetitions
# 	 push_object_octopus_hand_left       = 7   repetitions
# 	 push_object_octopus_hand_right      = 14  repetitions

# %%
def labelize(qin, qout):
    for h in range(qin.shape[0]):
        #x at 0 is depth with negative meaning behind an object
        #y at 1 is width with negative meaning partner-right = ego-left
        #x at 2 is height with negative meaning underneath
        currVec = np.abs(qin[h,:])
        if(currVec.sum() != 0):
            maxIDx = currVec.argmax()
            if(maxIDx == 0):
                if(np.sign(qin[h,maxIDx]) == -1):
                    #behind
                    qout[h] = humanStaticLabels.index('behind')
                elif(np.sign(qin[h,maxIDx]) == 1):
                    #in front
                    qout[h] = humanStaticLabels.index('in front of')
            elif(maxIDx == 1):
                if(np.sign(qin[h,maxIDx]) == -1):
                    #left
                    qout[h] = humanStaticLabels.index('left of')
                elif(np.sign(qin[h,maxIDx]) == 1):
                    #right
                    qout[h] = humanStaticLabels.index('right of')
            elif(maxIDx == 2):
                if(np.sign(qin[h,maxIDx]) == -1):
                    #underneath
                    qout[h] = humanStaticLabels.index('underneath')
                elif(np.sign(qin[h,maxIDx]) == 1):
                    #top of
                    qout[h] = humanStaticLabels.index('on top of')  
        else:
            qout[h] = humanStaticLabels.index('stationary')

# %%
def filterMovement(ts, thresh):
    lastMove = 0
    stillThere = True
    
    for timestep in range(1, ts.shape[0]):
        g = np.sqrt(np.sum(np.square(ts[timestep,:]-ts[lastMove,:])))
        if(g >= thresh):
            lastMove = timestep
            stillThere = False
#             print str(g).ljust(20) + ' shift'
        else:
#             print str(g).ljust(20) + ' still there'
            ts[timestep] = ts[lastMove]
#             if(stillThere):
#                 print 'delete'
#                 #np.delete(ts, timestep, axis = 0)
#             else:
#                 print 'no delete'
#                 stillThere = True

def removeStationary(inputArr, labelRemove, indsToCheck):
    i = 0
    while(i < inputArr.shape[0]):
        logic = True 
        for j in indsToCheck: 
            if(inputArr[i][j] == labelRemove):
                logic = logic and True
            else:
                logic = logic and False
        
        if(logic): #if labelRemove was present in all indsToCheck remove row
            inputArr = np.delete(inputArr,i,0)
        else:
            i += 1
    return inputArr

def formatFeatures(inputArr, idx):
    vec = np.zeros((len(humanStaticLabels)+1))
    for i in range(len(inputArr)):
        vec[inputArr[i][idx]] += 1
    vec[-1] = len(inputArr)
    return vec

# %%
#2 joint pairs will be used shoulder-hand and hand-object left and right doesnt matter
#both combine within a single model
#step 1 will be training these models with static poses to do clustering with a full GP configuration
joint = 0
action = 1
dataset = 2
start = 3
end = 4
verbose = True

contactThreshold = 0.2 #between 0.1 and 0.2 value smaller than which contact occurs
deltaDistanceThreshold = 0.01 #distance to move between frames for point-point relative movement to be considered true1
angleThreshold = 0.001
labelToRemove = humanStaticLabels.index('stationary');
indsToRemove = [18]

firstPass = True
handDataStruct = []

for currComb in combinationList:
    print str(currComb[0]) +'-' +str(currComb[1])
    infoK = [i for i in dataStruct if i[joint] == currComb[0]]
    infoL = [i for i in dataStruct if i[joint] == currComb[1]]
    for i in range(len(infoK)):
        if(infoK[i][1] in actionsAllowed):
            if('hand' in infoK[i][0] and 'object' in infoK[i][1]):
                if('Left' in infoK[i][0] and 'left' in infoK[i][1]):
                    condition = True
                elif('Right' in infoK[i][0] and 'right' in infoK[i][1]):
                    condition = True
                else:
                    condition = False
                    
                if(infoL[i][0] not in infoK[i][1]):
                    condition = False
                    obj = True
                    
            elif('hand' not in infoK[i][0] and 'object' in infoK[i][1]):
                condition = False
            else:
                condition = True
        else:
            condition = False
             
            
#         condition = False
        if(condition):
            
            Pk = infoK[i][4]
            Pl = infoL[i][4]

            #add gaussian noise on output
            Pk_Noise = np.random.normal(jointMu, jointSig, Pk.shape)
            Pl_Noise = np.random.normal(jointMu, jointSig, Pl.shape)

            Pk = Pk + Pk_Noise
            Pl = Pl + Pl_Noise

            q1 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #motion of k relative to l
            q2 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #motion of l relative to k
            q3 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #alpha
            q4 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #beta
            q5 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #gamma
            q7 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #contact
            q8 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #human static label
            
            filterMovement(Pk, deltaDistanceThreshold)
            filterMovement(Pl, deltaDistanceThreshold)
            

            q6 = (Pl[1:-1]-Pk[1:-1]) #direction vector from joint to joint

            q9 = qtc_2D(Pk,Pl,q1, deltaDistanceThreshold)
            lowV = np.abs(q9) < contactThreshold
            q7[lowV] = 1

            q6 = q6/q9[:,None]

            qtc_2D(Pl,Pk,q2, deltaDistanceThreshold)
            [a,b,g] = qtc_3D(Pk, Pl, angleThreshold, q3, q4, q5)
            
            labelize(q6,q8)

            q10 = Pl[1:-1]
            q11 = Pk[1:-1]
            
            q13 = np.ones((Pk.shape[0]-2,1), dtype=np.int)
            q12mag = distEuc(Pk[1:-1],Pk[:-2])
            lowV = np.abs(q12mag) < deltaDistanceThreshold
            q12 = (Pk[1:-1] - Pk[:-2])/q12mag[:,None]
            q12[lowV] = 0
            labelize(q12,q13)

            q15 = np.ones((Pk.shape[0]-2,1), dtype=np.int)
            q14mag = distEuc(Pl[1:-1],Pl[:-2])
            lowV = np.abs(q14mag) < deltaDistanceThreshold
            q14 = (Pl[1:-1] - Pl[:-2])/q14mag[:,None]
            q14[lowV] = 0
            labelize(q14,q15)
                
            tempQTC = np.hstack((q1,q2,q3,q4,q5,q6[:,0,None],q6[:,1,None],q6[:,2,None],q7,q8,q9[:,None],q10[:,0,None],q10[:,1,None],q10[:,2,None],q11[:,0,None],q11[:,1,None],q11[:,2,None],q13,q15))
    #         g = tempQTC.shape[0]
    #         tempQTC2 = uniqueQTC(tempQTC)

    #         gg = tempQTC2.shape[0]

    #         tempQTC = checkQTC(tempQTC2)

    #         ggg = tempQTC.shape[0]
            
            tempQTC = removeStationary(tempQTC, labelToRemove, indsToRemove)
#             v = formatFeatures(tempQTC, 18)
            handDataStruct.append([currComb[0], currComb[1], infoK[i][1], infoK[i][2], tempQTC.shape[0], tempQTC])

            if(verbose):
                print '[%s]' % ', '.join(map(str, handDataStruct[-1][:-1]))
                #print v
    #             print str((ggg-gg)).ljust(3) + ' added in check QTC'
    #             print str((gg-g)).ljust(3) + ' added in unique QT
# Out:
# handLeft-car
# [handLeft, car, carry_object_car_hand_left, 1, 0]
# [handLeft, car, carry_object_car_hand_left, 1, 3]
# [handLeft, car, carry_object_car_hand_left, 1, 7]
# [handLeft, car, carry_object_car_hand_left, 1, 15]
# [handLeft, car, carry_object_car_hand_left, 1, 4]
# [handLeft, car, carry_object_car_hand_left, 1, 9]
# [handLeft, car, carry_object_car_hand_left, 1, 8]
# [handLeft, car, carry_object_car_hand_left, 1, 11]
# [handLeft, car, carry_object_car_hand_left, 1, 8]
# [handLeft, car, carry_object_car_hand_left, 1, 5]
# [handLeft, car, drop_object_car_hand_left, 1, 5]
# [handLeft, car, drop_object_car_hand_left, 1, 6]
# [handLeft, car, drop_object_car_hand_left, 1, 7]
# [handLeft, car, drop_object_car_hand_left, 1, 4]
# [handLeft, car, drop_object_car_hand_left, 1, 8]
# [handLeft, car, drop_object_car_hand_left, 1, 5]
# [handLeft, car, drop_object_car_hand_left, 1, 2]
# [handLeft, car, drop_object_car_hand_left, 1, 12]
# [handLeft, car, drop_object_car_hand_left, 1, 7]
# [handLeft, car, drop_object_car_hand_left, 1, 5]
# [handLeft, car, drop_object_car_hand_left, 1, 7]
# [handLeft, car, lift_object_car_hand_left, 1, 4]
# [handLeft, car, lift_object_car_hand_left, 1, 4]
# [handLeft, car, lift_object_car_hand_left, 1, 6]
# [handLeft, car, lift_object_car_hand_left, 1, 3]
# [handLeft, car, lift_object_car_hand_left, 1, 9]
# [handLeft, car, lift_object_car_hand_left, 1, 5]
# [handLeft, car, lift_object_car_hand_left, 1, 5]
# [handLeft, car, lift_object_car_hand_left, 1, 7]
# [handLeft, car, lift_object_car_hand_left, 1, 5]
# [handLeft, car, lift_object_car_hand_left, 1, 7]
# [handLeft, car, lift_object_car_hand_left, 1, 7]
# [handLeft, car, pull_object_car_hand_left, 2, 9]
# [handLeft, car, pull_object_car_hand_left, 2, 8]
# [handLeft, car, pull_object_car_hand_left, 2, 6]
# [handLeft, car, pull_object_car_hand_left, 2, 8]
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:35: RuntimeWarning:invalid value encountered in divide
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:38: RuntimeWarning:divide by zero encountered in divide
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:90: RuntimeWarning:invalid value encountered in divide
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:97: RuntimeWarning:invalid value encountered in divide
# [handLeft, car, pull_object_car_hand_left, 2, 7]
# [handLeft, car, pull_object_car_hand_left, 2, 12]
# [handLeft, car, pull_object_car_hand_left, 2, 11]
# [handLeft, car, push_object_car_hand_left, 2, 5]
# [handLeft, car, push_object_car_hand_left, 2, 4]
# [handLeft, car, push_object_car_hand_left, 2, 9]
# [handLeft, car, push_object_car_hand_left, 2, 19]
# [handLeft, car, push_object_car_hand_left, 2, 9]
# [handLeft, car, push_object_car_hand_left, 2, 12]
# [handLeft, car, push_object_car_hand_left, 2, 8]
# [handLeft, car, push_object_car_hand_left, 2, 10]
# [handLeft, car, push_object_car_hand_left, 2, 7]
# [handLeft, car, push_object_car_hand_left, 2, 16]
# [handLeft, car, push_object_car_hand_left, 2, 6]
# [handLeft, car, push_object_car_hand_left, 2, 12]
# handRight-car
# [handRight, car, pull_object_car_hand_right, 3, 7]
# [handRight, car, pull_object_car_hand_right, 3, 2]
# [handRight, car, pull_object_car_hand_right, 3, 3]
# [handRight, car, pull_object_car_hand_right, 3, 8]
# [handRight, car, pull_object_car_hand_right, 3, 11]
# [handRight, car, pull_object_car_hand_right, 3, 9]
# [handRight, car, pull_object_car_hand_right, 3, 9]
# [handRight, car, pull_object_car_hand_right, 3, 12]
# [handRight, car, pull_object_car_hand_right, 3, 18]
# [handRight, car, pull_object_car_hand_right, 3, 7]
# [handRight, car, pull_object_car_hand_right, 3, 5]
# [handRight, car, push_object_car_hand_right, 3, 4]
# [handRight, car, push_object_car_hand_right, 3, 7]
# [handRight, car, push_object_car_hand_right, 3, 4]
# [handRight, car, push_object_car_hand_right, 3, 0]
# [handRight, car, push_object_car_hand_right, 3, 1]
# [handRight, car, push_object_car_hand_right, 3, 6]
# [handRight, car, push_object_car_hand_right, 3, 7]
# [handRight, car, push_object_car_hand_right, 3, 12]
# [handRight, car, push_object_car_hand_right, 3, 10]
# [handRight, car, push_object_car_hand_right, 3, 6]
# [handRight, car, push_object_car_hand_right, 3, 7]
# handLeft-octopus
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 10]
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 14]
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 8]
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 9]
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 13]
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 9]
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 7]
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 9]
# [handLeft, octopus, pull_object_octopus_hand_left, 2, 7]
# [handLeft, octopus, push_object_octopus_hand_left, 2, 4]
# [handLeft, octopus, push_object_octopus_hand_left, 2, 12]
# [handLeft, octopus, push_object_octopus_hand_left, 2, 3]
# [handLeft, octopus, push_object_octopus_hand_left, 2, 2]
# [handLeft, octopus, push_object_octopus_hand_left, 2, 2]
# [handLeft, octopus, push_object_octopus_hand_left, 2, 9]
# [handLeft, octopus, push_object_octopus_hand_left, 2, 6]
# handRight-octopus
# [handRight, octopus, pull_object_octopus_hand_right, 3, 5]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 6]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 19]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 8]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 7]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 2]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 4]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 0]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 6]
# [handRight, octopus, pull_object_octopus_hand_right, 3, 9]
# [handRight, octopus, push_object_octopus_hand_right, 3, 7]
# [handRight, octopus, push_object_octopus_hand_right, 3, 1]
# [handRight, octopus, push_object_octopus_hand_right, 3, 5]
# [handRight, octopus, push_object_octopus_hand_right, 3, 5]
# [handRight, octopus, push_object_octopus_hand_right, 3, 2]
# [handRight, octopus, push_object_octopus_hand_right, 3, 7]
# [handRight, octopus, push_object_octopus_hand_right, 3, 2]
# [handRight, octopus, push_object_octopus_hand_right, 3, 1]
# [handRight, octopus, push_object_octopus_hand_right, 3, 5]
# [handRight, octopus, push_object_octopus_hand_right, 3, 13]
# [handRight, octopus, push_object_octopus_hand_right, 3, 7]
# [handRight, octopus, push_object_octopus_hand_right, 3, 5]
# [handRight, octopus, push_object_octopus_hand_right, 3, 10]
# [handRight, octopus, push_object_octopus_hand_right, 3, 5]

# %%
#q1,q2         [0:2]   -> relative movement of points in terms of distance from each other (closer / farther)
#q3-5          [2:5]   -> relative movement of joints in tems of orientation from each other (difference in the paths they are following wrt each other)
#q6_1 to _3    [5:8]   -> direction vector from hand to other joint
#q7            [8]     -> contact status
#q8            [9]     -> instantaneous relative position of K wrt L
#q9            [10]    -> distance of points
#q10_1 to _3   [11:14] -> position of l
#q11_1 to _3   [14:17] -> position of k

featureSections = dict()
featureValues = dict()
featureSections['QTC_Motion'] = range(0,2)
featureValues['QTC_Motion'] = [-1,0,1]

featureSections['QTC_Orientation'] = range(2,5)
featureValues['QTC_Orientation'] = [-1,0,1]

featureSections['directionVector'] = range(5,8)
featureValues['directionVector'] = []

featureSections['contact'] = [8]
featureValues['contact'] = [0,1]

featureSections['relativePositionLabel'] = [9]
featureValues['relativePositionLabel'] = range(len(humanStaticLabels))

featureSections['euc_distance'] = [10]
featureValues['euc_distance'] = []

featureSections['posL'] = range(11,14)
featureValues['posL'] = []

featureSections['posK'] = range(14,17)
featureValues['posK'] = []

featureSections['selfMovementLabelL'] = [17]
featureValues['selfMovementLabelL']   = range(len(humanStaticLabels))

featureSections['selfMovementLabelK'] = [18]
featureValues['selfMovementLabelK']   = range(len(humanStaticLabels))


featureToUse = ['contact', 'selfMovementLabelK']
#selfMovementLabelK movement of hand
#selfMovementLabelL movement of object
featureInds = []
for h in featureToUse:
    featureInds += featureSections[h]
    
    
print featureInds
# Out:
# [8, 18]

# %%
for i in range(len(humanStaticLabels)):
    print str(i).ljust(2) + ': ' + str(humanStaticLabels[i])
#
# Out:
# 0 : left of
# 1 : right of
# 2 : on top of
# 3 : underneath
# 4 : in front of
# 5 : behind
# 6 : stationary

# %%
def formatFeatures2(inputArr, idx, valsPossible):
    print str(valsPossible) + str(len(valsPossible))
    print str(idx) +str(len(idx))
    if(valsPossible != None):
        vec = np.zeros((len(valsPossible)*len(idx)))
        for b in range(len(idx)):
            for i in range(len(inputArr)):
                
                offset = (len(valsPossible)*b)
                vec[offset + valsPossible.index(inputArr[i][idx[b]])] += 1
                print
        print vec
        return vec
    else:
        return np.array(-1)
    

for n in range(len(handDataStruct)):
#     print handDataStruct[n][0:3]
#     print featureToUse
#     print handDataStruct[n][5][:,featureInds]
    v = np.array(len(handDataStruct[n][5]))
    for j in featureToUse:
        vec = formatFeatures2(handDataStruct[n][5], featureSections[j], featureValues[j])
        if(vec[0] !=  -1):
            v = np.hstack((v,vec))
    handDataStruct[n][5] = v
# Out:
# [0, 1]2
# [8]1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-05a61aad0526> in <module>()
#      22     v = np.array(len(handDataStruct[n][5]))
#      23     for j in featureToUse:
# ---> 24         vec = formatFeatures2(handDataStruct[n][5], featureSections[j], featureValues[j])
#      25         if(vec[0] !=  -1):
#      26             v = np.hstack((v,vec))
#
# <ipython-input-50-05a61aad0526> in formatFeatures2(inputArr, idx, valsPossible)
#       8
#       9                 offset = (len(valsPossible)*b)
# ---> 10                 vec[offset + valsPossible.index(inputArr[i][idx[b]])] += 1
#      11                 print
#      12         print vec
#
# IndexError: invalid index to scalar variable.

# %%
#here model trains recognition of object location wrt each other
#feature vector => handDataStruct[5][:,5:8](vector from hand to object) and humanlabel handDataStruct[5][:,9]
#actionsAllowedList = ['lift_object', 'pull_object', 'push_object', 'drop_object',]

for a in range(len(handDataStruct)):
    for r in actionsAllowedList:
        if r in handDataStruct[a][2]:
            labelNum = actionsAllowedList.index(r)

    if(a == 0):
        allPoseY = handDataStruct[a][5]
        allPoseL = labelNum
    else:
        allPoseY = np.vstack((allPoseY, handDataStruct[a][5]))
        allPoseL = np.vstack((allPoseL, labelNum))
        
print allPoseY.shape
print allPoseL.shape
# Out:
# (113, 10)
# (113, 1)

# %%
k = 0
ratio = 70
numItems = 300

for k in range(len(actionsAllowedList)):
    this_label = [i for i in range(allPoseL.shape[0]) if allPoseL[i] == k]
    this_Y = allPoseY[this_label]
    this_L = allPoseL[this_label]
    if(len(this_L)< numItems-1):
        Idx = range(len(this_L))
    else:
        Idx = [ i for i in sorted(random.sample(xrange(len(this_L)),numItems)) ]
        
    if(k == 0):
        staticPoseY = np.asarray([this_Y[i] for i in Idx])
        staticPoseL = np.asarray([this_L[i] for i in Idx])
    else:
        print staticPoseY.shape
        print np.asarray([this_Y[i] for i in Idx]).shape
        staticPoseY = np.vstack((staticPoseY, np.asarray([this_Y[i] for i in Idx])))
        staticPoseL = np.vstack((staticPoseL, np.asarray([this_L[i] for i in Idx])))
        print
        
print len(this_label)
print len(this_Y)
j = np.asarray(this_label)
print j.shape
print this_Y.shape
print this_L.shape
print staticPoseY.shape
print staticPoseL.shape
# Out:
# (11, 10)
# (37, 10)
#
# (48, 10)
# (44, 10)
#
# (92, 10)
# (11, 10)
#
# (103, 10)
# (10, 10)
#
# 10
# 10
# (10,)
# (10, 10)
# (10, 1)
# (113, 10)
# (113, 1)

# %%
staticPoseModel = staticPose.staticPose()
staticPoseModel.readData(0,0,staticPoseY,staticPoseL, actionsAllowedList)

staticPoseModel.Quser = 2
Ntr = int(len(staticPoseModel.L)*ratio/100)
model_type = 'mrd'
model_num_inducing = 100
model_num_iterations = 800 #100
model_init_iterations = 800 #300
save_model=True
economy_save = True
visualise_output=True
experiment_number = 3
fname = '/home/daniel/SAM_Data_Models/Models/objectActions_exp' + str(experiment_number)

[Yall,Lall,YtestAll,LtestAll] = staticPoseModel.prepareData (model_type, Ntr,randSeed=experiment_number)

# %%
staticPoseModel.training(model_num_inducing, model_num_iterations, model_init_iterations, fname, save_model, economy_save, keepIfPresent=False)
# Out:
# WARNING: reconstraining parameters manifold_relevance_determination.Y0.Gaussian_noise.variance
# WARNING: reconstraining parameters manifold_relevance_determination.Y1.Gaussian_noise.variance
# Saving SAMObject: /home/daniel/SAM_Data_Models/Models/objectActions_exp3

# %%
if visualise_output: 
    ax = staticPoseModel.SAMObject.visualise()
    visualiseInfo=dict()
    visualiseInfo['ax']=ax
else:
    visualiseInfo=None

# %%
# curTestData = Yall[][None,:].tolist()
def formatDataFunc(Ydata):
        yDataList = []
        for j in range(Ydata.shape[0]):
            yDataList.append(Ydata[j][None,:])
        return yDataList

def testFunc(data, lab):
    d = staticPoseModel.testing(data, False)
    if(lab == d[0]):
        result = True
    else:
        result = False
    print 'Actual  ' + str(lab).ljust(11) + '  Model:  ' + str(d[0]).ljust(11) + '  with ' + str(d[1])[:6] + ' confidence: ' + str(result) + '\n'
    return d

# %%
def plot_confusion_matrix(cm, targetNames, title='Confusion matrix', cmap=plt.cm.inferno):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(targetNames))
    plt.xticks(tick_marks, targetNames, rotation=45)
    plt.yticks(tick_marks, targetNames)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

import sys
import time
from IPython.display import clear_output

def wait_watching_stdout(ar, dt=1, truncate=1000):
    while not ar.ready():
        stdouts = ar.stdout
        if any(stdouts):
            clear_output()
            print '-' * 30
            print "%.3fs elapsed" % ar.elapsed
            print ""
            for stdout in ar.stdout:
                if stdout:
                    print "\n%s" % (stdout[-truncate:])
            sys.stdout.flush()
        time.sleep(dt)

# %%
c = ipp.Client()
dview = c[:]

with dview.sync_imports():
    from SAM.SAM_Core import staticPose

dview.push({'staticPoseModel':staticPoseModel})
# Out:
# importing staticPose from SAM.SAM_Core on engine(s)
# <AsyncResult: _push>

# %%
ss = []
sstest = []
print
off1 = 11
off2 = 8

# allCount = Yall.shape[0]
# factor = 40
# numItems = int(allCount/factor)
cmSize = len(staticPoseModel.textLabels)
confMatrix = np.zeros((cmSize, cmSize))
numItems = Yall.shape[0]

off3 = len(str(numItems))

print 'estimated time: ' + str(numItems/60) + 'mins for ' + str(numItems) + ' items'
#format training data

yTrainingData = formatDataFunc(Yall)
YsampleIdx = [ i for i in sorted(random.sample(xrange(len(yTrainingData)),numItems)) ]

Ysample = [yTrainingData[i] for i in YsampleIdx]
Lsample = [staticPoseModel.textLabels[int(Lall[i])] for i in YsampleIdx]

# %time syn = dview.map_async(testFunc, Ysample, Lsample)
wait_watching_stdout(syn, dt=1, truncate=1000)
ret = syn.get()
# clear_output()
for i in range(len(ret)):

    currLabel = Lsample[i]

    if(currLabel == ret[i][0]):
        result = True
    else:
        result = False
    print str(i).rjust(off3) + '/' + str(numItems) + ' Truth: ' + currLabel.ljust(off1) + ' Model: ' + ret[i][0].ljust(off1) + ' with ' + str(1-ret[i][1])[:6].ljust(off2) + ' confidence: ' + str(result)
    confMatrix[staticPoseModel.textLabels.index(currLabel),staticPoseModel.textLabels.index(ret[i][0])] += 1
    ss.append(ret[i][0])
# Out:
# ------------------------------
# 19.084s elapsed
#
#
# object  Model:  pull_object  with 0.0005 confidence: False
#
# Actual  lift_object  Model:  pull_object  with 0.0003 confidence: False
#
# Actual  pull_object  Model:  pull_object  with 0.0001 confidence: True
#
# Actual  pull_object  Model:  push_object  with 0.0006 confidence: False
#
# Actual  pull_object  Model:  pull_object  with 0.0001 confidence: True
#
# Actual  pull_object  Model:  pull_object  with 0.0001 confidence: True
#
# Actual  pull_object  Model:  pull_object  with 0.0002 confidence: True
#
# Actual  pull_object  Model:  lift_object  with 0.0008 confidence: False
#
# Actual  pull_object  Model:  pull_object  with 0.0008 confidence: True
#
# Actual  pull_object  Model:  pull_object  with 0.0002 confidence: True
#
# Actual  pull_object  Model:  pull_object  with 0.0001 confidence: True
#
# Actual  pull_object  Model:  pull_object  with 0.0001 confidence: True
#
# Actual  pull_object  Model:  push_object  with 8.4593 confidence: False
#
# Actual  pull_object  Model:  pull_object  with 0.0003 confidence: True
#
#
#
# _object  Model:  pull_object  with 0.0002 confidence: True
#
# Actual  pull_object  Model:  push_object  with 0.0003 confidence: False
#
# Actual  pull_object  Model:  pull_object  with 0.0002 confidence: True
#
# Actual  pull_object  Model:  push_object  with 0.0009 confidence: False
#
# Actual  pull_object  Model:  pull_object  with 0.0004 confidence: True
#
# Actual  pull_object  Model:  pull_object  with 0.0003 confidence: True
#
# Actual  pull_object  Model:  pull_object  with 0.0006 confidence: True
#
# Actual  pull_object  Model:  push_object  with 0.0013 confidence: False
#
# Actual  pull_object  Model:  push_object  with 0.0007 confidence: False
#
# Actual  pull_object  Model:  pull_object  with 0.0002 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0006 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0006 confidence: True
#
# Actual  push_object  Model:  push_object  with 7.7027 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0002 confidence: True
#
#
#
# h_object  Model:  push_object  with 0.0013 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0010 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0004 confidence: True
#
# Actual  push_object  Model:  pull_object  with 0.0002 confidence: False
#
# Actual  push_object  Model:  push_object  with 0.0002 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0007 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0005 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0008 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0001 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0016 confidence: True
#
# Actual  push_object  Model:  carry_object  with 0.0017 confidence: False
#
# Actual  push_object  Model:  push_object  with 0.0009 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0002 confidence: True
#
# Actual  push_object  Model:  push_object  with 0.0006 confidence: True
#
#
#
# :  pull_object  with 0.0003 confidence: False
#
# Actual  push_object  Model:  pull_object  with 0.0002 confidence: False
#
# Actual  drop_object  Model:  drop_object  with 0.0004 confidence: True
#
# Actual  drop_object  Model:  push_object  with 0.0004 confidence: False
#
# Actual  drop_object  Model:  pull_object  with 0.0043 confidence: False
#
# Actual  drop_object  Model:  push_object  with 0.0002 confidence: False
#
# Actual  drop_object  Model:  pull_object  with 0.0007 confidence: False
#
# Actual  drop_object  Model:  drop_object  with 0.0002 confidence: True
#
# Actual  carry_object  Model:  pull_object  with 0.0001 confidence: False
#
# Actual  carry_object  Model:  push_object  with 0.0008 confidence: False
#
# Actual  carry_object  Model:  push_object  with 0.0004 confidence: False
#
# Actual  carry_object  Model:  pull_object  with 0.0003 confidence: False
#
# Actual  carry_object  Model:  push_object  with 0.0002 confidence: False
#
# Actual  carry_object  Model:  push_object  with 0.0006 confidence: False
#
#
#  0/79 Truth: lift_object Model: lift_object with 0.9993   confidence: True
#  1/79 Truth: lift_object Model: push_object with 0.9986   confidence: False
#  2/79 Truth: lift_object Model: pull_object with 0.9994   confidence: False
#  3/79 Truth: lift_object Model: lift_object with 0.9992   confidence: True
#  4/79 Truth: lift_object Model: pull_object with 0.9994   confidence: False
#  5/79 Truth: lift_object Model: pull_object with 0.9996   confidence: False
#  6/79 Truth: pull_object Model: pull_object with 0.9998   confidence: True
#  7/79 Truth: pull_object Model: push_object with 0.9993   confidence: False
#  8/79 Truth: pull_object Model: pull_object with 0.9998   confidence: True
#  9/79 Truth: pull_object Model: pull_object with 0.9998   confidence: True
# 10/79 Truth: pull_object Model: pull_object with 0.9997   confidence: True
# 11/79 Truth: pull_object Model: lift_object with 0.9991   confidence: False
# 12/79 Truth: pull_object Model: pull_object with 0.9991   confidence: True
# 13/79 Truth: pull_object Model: pull_object with 0.9997   confidence: True
# 14/79 Truth: pull_object Model: pull_object with 0.9998   confidence: True
# 15/79 Truth: pull_object Model: pull_object with 0.9998   confidence: True
# 16/79 Truth: pull_object Model: push_object with 0.9999   confidence: False
# 17/79 Truth: pull_object Model: pull_object with 0.9996   confidence: True
# 18/79 Truth: pull_object Model: carry_object with 0.9994   confidence: False
# 19/79 Truth: pull_object Model: pull_object with 0.9997   confidence: True
# 20/79 Truth: pull_object Model: pull_object with 0.9998   confidence: True
# 21/79 Truth: pull_object Model: pull_object with 0.9996   confidence: True
# 22/79 Truth: pull_object Model: pull_object with 0.9996   confidence: True
# 23/79 Truth: pull_object Model: pull_object with 0.9997   confidence: True
# 24/79 Truth: pull_object Model: pull_object with 0.9997   confidence: True
# 25/79 Truth: pull_object Model: push_object with 0.9996   confidence: False
# 26/79 Truth: pull_object Model: pull_object with 0.9997   confidence: True
# 27/79 Truth: pull_object Model: push_object with 0.9990   confidence: False
# 28/79 Truth: pull_object Model: pull_object with 0.9995   confidence: True
# 29/79 Truth: pull_object Model: pull_object with 0.9996   confidence: True
# 30/79 Truth: pull_object Model: pull_object with 0.9993   confidence: True
# 31/79 Truth: pull_object Model: push_object with 0.9986   confidence: False
# 32/79 Truth: pull_object Model: push_object with 0.9992   confidence: False
# 33/79 Truth: pull_object Model: pull_object with 0.9997   confidence: True
# 34/79 Truth: push_object Model: push_object with 0.9993   confidence: True
# 35/79 Truth: push_object Model: push_object with 0.9993   confidence: True
# 36/79 Truth: push_object Model: push_object with 0.9999   confidence: True
# 37/79 Truth: push_object Model: push_object with 0.9997   confidence: True
# 38/79 Truth: push_object Model: carry_object with 0.9996   confidence: False
# 39/79 Truth: push_object Model: pull_object with 0.9996   confidence: False
# 40/79 Truth: push_object Model: pull_object with 0.9995   confidence: False
# 41/79 Truth: push_object Model: push_object with 0.9996   confidence: True
# 42/79 Truth: push_object Model: push_object with 0.9992   confidence: True
# 43/79 Truth: push_object Model: push_object with 0.9996   confidence: True
# 44/79 Truth: push_object Model: push_object with 0.9987   confidence: True
# 45/79 Truth: push_object Model: drop_object with 0.9776   confidence: False
# 46/79 Truth: push_object Model: push_object with 0.9986   confidence: True
# 47/79 Truth: push_object Model: push_object with 0.9989   confidence: True
# 48/79 Truth: push_object Model: push_object with 0.9995   confidence: True
# 49/79 Truth: push_object Model: pull_object with 0.9997   confidence: False
# 50/79 Truth: push_object Model: push_object with 0.9997   confidence: True
# 51/79 Truth: push_object Model: push_object with 0.9992   confidence: True
# 52/79 Truth: push_object Model: push_object with 0.9994   confidence: True
# 53/79 Truth: push_object Model: push_object with 0.9991   confidence: True
# 54/79 Truth: push_object Model: push_object with 0.9998   confidence: True
# 55/79 Truth: push_object Model: push_object with 0.9983   confidence: True
# 56/79 Truth: push_object Model: carry_object with 0.9982   confidence: False
# 57/79 Truth: push_object Model: push_object with 0.9990   confidence: True
# 58/79 Truth: push_object Model: push_object with 0.9997   confidence: True
# 59/79 Truth: push_object Model: push_object with 0.9993   confidence: True
# 60/79 Truth: push_object Model: pull_object with 0.9996   confidence: False
# 61/79 Truth: push_object Model: pull_object with 0.9982   confidence: False
# 62/79 Truth: push_object Model: push_object with 0.9993   confidence: True
# 63/79 Truth: push_object Model: push_object with 0.9986   confidence: True
# 64/79 Truth: push_object Model: push_object with 0.9998   confidence: True
# 65/79 Truth: push_object Model: pull_object with 0.9996   confidence: False
# 66/79 Truth: push_object Model: pull_object with 0.9997   confidence: False
# 67/79 Truth: drop_object Model: drop_object with 0.9995   confidence: True
# 68/79 Truth: drop_object Model: push_object with 0.9995   confidence: False
# 69/79 Truth: drop_object Model: pull_object with 0.9956   confidence: False
# 70/79 Truth: drop_object Model: push_object with 0.9997   confidence: False
# 71/79 Truth: drop_object Model: pull_object with 0.9992   confidence: False
# 72/79 Truth: drop_object Model: drop_object with 0.9997   confidence: True
# 73/79 Truth: carry_object Model: pull_object with 0.9998   confidence: False
# 74/79 Truth: carry_object Model: push_object with 0.9991   confidence: False
# 75/79 Truth: carry_object Model: push_object with 0.9995   confidence: False
# 76/79 Truth: carry_object Model: pull_object with 0.9996   confidence: False
# 77/79 Truth: carry_object Model: push_object with 0.9997   confidence: False
# 78/79 Truth: carry_object Model: push_object with 0.9993   confidence: False

# %%
confMatLabels = copy.deepcopy(staticPoseModel.textLabels)
confMatLabels.sort()

from sklearn.metrics import confusion_matrix
h = confusion_matrix(Lsample, ss)
total = h.astype(np.float).sum(axis=1)
normConf = copy.deepcopy(h)
normConf = normConf.astype(np.float)

for l in range(h.shape[0]):
    normConf[l,:] = normConf[l,:].astype(np.float)*100/total[l].astype(np.float)

print normConf

plot_confusion_matrix(normConf, confMatLabels)
# Out:
# [[  0.           0.           0.          33.33333333  66.66666667]
#  [  0.          33.33333333   0.          33.33333333  33.33333333]
#  [  0.           0.          33.33333333  50.          16.66666667]
#  [  3.57142857   0.           3.57142857  71.42857143  21.42857143]
#  [  6.06060606   3.03030303   0.          21.21212121  69.6969697 ]]

# %%
percCorect = 100*np.diag(h.astype(np.float)).sum()/numItems

print str(percCorect)[:5].ljust(7) + "% correct for training data"
print
for i in range(cmSize):
    for j in range(cmSize):
        print str(normConf[i,j])[:5].ljust(7) + '% of ' + str(staticPoseModel.textLabels[i]) + ' classified as ' + str(staticPoseModel.textLabels[j])
    print

print
# Out:
# 59.49  % correct for training data
#
# 0.0    % of lift_object classified as lift_object
# 0.0    % of lift_object classified as pull_object
# 0.0    % of lift_object classified as push_object
# 33.33  % of lift_object classified as drop_object
# 66.66  % of lift_object classified as carry_object
#
# 0.0    % of pull_object classified as lift_object
# 33.33  % of pull_object classified as pull_object
# 0.0    % of pull_object classified as push_object
# 33.33  % of pull_object classified as drop_object
# 33.33  % of pull_object classified as carry_object
#
# 0.0    % of push_object classified as lift_object
# 0.0    % of push_object classified as pull_object
# 33.33  % of push_object classified as push_object
# 50.0   % of push_object classified as drop_object
# 16.66  % of push_object classified as carry_object
#
# 3.571  % of drop_object classified as lift_object
# 0.0    % of drop_object classified as pull_object
# 3.571  % of drop_object classified as push_object
# 71.42  % of drop_object classified as drop_object
# 21.42  % of drop_object classified as carry_object
#
# 6.060  % of carry_object classified as lift_object
# 3.030  % of carry_object classified as pull_object
# 0.0    % of carry_object classified as push_object
# 21.21  % of carry_object classified as drop_object
# 69.69  % of carry_object classified as carry_object

# %%
# allCount = Yall.shape[0]
# factor = 40
# numItems = int(allCount/factor)
cmSize = len(staticPoseModel.textLabels)
confMatrixTest = np.zeros((cmSize, cmSize))
numItems = YtestAll.shape[0]

off3 = len(str(numItems))

print 'estimated time: ' + str(numItems/60) + 'mins for ' + str(numItems) + ' items'
#format training data

yTrainingData = formatDataFunc(YtestAll)
YsampleIdx = [ i for i in sorted(random.sample(xrange(len(yTrainingData)),numItems)) ]

Ysample = [yTrainingData[i] for i in YsampleIdx]
Lsample = [staticPoseModel.textLabels[int(LtestAll[i])] for i in YsampleIdx]

# %time syn = dview.map_async(testFunc, Ysample, Lsample)
wait_watching_stdout(syn, dt=1, truncate=1000)
ret = syn.get()
clear_output()
for i in range(len(ret)):

    currLabel = Lsample[i]

    if(currLabel == ret[i][0]):
        result = True
    else:
        result = False
    print str(i).rjust(off3) + '/' + str(numItems) + ' Truth: ' + currLabel.ljust(off1) + ' Model: ' + ret[i][0].ljust(off1) + ' with ' + str(1-ret[i][1])[:6].ljust(off2) + ' confidence: ' + str(result)
    sstest.append(ret[i][0])
# Out:
#  0/34 Truth: lift_object Model: pull_object with 0.9996   confidence: False
#  1/34 Truth: lift_object Model: carry_object with 0.9990   confidence: False
#  2/34 Truth: lift_object Model: pull_object with 0.9990   confidence: False
#  3/34 Truth: lift_object Model: carry_object with 0.9983   confidence: False
#  4/34 Truth: lift_object Model: pull_object with 0.9994   confidence: False
#  5/34 Truth: pull_object Model: push_object with 0.9996   confidence: False
#  6/34 Truth: pull_object Model: push_object with 0.9996   confidence: False
#  7/34 Truth: pull_object Model: push_object with 0.9997   confidence: False
#  8/34 Truth: pull_object Model: push_object with 0.9997   confidence: False
#  9/34 Truth: pull_object Model: push_object with 0.9998   confidence: False
# 10/34 Truth: pull_object Model: push_object with 0.9995   confidence: False
# 11/34 Truth: pull_object Model: pull_object with 0.9999   confidence: True
# 12/34 Truth: pull_object Model: pull_object with 0.9997   confidence: True
# 13/34 Truth: pull_object Model: drop_object with 0.9776   confidence: False
# 14/34 Truth: push_object Model: push_object with 0.9997   confidence: True
# 15/34 Truth: push_object Model: push_object with 0.9998   confidence: True
# 16/34 Truth: push_object Model: pull_object with 0.9997   confidence: False
# 17/34 Truth: push_object Model: push_object with 0.9999   confidence: True
# 18/34 Truth: push_object Model: push_object with 0.9987   confidence: True
# 19/34 Truth: push_object Model: push_object with 0.9990   confidence: True
# 20/34 Truth: push_object Model: push_object with 0.9996   confidence: True
# 21/34 Truth: push_object Model: push_object with 0.9990   confidence: True
# 22/34 Truth: push_object Model: carry_object with 0.9991   confidence: False
# 23/34 Truth: push_object Model: carry_object with 0.9990   confidence: False
# 24/34 Truth: push_object Model: push_object with 0.9994   confidence: True
# 25/34 Truth: drop_object Model: drop_object with 0.9994   confidence: True
# 26/34 Truth: drop_object Model: push_object with 0.9994   confidence: False
# 27/34 Truth: drop_object Model: push_object with 0.9985   confidence: False
# 28/34 Truth: drop_object Model: drop_object with 0.9993   confidence: True
# 29/34 Truth: drop_object Model: push_object with 0.9994   confidence: False
# 30/34 Truth: carry_object Model: drop_object with 0.9776   confidence: False
# 31/34 Truth: carry_object Model: push_object with 0.9989   confidence: False
# 32/34 Truth: carry_object Model: push_object with 0.9996   confidence: False
# 33/34 Truth: carry_object Model: push_object with 0.9998   confidence: False

# %%
from sklearn.metrics import confusion_matrix
confMatrixTest = confusion_matrix(Lsample, sstest)
total = confMatrixTest.astype(np.float).sum(axis=1)
normConfTest = copy.deepcopy(confMatrixTest)
normConfTest = normConfTest.astype(np.float)

for l in range(confMatrixTest.shape[0]):
    normConfTest[l,:] = normConfTest[l,:].astype(np.float)*100/total[l].astype(np.float)

print normConfTest

plot_confusion_matrix(normConfTest, confMatLabels)
# Out:
# [[  0.          25.           0.           0.          75.        ]
#  [  0.          40.           0.           0.          60.        ]
#  [ 40.           0.           0.          60.           0.        ]
#  [  0.          11.11111111   0.          22.22222222  66.66666667]
#  [ 18.18181818   0.           0.           9.09090909  72.72727273]]

# %%
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix

percCorect = 100*np.diag(confMatrixTest.astype(np.float)).sum()/numItems 

print str(percCorect)[:5].ljust(7) + "% correct for testing data"
print
for i in range(cmSize):
    for j in range(cmSize):
        print str(normConfTest[i,j])[:5].ljust(7)  + '% of ' + str(staticPoseModel.textLabels[i]) + ' classified as ' + str(staticPoseModel.textLabels[j])
    print

print
# Out:
# 35.29  % correct for testing data
#
# 0.0    % of lift_object classified as lift_object
# 25.0   % of lift_object classified as pull_object
# 0.0    % of lift_object classified as push_object
# 0.0    % of lift_object classified as drop_object
# 75.0   % of lift_object classified as carry_object
#
# 0.0    % of pull_object classified as lift_object
# 40.0   % of pull_object classified as pull_object
# 0.0    % of pull_object classified as push_object
# 0.0    % of pull_object classified as drop_object
# 60.0   % of pull_object classified as carry_object
#
# 40.0   % of push_object classified as lift_object
# 0.0    % of push_object classified as pull_object
# 0.0    % of push_object classified as push_object
# 60.0   % of push_object classified as drop_object
# 0.0    % of push_object classified as carry_object
#
# 0.0    % of drop_object classified as lift_object
# 11.11  % of drop_object classified as pull_object
# 0.0    % of drop_object classified as push_object
# 22.22  % of drop_object classified as drop_object
# 66.66  % of drop_object classified as carry_object
#
# 18.18  % of carry_object classified as lift_object
# 0.0    % of carry_object classified as pull_object
# 0.0    % of carry_object classified as push_object
# 9.090  % of carry_object classified as drop_object
# 72.72  % of carry_object classified as carry_object
