# %%
jointMu = 0.2
jointSig = 0.5

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import readline
import GPy
from SAM.SAM_Core import SAMCore
from SAM.SAM_Core import SAMDriver
import pylab as pb
import sys 
from sys import executable
import subprocess
from subprocess import Popen, PIPE
import pickle
import os
from os import listdir, walk, system
from os.path import isfile, join, isdir
import time
import operator
import numpy
import numpy as np
import numpy.ma as ma
import datetime
import yarp
import copy
from itertools import combinations 
from ConfigParser import SafeConfigParser
from scipy.spatial import distance
from numpy.linalg import inv
import math
import ipyparallel as ipp
import random
from SAM.SAM_Core import staticPose

dataSetFolder = '/home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset'
dataFolderList = ['lift-drop-right_arm', 
                  'lift-drop-left_arm', 
                  'push-pull-left_arm', 
                  'push-pull-right_arm']

dataFolders = []
labelFolders = []
#check folders in list actually exist
for j in dataFolderList:
    t = join(dataSetFolder,j,'data')
    m = join(dataSetFolder,j,'labels')
    if(isdir(t) and isdir(m)):
        dataFolders.append(t)
        labelFolders.append(m)
print '\n'.join(dataFolders)
print
print '\n'.join(labelFolders)
#subDirFolderList = ['camera/left', 'camera/right', 'data', 'kinect/rgb', 'labels']
# Out:
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset/lift-drop-right_arm/data
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset/lift-drop-left_arm/data
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset/push-pull-left_arm/data
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset/push-pull-right_arm/data
#
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset/lift-drop-right_arm/labels
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset/lift-drop-left_arm/labels
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset/push-pull-left_arm/labels
# /home/daniel/WYSIWYD_PROJECT/actionRecognitionDataset/push-pull-right_arm/labels

# %%
def distEuc(a,b):
    temp = a-b
    temp = np.square(temp)
    temp = np.sum(temp,1)
    return np.sqrt(temp)

def qtc_2D(k,l,q,thresh):
    
    d1 = distEuc(k[:-2],l[1:-1])
    d2 = distEuc(k[1:-1],l[1:-1])
    d3 = distEuc(k[2:],l[1:-1])
    
    for i in range(len(d1)):
        #threshold distance moved
        diff1 = d2[i]-d1[i]
        if(np.abs(diff1) < thresh):
            diff1 = 0

        diff2 = d3[i]-d2[i]
        if(np.abs(diff2) < thresh):
            diff2 = 0

        #convert to qtc
        if(diff1 > 0 and diff2 > 0):
            q[i] = -1
        elif(diff1 < 0 and diff2 < 0):
            q[i] = +1
        else:
            q[i] = 0
    
    return d2

def frenetFrame(arr):
    t_num = np.diff(arr,axis=0)
    t = (t_num/np.abs(t_num)).astype(int)

    b_num = np.cross(t[:-1],t[1:])
    b = b_num/np.abs(b_num)
    t = t[1:]

    n = np.cross(b,t)

    frameArr = np.concatenate((t,n,b),axis=1).T
    fArr = frameArr.reshape((3,3,-1),order = 'F')
    return fArr

def qtc_3D(k, l, thresh, q3, q4, q5):
    fFrameK = frenetFrame(k)
    fFrameL = frenetFrame(l)
    alpArr = np.zeros(q3.shape)
    betArr = np.zeros(q3.shape)
    gamArr = np.zeros(q3.shape)
    
    for g in range(fFrameK.shape[2]):
        fKinv = np.linalg.pinv(fFrameK[:,:,g])
        R = np.dot(fFrameL[:,:,g],fKinv)
        
        alpha = np.arctan(R[1,0]/R[0,0])
        den = np.sqrt(pow(R[2,1],2) + pow(R[2,2],2))
        
        beta = np.arctan(-R[2,0]/den)
        gamma = np.arctan(R[2,1]/R[2,2])

        #threshold angles
        if(np.abs(alpha) < thresh or math.isnan(alpha)):
            alpha = 0
        if(np.abs(beta) < thresh or math.isnan(beta)):
            beta = 0
        if(np.abs(gamma) < thresh or math.isnan(gamma)):
            gamma = 0
        alpArr[g] = alpha
        betArr[g] = beta
        gamArr[g] = gamma
        
        q3[g] = np.sign(alpha)
        q4[g] = np.sign(beta)
        q5[g] = np.sign(gamma)
    
    return [alpArr,betArr,gamArr]
            
def checkQTC(qtcArr):
    #array of shape x by 11 with 0 to 4 of 11 being the ones that unique must apply to
    tArr = copy.deepcopy(qtcArr)
    for i in range(1,tArr.shape[0]):
        if(i != 0):
            currRow = tArr[i,:]
            Mod = False
            for q in range(tArr.shape[1]):
                r = tArr[i,q] - tArr[i-1,q]
                if(r == -2 or r == 2):
                    Mod = True
                    currRow[q] = 0
            if(Mod):    
                qtcArr = np.insert(qtcArr,i,currRow,axis=0)    
                Mod = False
    return qtcArr

def uniqueQTC(currQTC):
    #array of shape x by 11 with 0 to 4 of 11 being the ones that unique must apply to
    i = 0
    del1 = False
    del2 = False
    
    while(i < currQTC.shape[0]-2):
        if(i!=0):
            if(np.array_equal(currQTC[i,:5],currQTC[i-1,:5])):
                del1 = True
            if(np.array_equal(currQTC[i+1,:5],currQTC[i-1,:5])):
                del2 = True
        
        if(del1 and not del2):
            currQTC = np.delete(currQTC,i,0)
        elif(del2):
            currQTC = np.delete(currQTC,i,0)
            currQTC = np.delete(currQTC,i+1,0)
            
        i+=1
    return currQTC

# %%
#load kinect skeleton data for all folders in dataFolderList
numJoints = 9
data = dict()
firstPass = True
jointsList = []
objectsList = []
labelsList = []
numFolders = len(dataFolders)

for j in dataFolders:
    k = dataFolders.index(j)
    dataFile = open(join(dataFolders[k],'data.log'),'r')
    labelFile = open(join(labelFolders[k],'data.log'),'r')
    
    #number of lines in dataFile
    for i, l in enumerate(dataFile):
            pass
    lenDataFile = i+1
    
    #number of lines in labelFile
    for i, l in enumerate(labelFile):
            pass
    lenLabelFile = i+1
    dataFile.close()
    labelFile.close()
    
    
    if(lenLabelFile != lenDataFile):
        raise ValueError('Files not of same lenght')
    else:
        dataFile = open(join(dataFolders[k],'data.log'),'r')
        labelFile = open(join(labelFolders[k],'data.log'),'r')
        labelsList.append([])
        
        for curr in range(lenDataFile):
            line = dataFile.readline()
            labelLine = labelFile.readline()
            
            t = line.replace('(','').replace(')','').split(' ')
            del t[0:4]
           
            v = labelLine.split(' ')[2].replace('\n','').replace('(','').replace(')','')
            if(v == ''):
                v = 'unknown'
            labelsList[k].append(v)
            
            #parse skeleton data which has 9 sections by (x,y,z)
            for i in range(numJoints):
                a = i*4
                if(t[a] == 'shoulderCenter'):
                    t[a] = 'chest'
                
                if(firstPass):
                    data[t[a]] = [None]*numFolders
                    data[t[a]][k] = (np.array([float(t[a+1]), float(t[a+2]), float(t[a+3])]))
                    jointsList.append(t[a])
                else:
                    arr =  np.array([float(t[a+1]), float(t[a+2]), float(t[a+3])])
                    if(data[t[a]][k] != None):
                        data[t[a]][k] = np.vstack((data[t[a]][k],arr))
                    else:
                        data[t[a]][k] = arr

            currIdx = (numJoints*4 -1)
            numObjs = (len(t) - currIdx)/5

            for i in range(numObjs):
                a = currIdx + 1 + (i*5)
                if(t[a] in data):
                    arr = np.array([float(t[a+1]), float(t[a+2]), float(t[a+3])])
                    if(data[t[a]][k] != None):
                        data[t[a]][k] =  np.vstack((data[t[a]][k],arr))
                    else:
                        data[t[a]][k] = arr
                else:
                    data[t[a]] = [None]*(numFolders)
                    data[t[a]][k] = np.array([float(t[a+1]), float(t[a+2]), float(t[a+3])])
                    objectsList.append(t[a])

            firstPass = False
            
        dataFile.close()
        labelFile.close()
# Out:
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:59: FutureWarning:comparison to `None` will result in an elementwise object comparison in the future.
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:71: FutureWarning:comparison to `None` will result in an elementwise object comparison in the future.

# %%
print 'data has length = ' + str(len(data)) + ' joints'
strl =  'each joint has ' + str(len(data['head'])) + ' arrays of shape: '

for i in data['head']:
    strl += str(i.shape) + ', '
print strl

strl = 'labelsList has length = ' + str(len(labelsList)) + ' with sizes: '
for i in labelsList:
    strl += str(len(i)) + ', '
print strl
# Out:
# data has length = 12 joints
# each joint has 4 arrays of shape: (4637, 3), (4907, 3), (5914, 3), (5440, 3),
# labelsList has length = 4 with sizes: 4637, 4907, 5914, 5440,

# %%
#compile a list of all unique labels
setList = []
for x in labelsList:
    setList.append(list(set(x)))
flattenedList = [val for sublist in setList for val in sublist]
labels = list(set(flattenedList))
labels.sort()
for k in range(0,len(labels)):
    print str(k) + '  ' + labels[k]
# Out:
# 0  agent_entry
# 1  agent_exit
# 2  arms_lowered
# 3  arms_raised
# 4  carry_object_car
# 5  drop_object_car
# 6  dropping_arms
# 7  lift_object_car
# 8  no_agent
# 9  pull_object_car
# 10  pull_object_octopus
# 11  push_object_car
# 12  push_object_octopus
# 13  raising_arms
# 14  reach_object_car
# 15  reach_object_octopus
# 16  retract_hand
# 17  touch_octopus
# 18  unknown

# %%
dataStruct = []
verbose = True
for joint in jointsList+objectsList:
        for arr in range(len(data[joint])):
            for label in labels:
                if(verbose):
                    print
                    print 'current joint: ' + str(joint)
                    print 'curent label: ' + str(label)
                    print 'current dataset = ' + str(dataFolderList[arr])
                    print
                idxs = [i for i in range(len(labelsList[arr])) if labelsList[arr][i] == label]
                actionBlocks = []
                startIdx = 0
                for idxIndex in range(len(idxs)):
                    if(idxIndex != 0):
                        if(idxs[idxIndex] - idxs[idxIndex-1] != 1):
                            endIdx = idxIndex-1
                            actionData = data[joint][arr][startIdx:endIdx+1]
                            dataStruct.append([joint, label, arr, actionData.shape[0], actionData])
                            if(verbose):
                                print '[%s]' % ', '.join(map(str, dataStruct[-1][:-1]))
                            startIdx = idxIndex-1
                            #include end of previous acion as start of next action
                            #this is boundary idxIndex is start of next action and idxIndex-1 is end of previous action
                        if(idxIndex+2 > len(idxs)):
                            endIdx = idxIndex
                            actionData = data[joint][arr][startIdx:endIdx+1]
                            dataStruct.append([joint, label, arr, actionData.shape[0], actionData])
                            if(verbose):
                                print '[%s]' % ', '.join(map(str, dataStruct[-1][:-1]))
# Out:
# current joint: elbowLeft
# curent label: agent_entry
# current dataset = lift-drop-right_arm
#
# [elbowLeft, agent_entry, 0, 52]
#
# current joint: elbowLeft
# curent label: agent_exit
# current dataset = lift-drop-right_arm
#
# [elbowLeft, agent_exit, 0, 73]
#
# current joint: elbowLeft
# curent label: arms_lowered
# current dataset = lift-drop-right_arm
#
# [elbowLeft, arms_lowered, 0, 31]
# [elbowLeft, arms_lowered, 0, 18]
# [elbowLeft, arms_lowered, 0, 30]
# [elbowLeft, arms_lowered, 0, 50]
# [elbowLeft, arms_lowered, 0, 25]
# [elbowLeft, arms_lowered, 0, 35]
# [elbowLeft, arms_lowered, 0, 57]
# [elbowLeft, arms_lowered, 0, 21]
# [elbowLeft, arms_lowered, 0, 77]
# [elbowLeft, arms_lowered, 0, 52]
# [elbowLeft, arms_lowered, 0, 56]
# [elbowLeft, arms_lowered, 0, 18]
# [elbowLeft, arms_lowered, 0, 33]
# [elbowLeft, arms_lowered, 0, 41]
# [elbowLeft, arms_lowered, 0, 66]
# [elbowLeft, arms_lowered, 0, 38]
# [elbowLeft, arms_lowered, 0, 149]
# [elbowLeft, arms_lowered, 0, 93]
# [elbowLeft, arms_lowered, 0, 34]
# [elbowLeft, arms_lowered, 0, 38]
# [elbowLeft, arms_lowered, 0, 47]
# [elbowLeft, arms_lowered, 0, 42]
# [elbowLeft, arms_lowered, 0, 57]
# [elbowLeft, arms_lowered, 0, 27]
#
# current joint: elbowLeft
# curent label: arms_raised
# current dataset = lift-drop-right_arm
#
# [elbowLeft, arms_raised, 0, 129]
# [elbowLeft, arms_raised, 0, 57]
#
# current joint: elbowLeft
# curent label: carry_object_car
# current dataset = lift-drop-right_arm
#
# [elbowLeft, carry_object_car, 0, 43]
# [elbowLeft, carry_object_car, 0, 31]
# [elbowLeft, carry_object_car, 0, 46]
# [elbowLeft, carry_object_car, 0, 41]
# [elbowLeft, carry_object_car, 0, 32]
# [elbowLeft, carry_object_car, 0, 28]
# [elbowLeft, carry_object_car, 0, 35]
# [elbowLeft, carry_object_car, 0, 39]
# [elbowLeft, carry_object_car, 0, 74]
# [elbowLeft, carry_object_car, 0, 40]
# [elbowLeft, carry_object_car, 0, 34]
# [elbowLeft, carry_object_car, 0, 31]
# [elbowLeft, carry_object_car, 0, 52]
# [elbowLeft, carry_object_car, 0, 26]
# [elbowLeft, carry_object_car, 0, 56]
# [elbowLeft, carry_object_car, 0, 36]
# [elbowLeft, carry_object_car, 0, 24]
# [elbowLeft, carry_object_car, 0, 28]
# [elbowLeft, carry_object_car, 0, 34]
# [elbowLeft, carry_object_car, 0, 35]
#
# current joint: elbowLeft
# curent label: drop_object_car
# current dataset = lift-drop-right_arm
#
# [elbowLeft, drop_object_car, 0, 22]
# [elbowLeft, drop_object_car, 0, 14]
# [elbowLeft, drop_object_car, 0, 32]
# [elbowLeft, drop_object_car, 0, 20]
# [elbowLeft, drop_object_car, 0, 30]
# [elbowLeft, drop_object_car, 0, 20]
# [elbowLeft, drop_object_car, 0, 30]
# [elbowLeft, drop_object_car, 0, 22]
# [elbowLeft, drop_object_car, 0, 21]
# [elbowLeft, drop_object_car, 0, 30]
# [elbowLeft, drop_object_car, 0, 30]
# [elbowLeft, drop_object_car, 0, 19]
# [elbowLeft, drop_object_car, 0, 29]
# [elbowLeft, drop_object_car, 0, 34]
# [elbowLeft, drop_object_car, 0, 17]
# [elbowLeft, drop_object_car, 0, 15]
# [elbowLeft, drop_object_car, 0, 18]
# [elbowLeft, drop_object_car, 0, 23]
# [elbowLeft, drop_object_car, 0, 20]
# [elbowLeft, drop_object_car, 0, 24]
#
# current joint: elbowLeft
# curent label: dropping_arms
# current dataset = lift-drop-right_arm
#
# [elbowLeft, dropping_arms, 0, 28]
# [elbowLeft, dropping_arms, 0, 16]
# [elbowLeft, dropping_arms, 0, 17]
# [elbowLeft, dropping_arms, 0, 26]
#
# current joint: elbowLeft
# curent label: lift_object_car
# current dataset = lift-drop-right_arm
#
# [elbowLeft, lift_object_car, 0, 16]
# [elbowLeft, lift_object_car, 0, 30]
# [elbowLeft, lift_object_car, 0, 25]
# [elbowLeft, lift_object_car, 0, 26]
# [elbowLeft, lift_object_car, 0, 29]
# [elbowLeft, lift_object_car, 0, 32]
# [elbowLeft, lift_object_car, 0, 25]
# [elbowLeft, lift_object_car, 0, 26]
# [elbowLeft, lift_object_car, 0, 24]
# [elbowLeft, lift_object_car, 0, 31]
# [elbowLeft, lift_object_car, 0, 36]
# [elbowLeft, lift_object_car, 0, 21]
# [elbowLeft, lift_object_car, 0, 33]
# [elbowLeft, lift_object_car, 0, 25]
# [elbowLeft, lift_object_car, 0, 25]
# [elbowLeft, lift_object_car, 0, 24]
# [elbowLeft, lift_object_car, 0, 24]
# [elbowLeft, lift_object_car, 0, 29]
# [elbowLeft, lift_object_car, 0, 31]
# [elbowLeft, lift_object_car, 0, 25]
#
# current joint: elbowLeft
# curent label: no_agent
# current dataset = lift-drop-right_arm
#
# [elbowLeft, no_agent, 0, 69]
# [elbowLeft, no_agent, 0, 89]
#
# current joint: elbowLeft
# curent label: pull_object_car
# current dataset = lift-drop-right_arm
#
# [elbowLeft, pull_object_car, 0, 11]
#
# current joint: elbowLeft
# curent label: pull_object_octopus
# current dataset = lift-drop-right_arm
#
#
# current joint: elbowLeft
# curent label: push_object_car
# current dataset = lift-drop-right_arm
#
# [elbowLeft, push_object_car, 0, 12]
# [elbowLeft, push_object_car, 0, 23]
# [elbowLeft, push_object_car, 0, 17]
#
# current joint: elbowLeft
# curent label: push_object_octopus
# current dataset = lift-drop-right_arm
#
#
# current joint: elbowLeft
# curent label: raising_arms
# current dataset = lift-drop-right_arm
#
# [elbowLeft, raising_arms, 0, 31]
# [elbowLeft, raising_arms, 0, 11]
# [elbowLeft, raising_arms, 0, 20]
# [elbowLeft, raising_arms, 0, 33]
#
# current joint: elbowLeft
# curent label: reach_object_car
# current dataset = lift-drop-right_arm
#
# [elbowLeft, reach_object_car, 0, 18]
# [elbowLeft, reach_object_car, 0, 32]
# [elbowLeft, reach_object_car, 0, 37]
# [elbowLeft, reach_object_car, 0, 32]
# [elbowLeft, reach_object_car, 0, 26]
# [elbowLeft, reach_object_car, 0, 18]
# [elbowLeft, reach_object_car, 0, 15]
# [elbowLeft, reach_object_car, 0, 23]
# [elbowLeft, reach_object_car, 0, 19]
# [elbowLeft, reach_object_car, 0, 26]
# [elbowLeft, reach_object_car, 0, 31]
# [elbowLeft, reach_object_car, 0, 18]
# [elbowLeft, reach_object_car, 0, 19]
# [elbowLeft, reach_object_car, 0, 35]
# [elbowLeft, reach_object_car, 0, 17]
# [elbowLeft, reach_object_car, 0, 17]
# [elbowLeft, reach_object_car, 0, 33]
# [elbowLeft, reach_object_car, 0, 20]
# [elbowLeft, reach_object_car, 0, 19]
# [elbowLeft, reach_object_car, 0, 33]
# [elbowLeft, reach_object_car, 0, 17]
# [elbowLeft, reach_object_car, 0, 16]
# [elbowLeft, reach_object_car, 0, 23]
# [elbowLeft, reach_object_car, 0, 25]
#
# current joint: elbowLeft
# curent label: reach_object_octopus
# current dataset = lift-drop-right_arm
#
#
# current joint: elbowLeft
# curent label: retract_hand
# current dataset = lift-drop-right_arm
#
# [elbowLeft, retract_hand, 0, 20]
# [elbowLeft, retract_hand, 0, 24]
# [elbowLeft, retract_hand, 0, 16]
# [elbowLeft, retract_hand, 0, 31]
# [elbowLeft, retract_hand, 0, 18]
# [elbowLeft, retract_hand, 0, 17]
# [elbowLeft, retract_hand, 0, 19]
# [elbowLeft, retract_hand, 0, 23]
# [elbowLeft, retract_hand, 0, 31]
# [elbowLeft, retract_hand, 0, 18]
# [elbowLeft, retract_hand, 0, 27]
# [elbowLeft, retract_hand, 0, 25]
# [elbowLeft, retract_hand, 0, 22]
# [elbowLeft, retract_hand, 0, 24]
# [elbowLeft, retract_hand, 0, 24]
# [elbowLeft, retract_hand, 0, 24]
# [elbowLeft, retract_hand, 0, 21]
# [elbowLeft, retract_hand, 0, 19]
# [elbowLeft, retract_hand, 0, 28]
# [elbowLeft, retract_hand, 0, 13]
# [elbowLeft, retract_hand, 0, 18]
# [elbowLeft, retract_hand, 0, 20]
# [elbowLeft, retract_hand, 0, 22]
# [elbowLeft, retract_hand, 0, 39]
# [elbowLeft, retract_hand, 0, 14]
# [elbowLeft, retract_hand, 0, 18]
#
# current joint: elbowLeft
# curent label: touch_octopus
# current dataset = lift-drop-right_arm
#
#
# current joint: elbowLeft
# curent label: unknown
# current dataset = lift-drop-right_arm
#
# [elbowLeft, unknown, 0, 10]
#
# current joint: elbowLeft
# curent label: agent_entry
# current dataset = lift-drop-left_arm
#
# [elbowLeft, agent_entry, 1, 64]
#
# current joint: elbowLeft
# curent label: agent_exit
# current dataset = lift-drop-left_arm
#
# [elbowLeft, agent_exit, 1, 58]
#
# current joint: elbowLeft
# curent label: arms_lowered
# current dataset = lift-drop-left_arm
#
# [elbowLeft, arms_lowered, 1, 21]
# [elbowLeft, arms_lowered, 1, 32]
# [elbowLeft, arms_lowered, 1, 53]
# [elbowLeft, arms_lowered, 1, 33]
# [elbowLeft, arms_lowered, 1, 21]
# [elbowLeft, arms_lowered, 1, 26]
# [elbowLeft, arms_lowered, 1, 47]
# [elbowLeft, arms_lowered, 1, 38]
# [elbowLeft, arms_lowered, 1, 67]
# [elbowLeft, arms_lowered, 1, 95]
# [elbowLeft, arms_lowered, 1, 13]
# [elbowLeft, arms_lowered, 1, 29]
# [elbowLeft, arms_lowered, 1, 37]
# [elbowLeft, arms_lowered, 1, 83]
# [elbowLeft, arms_lowered, 1, 41]
# [elbowLeft, arms_lowered, 1, 100]
# [elbowLeft, arms_lowered, 1, 83]
# [elbowLeft, arms_lowered, 1, 75]
# [elbowLeft, arms_lowered, 1, 26]
# [elbowLeft, arms_lowered, 1, 110]
# [elbowLeft, arms_lowered, 1, 77]
# [elbowLeft, arms_lowered, 1, 99]
# [elbowLeft, arms_lowered, 1, 28]
#
# current joint: elbowLeft
# curent label: arms_raised
# current dataset = lift-drop-left_arm
#
# [elbowLeft, arms_raised, 1, 47]
# [elbowLeft, arms_raised, 1, 40]
# [elbowLeft, arms_raised, 1, 96]
# [elbowLeft, arms_raised, 1, 206]
# [elbowLeft, arms_raised, 1, 271]
#
# current joint: elbowLeft
# curent label: carry_object_car
# current dataset = lift-drop-left_arm
#
# [elbowLeft, carry_object_car, 1, 24]
# [elbowLeft, carry_object_car, 1, 28]
# [elbowLeft, carry_object_car, 1, 30]
# [elbowLeft, carry_object_car, 1, 60]
# [elbowLeft, carry_object_car, 1, 24]
# [elbowLeft, carry_object_car, 1, 18]
# [elbowLeft, carry_object_car, 1, 33]
# [elbowLeft, carry_object_car, 1, 33]
# [elbowLeft, carry_object_car, 1, 59]
# [elbowLeft, carry_object_car, 1, 46]
# [elbowLeft, carry_object_car, 1, 40]
# [elbowLeft, carry_object_car, 1, 45]
# [elbowLeft, carry_object_car, 1, 42]
# [elbowLeft, carry_object_car, 1, 54]
# [elbowLeft, carry_object_car, 1, 93]
# [elbowLeft, carry_object_car, 1, 54]
# [elbowLeft, carry_object_car, 1, 68]
#
# current joint: elbowLeft
# curent label: drop_object_car
# current dataset = lift-drop-left_arm
#
# [elbowLeft, drop_object_car, 1, 21]
# [elbowLeft, drop_object_car, 1, 29]
# [elbowLeft, drop_object_car, 1, 35]
# [elbowLeft, drop_object_car, 1, 17]
# [elbowLeft, drop_object_car, 1, 45]
# [elbowLeft, drop_object_car, 1, 11]
# [elbowLeft, drop_object_car, 1, 30]
# [elbowLeft, drop_object_car, 1, 19]
# [elbowLeft, drop_object_car, 1, 23]
# [elbowLeft, drop_object_car, 1, 26]
# [elbowLeft, drop_object_car, 1, 28]
# [elbowLeft, drop_object_car, 1, 50]
# [elbowLeft, drop_object_car, 1, 37]
# [elbowLeft, drop_object_car, 1, 40]
# [elbowLeft, drop_object_car, 1, 24]
# [elbowLeft, drop_object_car, 1, 39]
# [elbowLeft, drop_object_car, 1, 27]
#
# current joint: elbowLeft
# curent label: dropping_arms
# current dataset = lift-drop-left_arm
#
# [elbowLeft, dropping_arms, 1, 8]
# [elbowLeft, dropping_arms, 1, 26]
# [elbowLeft, dropping_arms, 1, 31]
# [elbowLeft, dropping_arms, 1, 26]
# [elbowLeft, dropping_arms, 1, 27]
#
# current joint: elbowLeft
# curent label: lift_object_car
# current dataset = lift-drop-left_arm
#
# [elbowLeft, lift_object_car, 1, 34]
# [elbowLeft, lift_object_car, 1, 31]
# [elbowLeft, lift_object_car, 1, 24]
# [elbowLeft, lift_object_car, 1, 14]
# [elbowLeft, lift_object_car, 1, 49]
# [elbowLeft, lift_object_car, 1, 24]
# [elbowLeft, lift_object_car, 1, 28]
# [elbowLeft, lift_object_car, 1, 37]
# [elbowLeft, lift_object_car, 1, 20]
# [elbowLeft, lift_object_car, 1, 21]
# [elbowLeft, lift_object_car, 1, 34]
# [elbowLeft, lift_object_car, 1, 53]
# [elbowLeft, lift_object_car, 1, 39]
# [elbowLeft, lift_object_car, 1, 42]
# [elbowLeft, lift_object_car, 1, 22]
# [elbowLeft, lift_object_car, 1, 20]
# [elbowLeft, lift_object_car, 1, 21]
#
# current joint: elbowLeft
# curent label: no_agent
# current dataset = lift-drop-left_arm
#
# [elbowLeft, no_agent, 1, 88]
# [elbowLeft, no_agent, 1, 79]
#
# current joint: elbowLeft
# curent label: pull_object_car
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowLeft
# curent label: pull_object_octopus
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowLeft
# curent label: push_object_car
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowLeft
# curent label: push_object_octopus
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowLeft
# curent label: raising_arms
# current dataset = lift-drop-left_arm
#
# [elbowLeft, raising_arms, 1, 13]
# [elbowLeft, raising_arms, 1, 16]
# [elbowLeft, raising_arms, 1, 22]
# [elbowLeft, raising_arms, 1, 15]
# [elbowLeft, raising_arms, 1, 18]
#
# current joint: elbowLeft
# curent label: reach_object_car
# current dataset = lift-drop-left_arm
#
# [elbowLeft, reach_object_car, 1, 19]
# [elbowLeft, reach_object_car, 1, 22]
# [elbowLeft, reach_object_car, 1, 19]
# [elbowLeft, reach_object_car, 1, 42]
# [elbowLeft, reach_object_car, 1, 24]
# [elbowLeft, reach_object_car, 1, 38]
# [elbowLeft, reach_object_car, 1, 32]
# [elbowLeft, reach_object_car, 1, 37]
# [elbowLeft, reach_object_car, 1, 29]
# [elbowLeft, reach_object_car, 1, 31]
# [elbowLeft, reach_object_car, 1, 19]
# [elbowLeft, reach_object_car, 1, 28]
# [elbowLeft, reach_object_car, 1, 37]
# [elbowLeft, reach_object_car, 1, 22]
# [elbowLeft, reach_object_car, 1, 39]
# [elbowLeft, reach_object_car, 1, 32]
# [elbowLeft, reach_object_car, 1, 43]
#
# current joint: elbowLeft
# curent label: reach_object_octopus
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowLeft
# curent label: retract_hand
# current dataset = lift-drop-left_arm
#
# [elbowLeft, retract_hand, 1, 26]
# [elbowLeft, retract_hand, 1, 16]
# [elbowLeft, retract_hand, 1, 31]
# [elbowLeft, retract_hand, 1, 18]
# [elbowLeft, retract_hand, 1, 24]
# [elbowLeft, retract_hand, 1, 17]
# [elbowLeft, retract_hand, 1, 23]
# [elbowLeft, retract_hand, 1, 23]
# [elbowLeft, retract_hand, 1, 21]
# [elbowLeft, retract_hand, 1, 19]
# [elbowLeft, retract_hand, 1, 19]
# [elbowLeft, retract_hand, 1, 22]
# [elbowLeft, retract_hand, 1, 24]
# [elbowLeft, retract_hand, 1, 19]
# [elbowLeft, retract_hand, 1, 20]
# [elbowLeft, retract_hand, 1, 17]
# [elbowLeft, retract_hand, 1, 20]
#
# current joint: elbowLeft
# curent label: touch_octopus
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowLeft
# curent label: unknown
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowLeft
# curent label: agent_entry
# current dataset = push-pull-left_arm
#
# [elbowLeft, agent_entry, 2, 60]
#
# current joint: elbowLeft
# curent label: agent_exit
# current dataset = push-pull-left_arm
#
# [elbowLeft, agent_exit, 2, 32]
#
# current joint: elbowLeft
# curent label: arms_lowered
# current dataset = push-pull-left_arm
#
# [elbowLeft, arms_lowered, 2, 61]
#
# current joint: elbowLeft
# curent label: arms_raised
# current dataset = push-pull-left_arm
#
# [elbowLeft, arms_raised, 2, 54]
# [elbowLeft, arms_raised, 2, 18]
# [elbowLeft, arms_raised, 2, 22]
# [elbowLeft, arms_raised, 2, 28]
# [elbowLeft, arms_raised, 2, 32]
# [elbowLeft, arms_raised, 2, 30]
# [elbowLeft, arms_raised, 2, 27]
# [elbowLeft, arms_raised, 2, 25]
# [elbowLeft, arms_raised, 2, 56]
# [elbowLeft, arms_raised, 2, 18]
# [elbowLeft, arms_raised, 2, 21]
# [elbowLeft, arms_raised, 2, 18]
# [elbowLeft, arms_raised, 2, 19]
# [elbowLeft, arms_raised, 2, 20]
# [elbowLeft, arms_raised, 2, 58]
# [elbowLeft, arms_raised, 2, 27]
# [elbowLeft, arms_raised, 2, 23]
# [elbowLeft, arms_raised, 2, 24]
# [elbowLeft, arms_raised, 2, 24]
# [elbowLeft, arms_raised, 2, 18]
# [elbowLeft, arms_raised, 2, 33]
# [elbowLeft, arms_raised, 2, 19]
# [elbowLeft, arms_raised, 2, 35]
# [elbowLeft, arms_raised, 2, 19]
# [elbowLeft, arms_raised, 2, 20]
# [elbowLeft, arms_raised, 2, 24]
# [elbowLeft, arms_raised, 2, 14]
# [elbowLeft, arms_raised, 2, 20]
# [elbowLeft, arms_raised, 2, 17]
# [elbowLeft, arms_raised, 2, 25]
#
# current joint: elbowLeft
# curent label: carry_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: elbowLeft
# curent label: drop_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: elbowLeft
# curent label: dropping_arms
# current dataset = push-pull-left_arm
#
# [elbowLeft, dropping_arms, 2, 14]
# [elbowLeft, dropping_arms, 2, 25]
# [elbowLeft, dropping_arms, 2, 28]
#
# current joint: elbowLeft
# curent label: lift_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: elbowLeft
# curent label: no_agent
# current dataset = push-pull-left_arm
#
# [elbowLeft, no_agent, 2, 75]
# [elbowLeft, no_agent, 2, 85]
#
# current joint: elbowLeft
# curent label: pull_object_car
# current dataset = push-pull-left_arm
#
# [elbowLeft, pull_object_car, 2, 40]
# [elbowLeft, pull_object_car, 2, 54]
# [elbowLeft, pull_object_car, 2, 33]
# [elbowLeft, pull_object_car, 2, 41]
# [elbowLeft, pull_object_car, 2, 35]
# [elbowLeft, pull_object_car, 2, 45]
# [elbowLeft, pull_object_car, 2, 26]
# [elbowLeft, pull_object_car, 2, 42]
# [elbowLeft, pull_object_car, 2, 23]
# [elbowLeft, pull_object_car, 2, 51]
# [elbowLeft, pull_object_car, 2, 49]
# [elbowLeft, pull_object_car, 2, 69]
# [elbowLeft, pull_object_car, 2, 20]
#
# current joint: elbowLeft
# curent label: pull_object_octopus
# current dataset = push-pull-left_arm
#
# [elbowLeft, pull_object_octopus, 2, 42]
# [elbowLeft, pull_object_octopus, 2, 47]
# [elbowLeft, pull_object_octopus, 2, 37]
# [elbowLeft, pull_object_octopus, 2, 32]
# [elbowLeft, pull_object_octopus, 2, 61]
# [elbowLeft, pull_object_octopus, 2, 44]
# [elbowLeft, pull_object_octopus, 2, 32]
# [elbowLeft, pull_object_octopus, 2, 40]
# [elbowLeft, pull_object_octopus, 2, 38]
# [elbowLeft, pull_object_octopus, 2, 35]
# [elbowLeft, pull_object_octopus, 2, 31]
# [elbowLeft, pull_object_octopus, 2, 31]
#
# current joint: elbowLeft
# curent label: push_object_car
# current dataset = push-pull-left_arm
#
# [elbowLeft, push_object_car, 2, 32]
# [elbowLeft, push_object_car, 2, 29]
# [elbowLeft, push_object_car, 2, 32]
# [elbowLeft, push_object_car, 2, 42]
# [elbowLeft, push_object_car, 2, 50]
# [elbowLeft, push_object_car, 2, 18]
# [elbowLeft, push_object_car, 2, 23]
# [elbowLeft, push_object_car, 2, 38]
# [elbowLeft, push_object_car, 2, 26]
# [elbowLeft, push_object_car, 2, 30]
# [elbowLeft, push_object_car, 2, 33]
# [elbowLeft, push_object_car, 2, 66]
# [elbowLeft, push_object_car, 2, 22]
# [elbowLeft, push_object_car, 2, 45]
# [elbowLeft, push_object_car, 2, 30]
#
# current joint: elbowLeft
# curent label: push_object_octopus
# current dataset = push-pull-left_arm
#
# [elbowLeft, push_object_octopus, 2, 20]
# [elbowLeft, push_object_octopus, 2, 40]
# [elbowLeft, push_object_octopus, 2, 26]
# [elbowLeft, push_object_octopus, 2, 43]
# [elbowLeft, push_object_octopus, 2, 34]
# [elbowLeft, push_object_octopus, 2, 56]
# [elbowLeft, push_object_octopus, 2, 14]
# [elbowLeft, push_object_octopus, 2, 27]
# [elbowLeft, push_object_octopus, 2, 34]
# [elbowLeft, push_object_octopus, 2, 37]
#
# current joint: elbowLeft
# curent label: raising_arms
# current dataset = push-pull-left_arm
#
#
# current joint: elbowLeft
# curent label: reach_object_car
# current dataset = push-pull-left_arm
#
# [elbowLeft, reach_object_car, 2, 28]
# [elbowLeft, reach_object_car, 2, 38]
# [elbowLeft, reach_object_car, 2, 19]
# [elbowLeft, reach_object_car, 2, 32]
# [elbowLeft, reach_object_car, 2, 29]
# [elbowLeft, reach_object_car, 2, 18]
# [elbowLeft, reach_object_car, 2, 31]
# [elbowLeft, reach_object_car, 2, 32]
# [elbowLeft, reach_object_car, 2, 24]
# [elbowLeft, reach_object_car, 2, 40]
# [elbowLeft, reach_object_car, 2, 26]
# [elbowLeft, reach_object_car, 2, 35]
# [elbowLeft, reach_object_car, 2, 23]
# [elbowLeft, reach_object_car, 2, 40]
# [elbowLeft, reach_object_car, 2, 34]
# [elbowLeft, reach_object_car, 2, 49]
# [elbowLeft, reach_object_car, 2, 30]
# [elbowLeft, reach_object_car, 2, 23]
# [elbowLeft, reach_object_car, 2, 37]
# [elbowLeft, reach_object_car, 2, 24]
# [elbowLeft, reach_object_car, 2, 20]
# [elbowLeft, reach_object_car, 2, 24]
# [elbowLeft, reach_object_car, 2, 26]
# [elbowLeft, reach_object_car, 2, 18]
# [elbowLeft, reach_object_car, 2, 20]
# [elbowLeft, reach_object_car, 2, 19]
# [elbowLeft, reach_object_car, 2, 17]
#
# current joint: elbowLeft
# curent label: reach_object_octopus
# current dataset = push-pull-left_arm
#
# [elbowLeft, reach_object_octopus, 2, 27]
# [elbowLeft, reach_object_octopus, 2, 28]
# [elbowLeft, reach_object_octopus, 2, 27]
# [elbowLeft, reach_object_octopus, 2, 19]
# [elbowLeft, reach_object_octopus, 2, 28]
# [elbowLeft, reach_object_octopus, 2, 28]
# [elbowLeft, reach_object_octopus, 2, 32]
# [elbowLeft, reach_object_octopus, 2, 37]
# [elbowLeft, reach_object_octopus, 2, 30]
# [elbowLeft, reach_object_octopus, 2, 23]
# [elbowLeft, reach_object_octopus, 2, 26]
# [elbowLeft, reach_object_octopus, 2, 21]
# [elbowLeft, reach_object_octopus, 2, 41]
# [elbowLeft, reach_object_octopus, 2, 28]
# [elbowLeft, reach_object_octopus, 2, 33]
# [elbowLeft, reach_object_octopus, 2, 15]
# [elbowLeft, reach_object_octopus, 2, 15]
# [elbowLeft, reach_object_octopus, 2, 27]
# [elbowLeft, reach_object_octopus, 2, 22]
# [elbowLeft, reach_object_octopus, 2, 24]
# [elbowLeft, reach_object_octopus, 2, 41]
# [elbowLeft, reach_object_octopus, 2, 31]
#
# current joint: elbowLeft
# curent label: retract_hand
# current dataset = push-pull-left_arm
#
# [elbowLeft, retract_hand, 2, 39]
# [elbowLeft, retract_hand, 2, 19]
# [elbowLeft, retract_hand, 2, 38]
# [elbowLeft, retract_hand, 2, 46]
# [elbowLeft, retract_hand, 2, 28]
# [elbowLeft, retract_hand, 2, 48]
# [elbowLeft, retract_hand, 2, 45]
# [elbowLeft, retract_hand, 2, 27]
# [elbowLeft, retract_hand, 2, 29]
# [elbowLeft, retract_hand, 2, 52]
# [elbowLeft, retract_hand, 2, 33]
# [elbowLeft, retract_hand, 2, 25]
# [elbowLeft, retract_hand, 2, 35]
# [elbowLeft, retract_hand, 2, 37]
# [elbowLeft, retract_hand, 2, 45]
# [elbowLeft, retract_hand, 2, 21]
# [elbowLeft, retract_hand, 2, 32]
# [elbowLeft, retract_hand, 2, 22]
# [elbowLeft, retract_hand, 2, 46]
# [elbowLeft, retract_hand, 2, 34]
# [elbowLeft, retract_hand, 2, 32]
# [elbowLeft, retract_hand, 2, 46]
# [elbowLeft, retract_hand, 2, 30]
# [elbowLeft, retract_hand, 2, 27]
# [elbowLeft, retract_hand, 2, 36]
# [elbowLeft, retract_hand, 2, 34]
# [elbowLeft, retract_hand, 2, 32]
# [elbowLeft, retract_hand, 2, 39]
# [elbowLeft, retract_hand, 2, 41]
# [elbowLeft, retract_hand, 2, 34]
# [elbowLeft, retract_hand, 2, 44]
# [elbowLeft, retract_hand, 2, 37]
# [elbowLeft, retract_hand, 2, 31]
# [elbowLeft, retract_hand, 2, 33]
# [elbowLeft, retract_hand, 2, 49]
# [elbowLeft, retract_hand, 2, 48]
# [elbowLeft, retract_hand, 2, 39]
# [elbowLeft, retract_hand, 2, 44]
# [elbowLeft, retract_hand, 2, 31]
# [elbowLeft, retract_hand, 2, 36]
# [elbowLeft, retract_hand, 2, 17]
# [elbowLeft, retract_hand, 2, 17]
# [elbowLeft, retract_hand, 2, 14]
# [elbowLeft, retract_hand, 2, 27]
# [elbowLeft, retract_hand, 2, 27]
# [elbowLeft, retract_hand, 2, 52]
# [elbowLeft, retract_hand, 2, 30]
# [elbowLeft, retract_hand, 2, 32]
# [elbowLeft, retract_hand, 2, 38]
#
# current joint: elbowLeft
# curent label: touch_octopus
# current dataset = push-pull-left_arm
#
# [elbowLeft, touch_octopus, 2, 17]
#
# current joint: elbowLeft
# curent label: unknown
# current dataset = push-pull-left_arm
#
#
# current joint: elbowLeft
# curent label: agent_entry
# current dataset = push-pull-right_arm
#
# [elbowLeft, agent_entry, 3, 42]
#
# current joint: elbowLeft
# curent label: agent_exit
# current dataset = push-pull-right_arm
#
# [elbowLeft, agent_exit, 3, 45]
#
# current joint: elbowLeft
# curent label: arms_lowered
# current dataset = push-pull-right_arm
#
# [elbowLeft, arms_lowered, 3, 57]
# [elbowLeft, arms_lowered, 3, 33]
# [elbowLeft, arms_lowered, 3, 49]
#
# current joint: elbowLeft
# curent label: arms_raised
# current dataset = push-pull-right_arm
#
# [elbowLeft, arms_raised, 3, 83]
# [elbowLeft, arms_raised, 3, 50]
# [elbowLeft, arms_raised, 3, 26]
# [elbowLeft, arms_raised, 3, 19]
# [elbowLeft, arms_raised, 3, 28]
# [elbowLeft, arms_raised, 3, 24]
# [elbowLeft, arms_raised, 3, 18]
# [elbowLeft, arms_raised, 3, 24]
# [elbowLeft, arms_raised, 3, 27]
# [elbowLeft, arms_raised, 3, 17]
# [elbowLeft, arms_raised, 3, 18]
# [elbowLeft, arms_raised, 3, 15]
# [elbowLeft, arms_raised, 3, 28]
# [elbowLeft, arms_raised, 3, 15]
# [elbowLeft, arms_raised, 3, 12]
# [elbowLeft, arms_raised, 3, 11]
# [elbowLeft, arms_raised, 3, 8]
# [elbowLeft, arms_raised, 3, 14]
# [elbowLeft, arms_raised, 3, 28]
# [elbowLeft, arms_raised, 3, 20]
# [elbowLeft, arms_raised, 3, 32]
# [elbowLeft, arms_raised, 3, 13]
# [elbowLeft, arms_raised, 3, 14]
# [elbowLeft, arms_raised, 3, 28]
# [elbowLeft, arms_raised, 3, 23]
# [elbowLeft, arms_raised, 3, 21]
# [elbowLeft, arms_raised, 3, 28]
# [elbowLeft, arms_raised, 3, 9]
# [elbowLeft, arms_raised, 3, 50]
# [elbowLeft, arms_raised, 3, 35]
# [elbowLeft, arms_raised, 3, 37]
# [elbowLeft, arms_raised, 3, 39]
# [elbowLeft, arms_raised, 3, 15]
# [elbowLeft, arms_raised, 3, 19]
#
# current joint: elbowLeft
# curent label: carry_object_car
# current dataset = push-pull-right_arm
#
#
# current joint: elbowLeft
# curent label: drop_object_car
# current dataset = push-pull-right_arm
#
#
# current joint: elbowLeft
# curent label: dropping_arms
# current dataset = push-pull-right_arm
#
# [elbowLeft, dropping_arms, 3, 14]
# [elbowLeft, dropping_arms, 3, 23]
#
# current joint: elbowLeft
# curent label: lift_object_car
# current dataset = push-pull-right_arm
#
#
# current joint: elbowLeft
# curent label: no_agent
# current dataset = push-pull-right_arm
#
# [elbowLeft, no_agent, 3, 95]
# [elbowLeft, no_agent, 3, 96]
#
# current joint: elbowLeft
# curent label: pull_object_car
# current dataset = push-pull-right_arm
#
# [elbowLeft, pull_object_car, 3, 35]
# [elbowLeft, pull_object_car, 3, 18]
# [elbowLeft, pull_object_car, 3, 22]
# [elbowLeft, pull_object_car, 3, 37]
# [elbowLeft, pull_object_car, 3, 33]
# [elbowLeft, pull_object_car, 3, 41]
# [elbowLeft, pull_object_car, 3, 39]
# [elbowLeft, pull_object_car, 3, 42]
# [elbowLeft, pull_object_car, 3, 56]
# [elbowLeft, pull_object_car, 3, 23]
# [elbowLeft, pull_object_car, 3, 31]
# [elbowLeft, pull_object_car, 3, 44]
#
# current joint: elbowLeft
# curent label: pull_object_octopus
# current dataset = push-pull-right_arm
#
# [elbowLeft, pull_object_octopus, 3, 20]
# [elbowLeft, pull_object_octopus, 3, 22]
# [elbowLeft, pull_object_octopus, 3, 65]
# [elbowLeft, pull_object_octopus, 3, 46]
# [elbowLeft, pull_object_octopus, 3, 38]
# [elbowLeft, pull_object_octopus, 3, 27]
# [elbowLeft, pull_object_octopus, 3, 24]
# [elbowLeft, pull_object_octopus, 3, 15]
# [elbowLeft, pull_object_octopus, 3, 33]
# [elbowLeft, pull_object_octopus, 3, 33]
# [elbowLeft, pull_object_octopus, 3, 36]
#
# current joint: elbowLeft
# curent label: push_object_car
# current dataset = push-pull-right_arm
#
# [elbowLeft, push_object_car, 3, 17]
# [elbowLeft, push_object_car, 3, 14]
# [elbowLeft, push_object_car, 3, 22]
# [elbowLeft, push_object_car, 3, 12]
# [elbowLeft, push_object_car, 3, 14]
# [elbowLeft, push_object_car, 3, 27]
# [elbowLeft, push_object_car, 3, 64]
# [elbowLeft, push_object_car, 3, 28]
# [elbowLeft, push_object_car, 3, 44]
# [elbowLeft, push_object_car, 3, 33]
# [elbowLeft, push_object_car, 3, 28]
# [elbowLeft, push_object_car, 3, 19]
# [elbowLeft, push_object_car, 3, 20]
# [elbowLeft, push_object_car, 3, 43]
#
# current joint: elbowLeft
# curent label: push_object_octopus
# current dataset = push-pull-right_arm
#
# [elbowLeft, push_object_octopus, 3, 24]
# [elbowLeft, push_object_octopus, 3, 2]
# [elbowLeft, push_object_octopus, 3, 19]
# [elbowLeft, push_object_octopus, 3, 23]
# [elbowLeft, push_object_octopus, 3, 16]
# [elbowLeft, push_object_octopus, 3, 26]
# [elbowLeft, push_object_octopus, 3, 22]
# [elbowLeft, push_object_octopus, 3, 37]
# [elbowLeft, push_object_octopus, 3, 20]
# [elbowLeft, push_object_octopus, 3, 22]
# [elbowLeft, push_object_octopus, 3, 32]
# [elbowLeft, push_object_octopus, 3, 51]
# [elbowLeft, push_object_octopus, 3, 15]
# [elbowLeft, push_object_octopus, 3, 18]
# [elbowLeft, push_object_octopus, 3, 40]
# [elbowLeft, push_object_octopus, 3, 41]
# [elbowLeft, push_object_octopus, 3, 67]
#
# current joint: elbowLeft
# curent label: raising_arms
# current dataset = push-pull-right_arm
#
# [elbowLeft, raising_arms, 3, 16]
# [elbowLeft, raising_arms, 3, 12]
# [elbowLeft, raising_arms, 3, 21]
#
# current joint: elbowLeft
# curent label: reach_object_car
# current dataset = push-pull-right_arm
#
# [elbowLeft, reach_object_car, 3, 22]
# [elbowLeft, reach_object_car, 3, 17]
# [elbowLeft, reach_object_car, 3, 32]
# [elbowLeft, reach_object_car, 3, 19]
# [elbowLeft, reach_object_car, 3, 9]
# [elbowLeft, reach_object_car, 3, 25]
# [elbowLeft, reach_object_car, 3, 16]
# [elbowLeft, reach_object_car, 3, 15]
# [elbowLeft, reach_object_car, 3, 19]
# [elbowLeft, reach_object_car, 3, 14]
# [elbowLeft, reach_object_car, 3, 22]
# [elbowLeft, reach_object_car, 3, 22]
# [elbowLeft, reach_object_car, 3, 29]
# [elbowLeft, reach_object_car, 3, 19]
# [elbowLeft, reach_object_car, 3, 22]
# [elbowLeft, reach_object_car, 3, 32]
# [elbowLeft, reach_object_car, 3, 27]
# [elbowLeft, reach_object_car, 3, 22]
# [elbowLeft, reach_object_car, 3, 16]
# [elbowLeft, reach_object_car, 3, 12]
# [elbowLeft, reach_object_car, 3, 10]
# [elbowLeft, reach_object_car, 3, 19]
# [elbowLeft, reach_object_car, 3, 23]
# [elbowLeft, reach_object_car, 3, 32]
# [elbowLeft, reach_object_car, 3, 15]
#
# current joint: elbowLeft
# curent label: reach_object_octopus
# current dataset = push-pull-right_arm
#
# [elbowLeft, reach_object_octopus, 3, 47]
# [elbowLeft, reach_object_octopus, 3, 21]
# [elbowLeft, reach_object_octopus, 3, 14]
# [elbowLeft, reach_object_octopus, 3, 20]
# [elbowLeft, reach_object_octopus, 3, 13]
# [elbowLeft, reach_object_octopus, 3, 19]
# [elbowLeft, reach_object_octopus, 3, 15]
# [elbowLeft, reach_object_octopus, 3, 19]
# [elbowLeft, reach_object_octopus, 3, 25]
# [elbowLeft, reach_object_octopus, 3, 35]
# [elbowLeft, reach_object_octopus, 3, 18]
# [elbowLeft, reach_object_octopus, 3, 30]
# [elbowLeft, reach_object_octopus, 3, 13]
# [elbowLeft, reach_object_octopus, 3, 19]
# [elbowLeft, reach_object_octopus, 3, 31]
# [elbowLeft, reach_object_octopus, 3, 12]
# [elbowLeft, reach_object_octopus, 3, 15]
# [elbowLeft, reach_object_octopus, 3, 14]
# [elbowLeft, reach_object_octopus, 3, 29]
# [elbowLeft, reach_object_octopus, 3, 21]
# [elbowLeft, reach_object_octopus, 3, 37]
# [elbowLeft, reach_object_octopus, 3, 32]
# [elbowLeft, reach_object_octopus, 3, 16]
# [elbowLeft, reach_object_octopus, 3, 25]
# [elbowLeft, reach_object_octopus, 3, 34]
#
# current joint: elbowLeft
# curent label: retract_hand
# current dataset = push-pull-right_arm
#
# [elbowLeft, retract_hand, 3, 31]
# [elbowLeft, retract_hand, 3, 23]
# [elbowLeft, retract_hand, 3, 21]
# [elbowLeft, retract_hand, 3, 39]
# [elbowLeft, retract_hand, 3, 25]
# [elbowLeft, retract_hand, 3, 26]
# [elbowLeft, retract_hand, 3, 34]
# [elbowLeft, retract_hand, 3, 66]
# [elbowLeft, retract_hand, 3, 30]
# [elbowLeft, retract_hand, 3, 34]
# [elbowLeft, retract_hand, 3, 28]
# [elbowLeft, retract_hand, 3, 45]
# [elbowLeft, retract_hand, 3, 27]
# [elbowLeft, retract_hand, 3, 33]
# [elbowLeft, retract_hand, 3, 28]
# [elbowLeft, retract_hand, 3, 21]
# [elbowLeft, retract_hand, 3, 37]
# [elbowLeft, retract_hand, 3, 23]
# [elbowLeft, retract_hand, 3, 29]
# [elbowLeft, retract_hand, 3, 27]
# [elbowLeft, retract_hand, 3, 30]
# [elbowLeft, retract_hand, 3, 21]
# [elbowLeft, retract_hand, 3, 28]
# [elbowLeft, retract_hand, 3, 24]
# [elbowLeft, retract_hand, 3, 31]
# [elbowLeft, retract_hand, 3, 24]
# [elbowLeft, retract_hand, 3, 26]
# [elbowLeft, retract_hand, 3, 34]
# [elbowLeft, retract_hand, 3, 45]
# [elbowLeft, retract_hand, 3, 30]
# [elbowLeft, retract_hand, 3, 24]
# [elbowLeft, retract_hand, 3, 26]
# [elbowLeft, retract_hand, 3, 23]
# [elbowLeft, retract_hand, 3, 47]
# [elbowLeft, retract_hand, 3, 36]
# [elbowLeft, retract_hand, 3, 38]
# [elbowLeft, retract_hand, 3, 23]
# [elbowLeft, retract_hand, 3, 33]
# [elbowLeft, retract_hand, 3, 37]
# [elbowLeft, retract_hand, 3, 29]
# [elbowLeft, retract_hand, 3, 30]
# [elbowLeft, retract_hand, 3, 25]
# [elbowLeft, retract_hand, 3, 33]
# [elbowLeft, retract_hand, 3, 27]
# [elbowLeft, retract_hand, 3, 21]
# [elbowLeft, retract_hand, 3, 33]
# [elbowLeft, retract_hand, 3, 47]
# [elbowLeft, retract_hand, 3, 35]
# [elbowLeft, retract_hand, 3, 32]
#
# current joint: elbowLeft
# curent label: touch_octopus
# current dataset = push-pull-right_arm
#
#
# current joint: elbowLeft
# curent label: unknown
# current dataset = push-pull-right_arm
#
# [elbowLeft, unknown, 3, 31]
#
# current joint: elbowRight
# curent label: agent_entry
# current dataset = lift-drop-right_arm
#
# [elbowRight, agent_entry, 0, 52]
#
# current joint: elbowRight
# curent label: agent_exit
# current dataset = lift-drop-right_arm
#
# [elbowRight, agent_exit, 0, 73]
#
# current joint: elbowRight
# curent label: arms_lowered
# current dataset = lift-drop-right_arm
#
# [elbowRight, arms_lowered, 0, 31]
# [elbowRight, arms_lowered, 0, 18]
# [elbowRight, arms_lowered, 0, 30]
# [elbowRight, arms_lowered, 0, 50]
# [elbowRight, arms_lowered, 0, 25]
# [elbowRight, arms_lowered, 0, 35]
# [elbowRight, arms_lowered, 0, 57]
# [elbowRight, arms_lowered, 0, 21]
# [elbowRight, arms_lowered, 0, 77]
# [elbowRight, arms_lowered, 0, 52]
# [elbowRight, arms_lowered, 0, 56]
# [elbowRight, arms_lowered, 0, 18]
# [elbowRight, arms_lowered, 0, 33]
# [elbowRight, arms_lowered, 0, 41]
# [elbowRight, arms_lowered, 0, 66]
# [elbowRight, arms_lowered, 0, 38]
# [elbowRight, arms_lowered, 0, 149]
# [elbowRight, arms_lowered, 0, 93]
# [elbowRight, arms_lowered, 0, 34]
# [elbowRight, arms_lowered, 0, 38]
# [elbowRight, arms_lowered, 0, 47]
# [elbowRight, arms_lowered, 0, 42]
# [elbowRight, arms_lowered, 0, 57]
# [elbowRight, arms_lowered, 0, 27]
#
# current joint: elbowRight
# curent label: arms_raised
# current dataset = lift-drop-right_arm
#
# [elbowRight, arms_raised, 0, 129]
# [elbowRight, arms_raised, 0, 57]
#
# current joint: elbowRight
# curent label: carry_object_car
# current dataset = lift-drop-right_arm
#
# [elbowRight, carry_object_car, 0, 43]
# [elbowRight, carry_object_car, 0, 31]
# [elbowRight, carry_object_car, 0, 46]
# [elbowRight, carry_object_car, 0, 41]
# [elbowRight, carry_object_car, 0, 32]
# [elbowRight, carry_object_car, 0, 28]
# [elbowRight, carry_object_car, 0, 35]
# [elbowRight, carry_object_car, 0, 39]
# [elbowRight, carry_object_car, 0, 74]
# [elbowRight, carry_object_car, 0, 40]
# [elbowRight, carry_object_car, 0, 34]
# [elbowRight, carry_object_car, 0, 31]
# [elbowRight, carry_object_car, 0, 52]
# [elbowRight, carry_object_car, 0, 26]
# [elbowRight, carry_object_car, 0, 56]
# [elbowRight, carry_object_car, 0, 36]
# [elbowRight, carry_object_car, 0, 24]
# [elbowRight, carry_object_car, 0, 28]
# [elbowRight, carry_object_car, 0, 34]
# [elbowRight, carry_object_car, 0, 35]
#
# current joint: elbowRight
# curent label: drop_object_car
# current dataset = lift-drop-right_arm
#
# [elbowRight, drop_object_car, 0, 22]
# [elbowRight, drop_object_car, 0, 14]
# [elbowRight, drop_object_car, 0, 32]
# [elbowRight, drop_object_car, 0, 20]
# [elbowRight, drop_object_car, 0, 30]
# [elbowRight, drop_object_car, 0, 20]
# [elbowRight, drop_object_car, 0, 30]
# [elbowRight, drop_object_car, 0, 22]
# [elbowRight, drop_object_car, 0, 21]
# [elbowRight, drop_object_car, 0, 30]
# [elbowRight, drop_object_car, 0, 30]
# [elbowRight, drop_object_car, 0, 19]
# [elbowRight, drop_object_car, 0, 29]
# [elbowRight, drop_object_car, 0, 34]
# [elbowRight, drop_object_car, 0, 17]
# [elbowRight, drop_object_car, 0, 15]
# [elbowRight, drop_object_car, 0, 18]
# [elbowRight, drop_object_car, 0, 23]
# [elbowRight, drop_object_car, 0, 20]
# [elbowRight, drop_object_car, 0, 24]
#
# current joint: elbowRight
# curent label: dropping_arms
# current dataset = lift-drop-right_arm
#
# [elbowRight, dropping_arms, 0, 28]
# [elbowRight, dropping_arms, 0, 16]
# [elbowRight, dropping_arms, 0, 17]
# [elbowRight, dropping_arms, 0, 26]
#
# current joint: elbowRight
# curent label: lift_object_car
# current dataset = lift-drop-right_arm
#
# [elbowRight, lift_object_car, 0, 16]
# [elbowRight, lift_object_car, 0, 30]
# [elbowRight, lift_object_car, 0, 25]
# [elbowRight, lift_object_car, 0, 26]
# [elbowRight, lift_object_car, 0, 29]
# [elbowRight, lift_object_car, 0, 32]
# [elbowRight, lift_object_car, 0, 25]
# [elbowRight, lift_object_car, 0, 26]
# [elbowRight, lift_object_car, 0, 24]
# [elbowRight, lift_object_car, 0, 31]
# [elbowRight, lift_object_car, 0, 36]
# [elbowRight, lift_object_car, 0, 21]
# [elbowRight, lift_object_car, 0, 33]
# [elbowRight, lift_object_car, 0, 25]
# [elbowRight, lift_object_car, 0, 25]
# [elbowRight, lift_object_car, 0, 24]
# [elbowRight, lift_object_car, 0, 24]
# [elbowRight, lift_object_car, 0, 29]
# [elbowRight, lift_object_car, 0, 31]
# [elbowRight, lift_object_car, 0, 25]
#
# current joint: elbowRight
# curent label: no_agent
# current dataset = lift-drop-right_arm
#
# [elbowRight, no_agent, 0, 69]
# [elbowRight, no_agent, 0, 89]
#
# current joint: elbowRight
# curent label: pull_object_car
# current dataset = lift-drop-right_arm
#
# [elbowRight, pull_object_car, 0, 11]
#
# current joint: elbowRight
# curent label: pull_object_octopus
# current dataset = lift-drop-right_arm
#
#
# current joint: elbowRight
# curent label: push_object_car
# current dataset = lift-drop-right_arm
#
# [elbowRight, push_object_car, 0, 12]
# [elbowRight, push_object_car, 0, 23]
# [elbowRight, push_object_car, 0, 17]
#
# current joint: elbowRight
# curent label: push_object_octopus
# current dataset = lift-drop-right_arm
#
#
# current joint: elbowRight
# curent label: raising_arms
# current dataset = lift-drop-right_arm
#
# [elbowRight, raising_arms, 0, 31]
# [elbowRight, raising_arms, 0, 11]
# [elbowRight, raising_arms, 0, 20]
# [elbowRight, raising_arms, 0, 33]
#
# current joint: elbowRight
# curent label: reach_object_car
# current dataset = lift-drop-right_arm
#
# [elbowRight, reach_object_car, 0, 18]
# [elbowRight, reach_object_car, 0, 32]
# [elbowRight, reach_object_car, 0, 37]
# [elbowRight, reach_object_car, 0, 32]
# [elbowRight, reach_object_car, 0, 26]
# [elbowRight, reach_object_car, 0, 18]
# [elbowRight, reach_object_car, 0, 15]
# [elbowRight, reach_object_car, 0, 23]
# [elbowRight, reach_object_car, 0, 19]
# [elbowRight, reach_object_car, 0, 26]
# [elbowRight, reach_object_car, 0, 31]
# [elbowRight, reach_object_car, 0, 18]
# [elbowRight, reach_object_car, 0, 19]
# [elbowRight, reach_object_car, 0, 35]
# [elbowRight, reach_object_car, 0, 17]
# [elbowRight, reach_object_car, 0, 17]
# [elbowRight, reach_object_car, 0, 33]
# [elbowRight, reach_object_car, 0, 20]
# [elbowRight, reach_object_car, 0, 19]
# [elbowRight, reach_object_car, 0, 33]
# [elbowRight, reach_object_car, 0, 17]
# [elbowRight, reach_object_car, 0, 16]
# [elbowRight, reach_object_car, 0, 23]
# [elbowRight, reach_object_car, 0, 25]
#
# current joint: elbowRight
# curent label: reach_object_octopus
# current dataset = lift-drop-right_arm
#
#
# current joint: elbowRight
# curent label: retract_hand
# current dataset = lift-drop-right_arm
#
# [elbowRight, retract_hand, 0, 20]
# [elbowRight, retract_hand, 0, 24]
# [elbowRight, retract_hand, 0, 16]
# [elbowRight, retract_hand, 0, 31]
# [elbowRight, retract_hand, 0, 18]
# [elbowRight, retract_hand, 0, 17]
# [elbowRight, retract_hand, 0, 19]
# [elbowRight, retract_hand, 0, 23]
# [elbowRight, retract_hand, 0, 31]
# [elbowRight, retract_hand, 0, 18]
# [elbowRight, retract_hand, 0, 27]
# [elbowRight, retract_hand, 0, 25]
# [elbowRight, retract_hand, 0, 22]
# [elbowRight, retract_hand, 0, 24]
# [elbowRight, retract_hand, 0, 24]
# [elbowRight, retract_hand, 0, 24]
# [elbowRight, retract_hand, 0, 21]
# [elbowRight, retract_hand, 0, 19]
# [elbowRight, retract_hand, 0, 28]
# [elbowRight, retract_hand, 0, 13]
# [elbowRight, retract_hand, 0, 18]
# [elbowRight, retract_hand, 0, 20]
# [elbowRight, retract_hand, 0, 22]
# [elbowRight, retract_hand, 0, 39]
# [elbowRight, retract_hand, 0, 14]
# [elbowRight, retract_hand, 0, 18]
#
# current joint: elbowRight
# curent label: touch_octopus
# current dataset = lift-drop-right_arm
#
#
# current joint: elbowRight
# curent label: unknown
# current dataset = lift-drop-right_arm
#
# [elbowRight, unknown, 0, 10]
#
# current joint: elbowRight
# curent label: agent_entry
# current dataset = lift-drop-left_arm
#
# [elbowRight, agent_entry, 1, 64]
#
# current joint: elbowRight
# curent label: agent_exit
# current dataset = lift-drop-left_arm
#
# [elbowRight, agent_exit, 1, 58]
#
# current joint: elbowRight
# curent label: arms_lowered
# current dataset = lift-drop-left_arm
#
# [elbowRight, arms_lowered, 1, 21]
# [elbowRight, arms_lowered, 1, 32]
# [elbowRight, arms_lowered, 1, 53]
# [elbowRight, arms_lowered, 1, 33]
# [elbowRight, arms_lowered, 1, 21]
# [elbowRight, arms_lowered, 1, 26]
# [elbowRight, arms_lowered, 1, 47]
# [elbowRight, arms_lowered, 1, 38]
# [elbowRight, arms_lowered, 1, 67]
# [elbowRight, arms_lowered, 1, 95]
# [elbowRight, arms_lowered, 1, 13]
# [elbowRight, arms_lowered, 1, 29]
# [elbowRight, arms_lowered, 1, 37]
# [elbowRight, arms_lowered, 1, 83]
# [elbowRight, arms_lowered, 1, 41]
# [elbowRight, arms_lowered, 1, 100]
# [elbowRight, arms_lowered, 1, 83]
# [elbowRight, arms_lowered, 1, 75]
# [elbowRight, arms_lowered, 1, 26]
# [elbowRight, arms_lowered, 1, 110]
# [elbowRight, arms_lowered, 1, 77]
# [elbowRight, arms_lowered, 1, 99]
# [elbowRight, arms_lowered, 1, 28]
#
# current joint: elbowRight
# curent label: arms_raised
# current dataset = lift-drop-left_arm
#
# [elbowRight, arms_raised, 1, 47]
# [elbowRight, arms_raised, 1, 40]
# [elbowRight, arms_raised, 1, 96]
# [elbowRight, arms_raised, 1, 206]
# [elbowRight, arms_raised, 1, 271]
#
# current joint: elbowRight
# curent label: carry_object_car
# current dataset = lift-drop-left_arm
#
# [elbowRight, carry_object_car, 1, 24]
# [elbowRight, carry_object_car, 1, 28]
# [elbowRight, carry_object_car, 1, 30]
# [elbowRight, carry_object_car, 1, 60]
# [elbowRight, carry_object_car, 1, 24]
# [elbowRight, carry_object_car, 1, 18]
# [elbowRight, carry_object_car, 1, 33]
# [elbowRight, carry_object_car, 1, 33]
# [elbowRight, carry_object_car, 1, 59]
# [elbowRight, carry_object_car, 1, 46]
# [elbowRight, carry_object_car, 1, 40]
# [elbowRight, carry_object_car, 1, 45]
# [elbowRight, carry_object_car, 1, 42]
# [elbowRight, carry_object_car, 1, 54]
# [elbowRight, carry_object_car, 1, 93]
# [elbowRight, carry_object_car, 1, 54]
# [elbowRight, carry_object_car, 1, 68]
#
# current joint: elbowRight
# curent label: drop_object_car
# current dataset = lift-drop-left_arm
#
# [elbowRight, drop_object_car, 1, 21]
# [elbowRight, drop_object_car, 1, 29]
# [elbowRight, drop_object_car, 1, 35]
# [elbowRight, drop_object_car, 1, 17]
# [elbowRight, drop_object_car, 1, 45]
# [elbowRight, drop_object_car, 1, 11]
# [elbowRight, drop_object_car, 1, 30]
# [elbowRight, drop_object_car, 1, 19]
# [elbowRight, drop_object_car, 1, 23]
# [elbowRight, drop_object_car, 1, 26]
# [elbowRight, drop_object_car, 1, 28]
# [elbowRight, drop_object_car, 1, 50]
# [elbowRight, drop_object_car, 1, 37]
# [elbowRight, drop_object_car, 1, 40]
# [elbowRight, drop_object_car, 1, 24]
# [elbowRight, drop_object_car, 1, 39]
# [elbowRight, drop_object_car, 1, 27]
#
# current joint: elbowRight
# curent label: dropping_arms
# current dataset = lift-drop-left_arm
#
# [elbowRight, dropping_arms, 1, 8]
# [elbowRight, dropping_arms, 1, 26]
# [elbowRight, dropping_arms, 1, 31]
# [elbowRight, dropping_arms, 1, 26]
# [elbowRight, dropping_arms, 1, 27]
#
# current joint: elbowRight
# curent label: lift_object_car
# current dataset = lift-drop-left_arm
#
# [elbowRight, lift_object_car, 1, 34]
# [elbowRight, lift_object_car, 1, 31]
# [elbowRight, lift_object_car, 1, 24]
# [elbowRight, lift_object_car, 1, 14]
# [elbowRight, lift_object_car, 1, 49]
# [elbowRight, lift_object_car, 1, 24]
# [elbowRight, lift_object_car, 1, 28]
# [elbowRight, lift_object_car, 1, 37]
# [elbowRight, lift_object_car, 1, 20]
# [elbowRight, lift_object_car, 1, 21]
# [elbowRight, lift_object_car, 1, 34]
# [elbowRight, lift_object_car, 1, 53]
# [elbowRight, lift_object_car, 1, 39]
# [elbowRight, lift_object_car, 1, 42]
# [elbowRight, lift_object_car, 1, 22]
# [elbowRight, lift_object_car, 1, 20]
# [elbowRight, lift_object_car, 1, 21]
#
# current joint: elbowRight
# curent label: no_agent
# current dataset = lift-drop-left_arm
#
# [elbowRight, no_agent, 1, 88]
# [elbowRight, no_agent, 1, 79]
#
# current joint: elbowRight
# curent label: pull_object_car
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowRight
# curent label: pull_object_octopus
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowRight
# curent label: push_object_car
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowRight
# curent label: push_object_octopus
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowRight
# curent label: raising_arms
# current dataset = lift-drop-left_arm
#
# [elbowRight, raising_arms, 1, 13]
# [elbowRight, raising_arms, 1, 16]
# [elbowRight, raising_arms, 1, 22]
# [elbowRight, raising_arms, 1, 15]
# [elbowRight, raising_arms, 1, 18]
#
# current joint: elbowRight
# curent label: reach_object_car
# current dataset = lift-drop-left_arm
#
# [elbowRight, reach_object_car, 1, 19]
# [elbowRight, reach_object_car, 1, 22]
# [elbowRight, reach_object_car, 1, 19]
# [elbowRight, reach_object_car, 1, 42]
# [elbowRight, reach_object_car, 1, 24]
# [elbowRight, reach_object_car, 1, 38]
# [elbowRight, reach_object_car, 1, 32]
# [elbowRight, reach_object_car, 1, 37]
# [elbowRight, reach_object_car, 1, 29]
# [elbowRight, reach_object_car, 1, 31]
# [elbowRight, reach_object_car, 1, 19]
# [elbowRight, reach_object_car, 1, 28]
# [elbowRight, reach_object_car, 1, 37]
# [elbowRight, reach_object_car, 1, 22]
# [elbowRight, reach_object_car, 1, 39]
# [elbowRight, reach_object_car, 1, 32]
# [elbowRight, reach_object_car, 1, 43]
#
# current joint: elbowRight
# curent label: reach_object_octopus
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowRight
# curent label: retract_hand
# current dataset = lift-drop-left_arm
#
# [elbowRight, retract_hand, 1, 26]
# [elbowRight, retract_hand, 1, 16]
# [elbowRight, retract_hand, 1, 31]
# [elbowRight, retract_hand, 1, 18]
# [elbowRight, retract_hand, 1, 24]
# [elbowRight, retract_hand, 1, 17]
# [elbowRight, retract_hand, 1, 23]
# [elbowRight, retract_hand, 1, 23]
# [elbowRight, retract_hand, 1, 21]
# [elbowRight, retract_hand, 1, 19]
# [elbowRight, retract_hand, 1, 19]
# [elbowRight, retract_hand, 1, 22]
# [elbowRight, retract_hand, 1, 24]
# [elbowRight, retract_hand, 1, 19]
# [elbowRight, retract_hand, 1, 20]
# [elbowRight, retract_hand, 1, 17]
# [elbowRight, retract_hand, 1, 20]
#
# current joint: elbowRight
# curent label: touch_octopus
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowRight
# curent label: unknown
# current dataset = lift-drop-left_arm
#
#
# current joint: elbowRight
# curent label: agent_entry
# current dataset = push-pull-left_arm
#
# [elbowRight, agent_entry, 2, 60]
#
# current joint: elbowRight
# curent label: agent_exit
# current dataset = push-pull-left_arm
#
# [elbowRight, agent_exit, 2, 32]
#
# current joint: elbowRight
# curent label: arms_lowered
# current dataset = push-pull-left_arm
#
# [elbowRight, arms_lowered, 2, 61]
#
# current joint: elbowRight
# curent label: arms_raised
# current dataset = push-pull-left_arm
#
# [elbowRight, arms_raised, 2, 54]
# [elbowRight, arms_raised, 2, 18]
# [elbowRight, arms_raised, 2, 22]
# [elbowRight, arms_raised, 2, 28]
# [elbowRight, arms_raised, 2, 32]
# [elbowRight, arms_raised, 2, 30]
# [elbowRight, arms_raised, 2, 27]
# [elbowRight, arms_raised, 2, 25]
# [elbowRight, arms_raised, 2, 56]
# [elbowRight, arms_raised, 2, 18]
# [elbowRight, arms_raised, 2, 21]
# [elbowRight, arms_raised, 2, 18]
# [elbowRight, arms_raised, 2, 19]
# [elbowRight, arms_raised, 2, 20]
# [elbowRight, arms_raised, 2, 58]
# [elbowRight, arms_raised, 2, 27]
# [elbowRight, arms_raised, 2, 23]
# [elbowRight, arms_raised, 2, 24]
# [elbowRight, arms_raised, 2, 24]
# [elbowRight, arms_raised, 2, 18]
# [elbowRight, arms_raised, 2, 33]
# [elbowRight, arms_raised, 2, 19]
# [elbowRight, arms_raised, 2, 35]
# [elbowRight, arms_raised, 2, 19]
# [elbowRight, arms_raised, 2, 20]
# [elbowRight, arms_raised, 2, 24]
# [elbowRight, arms_raised, 2, 14]
# [elbowRight, arms_raised, 2, 20]
# [elbowRight, arms_raised, 2, 17]
# [elbowRight, arms_raised, 2, 25]
#
# current joint: elbowRight
# curent label: carry_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: elbowRight
# curent label: drop_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: elbowRight
# curent label: dropping_arms
# current dataset = push-pull-left_arm
#
# [elbowRight, dropping_arms, 2, 14]
# [elbowRight, dropping_arms, 2, 25]
# [elbowRight, dropping_arms, 2, 28]
#
# current joint: elbowRight
# curent label: lift_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: elbowRight
# curent label: no_agent
# current dataset = push-pull-left_arm
#
# [elbowRight, no_agent, 2, 75]
# [elbowRight, no_agent, 2, 85]
#
# current joint: elbowRight
# curent label: pull_object_car
# current dataset = push-pull-left_arm
#
# [elbowRight, pull_object_car, 2, 40]
# [elbowRight, pull_object_car, 2, 54]
# [elbowRight, pull_object_car, 2, 33]
# [elbowRight, pull_object_car, 2, 41]
# [elbowRight, pull_object_car, 2, 35]
# [elbowRight, pull_object_car, 2, 45]
# [elbowRight, pull_object_car, 2, 26]
# [elbowRight, pull_object_car, 2, 42]
# [elbowRight, pull_object_car, 2, 23]
# [elbowRight, pull_object_car, 2, 51]
# [elbowRight, pull_object_car, 2, 49]
# [elbowRight, pull_object_car, 2, 69]
# [elbowRight, pull_object_car, 2, 20]
#
# current joint: elbowRight
# curent label: pull_object_octopus
# current dataset = push-pull-left_arm
#
# [elbowRight, pull_object_octopus, 2, 42]
# [elbowRight, pull_object_octopus, 2, 47]
# [elbowRight, pull_object_octopus, 2, 37]
# [elbowRight, pull_object_octopus, 2, 32]
# [elbowRight, pull_object_octopus, 2, 61]
# [elbowRight, pull_object_octopus, 2, 44]
# [elbowRight, pull_object_octopus, 2, 32]
# [elbowRight, pull_object_octopus, 2, 40]
# [elbowRight, pull_object_octopus, 2, 38]
# [elbowRight, pull_object_octopus, 2, 35]
# [elbowRight, pull_object_octopus, 2, 31]
# [elbowRight, pull_object_octopus, 2, 31]
#
# current joint: elbowRight
# curent label: push_object_car
# current dataset = push-pull-left_arm
#
# [elbowRight, push_object_car, 2, 32]
# [elbowRight, push_object_car, 2, 29]
# [elbowRight, push_object_car, 2, 32]
# [elbowRight, push_object_car, 2, 42]
# [elbowRight, push_object_car, 2, 50]
# [elbowRight, push_object_car, 2, 18]
# [elbowRight, push_object_car, 2, 23]
# [elbowRight, push_object_car, 2, 38]
# [elbowRight, push_object_car, 2, 26]
# [elbowRight, push_object_car, 2, 30]
# [elbowRight, push_object_car, 2, 33]
# ...
# [octopus, arms_raised, 2, 18]
# [octopus, arms_raised, 2, 22]
# [octopus, arms_raised, 2, 28]
# [octopus, arms_raised, 2, 32]
# [octopus, arms_raised, 2, 30]
# [octopus, arms_raised, 2, 27]
# [octopus, arms_raised, 2, 25]
# [octopus, arms_raised, 2, 56]
# [octopus, arms_raised, 2, 18]
# [octopus, arms_raised, 2, 21]
# [octopus, arms_raised, 2, 18]
# [octopus, arms_raised, 2, 19]
# [octopus, arms_raised, 2, 20]
# [octopus, arms_raised, 2, 58]
# [octopus, arms_raised, 2, 27]
# [octopus, arms_raised, 2, 23]
# [octopus, arms_raised, 2, 24]
# [octopus, arms_raised, 2, 24]
# [octopus, arms_raised, 2, 18]
# [octopus, arms_raised, 2, 33]
# [octopus, arms_raised, 2, 19]
# [octopus, arms_raised, 2, 35]
# [octopus, arms_raised, 2, 19]
# [octopus, arms_raised, 2, 20]
# [octopus, arms_raised, 2, 24]
# [octopus, arms_raised, 2, 14]
# [octopus, arms_raised, 2, 20]
# [octopus, arms_raised, 2, 17]
# [octopus, arms_raised, 2, 25]
#
# current joint: octopus
# curent label: carry_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: octopus
# curent label: drop_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: octopus
# curent label: dropping_arms
# current dataset = push-pull-left_arm
#
# [octopus, dropping_arms, 2, 14]
# [octopus, dropping_arms, 2, 25]
# [octopus, dropping_arms, 2, 28]
#
# current joint: octopus
# curent label: lift_object_car
# current dataset = push-pull-left_arm
#
#
# current joint: octopus
# curent label: no_agent
# current dataset = push-pull-left_arm
#
# [octopus, no_agent, 2, 75]
# [octopus, no_agent, 2, 85]
#
# current joint: octopus
# curent label: pull_object_car
# current dataset = push-pull-left_arm
#
# [octopus, pull_object_car, 2, 40]
# [octopus, pull_object_car, 2, 54]
# [octopus, pull_object_car, 2, 33]
# [octopus, pull_object_car, 2, 41]
# [octopus, pull_object_car, 2, 35]
# [octopus, pull_object_car, 2, 45]
# [octopus, pull_object_car, 2, 26]
# [octopus, pull_object_car, 2, 42]
# [octopus, pull_object_car, 2, 23]
# [octopus, pull_object_car, 2, 51]
# [octopus, pull_object_car, 2, 49]
# [octopus, pull_object_car, 2, 69]
# [octopus, pull_object_car, 2, 20]
#
# current joint: octopus
# curent label: pull_object_octopus
# current dataset = push-pull-left_arm
#
# [octopus, pull_object_octopus, 2, 42]
# [octopus, pull_object_octopus, 2, 47]
# [octopus, pull_object_octopus, 2, 37]
# [octopus, pull_object_octopus, 2, 32]
# [octopus, pull_object_octopus, 2, 61]
# [octopus, pull_object_octopus, 2, 44]
# [octopus, pull_object_octopus, 2, 32]
# [octopus, pull_object_octopus, 2, 40]
# [octopus, pull_object_octopus, 2, 38]
# [octopus, pull_object_octopus, 2, 35]
# [octopus, pull_object_octopus, 2, 31]
# [octopus, pull_object_octopus, 2, 31]
#
# current joint: octopus
# curent label: push_object_car
# current dataset = push-pull-left_arm
#
# [octopus, push_object_car, 2, 32]
# [octopus, push_object_car, 2, 29]
# [octopus, push_object_car, 2, 32]
# [octopus, push_object_car, 2, 42]
# [octopus, push_object_car, 2, 50]
# [octopus, push_object_car, 2, 18]
# [octopus, push_object_car, 2, 23]
# [octopus, push_object_car, 2, 38]
# [octopus, push_object_car, 2, 26]
# [octopus, push_object_car, 2, 30]
# [octopus, push_object_car, 2, 33]
# [octopus, push_object_car, 2, 66]
# [octopus, push_object_car, 2, 22]
# [octopus, push_object_car, 2, 45]
# [octopus, push_object_car, 2, 30]
#
# current joint: octopus
# curent label: push_object_octopus
# current dataset = push-pull-left_arm
#
# [octopus, push_object_octopus, 2, 20]
# [octopus, push_object_octopus, 2, 40]
# [octopus, push_object_octopus, 2, 26]
# [octopus, push_object_octopus, 2, 43]
# [octopus, push_object_octopus, 2, 34]
# [octopus, push_object_octopus, 2, 56]
# [octopus, push_object_octopus, 2, 14]
# [octopus, push_object_octopus, 2, 27]
# [octopus, push_object_octopus, 2, 34]
# [octopus, push_object_octopus, 2, 37]
#
# current joint: octopus
# curent label: raising_arms
# current dataset = push-pull-left_arm
#
#
# current joint: octopus
# curent label: reach_object_car
# current dataset = push-pull-left_arm
#
# [octopus, reach_object_car, 2, 28]
# [octopus, reach_object_car, 2, 38]
# [octopus, reach_object_car, 2, 19]
# [octopus, reach_object_car, 2, 32]
# [octopus, reach_object_car, 2, 29]
# [octopus, reach_object_car, 2, 18]
# [octopus, reach_object_car, 2, 31]
# [octopus, reach_object_car, 2, 32]
# [octopus, reach_object_car, 2, 24]
# [octopus, reach_object_car, 2, 40]
# [octopus, reach_object_car, 2, 26]
# [octopus, reach_object_car, 2, 35]
# [octopus, reach_object_car, 2, 23]
# [octopus, reach_object_car, 2, 40]
# [octopus, reach_object_car, 2, 34]
# [octopus, reach_object_car, 2, 49]
# [octopus, reach_object_car, 2, 30]
# [octopus, reach_object_car, 2, 23]
# [octopus, reach_object_car, 2, 37]
# [octopus, reach_object_car, 2, 24]
# [octopus, reach_object_car, 2, 20]
# [octopus, reach_object_car, 2, 24]
# [octopus, reach_object_car, 2, 26]
# [octopus, reach_object_car, 2, 18]
# [octopus, reach_object_car, 2, 20]
# [octopus, reach_object_car, 2, 19]
# [octopus, reach_object_car, 2, 17]
#
# current joint: octopus
# curent label: reach_object_octopus
# current dataset = push-pull-left_arm
#
# [octopus, reach_object_octopus, 2, 27]
# [octopus, reach_object_octopus, 2, 28]
# [octopus, reach_object_octopus, 2, 27]
# [octopus, reach_object_octopus, 2, 19]
# [octopus, reach_object_octopus, 2, 28]
# [octopus, reach_object_octopus, 2, 28]
# [octopus, reach_object_octopus, 2, 32]
# [octopus, reach_object_octopus, 2, 37]
# [octopus, reach_object_octopus, 2, 30]
# [octopus, reach_object_octopus, 2, 23]
# [octopus, reach_object_octopus, 2, 26]
# [octopus, reach_object_octopus, 2, 21]
# [octopus, reach_object_octopus, 2, 41]
# [octopus, reach_object_octopus, 2, 28]
# [octopus, reach_object_octopus, 2, 33]
# [octopus, reach_object_octopus, 2, 15]
# [octopus, reach_object_octopus, 2, 15]
# [octopus, reach_object_octopus, 2, 27]
# [octopus, reach_object_octopus, 2, 22]
# [octopus, reach_object_octopus, 2, 24]
# [octopus, reach_object_octopus, 2, 41]
# [octopus, reach_object_octopus, 2, 31]
#
# current joint: octopus
# curent label: retract_hand
# current dataset = push-pull-left_arm
#
# [octopus, retract_hand, 2, 39]
# [octopus, retract_hand, 2, 19]
# [octopus, retract_hand, 2, 38]
# [octopus, retract_hand, 2, 46]
# [octopus, retract_hand, 2, 28]
# [octopus, retract_hand, 2, 48]
# [octopus, retract_hand, 2, 45]
# [octopus, retract_hand, 2, 27]
# [octopus, retract_hand, 2, 29]
# [octopus, retract_hand, 2, 52]
# [octopus, retract_hand, 2, 33]
# [octopus, retract_hand, 2, 25]
# [octopus, retract_hand, 2, 35]
# [octopus, retract_hand, 2, 37]
# [octopus, retract_hand, 2, 45]
# [octopus, retract_hand, 2, 21]
# [octopus, retract_hand, 2, 32]
# [octopus, retract_hand, 2, 22]
# [octopus, retract_hand, 2, 46]
# [octopus, retract_hand, 2, 34]
# [octopus, retract_hand, 2, 32]
# [octopus, retract_hand, 2, 46]
# [octopus, retract_hand, 2, 30]
# [octopus, retract_hand, 2, 27]
# [octopus, retract_hand, 2, 36]
# [octopus, retract_hand, 2, 34]
# [octopus, retract_hand, 2, 32]
# [octopus, retract_hand, 2, 39]
# [octopus, retract_hand, 2, 41]
# [octopus, retract_hand, 2, 34]
# [octopus, retract_hand, 2, 44]
# [octopus, retract_hand, 2, 37]
# [octopus, retract_hand, 2, 31]
# [octopus, retract_hand, 2, 33]
# [octopus, retract_hand, 2, 49]
# [octopus, retract_hand, 2, 48]
# [octopus, retract_hand, 2, 39]
# [octopus, retract_hand, 2, 44]
# [octopus, retract_hand, 2, 31]
# [octopus, retract_hand, 2, 36]
# [octopus, retract_hand, 2, 17]
# [octopus, retract_hand, 2, 17]
# [octopus, retract_hand, 2, 14]
# [octopus, retract_hand, 2, 27]
# [octopus, retract_hand, 2, 27]
# [octopus, retract_hand, 2, 52]
# [octopus, retract_hand, 2, 30]
# [octopus, retract_hand, 2, 32]
# [octopus, retract_hand, 2, 38]
#
# current joint: octopus
# curent label: touch_octopus
# current dataset = push-pull-left_arm
#
# [octopus, touch_octopus, 2, 17]
#
# current joint: octopus
# curent label: unknown
# current dataset = push-pull-left_arm
#
#
# current joint: octopus
# curent label: agent_entry
# current dataset = push-pull-right_arm
#
# [octopus, agent_entry, 3, 42]
#
# current joint: octopus
# curent label: agent_exit
# current dataset = push-pull-right_arm
#
# [octopus, agent_exit, 3, 45]
#
# current joint: octopus
# curent label: arms_lowered
# current dataset = push-pull-right_arm
#
# [octopus, arms_lowered, 3, 57]
# [octopus, arms_lowered, 3, 33]
# [octopus, arms_lowered, 3, 49]
#
# current joint: octopus
# curent label: arms_raised
# current dataset = push-pull-right_arm
#
# [octopus, arms_raised, 3, 83]
# [octopus, arms_raised, 3, 50]
# [octopus, arms_raised, 3, 26]
# [octopus, arms_raised, 3, 19]
# [octopus, arms_raised, 3, 28]
# [octopus, arms_raised, 3, 24]
# [octopus, arms_raised, 3, 18]
# [octopus, arms_raised, 3, 24]
# [octopus, arms_raised, 3, 27]
# [octopus, arms_raised, 3, 17]
# [octopus, arms_raised, 3, 18]
# [octopus, arms_raised, 3, 15]
# [octopus, arms_raised, 3, 28]
# [octopus, arms_raised, 3, 15]
# [octopus, arms_raised, 3, 12]
# [octopus, arms_raised, 3, 11]
# [octopus, arms_raised, 3, 8]
# [octopus, arms_raised, 3, 14]
# [octopus, arms_raised, 3, 28]
# [octopus, arms_raised, 3, 20]
# [octopus, arms_raised, 3, 32]
# [octopus, arms_raised, 3, 13]
# [octopus, arms_raised, 3, 14]
# [octopus, arms_raised, 3, 28]
# [octopus, arms_raised, 3, 23]
# [octopus, arms_raised, 3, 21]
# [octopus, arms_raised, 3, 28]
# [octopus, arms_raised, 3, 9]
# [octopus, arms_raised, 3, 50]
# [octopus, arms_raised, 3, 35]
# [octopus, arms_raised, 3, 37]
# [octopus, arms_raised, 3, 39]
# [octopus, arms_raised, 3, 15]
# [octopus, arms_raised, 3, 19]
#
# current joint: octopus
# curent label: carry_object_car
# current dataset = push-pull-right_arm
#
#
# current joint: octopus
# curent label: drop_object_car
# current dataset = push-pull-right_arm
#
#
# current joint: octopus
# curent label: dropping_arms
# current dataset = push-pull-right_arm
#
# [octopus, dropping_arms, 3, 14]
# [octopus, dropping_arms, 3, 23]
#
# current joint: octopus
# curent label: lift_object_car
# current dataset = push-pull-right_arm
#
#
# current joint: octopus
# curent label: no_agent
# current dataset = push-pull-right_arm
#
# [octopus, no_agent, 3, 95]
# [octopus, no_agent, 3, 96]
#
# current joint: octopus
# curent label: pull_object_car
# current dataset = push-pull-right_arm
#
# [octopus, pull_object_car, 3, 35]
# [octopus, pull_object_car, 3, 18]
# [octopus, pull_object_car, 3, 22]
# [octopus, pull_object_car, 3, 37]
# [octopus, pull_object_car, 3, 33]
# [octopus, pull_object_car, 3, 41]
# [octopus, pull_object_car, 3, 39]
# [octopus, pull_object_car, 3, 42]
# [octopus, pull_object_car, 3, 56]
# [octopus, pull_object_car, 3, 23]
# [octopus, pull_object_car, 3, 31]
# [octopus, pull_object_car, 3, 44]
#
# current joint: octopus
# curent label: pull_object_octopus
# current dataset = push-pull-right_arm
#
# [octopus, pull_object_octopus, 3, 20]
# [octopus, pull_object_octopus, 3, 22]
# [octopus, pull_object_octopus, 3, 65]
# [octopus, pull_object_octopus, 3, 46]
# [octopus, pull_object_octopus, 3, 38]
# [octopus, pull_object_octopus, 3, 27]
# [octopus, pull_object_octopus, 3, 24]
# [octopus, pull_object_octopus, 3, 15]
# [octopus, pull_object_octopus, 3, 33]
# [octopus, pull_object_octopus, 3, 33]
# [octopus, pull_object_octopus, 3, 36]
#
# current joint: octopus
# curent label: push_object_car
# current dataset = push-pull-right_arm
#
# [octopus, push_object_car, 3, 17]
# [octopus, push_object_car, 3, 14]
# [octopus, push_object_car, 3, 22]
# [octopus, push_object_car, 3, 12]
# [octopus, push_object_car, 3, 14]
# [octopus, push_object_car, 3, 27]
# [octopus, push_object_car, 3, 64]
# [octopus, push_object_car, 3, 28]
# [octopus, push_object_car, 3, 44]
# [octopus, push_object_car, 3, 33]
# [octopus, push_object_car, 3, 28]
# [octopus, push_object_car, 3, 19]
# [octopus, push_object_car, 3, 20]
# [octopus, push_object_car, 3, 43]
#
# current joint: octopus
# curent label: push_object_octopus
# current dataset = push-pull-right_arm
#
# [octopus, push_object_octopus, 3, 24]
# [octopus, push_object_octopus, 3, 2]
# [octopus, push_object_octopus, 3, 19]
# [octopus, push_object_octopus, 3, 23]
# [octopus, push_object_octopus, 3, 16]
# [octopus, push_object_octopus, 3, 26]
# [octopus, push_object_octopus, 3, 22]
# [octopus, push_object_octopus, 3, 37]
# [octopus, push_object_octopus, 3, 20]
# [octopus, push_object_octopus, 3, 22]
# [octopus, push_object_octopus, 3, 32]
# [octopus, push_object_octopus, 3, 51]
# [octopus, push_object_octopus, 3, 15]
# [octopus, push_object_octopus, 3, 18]
# [octopus, push_object_octopus, 3, 40]
# [octopus, push_object_octopus, 3, 41]
# [octopus, push_object_octopus, 3, 67]
#
# current joint: octopus
# curent label: raising_arms
# current dataset = push-pull-right_arm
#
# [octopus, raising_arms, 3, 16]
# [octopus, raising_arms, 3, 12]
# [octopus, raising_arms, 3, 21]
#
# current joint: octopus
# curent label: reach_object_car
# current dataset = push-pull-right_arm
#
# [octopus, reach_object_car, 3, 22]
# [octopus, reach_object_car, 3, 17]
# [octopus, reach_object_car, 3, 32]
# [octopus, reach_object_car, 3, 19]
# [octopus, reach_object_car, 3, 9]
# [octopus, reach_object_car, 3, 25]
# [octopus, reach_object_car, 3, 16]
# [octopus, reach_object_car, 3, 15]
# [octopus, reach_object_car, 3, 19]
# [octopus, reach_object_car, 3, 14]
# [octopus, reach_object_car, 3, 22]
# [octopus, reach_object_car, 3, 22]
# [octopus, reach_object_car, 3, 29]
# [octopus, reach_object_car, 3, 19]
# [octopus, reach_object_car, 3, 22]
# [octopus, reach_object_car, 3, 32]
# [octopus, reach_object_car, 3, 27]
# [octopus, reach_object_car, 3, 22]
# [octopus, reach_object_car, 3, 16]
# [octopus, reach_object_car, 3, 12]
# [octopus, reach_object_car, 3, 10]
# [octopus, reach_object_car, 3, 19]
# [octopus, reach_object_car, 3, 23]
# [octopus, reach_object_car, 3, 32]
# [octopus, reach_object_car, 3, 15]
#
# current joint: octopus
# curent label: reach_object_octopus
# current dataset = push-pull-right_arm
#
# [octopus, reach_object_octopus, 3, 47]
# [octopus, reach_object_octopus, 3, 21]
# [octopus, reach_object_octopus, 3, 14]
# [octopus, reach_object_octopus, 3, 20]
# [octopus, reach_object_octopus, 3, 13]
# [octopus, reach_object_octopus, 3, 19]
# [octopus, reach_object_octopus, 3, 15]
# [octopus, reach_object_octopus, 3, 19]
# [octopus, reach_object_octopus, 3, 25]
# [octopus, reach_object_octopus, 3, 35]
# [octopus, reach_object_octopus, 3, 18]
# [octopus, reach_object_octopus, 3, 30]
# [octopus, reach_object_octopus, 3, 13]
# [octopus, reach_object_octopus, 3, 19]
# [octopus, reach_object_octopus, 3, 31]
# [octopus, reach_object_octopus, 3, 12]
# [octopus, reach_object_octopus, 3, 15]
# [octopus, reach_object_octopus, 3, 14]
# [octopus, reach_object_octopus, 3, 29]
# [octopus, reach_object_octopus, 3, 21]
# [octopus, reach_object_octopus, 3, 37]
# [octopus, reach_object_octopus, 3, 32]
# [octopus, reach_object_octopus, 3, 16]
# [octopus, reach_object_octopus, 3, 25]
# [octopus, reach_object_octopus, 3, 34]
#
# current joint: octopus
# curent label: retract_hand
# current dataset = push-pull-right_arm
#
# [octopus, retract_hand, 3, 31]
# [octopus, retract_hand, 3, 23]
# [octopus, retract_hand, 3, 21]
# [octopus, retract_hand, 3, 39]
# [octopus, retract_hand, 3, 25]
# [octopus, retract_hand, 3, 26]
# [octopus, retract_hand, 3, 34]
# [octopus, retract_hand, 3, 66]
# [octopus, retract_hand, 3, 30]
# [octopus, retract_hand, 3, 34]
# [octopus, retract_hand, 3, 28]
# [octopus, retract_hand, 3, 45]
# [octopus, retract_hand, 3, 27]
# [octopus, retract_hand, 3, 33]
# [octopus, retract_hand, 3, 28]
# [octopus, retract_hand, 3, 21]
# [octopus, retract_hand, 3, 37]
# [octopus, retract_hand, 3, 23]
# [octopus, retract_hand, 3, 29]
# [octopus, retract_hand, 3, 27]
# [octopus, retract_hand, 3, 30]
# [octopus, retract_hand, 3, 21]
# [octopus, retract_hand, 3, 28]
# [octopus, retract_hand, 3, 24]
# [octopus, retract_hand, 3, 31]
# [octopus, retract_hand, 3, 24]
# [octopus, retract_hand, 3, 26]
# [octopus, retract_hand, 3, 34]
# [octopus, retract_hand, 3, 45]
# [octopus, retract_hand, 3, 30]
# [octopus, retract_hand, 3, 24]
# [octopus, retract_hand, 3, 26]
# [octopus, retract_hand, 3, 23]
# [octopus, retract_hand, 3, 47]
# [octopus, retract_hand, 3, 36]
# [octopus, retract_hand, 3, 38]
# [octopus, retract_hand, 3, 23]
# [octopus, retract_hand, 3, 33]
# [octopus, retract_hand, 3, 37]
# [octopus, retract_hand, 3, 29]
# [octopus, retract_hand, 3, 30]
# [octopus, retract_hand, 3, 25]
# [octopus, retract_hand, 3, 33]
# [octopus, retract_hand, 3, 27]
# [octopus, retract_hand, 3, 21]
# [octopus, retract_hand, 3, 33]
# [octopus, retract_hand, 3, 47]
# [octopus, retract_hand, 3, 35]
# [octopus, retract_hand, 3, 32]
#
# current joint: octopus
# curent label: touch_octopus
# current dataset = push-pull-right_arm
#
#
# current joint: octopus
# curent label: unknown
# current dataset = push-pull-right_arm
#
# [octopus, unknown, 3, 31]

# %%
joint = 0
action = 1
dataset = 2
start = 3
end = 4
for a in range(len(dataFolderList)):
    print 'Dataset ' + str(a) + ' : ' + dataFolderList[a]
    for b in range(len(labels)):
        y = len([i[1] for i in dataStruct if i[joint] == 'head' and i[dataset] == a and i[action] == labels[b]])
        print '\t ' + str(labels[b]).ljust(21) + ' = ' + str(y).ljust(3) + ' repetitions'
    print
# Out:
# Dataset 0 : lift-drop-right_arm
# 	 agent_entry           = 1   repetitions
# 	 agent_exit            = 1   repetitions
# 	 arms_lowered          = 24  repetitions
# 	 arms_raised           = 2   repetitions
# 	 carry_object_car      = 20  repetitions
# 	 drop_object_car       = 20  repetitions
# 	 dropping_arms         = 4   repetitions
# 	 lift_object_car       = 20  repetitions
# 	 no_agent              = 2   repetitions
# 	 pull_object_car       = 1   repetitions
# 	 pull_object_octopus   = 0   repetitions
# 	 push_object_car       = 3   repetitions
# 	 push_object_octopus   = 0   repetitions
# 	 raising_arms          = 4   repetitions
# 	 reach_object_car      = 24  repetitions
# 	 reach_object_octopus  = 0   repetitions
# 	 retract_hand          = 26  repetitions
# 	 touch_octopus         = 0   repetitions
# 	 unknown               = 1   repetitions
#
# Dataset 1 : lift-drop-left_arm
# 	 agent_entry           = 1   repetitions
# 	 agent_exit            = 1   repetitions
# 	 arms_lowered          = 23  repetitions
# 	 arms_raised           = 5   repetitions
# 	 carry_object_car      = 17  repetitions
# 	 drop_object_car       = 17  repetitions
# 	 dropping_arms         = 5   repetitions
# 	 lift_object_car       = 17  repetitions
# 	 no_agent              = 2   repetitions
# 	 pull_object_car       = 0   repetitions
# 	 pull_object_octopus   = 0   repetitions
# 	 push_object_car       = 0   repetitions
# 	 push_object_octopus   = 0   repetitions
# 	 raising_arms          = 5   repetitions
# 	 reach_object_car      = 17  repetitions
# 	 reach_object_octopus  = 0   repetitions
# 	 retract_hand          = 17  repetitions
# 	 touch_octopus         = 0   repetitions
# 	 unknown               = 0   repetitions
#
# Dataset 2 : push-pull-left_arm
# 	 agent_entry           = 1   repetitions
# 	 agent_exit            = 1   repetitions
# 	 arms_lowered          = 1   repetitions
# 	 arms_raised           = 30  repetitions
# 	 carry_object_car      = 0   repetitions
# 	 drop_object_car       = 0   repetitions
# 	 dropping_arms         = 3   repetitions
# 	 lift_object_car       = 0   repetitions
# 	 no_agent              = 2   repetitions
# 	 pull_object_car       = 13  repetitions
# 	 pull_object_octopus   = 12  repetitions
# 	 push_object_car       = 15  repetitions
# 	 push_object_octopus   = 10  repetitions
# 	 raising_arms          = 0   repetitions
# 	 reach_object_car      = 27  repetitions
# 	 reach_object_octopus  = 22  repetitions
# 	 retract_hand          = 49  repetitions
# 	 touch_octopus         = 1   repetitions
# 	 unknown               = 0   repetitions
#
# Dataset 3 : push-pull-right_arm
# 	 agent_entry           = 1   repetitions
# 	 agent_exit            = 1   repetitions
# 	 arms_lowered          = 3   repetitions
# 	 arms_raised           = 34  repetitions
# 	 carry_object_car      = 0   repetitions
# 	 drop_object_car       = 0   repetitions
# 	 dropping_arms         = 2   repetitions
# 	 lift_object_car       = 0   repetitions
# 	 no_agent              = 2   repetitions
# 	 pull_object_car       = 12  repetitions
# 	 pull_object_octopus   = 11  repetitions
# 	 push_object_car       = 14  repetitions
# 	 push_object_octopus   = 17  repetitions
# 	 raising_arms          = 3   repetitions
# 	 reach_object_car      = 25  repetitions
# 	 reach_object_octopus  = 25  repetitions
# 	 retract_hand          = 49  repetitions
# 	 touch_octopus         = 0   repetitions
# 	 unknown               = 1   repetitions

# %%
jointsList.sort()
modJointsListHand_R = [i for i in jointsList if i != 'elbowRight' and i != 'handRight']
modJointsListHand_L = [i for i in jointsList if i != 'elbowLeft' and i != 'handLeft']

modJointsListHand_R = []
modJointsListHand_L = []
combinationList = []

if(len(modJointsListHand_R) > 0):
    for i in range(len(modJointsListHand_R)):
        combinationList.append(['handLeft', modJointsListHand_L[i]])
        combinationList.append(['handRight', modJointsListHand_R[i]])
    del combinationList[combinationList.index(['handLeft', 'handRight'])]

for i in objectsList[1:]:
    combinationList.append(['handLeft',i])
    combinationList.append(['handRight',i])


print 'Available joint pairs for hands:'
print
for i in combinationList:
    print '\t' + str(i)
# Out:
# Available joint pairs for hands:
#
# 	['handLeft', 'car']
# 	['handRight', 'car']
# 	['handLeft', 'octopus']
# 	['handRight', 'octopus']

# %%
humanStaticLabels = []
humanStaticLabels.append('left of')
humanStaticLabels.append('right of')
humanStaticLabels.append('on top of')
humanStaticLabels.append('underneath')
humanStaticLabels.append('in front of')
humanStaticLabels.append('behind')

# %%
#2 joint pairs will be used shoulder-hand and hand-object left and right doesnt matter
#both combine within a single model
#step 1 will be training these models with static poses to do clustering with a full GP configuration
joint = 0
action = 1
dataset = 2
start = 3
end = 4
verbose = True

contactThreshold = 0.1
deltaDistanceThreshold = 0.000005
originThreshold = 0.01
angleThreshold = 0.001

firstPass = True
handDataStruct = []

for currComb in combinationList:
    print str(currComb[0]) +'-' +str(currComb[1])
    infoK = [i for i in dataStruct if i[joint] == currComb[0]]
    infoL = [i for i in dataStruct if i[joint] == currComb[1]]
    
    for i in range(len(infoK)):
        Pk = infoK[i][4]
        Pl = infoL[i][4]
        
        #add gaussian noise on output
        Pk_Noise = np.random.normal(jointMu, jointSig, Pk.shape)
        Pl_Noise = np.random.normal(jointMu, jointSig, Pl.shape)
        
        Pk = Pk + Pk_Noise
        Pl = Pl + Pl_Noise
        
        q1 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #motion of k relative to l
        q2 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #motion of l relative to k
        q3 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #alpha
        q4 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #beta
        q5 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #gamma
        q7 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #contact
        q8 = np.zeros((Pk.shape[0]-2,1), dtype=np.int) #human static label

        lowV = np.abs(Pk) < originThreshold  # Where values are low
        Pk[lowV] = 0
        
        lowV = np.abs(Pl) < originThreshold  # Where values are low
        Pl[lowV] = 0
        
        q6 = (Pl[1:-1]-Pk[1:-1]) #direction vector from joint to joint

        q9 = qtc_2D(Pk,Pl,q1, deltaDistanceThreshold)
        lowV = np.abs(q9) < contactThreshold
        q7[lowV] = 1
        
        q6 = q6/q9[:,None]
        
        qtc_2D(Pl,Pk,q2, deltaDistanceThreshold)
        [a,b,g] = qtc_3D(Pk, Pl, angleThreshold, q3, q4, q5)
        
        for h in range(q6.shape[0]):
            #x at 0 is depth with negative meaning behind an object
            #y at 1 is width with negative meaning partner-right = ego-left
            #x at 2 is height with negative meaning underneath
            currVec = np.abs(q6[h,:])
            maxIDx = currVec.argmax()
            if(maxIDx == 0):
                if(np.sign(q6[h,maxIDx]) == -1):
                    #behind
                    q8[h] = humanStaticLabels.index('behind')
                elif(np.sign(q6[h,maxIDx]) == 1):
                    #in front
                    q8[h] = humanStaticLabels.index('in front of')
            elif(maxIDx == 1):
                if(np.sign(q6[h,maxIDx]) == -1):
                    #left
                    q8[h] = humanStaticLabels.index('left of')
                elif(np.sign(q6[h,maxIDx]) == 1):
                    #right
                    q8[h] = humanStaticLabels.index('right of')
            elif(maxIDx == 2):
                if(np.sign(q6[h,maxIDx]) == -1):
                    #underneath
                    q8[h] = humanStaticLabels.index('underneath')
                elif(np.sign(q6[h,maxIDx]) == 1):
                    #top of
                    q8[h] = humanStaticLabels.index('on top of')  
        
        q10 = Pl[1:-1]
        q11 = Pk[1:-1]
        tempQTC = np.hstack((q1,q2,q3,q4,q5,q6[:,0,None],q6[:,1,None],q6[:,2,None],q7,q8,q9[:,None],q10[:,0,None],q10[:,1,None],q10[:,2,None],q11[:,0,None],q11[:,1,None],q11[:,2,None]))
        
        #q1,q2 -> relative movement of points in terms of distance from each other (closer / farther)
        #q3-5-> relative movement of joints in tems of orientation from each other (difference in the paths they are following wrt each other)
        #q6_1 to _3 -> direction vector from hand to other joint
        #q7 -> contact status
        #q8 -> humanStaticLabel
        
        g = tempQTC.shape[0]
        tempQTC2 = uniqueQTC(tempQTC)

        gg = tempQTC2.shape[0]
        
        tempQTC = checkQTC(tempQTC2)
        
        ggg = tempQTC.shape[0]

        handDataStruct.append([currComb[0], currComb[1], infoK[i][1], infoK[i][2], tempQTC.shape[0], tempQTC])
        
        if(verbose):
            print '[%s]' % ', '.join(map(str, handDataStruct[-1][:-1]))
            print str((ggg-gg)).ljust(3) + ' added in check QTC'
            print str((gg-g)).ljust(3) + ' added in unique QTC'
            print
# Out:
# handLeft-car
# [handLeft, car, agent_entry, 0, 41]
# 11  added in check QTC
# -20 added in unique QTC
#
# [handLeft, car, agent_exit, 0, 41]
# 14  added in check QTC
# -44 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 21]
# 8   added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 12]
# 4   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 23]
# 9   added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 38]
# 16  added in check QTC
# -26 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 35]
# 13  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 30]
# 12  added in check QTC
# -15 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 64]
# 25  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 30]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 79]
# 31  added in check QTC
# -27 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 42]
# 16  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 64]
# 29  added in check QTC
# -19 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 11]
# 5   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 40]
# 16  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 30]
# 12  added in check QTC
# -21 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 91]
# 35  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 29]
# 11  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 112]
# 44  added in check QTC
# -79 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 79]
# 30  added in check QTC
# -42 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 58]
# 26  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 63]
# 27  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 46]
# 19  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 62]
# 22  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 70]
# 29  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, arms_lowered, 0, 33]
# 14  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, arms_raised, 0, 92]
# 36  added in check QTC
# -71 added in unique QTC
#
# [handLeft, car, arms_raised, 0, 59]
# 23  added in check QTC
# -19 added in unique QTC
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:38: RuntimeWarning:divide by zero encountered in divide
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:58: RuntimeWarning:divide by zero encountered in double_scalars
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:35: RuntimeWarning:invalid value encountered in divide
# [handLeft, car, carry_object_car, 0, 44]
# 20  added in check QTC
# -17 added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 37]
# 16  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 51]
# 21  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 67]
# 28  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 51]
# 21  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 36]
# 14  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 21]
# 8   added in check QTC
# -20 added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 32]
# 13  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 67]
# 29  added in check QTC
# -34 added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 61]
# 25  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 54]
# 22  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 44]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 35]
# 13  added in check QTC
# -28 added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 42]
# 18  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 54]
# 24  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 55]
# 21  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 35]
# 16  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 25]
# 11  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 45]
# 17  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, carry_object_car, 0, 41]
# 18  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 34]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 16]
# 6   added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 32]
# 12  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 29]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 48]
# 20  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 29]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 24]
# 9   added in check QTC
# -13 added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 22]
# 9   added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 31]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 49]
# 21  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 44]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 27]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 22]
# 7   added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 51]
# 21  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 24]
# 10  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 9]
# 2   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 26]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 13]
# 4   added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 16]
# 6   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, drop_object_car, 0, 27]
# 11  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, dropping_arms, 0, 40]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, dropping_arms, 0, 22]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, dropping_arms, 0, 20]
# 8   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, dropping_arms, 0, 29]
# 11  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 22]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 46]
# 18  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 13]
# 4   added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 40]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 45]
# 20  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 35]
# 14  added in check QTC
# -9  added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 24]
# 10  added in check QTC
# -9  added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 19]
# 7   added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 34]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 47]
# 20  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 56]
# 22  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 32]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 48]
# 17  added in check QTC
# 0   added in unique QTC
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:58: RuntimeWarning:invalid value encountered in double_scalars
# [handLeft, car, lift_object_car, 0, 39]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 23]
# 8   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 36]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 15]
# 5   added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 23]
# 8   added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 41]
# 14  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, lift_object_car, 0, 29]
# 12  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, no_agent, 0, 67]
# 28  added in check QTC
# -28 added in unique QTC
#
# [handLeft, car, no_agent, 0, 87]
# 37  added in check QTC
# -37 added in unique QTC
#
# [handLeft, car, pull_object_car, 0, 15]
# 6   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 0, 16]
# 6   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 0, 36]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 0, 23]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, raising_arms, 0, 32]
# 13  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, raising_arms, 0, 15]
# 6   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, raising_arms, 0, 19]
# 5   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, raising_arms, 0, 35]
# 14  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 14]
# 4   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 49]
# 19  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 40]
# 17  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 33]
# 13  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 40]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 16]
# 6   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 18]
# 7   added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 36]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 26]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 37]
# 14  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 47]
# 20  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 24]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 19]
# 7   added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 53]
# 20  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 16]
# 6   added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 24]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 50]
# 21  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 29]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 20]
# 7   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 45]
# 16  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 25]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 26]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 33]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 0, 39]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 0, 22]
# 8   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 36]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 0, 13]
# 5   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 48]
# 19  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 0, 23]
# 8   added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 23]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 0, 30]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 0, 28]
# 11  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 34]
# 13  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 19]
# 8   added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 20]
# 7   added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, retract_hand, 0, 38]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 0, 22]
# 6   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 17]
# 5   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, retract_hand, 0, 15]
# 5   added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, retract_hand, 0, 34]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 0, 28]
# 12  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 21]
# 8   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 16]
# 6   added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, retract_hand, 0, 11]
# 4   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 14]
# 4   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 16]
# 6   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 30]
# 12  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 22]
# 7   added in check QTC
# -22 added in unique QTC
#
# [handLeft, car, retract_hand, 0, 16]
# 6   added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, retract_hand, 0, 22]
# 9   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, unknown, 0, 12]
# 4   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, agent_entry, 1, 69]
# 29  added in check QTC
# -22 added in unique QTC
#
# [handLeft, car, agent_exit, 1, 51]
# 21  added in check QTC
# -26 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 28]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 42]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 32]
# 11  added in check QTC
# -30 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 39]
# 15  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 29]
# 12  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 41]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 51]
# 20  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 49]
# 20  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 78]
# 31  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 64]
# 27  added in check QTC
# -56 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 13]
# 4   added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 44]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 28]
# 11  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 44]
# 15  added in check QTC
# -52 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 25]
# 10  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 89]
# 39  added in check QTC
# -48 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 114]
# 41  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 63]
# 23  added in check QTC
# -33 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 35]
# 15  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 66]
# 26  added in check QTC
# -68 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 45]
# 18  added in check QTC
# -48 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 70]
# 27  added in check QTC
# -54 added in unique QTC
#
# [handLeft, car, arms_lowered, 1, 42]
# 17  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, arms_raised, 1, 45]
# 18  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, arms_raised, 1, 39]
# 17  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, arms_raised, 1, 84]
# 36  added in check QTC
# -46 added in unique QTC
#
# [handLeft, car, arms_raised, 1, 246]
# 106 added in check QTC
# -64 added in unique QTC
#
# [handLeft, car, arms_raised, 1, 170]
# 71  added in check QTC
# -170 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 27]
# 11  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 43]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 21]
# 9   added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 46]
# 15  added in check QTC
# -27 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 39]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 25]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 45]
# 18  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 37]
# 16  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 55]
# 20  added in check QTC
# -22 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 28]
# 10  added in check QTC
# -26 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 58]
# 23  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 39]
# 16  added in check QTC
# -20 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 50]
# 18  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 73]
# 29  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 117]
# 44  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 49]
# 21  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, carry_object_car, 1, 68]
# 29  added in check QTC
# -27 added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 25]
# 11  added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 46]
# 19  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 50]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 22]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 32]
# 13  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 14]
# 5   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 44]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 29]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 33]
# 13  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 42]
# 18  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 44]
# 18  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 51]
# 23  added in check QTC
# -20 added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 33]
# 12  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 56]
# 21  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 34]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 64]
# 28  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, drop_object_car, 1, 43]
# 18  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, dropping_arms, 1, 9]
# 3   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, dropping_arms, 1, 38]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, dropping_arms, 1, 43]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, dropping_arms, 1, 37]
# 16  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, dropping_arms, 1, 17]
# 6   added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 49]
# 20  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 28]
# 12  added in check QTC
# -13 added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 37]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 19]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 76]
# 29  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 38]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 42]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 43]
# 18  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 29]
# 12  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 31]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 21]
# 9   added in check QTC
# -20 added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 54]
# 21  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 37]
# 16  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 35]
# 14  added in check QTC
# -19 added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 30]
# 12  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 15]
# 4   added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, lift_object_car, 1, 18]
# 7   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, no_agent, 1, 94]
# 36  added in check QTC
# -28 added in unique QTC
#
# [handLeft, car, no_agent, 1, 118]
# 47  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, raising_arms, 1, 12]
# 5   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, raising_arms, 1, 27]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, raising_arms, 1, 26]
# 9   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, raising_arms, 1, 20]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, raising_arms, 1, 10]
# 4   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 29]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 25]
# 9   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 11]
# 4   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 36]
# 14  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 35]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 35]
# 14  added in check QTC
# -15 added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 38]
# 14  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 48]
# 20  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 21]
# 8   added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 44]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 18]
# 7   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 16]
# 6   added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 59]
# 24  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 35]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 33]
# 13  added in check QTC
# -17 added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 24]
# 10  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, reach_object_car, 1, 70]
# 29  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 1, 14]
# 4   added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, retract_hand, 1, 26]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 1, 27]
# 9   added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, retract_hand, 1, 29]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 1, 21]
# 8   added in check QTC
# -9  added in unique QTC
#
# [handLeft, car, retract_hand, 1, 24]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 1, 30]
# 11  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, retract_hand, 1, 21]
# 8   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, retract_hand, 1, 32]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 1, 18]
# 7   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, retract_hand, 1, 12]
# 5   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, retract_hand, 1, 17]
# 7   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, retract_hand, 1, 32]
# 14  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 1, 20]
# 8   added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, retract_hand, 1, 28]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 1, 17]
# 6   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 1, 27]
# 10  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, agent_entry, 2, 54]
# 22  added in check QTC
# -26 added in unique QTC
#
# [handLeft, car, agent_exit, 2, 38]
# 16  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, arms_lowered, 2, 59]
# 27  added in check QTC
# -27 added in unique QTC
#
# [handLeft, car, arms_raised, 2, 61]
# 26  added in check QTC
# -17 added in unique QTC
#
# [handLeft, car, arms_raised, 2, 28]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 26]
# 11  added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 32]
# 9   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 33]
# 15  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, arms_raised, 2, 42]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 42]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 33]
# 12  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 54]
# 21  added in check QTC
# -21 added in unique QTC
#
# [handLeft, car, arms_raised, 2, 25]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 25]
# 9   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 27]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 19]
# 8   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 31]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 86]
# 36  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 31]
# 14  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 26]
# 11  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 35]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 37]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 18]
# 6   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 39]
# 16  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 16]
# 5   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 43]
# 16  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 27]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 24]
# 11  added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 34]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 12]
# 4   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, arms_raised, 2, 30]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 25]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 2, 30]
# 12  added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, dropping_arms, 2, 19]
# 8   added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, dropping_arms, 2, 28]
# 11  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, dropping_arms, 2, 24]
# 10  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, no_agent, 2, 83]
# 34  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, no_agent, 2, 79]
# 32  added in check QTC
# -36 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 25]
# 11  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 42]
# 18  added in check QTC
# -28 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 26]
# 11  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 57]
# 22  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 50]
# 21  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 30]
# 11  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 22]
# 8   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 42]
# 16  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 28]
# 11  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 60]
# 22  added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 44]
# 17  added in check QTC
# -20 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 49]
# 20  added in check QTC
# -38 added in unique QTC
#
# [handLeft, car, pull_object_car, 2, 27]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 65]
# 25  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 53]
# 20  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 35]
# 12  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 37]
# 15  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 51]
# 22  added in check QTC
# -30 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 46]
# 20  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 28]
# 12  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 38]
# 14  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 50]
# 20  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 55]
# 23  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 37]
# 16  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, pull_object_octopus, 2, 49]
# 20  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 2, 28]
# 11  added in check QTC
# -13 added in unique QTC
#
# [handLeft, car, push_object_car, 2, 44]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 2, 29]
# 11  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, push_object_car, 2, 63]
# 23  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 2, 29]
# 11  added in check QTC
# -30 added in unique QTC
#
# [handLeft, car, push_object_car, 2, 29]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 2, 35]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 2, 59]
# 23  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 2, 26]
# 10  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, push_object_car, 2, 28]
# 11  added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, push_object_car, 2, 50]
# 19  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 2, 44]
# 15  added in check QTC
# -35 added in unique QTC
#
# [handLeft, car, push_object_car, 2, 27]
# 10  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, push_object_car, 2, 47]
# 20  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, push_object_car, 2, 20]
# 8   added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 21]
# 9   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 51]
# 19  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 26]
# 11  added in check QTC
# -9  added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 49]
# 21  added in check QTC
# -13 added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 43]
# 17  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 45]
# 19  added in check QTC
# -28 added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 20]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 33]
# 15  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 42]
# 17  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, push_object_octopus, 2, 39]
# 17  added in check QTC
# -13 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 43]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 63]
# 27  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 27]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 26]
# 10  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 38]
# 15  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 26]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 38]
# 13  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 41]
# 17  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 36]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 44]
# 18  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 39]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 32]
# 14  added in check QTC
# -15 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 36]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 34]
# 12  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 35]
# 14  added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 84]
# 37  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 30]
# 12  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 17]
# 3   added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 41]
# 17  added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 16]
# 6   added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 23]
# 9   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 37]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 17]
# 6   added in check QTC
# -13 added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 20]
# 8   added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 24]
# 11  added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 15]
# 6   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, reach_object_car, 2, 25]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 18]
# 7   added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 29]
# 11  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 19]
# 8   added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 16]
# 7   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 40]
# 18  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 43]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 40]
# 16  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 31]
# 12  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 20]
# 6   added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 35]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 22]
# 9   added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 28]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 32]
# 12  added in check QTC
# -19 added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 30]
# 12  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 47]
# 18  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 18]
# 8   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 11]
# 3   added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 43]
# 18  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 34]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 37]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 40]
# 15  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, reach_object_octopus, 2, 45]
# 20  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 28]
# 10  added in check QTC
# -19 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 16]
# 6   added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 56]
# 24  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 45]
# 18  added in check QTC
# -17 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 35]
# 16  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 56]
# 24  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 39]
# 14  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 23]
# 9   added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 27]
# 11  added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 42]
# 16  added in check QTC
# -24 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 29]
# 9   added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 24]
# 9   added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 59]
# 26  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 55]
# 22  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 68]
# 25  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 21]
# 8   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 27]
# 8   added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 25]
# 11  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 67]
# 25  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 29]
# 11  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 48]
# 18  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 53]
# 22  added in check QTC
# -13 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 45]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 40]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 30]
# 11  added in check QTC
# -15 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 35]
# 13  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 53]
# 24  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 46]
# 17  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 27]
# 10  added in check QTC
# -22 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 48]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 42]
# 19  added in check QTC
# -19 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 24]
# 7   added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 18]
# 7   added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 48]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 56]
# 21  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 38]
# 12  added in check QTC
# -20 added in unique QTC
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:61: RuntimeWarning:invalid value encountered in double_scalars
#  /home/daniel/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:62: RuntimeWarning:invalid value encountered in double_scalars
# [handLeft, car, retract_hand, 2, 28]
# 11  added in check QTC
# -20 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 62]
# 24  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 32]
# 13  added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, retract_hand, 2, 57]
# 23  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 16]
# 7   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 22]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 20]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 34]
# 13  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 27]
# 9   added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 86]
# 36  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 36]
# 13  added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, retract_hand, 2, 54]
# 24  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, retract_hand, 2, 24]
# 10  added in check QTC
# -22 added in unique QTC
#
# [handLeft, car, touch_octopus, 2, 22]
# 9   added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, agent_entry, 3, 39]
# 15  added in check QTC
# -16 added in unique QTC
#
# [handLeft, car, agent_exit, 3, 58]
# 24  added in check QTC
# -9  added in unique QTC
#
# [handLeft, car, arms_lowered, 3, 36]
# 15  added in check QTC
# -34 added in unique QTC
#
# [handLeft, car, arms_lowered, 3, 34]
# 11  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, arms_lowered, 3, 57]
# 23  added in check QTC
# -13 added in unique QTC
#
# [handLeft, car, arms_raised, 3, 68]
# 28  added in check QTC
# -41 added in unique QTC
#
# [handLeft, car, arms_raised, 3, 68]
# 27  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 26]
# 11  added in check QTC
# -9  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 19]
# 8   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 24]
# 9   added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, arms_raised, 3, 28]
# 9   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 26]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 36]
# 15  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 27]
# 11  added in check QTC
# -9  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 25]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 20]
# 7   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 20]
# 8   added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 34]
# 13  added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 19]
# 6   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 16]
# 6   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 14]
# 5   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 8]
# 2   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 20]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 42]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 17]
# 6   added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 51]
# 21  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 14]
# 3   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 19]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 33]
# 12  added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 33]
# 14  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 31]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 28]
# 13  added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, arms_raised, 3, 11]
# 4   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 72]
# 30  added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, arms_raised, 3, 53]
# 20  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 44]
# 20  added in check QTC
# -11 added in unique QTC
#
# [handLeft, car, arms_raised, 3, 36]
# 14  added in check QTC
# -15 added in unique QTC
#
# [handLeft, car, arms_raised, 3, 22]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, arms_raised, 3, 10]
# 3   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, dropping_arms, 3, 18]
# 6   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, dropping_arms, 3, 32]
# 12  added in check QTC
# -1  added in unique QTC
#
# [handLeft, car, no_agent, 3, 108]
# 44  added in check QTC
# -29 added in unique QTC
#
# [handLeft, car, no_agent, 3, 58]
# 22  added in check QTC
# -58 added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 50]
# 19  added in check QTC
# -2  added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 17]
# 6   added in check QTC
# -5  added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 35]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 35]
# 14  added in check QTC
# -14 added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 36]
# 13  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 45]
# 18  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 59]
# 22  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 34]
# 12  added in check QTC
# -18 added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 51]
# 19  added in check QTC
# -22 added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 17]
# 6   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 41]
# 15  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, pull_object_car, 3, 34]
# 13  added in check QTC
# -21 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 12]
# 4   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 29]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 60]
# 25  added in check QTC
# -28 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 40]
# 16  added in check QTC
# -20 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 58]
# 22  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 42]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 26]
# 11  added in check QTC
# -7  added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 23]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 33]
# 14  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 36]
# 13  added in check QTC
# -8  added in unique QTC
#
# [handLeft, car, pull_object_octopus, 3, 39]
# 17  added in check QTC
# -12 added in unique QTC
#
# [handLeft, car, push_object_car, 3, 24]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 3, 10]
# 4   added in check QTC
# -6  added in unique QTC
#
# [handLeft, car, push_object_car, 3, 26]
# 10  added in check QTC
# -4  added in unique QTC
#
# [handLeft, car, push_object_car, 3, 13]
# 6   added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, push_object_car, 3, 17]
# 5   added in check QTC
# 0   added in unique QTC
#
# [handLeft, car, push_object_car, 3, 36]
# 14  added in check QTC
# -3  added in unique QTC
#
# [handLeft, car, push_object_car, 3, 67]
# 27  added in check QTC
# -22 added in unique QTC
#
# [handLeft, car, push_object_car, 3, 24]
# 8   added in check QTC
# -10 added in unique QTC
#
# [handLeft, car, push_object_car, 3, 48]
# 21  added in check QTC
# -15 added in unique QTC
#
# ...
# 15  added in check QTC
# -2  added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 37]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 32]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 42]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 8]
# 3   added in check QTC
# -2  added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 27]
# 9   added in check QTC
# -30 added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 53]
# 20  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 58]
# 23  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 29]
# 10  added in check QTC
# -18 added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 22]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, arms_raised, 3, 21]
# 8   added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, dropping_arms, 3, 19]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, dropping_arms, 3, 32]
# 13  added in check QTC
# -2  added in unique QTC
#
# [handRight, octopus, no_agent, 3, 74]
# 29  added in check QTC
# -48 added in unique QTC
#
# [handRight, octopus, no_agent, 3, 84]
# 36  added in check QTC
# -46 added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 39]
# 14  added in check QTC
# -8  added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 21]
# 7   added in check QTC
# -2  added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 33]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 36]
# 10  added in check QTC
# -9  added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 50]
# 19  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 39]
# 14  added in check QTC
# -14 added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 44]
# 18  added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 46]
# 20  added in check QTC
# -14 added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 66]
# 27  added in check QTC
# -15 added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 35]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 45]
# 18  added in check QTC
# -2  added in unique QTC
#
# [handRight, octopus, pull_object_car, 3, 40]
# 16  added in check QTC
# -18 added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 28]
# 11  added in check QTC
# -1  added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 31]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 51]
# 20  added in check QTC
# -32 added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 30]
# 10  added in check QTC
# -24 added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 25]
# 7   added in check QTC
# -18 added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 42]
# 18  added in check QTC
# -1  added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 14]
# 4   added in check QTC
# -12 added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 22]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 30]
# 11  added in check QTC
# -12 added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 43]
# 18  added in check QTC
# -6  added in unique QTC
#
# [handRight, octopus, pull_object_octopus, 3, 53]
# 19  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 24]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 19]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 20]
# 7   added in check QTC
# -7  added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 18]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 19]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 39]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 64]
# 28  added in check QTC
# -26 added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 46]
# 20  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 36]
# 14  added in check QTC
# -20 added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 40]
# 16  added in check QTC
# -7  added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 24]
# 10  added in check QTC
# -12 added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 21]
# 8   added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 30]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_car, 3, 25]
# 10  added in check QTC
# -26 added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 21]
# 9   added in check QTC
# -10 added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 0]
# 0   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 18]
# 7   added in check QTC
# -6  added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 28]
# 10  added in check QTC
# -3  added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 23]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 34]
# 11  added in check QTC
# -1  added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 32]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 24]
# 8   added in check QTC
# -19 added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 28]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 31]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 20]
# 6   added in check QTC
# -16 added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 28]
# 11  added in check QTC
# -32 added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 22]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 24]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 36]
# 14  added in check QTC
# -16 added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 64]
# 25  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, push_object_octopus, 3, 53]
# 21  added in check QTC
# -33 added in unique QTC
#
# [handRight, octopus, raising_arms, 3, 21]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, raising_arms, 3, 15]
# 5   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, raising_arms, 3, 26]
# 7   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 35]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 26]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 26]
# 10  added in check QTC
# -14 added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 28]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 12]
# 5   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 21]
# 8   added in check QTC
# -10 added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 23]
# 9   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 23]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 27]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 17]
# 7   added in check QTC
# -2  added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 35]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 31]
# 11  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 47]
# 20  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 14]
# 5   added in check QTC
# -8  added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 34]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 20]
# 8   added in check QTC
# -18 added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 31]
# 13  added in check QTC
# -7  added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 23]
# 9   added in check QTC
# -6  added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 24]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 14]
# 6   added in check QTC
# -2  added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 7]
# 2   added in check QTC
# -3  added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 27]
# 10  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 34]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 39]
# 16  added in check QTC
# -7  added in unique QTC
#
# [handRight, octopus, reach_object_car, 3, 14]
# 5   added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 51]
# 20  added in check QTC
# -14 added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 19]
# 6   added in check QTC
# -6  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 16]
# 4   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 30]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 19]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 18]
# 6   added in check QTC
# -5  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 15]
# 6   added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 16]
# 6   added in check QTC
# -7  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 27]
# 9   added in check QTC
# -5  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 41]
# 18  added in check QTC
# -10 added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 28]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 28]
# 11  added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 11]
# 4   added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 29]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 46]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 11]
# 3   added in check QTC
# -2  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 9]
# 2   added in check QTC
# -6  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 20]
# 8   added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 38]
# 15  added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 31]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 58]
# 23  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 19]
# 7   added in check QTC
# -18 added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 16]
# 6   added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 19]
# 6   added in check QTC
# -10 added in unique QTC
#
# [handRight, octopus, reach_object_octopus, 3, 48]
# 20  added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 29]
# 11  added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 35]
# 14  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 13]
# 5   added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 49]
# 20  added in check QTC
# -8  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 21]
# 8   added in check QTC
# -10 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 25]
# 10  added in check QTC
# -9  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 31]
# 13  added in check QTC
# -14 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 47]
# 18  added in check QTC
# -35 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 38]
# 14  added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 42]
# 18  added in check QTC
# -8  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 34]
# 13  added in check QTC
# -5  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 39]
# 16  added in check QTC
# -20 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 42]
# 17  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 35]
# 16  added in check QTC
# -12 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 42]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 19]
# 6   added in check QTC
# -6  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 25]
# 10  added in check QTC
# -20 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 34]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 19]
# 5   added in check QTC
# -13 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 44]
# 19  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 31]
# 11  added in check QTC
# -8  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 31]
# 12  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 21]
# 6   added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 19]
# 8   added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 42]
# 17  added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 38]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 22]
# 9   added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 33]
# 14  added in check QTC
# -13 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 45]
# 17  added in check QTC
# -15 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 19]
# 6   added in check QTC
# -15 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 28]
# 10  added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 19]
# 6   added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 29]
# 12  added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 67]
# 26  added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 57]
# 23  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 55]
# 23  added in check QTC
# -4  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 36]
# 15  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 53]
# 22  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 36]
# 14  added in check QTC
# -13 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 25]
# 9   added in check QTC
# -11 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 20]
# 8   added in check QTC
# -16 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 19]
# 8   added in check QTC
# -12 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 29]
# 11  added in check QTC
# -13 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 41]
# 16  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 32]
# 13  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 34]
# 15  added in check QTC
# -12 added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 70]
# 30  added in check QTC
# -5  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 39]
# 12  added in check QTC
# -6  added in unique QTC
#
# [handRight, octopus, retract_hand, 3, 53]
# 23  added in check QTC
# 0   added in unique QTC
#
# [handRight, octopus, unknown, 3, 22]
# 9   added in check QTC
# -16 added in unique QTC

# %%
#here model trains recognition of object location wrt each other
#feature vector => handDataStruct[5][:,5:8](vector from hand to object) and humanlabel handDataStruct[5][:,9]
for a in range(len(handDataStruct)):
    if(a == 0):
        allPoseY = handDataStruct[a][5][:,5:8]
#         allPoseY = handDataStruct[a][5][:,11:]
        allPoseL = handDataStruct[a][5][:,9,None]
    else:
        allPoseY = np.vstack((allPoseY, handDataStruct[a][5][:,5:8]))
#         allPoseY = np.vstack((allPoseY, handDataStruct[a][5][:,11:]))
        allPoseL = np.vstack((allPoseL, handDataStruct[a][5][:,9,None]))
    
        
print allPoseY.shape
print allPoseL.shape
# Out:
# (94934, 3)
# (94934, 1)

# %%
k = 0
ratio = 70
numItems = 300

for k in range(len(humanStaticLabels)):
    this_label = [i for i in range(allPoseL.shape[0]) if allPoseL[i] == k]
    this_Y = allPoseY[this_label]
    this_L = allPoseL[this_label]
    if(len(this_L)< numItems-1):
        Idx =range(len(this_L))
    else:
        Idx = [ i for i in sorted(random.sample(xrange(len(this_L)),numItems)) ]
        
    if(k == 0):
        staticPoseY = np.asarray([this_Y[i] for i in Idx])
        staticPoseL = np.asarray([this_L[i] for i in Idx])
    else:
        staticPoseY = np.vstack((staticPoseY, np.asarray([this_Y[i] for i in Idx])))
        staticPoseL = np.vstack((staticPoseL, np.asarray([this_L[i] for i in Idx])))
        
print len(this_label)
print len(this_Y)
j = np.asarray(this_label)
print j.shape
print this_Y.shape
print this_L.shape
print staticPoseY.shape
print staticPoseL.shape
# Out:
# 5415
# 5415
# (5415,)
# (5415, 3)
# (5415, 1)
# (1800, 3)
# (1800, 1)

# %%
staticPoseModel = staticPose.staticPose()
staticPoseModel.readData(0,0,staticPoseY,staticPoseL, humanStaticLabels)

staticPoseModel.Quser = 2
Ntr = int(len(staticPoseModel.L)*ratio/100)
model_type = 'mrd'
model_num_inducing = 10
model_num_iterations = 600 #100
model_init_iterations = 600 #300
save_model=True
economy_save = True
visualise_output=True
experiment_number = 2
fname = '/home/daniel/SAM_Data_Models/Models/staticPose_exp' + str(experiment_number)

[Yall,Lall,YtestAll,LtestAll] = staticPoseModel.prepareData (model_type, Ntr,randSeed=experiment_number)

# %%
staticPoseModel.training(model_num_inducing, model_num_iterations, model_init_iterations, fname, save_model, economy_save, keepIfPresent=True)
# Out:
# Training for 600|600 iterations...
# WARNING: reconstraining parameters manifold_relevance_determination.Y0.Gaussian_noise.variance
# WARNING: reconstraining parameters manifold_relevance_determination.Y1.Gaussian_noise.variance
# Saving SAMObject: /home/daniel/SAM_Data_Models/Models/staticPose_exp2

# %%
if visualise_output: 
    ax = staticPoseModel.SAMObject.visualise()
    visualiseInfo=dict()
    visualiseInfo['ax']=ax
else:
    visualiseInfo=None
# Out:
# Warning: subsampling X, as it has more samples then 1000. X.shape=(1260, 2)
#  /home/daniel/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning:This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.

# %%
# curTestData = Yall[][None,:].tolist()
def formatDataFunc(Ydata):
        yDataList = []
        for j in range(Ydata.shape[0]):
            yDataList.append(Ydata[j][None,:])
        return yDataList

def testFunc(data, lab):
    d = staticPoseModel.testing(data, False)
    if(lab == d[0]):
        result = True
    else:
        result = False
    print 'Actual  ' + str(lab).ljust(11) + '  Model:  ' + str(d[0]).ljust(11) + '  with ' + str(d[1])[:6] + ' confidence: ' + str(result) + '\n'
    return d

# %%
def plot_confusion_matrix(cm, targetNames, title='Confusion matrix', cmap=plt.cm.inferno):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(targetNames))
    plt.xticks(tick_marks, targetNames, rotation=45)
    plt.yticks(tick_marks, targetNames)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

import sys
import time
from IPython.display import clear_output

def wait_watching_stdout(ar, dt=1, truncate=1000):
    while not ar.ready():
        stdouts = ar.stdout
        if any(stdouts):
            clear_output()
            print '-' * 30
            print "%.3fs elapsed" % ar.elapsed
            print ""
            for stdout in ar.stdout:
                if stdout:
                    print "\n%s" % (stdout[-truncate:])
            sys.stdout.flush()
        time.sleep(dt)

# %%
c = ipp.Client()
dview = c[:]

with dview.sync_imports():
    from SAM.SAM_Core import staticPose

dview.push({'staticPoseModel':staticPoseModel})
# Out:
# importing staticPose from SAM.SAM_Core on engine(s)
# <AsyncResult: _push>

# %%
ss = []
sstest = []
print
off1 = 11
off2 = 8

# allCount = Yall.shape[0]
# factor = 40
# numItems = int(allCount/factor)
cmSize = len(staticPoseModel.textLabels)
confMatrix = np.zeros((cmSize, cmSize))
numItems = Yall.shape[0]

off3 = len(str(numItems))

print 'estimated time: ' + str(numItems/60) + 'mins for ' + str(numItems) + ' items'
#format training data

yTrainingData = formatDataFunc(Yall)
YsampleIdx = [ i for i in sorted(random.sample(xrange(len(yTrainingData)),numItems)) ]

Ysample = [yTrainingData[i] for i in YsampleIdx]
Lsample = [staticPoseModel.textLabels[int(Lall[i])] for i in YsampleIdx]

# %time syn = dview.map_async(testFunc, Ysample, Lsample)
wait_watching_stdout(syn, dt=1, truncate=1000)
ret = syn.get()
# clear_output()
for i in range(len(ret)):

    currLabel = Lsample[i]

    if(currLabel == ret[i][0]):
        result = True
    else:
        result = False
    print str(i).rjust(off3) + '/' + str(numItems) + ' Truth: ' + currLabel.ljust(off1) + ' Model: ' + ret[i][0].ljust(off1) + ' with ' + str(1-ret[i][1])[:6].ljust(off2) + ' confidence: ' + str(result)
    confMatrix[staticPoseModel.textLabels.index(currLabel),staticPoseModel.textLabels.index(ret[i][0])] += 1
    ss.append(ret[i][0])
# Out:
# ------------------------------
# 111.490s elapsed
#
#
# of     Model:  right of     with 0.0291 confidence: True
#
# Actual  right of     Model:  right of     with 0.0248 confidence: True
#
# Actual  right of     Model:  left of      with 0.0367 confidence: False
#
# Actual  right of     Model:  right of     with 0.0237 confidence: True
#
# Actual  right of     Model:  right of     with 0.0368 confidence: True
#
# Actual  right of     Model:  right of     with 0.0226 confidence: True
#
# Actual  right of     Model:  on top of    with 0.0405 confidence: False
#
# Actual  right of     Model:  on top of    with 0.0472 confidence: False
#
# Actual  right of     Model:  left of      with 0.0514 confidence: False
#
# Actual  right of     Model:  right of     with 0.0628 confidence: True
#
# Actual  right of     Model:  right of     with 0.0344 confidence: True
#
# Actual  right of     Model:  right of     with 0.0514 confidence: True
#
# Actual  right of     Model:  left of      with 0.0271 confidence: False
#
# Actual  right of     Model:  left of      with 0.0258 confidence: False
#
#
#
#  top of    Model:  on top of    with 0.1040 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.0715 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.0493 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.0988 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.0676 confidence: True
#
# Actual  on top of    Model:  left of      with 0.0370 confidence: False
#
# Actual  on top of    Model:  on top of    with 0.0360 confidence: True
#
# Actual  on top of    Model:  left of      with 0.0388 confidence: False
#
# Actual  on top of    Model:  on top of    with 0.0603 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.0241 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.0855 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.1869 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.0573 confidence: True
#
# Actual  on top of    Model:  on top of    with 0.0240 confidence: True
#
#
#
# rneath   Model:  underneath   with 0.0289 confidence: True
#
# Actual  underneath   Model:  in front of  with 0.0434 confidence: False
#
# Actual  underneath   Model:  underneath   with 0.1197 confidence: True
#
# Actual  underneath   Model:  underneath   with 0.1459 confidence: True
#
# Actual  underneath   Model:  underneath   with 0.0319 confidence: True
#
# Actual  underneath   Model:  underneath   with 0.0719 confidence: True
#
# Actual  underneath   Model:  underneath   with 0.2268 confidence: True
#
# Actual  underneath   Model:  in front of  with 0.0422 confidence: False
#
# Actual  underneath   Model:  underneath   with 0.0520 confidence: True
#
# Actual  underneath   Model:  right of     with 0.0225 confidence: False
#
# Actual  underneath   Model:  in front of  with 0.0543 confidence: False
#
# Actual  underneath   Model:  underneath   with 0.0253 confidence: True
#
# Actual  underneath   Model:  underneath   with 0.0351 confidence: True
#
# Actual  underneath   Model:  underneath   with 0.0807 confidence: True
#
#
#
#  front of  Model:  in front of  with 0.0589 confidence: True
#
# Actual  in front of  Model:  underneath   with 0.0298 confidence: False
#
# Actual  in front of  Model:  in front of  with 0.0226 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0620 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0412 confidence: True
#
# Actual  in front of  Model:  on top of    with 0.0905 confidence: False
#
# Actual  in front of  Model:  in front of  with 0.0223 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0244 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0287 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0304 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0231 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0392 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0386 confidence: True
#
# Actual  in front of  Model:  in front of  with 0.0391 confidence: True
#
#
#
# hind       Model:  behind       with 0.0263 confidence: True
#
# Actual  behind       Model:  behind       with 0.0299 confidence: True
#
# Actual  behind       Model:  behind       with 0.0253 confidence: True
#
# Actual  behind       Model:  right of     with 0.0244 confidence: False
#
# Actual  behind       Model:  behind       with 0.1286 confidence: True
#
# Actual  behind       Model:  right of     with 0.0232 confidence: False
#
# Actual  behind       Model:  behind       with 0.1889 confidence: True
#
# Actual  behind       Model:  behind       with 0.3182 confidence: True
#
# Actual  behind       Model:  behind       with 0.0272 confidence: True
#
# Actual  behind       Model:  behind       with 0.0282 confidence: True
#
# Actual  behind       Model:  behind       with 0.1832 confidence: True
#
# Actual  behind       Model:  behind       with 0.0413 confidence: True
#
# Actual  behind       Model:  behind       with 0.1307 confidence: True
#
# Actual  behind       Model:  behind       with 0.1749 confidence: True
#
#
#    0/1260 Truth: left of     Model: left of     with 0.9493   confidence: True
#    1/1260 Truth: left of     Model: left of     with 0.9615   confidence: True
#    2/1260 Truth: left of     Model: left of     with 0.9326   confidence: True
#    3/1260 Truth: left of     Model: on top of   with 0.9760   confidence: False
#    4/1260 Truth: left of     Model: left of     with 0.9660   confidence: True
#    5/1260 Truth: left of     Model: left of     with 0.8100   confidence: True
#    6/1260 Truth: left of     Model: in front of with 0.9707   confidence: False
#    7/1260 Truth: left of     Model: in front of with 0.9773   confidence: False
#    8/1260 Truth: left of     Model: on top of   with 0.9777   confidence: False
#    9/1260 Truth: left of     Model: in front of with 0.9730   confidence: False
#   10/1260 Truth: left of     Model: left of     with 0.9627   confidence: True
#   11/1260 Truth: left of     Model: left of     with 0.9695   confidence: True
#   12/1260 Truth: left of     Model: left of     with 0.9708   confidence: True
#   13/1260 Truth: left of     Model: left of     with 0.9610   confidence: True
#   14/1260 Truth: left of     Model: left of     with 0.9643   confidence: True
#   15/1260 Truth: left of     Model: left of     with 0.9670   confidence: True
#   16/1260 Truth: left of     Model: left of     with 0.9555   confidence: True
#   17/1260 Truth: left of     Model: left of     with 0.9454   confidence: True
#   18/1260 Truth: left of     Model: in front of with 0.9730   confidence: False
#   19/1260 Truth: left of     Model: in front of with 0.9623   confidence: False
#   20/1260 Truth: left of     Model: on top of   with 0.9716   confidence: False
#   21/1260 Truth: left of     Model: left of     with 0.9698   confidence: True
#   22/1260 Truth: left of     Model: left of     with 0.9385   confidence: True
#   23/1260 Truth: left of     Model: left of     with 0.9501   confidence: True
#   24/1260 Truth: left of     Model: left of     with 0.8530   confidence: True
#   25/1260 Truth: left of     Model: left of     with 0.9406   confidence: True
#   26/1260 Truth: left of     Model: left of     with 0.9602   confidence: True
#   27/1260 Truth: left of     Model: left of     with 0.9693   confidence: True
#   28/1260 Truth: left of     Model: left of     with 0.4781   confidence: True
#   29/1260 Truth: left of     Model: on top of   with 0.9410   confidence: False
#   30/1260 Truth: left of     Model: left of     with 0.9646   confidence: True
#   31/1260 Truth: left of     Model: left of     with 0.9604   confidence: True
#   32/1260 Truth: left of     Model: left of     with 0.9568   confidence: True
#   33/1260 Truth: left of     Model: underneath  with 0.9279   confidence: False
#   34/1260 Truth: left of     Model: on top of   with 0.9613   confidence: False
#   35/1260 Truth: left of     Model: left of     with 0.9775   confidence: True
#   36/1260 Truth: left of     Model: left of     with 0.9666   confidence: True
#   37/1260 Truth: left of     Model: left of     with 0.9573   confidence: True
#   38/1260 Truth: left of     Model: underneath  with 0.2960   confidence: False
#   39/1260 Truth: left of     Model: left of     with 0.9550   confidence: True
#   40/1260 Truth: left of     Model: on top of   with 0.9800   confidence: False
#   41/1260 Truth: left of     Model: left of     with 0.9665   confidence: True
#   42/1260 Truth: left of     Model: on top of   with 0.9316   confidence: False
#   43/1260 Truth: left of     Model: right of    with 0.9719   confidence: False
#   44/1260 Truth: left of     Model: left of     with 0.9445   confidence: True
#   45/1260 Truth: left of     Model: on top of   with 0.9710   confidence: False
#   46/1260 Truth: left of     Model: left of     with 0.9602   confidence: True
#   47/1260 Truth: left of     Model: in front of with 0.9795   confidence: False
#   48/1260 Truth: left of     Model: left of     with 0.9672   confidence: True
#   49/1260 Truth: left of     Model: left of     with 0.9681   confidence: True
#   50/1260 Truth: left of     Model: left of     with 0.9674   confidence: True
#   51/1260 Truth: left of     Model: left of     with 0.9603   confidence: True
#   52/1260 Truth: left of     Model: left of     with 0.9690   confidence: True
#   53/1260 Truth: left of     Model: behind      with 0.7897   confidence: False
#   54/1260 Truth: left of     Model: left of     with 0.9629   confidence: True
#   55/1260 Truth: left of     Model: on top of   with 0.9758   confidence: False
#   56/1260 Truth: left of     Model: left of     with 0.9650   confidence: True
#   57/1260 Truth: left of     Model: left of     with 0.9517   confidence: True
#   58/1260 Truth: left of     Model: underneath  with 0.9281   confidence: False
#   59/1260 Truth: left of     Model: left of     with 0.9740   confidence: True
#   60/1260 Truth: left of     Model: in front of with 0.9754   confidence: False
#   61/1260 Truth: left of     Model: underneath  with 0.8686   confidence: False
#   62/1260 Truth: left of     Model: left of     with 0.9644   confidence: True
#   63/1260 Truth: left of     Model: left of     with 0.9683   confidence: True
#   64/1260 Truth: left of     Model: left of     with 0.9488   confidence: True
#   65/1260 Truth: left of     Model: left of     with 0.6523   confidence: True
#   66/1260 Truth: left of     Model: on top of   with 0.9776   confidence: False
#   67/1260 Truth: left of     Model: left of     with 0.8228   confidence: True
#   68/1260 Truth: left of     Model: left of     with 0.9682   confidence: True
#   69/1260 Truth: left of     Model: left of     with 0.9420   confidence: True
#   70/1260 Truth: left of     Model: on top of   with 0.9746   confidence: False
#   71/1260 Truth: left of     Model: in front of with 0.9802   confidence: False
#   72/1260 Truth: left of     Model: left of     with 0.9710   confidence: True
#   73/1260 Truth: left of     Model: left of     with 0.9605   confidence: True
#   74/1260 Truth: left of     Model: on top of   with 0.9664   confidence: False
#   75/1260 Truth: left of     Model: left of     with 0.9334   confidence: True
#   76/1260 Truth: left of     Model: left of     with 0.9685   confidence: True
#   77/1260 Truth: left of     Model: left of     with 0.9564   confidence: True
#   78/1260 Truth: left of     Model: left of     with 0.9558   confidence: True
#   79/1260 Truth: left of     Model: left of     with 0.9514   confidence: True
#   80/1260 Truth: left of     Model: left of     with 0.4936   confidence: True
#   81/1260 Truth: left of     Model: left of     with 0.9523   confidence: True
#   82/1260 Truth: left of     Model: in front of with 0.9470   confidence: False
#   83/1260 Truth: left of     Model: underneath  with 0.9677   confidence: False
#   84/1260 Truth: left of     Model: left of     with 0.9498   confidence: True
#   85/1260 Truth: left of     Model: in front of with 0.9802   confidence: False
#   86/1260 Truth: left of     Model: left of     with 0.9680   confidence: True
#   87/1260 Truth: left of     Model: on top of   with 0.9196   confidence: False
#   88/1260 Truth: left of     Model: on top of   with 0.9748   confidence: False
#   89/1260 Truth: left of     Model: on top of   with 0.9784   confidence: False
#   90/1260 Truth: left of     Model: on top of   with 0.9429   confidence: False
#   91/1260 Truth: left of     Model: on top of   with 0.9743   confidence: False
#   92/1260 Truth: left of     Model: on top of   with 0.9284   confidence: False
#   93/1260 Truth: left of     Model: right of    with 0.9670   confidence: False
#   94/1260 Truth: left of     Model: left of     with 0.9515   confidence: True
#   95/1260 Truth: left of     Model: right of    with 0.9758   confidence: False
#   96/1260 Truth: left of     Model: on top of   with 0.9775   confidence: False
#   97/1260 Truth: left of     Model: on top of   with 0.9591   confidence: False
#   98/1260 Truth: left of     Model: left of     with 0.9507   confidence: True
#   99/1260 Truth: left of     Model: in front of with 0.9398   confidence: False
#  100/1260 Truth: left of     Model: left of     with 0.8215   confidence: True
#  101/1260 Truth: left of     Model: left of     with 0.9510   confidence: True
#  102/1260 Truth: left of     Model: left of     with 0.9611   confidence: True
#  103/1260 Truth: left of     Model: behind      with 0.6424   confidence: False
#  104/1260 Truth: left of     Model: left of     with 0.9602   confidence: True
#  105/1260 Truth: left of     Model: on top of   with 0.9347   confidence: False
#  106/1260 Truth: left of     Model: left of     with 0.9663   confidence: True
#  107/1260 Truth: left of     Model: in front of with 0.9801   confidence: False
#  108/1260 Truth: left of     Model: left of     with 0.9630   confidence: True
#  109/1260 Truth: left of     Model: underneath  with 0.2857   confidence: False
#  110/1260 Truth: left of     Model: on top of   with 0.9760   confidence: False
#  111/1260 Truth: left of     Model: left of     with 0.9618   confidence: True
#  112/1260 Truth: left of     Model: left of     with 0.9385   confidence: True
#  113/1260 Truth: left of     Model: left of     with 0.9666   confidence: True
#  114/1260 Truth: left of     Model: in front of with 0.9798   confidence: False
#  115/1260 Truth: left of     Model: in front of with 0.9799   confidence: False
#  116/1260 Truth: left of     Model: left of     with 0.9638   confidence: True
#  117/1260 Truth: left of     Model: left of     with 0.9652   confidence: True
#  118/1260 Truth: left of     Model: left of     with 0.9690   confidence: True
#  119/1260 Truth: left of     Model: left of     with 0.9491   confidence: True
#  120/1260 Truth: left of     Model: left of     with 0.6358   confidence: True
#  121/1260 Truth: left of     Model: left of     with 0.9576   confidence: True
#  122/1260 Truth: left of     Model: left of     with 0.9525   confidence: True
#  123/1260 Truth: left of     Model: left of     with 0.9644   confidence: True
#  124/1260 Truth: left of     Model: left of     with 0.8025   confidence: True
#  125/1260 Truth: left of     Model: on top of   with 0.9301   confidence: False
#  126/1260 Truth: left of     Model: on top of   with 0.9815   confidence: False
#  127/1260 Truth: left of     Model: left of     with 0.9456   confidence: True
#  128/1260 Truth: left of     Model: left of     with 0.9652   confidence: True
#  129/1260 Truth: left of     Model: on top of   with 0.9363   confidence: False
#  130/1260 Truth: left of     Model: left of     with 0.9594   confidence: True
#  131/1260 Truth: left of     Model: in front of with 0.9750   confidence: False
#  132/1260 Truth: left of     Model: left of     with 0.9651   confidence: True
#  133/1260 Truth: left of     Model: left of     with 0.9557   confidence: True
#  134/1260 Truth: left of     Model: left of     with 0.9661   confidence: True
#  135/1260 Truth: left of     Model: left of     with 0.9616   confidence: True
#  136/1260 Truth: left of     Model: on top of   with 0.9444   confidence: False
#  137/1260 Truth: left of     Model: left of     with 0.6421   confidence: True
#  138/1260 Truth: left of     Model: in front of with 0.9797   confidence: False
#  139/1260 Truth: left of     Model: in front of with 0.9208   confidence: False
#  140/1260 Truth: left of     Model: left of     with 0.9684   confidence: True
#  141/1260 Truth: left of     Model: left of     with 0.5460   confidence: True
#  142/1260 Truth: left of     Model: on top of   with 0.9797   confidence: False
#  143/1260 Truth: left of     Model: left of     with 0.9473   confidence: True
#  144/1260 Truth: left of     Model: left of     with 0.9579   confidence: True
#  145/1260 Truth: left of     Model: on top of   with 0.9759   confidence: False
#  146/1260 Truth: left of     Model: left of     with 0.9270   confidence: True
#  147/1260 Truth: left of     Model: left of     with 0.9677   confidence: True
#  148/1260 Truth: left of     Model: left of     with 0.6482   confidence: True
#  149/1260 Truth: left of     Model: left of     with 0.9511   confidence: True
#  150/1260 Truth: left of     Model: on top of   with 0.9702   confidence: False
#  151/1260 Truth: left of     Model: on top of   with 0.9343   confidence: False
#  152/1260 Truth: left of     Model: on top of   with 0.9160   confidence: False
#  153/1260 Truth: left of     Model: left of     with 0.9675   confidence: True
#  154/1260 Truth: left of     Model: left of     with 0.9560   confidence: True
#  155/1260 Truth: left of     Model: left of     with 0.9678   confidence: True
#  156/1260 Truth: left of     Model: left of     with 0.9601   confidence: True
#  157/1260 Truth: left of     Model: in front of with 0.9779   confidence: False
#  158/1260 Truth: left of     Model: left of     with 0.9598   confidence: True
#  159/1260 Truth: left of     Model: left of     with 0.9636   confidence: True
#  160/1260 Truth: left of     Model: left of     with 0.9663   confidence: True
#  161/1260 Truth: left of     Model: right of    with 0.9690   confidence: False
#  162/1260 Truth: left of     Model: left of     with 0.9631   confidence: True
#  163/1260 Truth: left of     Model: left of     with 0.9673   confidence: True
#  164/1260 Truth: left of     Model: left of     with 0.9601   confidence: True
#  165/1260 Truth: left of     Model: left of     with 0.9454   confidence: True
#  166/1260 Truth: left of     Model: left of     with 0.9633   confidence: True
#  167/1260 Truth: left of     Model: underneath  with 0.9615   confidence: False
#  168/1260 Truth: left of     Model: left of     with 0.9625   confidence: True
#  169/1260 Truth: left of     Model: left of     with 0.9085   confidence: True
#  170/1260 Truth: left of     Model: left of     with 0.9580   confidence: True
#  171/1260 Truth: left of     Model: in front of with 0.9759   confidence: False
#  172/1260 Truth: left of     Model: left of     with 0.9695   confidence: True
#  173/1260 Truth: left of     Model: left of     with 0.9559   confidence: True
#  174/1260 Truth: left of     Model: left of     with 0.9641   confidence: True
#  175/1260 Truth: left of     Model: left of     with 0.9681   confidence: True
#  176/1260 Truth: left of     Model: left of     with 0.9647   confidence: True
#  177/1260 Truth: left of     Model: left of     with 0.6981   confidence: True
#  178/1260 Truth: left of     Model: left of     with 0.9561   confidence: True
#  179/1260 Truth: left of     Model: left of     with 0.9683   confidence: True
#  180/1260 Truth: left of     Model: left of     with 0.9637   confidence: True
#  181/1260 Truth: left of     Model: underneath  with 0.9589   confidence: False
#  182/1260 Truth: left of     Model: left of     with 0.9681   confidence: True
#  183/1260 Truth: left of     Model: left of     with 0.9666   confidence: True
#  184/1260 Truth: left of     Model: left of     with 0.9654   confidence: True
#  185/1260 Truth: left of     Model: underneath  with 0.9180   confidence: False
#  186/1260 Truth: left of     Model: left of     with 0.9670   confidence: True
#  187/1260 Truth: left of     Model: left of     with 0.9660   confidence: True
#  188/1260 Truth: left of     Model: underneath  with 0.9410   confidence: False
#  189/1260 Truth: left of     Model: left of     with 0.9623   confidence: True
#  190/1260 Truth: left of     Model: on top of   with 0.9759   confidence: False
#  191/1260 Truth: left of     Model: left of     with 0.9605   confidence: True
#  192/1260 Truth: left of     Model: right of    with 0.9699   confidence: False
#  193/1260 Truth: left of     Model: underneath  with 0.8440   confidence: False
#  194/1260 Truth: left of     Model: underneath  with 0.9459   confidence: False
#  195/1260 Truth: left of     Model: on top of   with 0.9653   confidence: False
#  196/1260 Truth: left of     Model: left of     with 0.9206   confidence: True
#  197/1260 Truth: left of     Model: left of     with 0.9636   confidence: True
#  198/1260 Truth: left of     Model: left of     with 0.9334   confidence: True
#  199/1260 Truth: left of     Model: behind      with 0.9730   confidence: False
#  200/1260 Truth: left of     Model: underneath  with 0.9628   confidence: False
#  201/1260 Truth: left of     Model: on top of   with 0.9166   confidence: False
#  202/1260 Truth: left of     Model: in front of with 0.9801   confidence: False
#  203/1260 Truth: left of     Model: left of     with 0.9614   confidence: True
#  204/1260 Truth: left of     Model: in front of with 0.9796   confidence: False
#  205/1260 Truth: left of     Model: underneath  with 0.9013   confidence: False
#  206/1260 Truth: left of     Model: left of     with 0.9512   confidence: True
#  207/1260 Truth: left of     Model: left of     with 0.9215   confidence: True
#  208/1260 Truth: left of     Model: underneath  with 0.2473   confidence: False
#  209/1260 Truth: left of     Model: on top of   with 0.8128   confidence: False
#  210/1260 Truth: left of     Model: in front of with 0.9618   confidence: False
#  211/1260 Truth: left of     Model: on top of   with 0.9781   confidence: False
#  212/1260 Truth: left of     Model: on top of   with 0.9768   confidence: False
#  213/1260 Truth: left of     Model: on top of   with 0.9773   confidence: False
#  214/1260 Truth: left of     Model: in front of with 0.9796   confidence: False
#  215/1260 Truth: left of     Model: on top of   with 0.9437   confidence: False
#  216/1260 Truth: left of     Model: left of     with 0.9627   confidence: True
#  217/1260 Truth: left of     Model: left of     with 0.9539   confidence: True
#  218/1260 Truth: right of    Model: on top of   with 0.9637   confidence: False
#  219/1260 Truth: right of    Model: right of    with 0.9752   confidence: True
#  220/1260 Truth: right of    Model: right of    with 0.9556   confidence: True
#  221/1260 Truth: right of    Model: right of    with 0.9702   confidence: True
#  222/1260 Truth: right of    Model: right of    with 0.9754   confidence: True
#  223/1260 Truth: right of    Model: on top of   with 0.9575   confidence: False
#  224/1260 Truth: right of    Model: right of    with 0.9731   confidence: True
#  225/1260 Truth: right of    Model: right of    with 0.9686   confidence: True
#  226/1260 Truth: right of    Model: right of    with 0.9760   confidence: True
#  227/1260 Truth: right of    Model: in front of with 0.9479   confidence: False
#  228/1260 Truth: right of    Model: right of    with 0.9683   confidence: True
#  229/1260 Truth: right of    Model: right of    with 0.8387   confidence: True
#  230/1260 Truth: right of    Model: on top of   with 0.9582   confidence: False
#  231/1260 Truth: right of    Model: right of    with 0.9342   confidence: True
#  232/1260 Truth: right of    Model: left of     with 0.9718   confidence: False
#  233/1260 Truth: right of    Model: right of    with 0.9707   confidence: True
#  234/1260 Truth: right of    Model: underneath  with 0.9770   confidence: False
#  235/1260 Truth: right of    Model: right of    with 0.9717   confidence: True
#  236/1260 Truth: right of    Model: right of    with 0.9169   confidence: True
#  237/1260 Truth: right of    Model: right of    with 0.9762   confidence: True
#  238/1260 Truth: right of    Model: right of    with 0.9708   confidence: True
#  239/1260 Truth: right of    Model: right of    with 0.9751   confidence: True
#  240/1260 Truth: right of    Model: left of     with 0.9632   confidence: False
#  241/1260 Truth: right of    Model: right of    with 0.9762   confidence: True
#  242/1260 Truth: right of    Model: right of    with 0.9631   confidence: True
#  243/1260 Truth: right of    Model: right of    with 0.9773   confidence: True
#  244/1260 Truth: right of    Model: on top of   with 0.9594   confidence: False
#  245/1260 Truth: right of    Model: on top of   with 0.9527   confidence: False
#  246/1260 Truth: right of    Model: left of     with 0.9485   confidence: False
#  247/1260 Truth: right of    Model: right of    with 0.9371   confidence: True
#  248/1260 Truth: right of    Model: right of    with 0.9655   confidence: True
#  249/1260 Truth: right of    Model: right of    with 0.9485   confidence: True
#  250/1260 Truth: right of    Model: left of     with 0.9728   confidence: False
#  251/1260 Truth: right of    Model: left of     with 0.9741   confidence: False
#  252/1260 Truth: right of    Model: right of    with 0.9672   confidence: True
#  253/1260 Truth: right of    Model: right of    with 0.9755   confidence: True
#  254/1260 Truth: right of    Model: right of    with 0.9753   confidence: True
#  255/1260 Truth: right of    Model: right of    with 0.9748   confidence: True
#  256/1260 Truth: right of    Model: right of    with 0.9443   confidence: True
#  257/1260 Truth: right of    Model: underneath  with 0.9773   confidence: False
#  258/1260 Truth: right of    Model: right of    with 0.9341   confidence: True
#  259/1260 Truth: right of    Model: right of    with 0.9384   confidence: True
#  260/1260 Truth: right of    Model: on top of   with 0.9667   confidence: False
#  261/1260 Truth: right of    Model: right of    with 0.9726   confidence: True
#  262/1260 Truth: right of    Model: right of    with 0.9692   confidence: True
#  263/1260 Truth: right of    Model: right of    with 0.9594   confidence: True
#  264/1260 Truth: right of    Model: on top of   with 0.9731   confidence: False
#  265/1260 Truth: right of    Model: right of    with 0.9592   confidence: True
#  266/1260 Truth: right of    Model: right of    with 0.9762   confidence: True
#  267/1260 Truth: right of    Model: right of    with 0.9738   confidence: True
#  268/1260 Truth: right of    Model: on top of   with 0.9649   confidence: False
#  269/1260 Truth: right of    Model: on top of   with 0.9717   confidence: False
#  270/1260 Truth: right of    Model: underneath  with 0.9776   confidence: False
#  271/1260 Truth: right of    Model: right of    with 0.9616   confidence: True
#  272/1260 Truth: right of    Model: right of    with 0.9762   confidence: True
#  273/1260 Truth: right of    Model: right of    with 0.9528   confidence: True
#  274/1260 Truth: right of    Model: right of    with 0.9748   confidence: True
#  275/1260 Truth: right of    Model: right of    with 0.9708   confidence: True
#  276/1260 Truth: right of    Model: right of    with 0.9415   confidence: True
#  277/1260 Truth: right of    Model: right of    with 0.9767   confidence: True
#  278/1260 Truth: right of    Model: right of    with 0.9093   confidence: True
#  279/1260 Truth: right of    Model: right of    with 0.9655   confidence: True
#  280/1260 Truth: right of    Model: right of    with 0.9630   confidence: True
#  281/1260 Truth: right of    Model: right of    with 0.9753   confidence: True
#  282/1260 Truth: right of    Model: right of    with 0.9668   confidence: True
#  283/1260 Truth: right of    Model: right of    with 0.9758   confidence: True
#  284/1260 Truth: right of    Model: right of    with 0.9728   confidence: True
#  285/1260 Truth: right of    Model: right of    with 0.9713   confidence: True
#  286/1260 Truth: right of    Model: right of    with 0.9189   confidence: True
#  287/1260 Truth: right of    Model: right of    with 0.9378   confidence: True
#  288/1260 Truth: right of    Model: left of     with 0.9723   confidence: False
#  289/1260 Truth: right of    Model: right of    with 0.9691   confidence: True
#  290/1260 Truth: right of    Model: right of    with 0.9271   confidence: True
#  291/1260 Truth: right of    Model: right of    with 0.9055   confidence: True
#  292/1260 Truth: right of    Model: right of    with 0.9283   confidence: True
#  293/1260 Truth: right of    Model: right of    with 0.9618   confidence: True
#  294/1260 Truth: right of    Model: right of    with 0.9427   confidence: True
#  295/1260 Truth: right of    Model: right of    with 0.9438   confidence: True
#  296/1260 Truth: right of    Model: right of    with 0.9435   confidence: True
#  297/1260 Truth: right of    Model: right of    with 0.9773   confidence: True
#  298/1260 Truth: right of    Model: right of    with 0.9437   confidence: True
#  299/1260 Truth: right of    Model: on top of   with 0.9644   confidence: False
#  300/1260 Truth: right of    Model: right of    with 0.9758   confidence: True
#  301/1260 Truth: right of    Model: right of    with 0.9392   confidence: True
#  302/1260 Truth: right of    Model: on top of   with 0.9624   confidence: False
#  303/1260 Truth: right of    Model: right of    with 0.9685   confidence: True
#  304/1260 Truth: right of    Model: right of    with 0.9474   confidence: True
#  305/1260 Truth: right of    Model: right of    with 0.9667   confidence: True
#  306/1260 Truth: right of    Model: on top of   with 0.9647   confidence: False
#  307/1260 Truth: right of    Model: right of    with 0.9734   confidence: True
#  308/1260 Truth: right of    Model: right of    with 0.9733   confidence: True
#  309/1260 Truth: right of    Model: on top of   with 0.9570   confidence: False
#  310/1260 Truth: right of    Model: left of     with 0.9739   confidence: False
#  311/1260 Truth: right of    Model: on top of   with 0.9598   confidence: False
#  312/1260 Truth: right of    Model: right of    with 0.9326   confidence: True
#  313/1260 Truth: right of    Model: right of    with 0.9660   confidence: True
#  314/1260 Truth: right of    Model: right of    with 0.9573   confidence: True
#  315/1260 Truth: right of    Model: on top of   with 0.9495   confidence: False
#  316/1260 Truth: right of    Model: right of    with 0.9740   confidence: True
#  317/1260 Truth: right of    Model: right of    with 0.9650   confidence: True
#  318/1260 Truth: right of    Model: right of    with 0.9749   confidence: True
#  319/1260 Truth: right of    Model: right of    with 0.9766   confidence: True
#  320/1260 Truth: right of    Model: right of    with 0.9682   confidence: True
#  321/1260 Truth: right of    Model: right of    with 0.9581   confidence: True
#  322/1260 Truth: right of    Model: right of    with 0.9733   confidence: True
#  323/1260 Truth: right of    Model: right of    with 0.9679   confidence: True
#  324/1260 Truth: right of    Model: right of    with 0.9439   confidence: True
#  325/1260 Truth: right of    Model: right of    with 0.9662   confidence: True
#  326/1260 Truth: right of    Model: right of    with 0.9412   confidence: True
#  327/1260 Truth: right of    Model: right of    with 0.9717   confidence: True
#  328/1260 Truth: right of    Model: right of    with 0.9640   confidence: True
#  329/1260 Truth: right of    Model: right of    with 0.9521   confidence: True
#  330/1260 Truth: right of    Model: right of    with 0.9770   confidence: True
#  331/1260 Truth: right of    Model: right of    with 0.9770   confidence: True
#  332/1260 Truth: right of    Model: left of     with 0.9732   confidence: False
#  333/1260 Truth: right of    Model: right of    with 0.9418   confidence: True
#  334/1260 Truth: right of    Model: right of    with 0.9681   confidence: True
#  335/1260 Truth: right of    Model: right of    with 0.9733   confidence: True
#  336/1260 Truth: right of    Model: right of    with 0.9344   confidence: True
#  337/1260 Truth: right of    Model: right of    with 0.9634   confidence: True
#  338/1260 Truth: right of    Model: right of    with 0.8735   confidence: True
#  339/1260 Truth: right of    Model: right of    with 0.9721   confidence: True
#  340/1260 Truth: right of    Model: underneath  with 0.9777   confidence: False
#  341/1260 Truth: right of    Model: right of    with 0.9672   confidence: True
#  342/1260 Truth: right of    Model: right of    with 0.9393   confidence: True
#  343/1260 Truth: right of    Model: left of     with 0.9735   confidence: False
#  344/1260 Truth: right of    Model: right of    with 0.9608   confidence: True
#  345/1260 Truth: right of    Model: right of    with 0.9560   confidence: True
#  346/1260 Truth: right of    Model: right of    with 0.9755   confidence: True
#  347/1260 Truth: right of    Model: right of    with 0.9638   confidence: True
#  348/1260 Truth: right of    Model: right of    with 0.9755   confidence: True
#  349/1260 Truth: right of    Model: right of    with 0.9707   confidence: True
#  350/1260 Truth: right of    Model: on top of   with 0.9602   confidence: False
#  351/1260 Truth: right of    Model: left of     with 0.9741   confidence: False
#  352/1260 Truth: right of    Model: right of    with 0.9695   confidence: True
#  353/1260 Truth: right of    Model: right of    with 0.9597   confidence: True
#  354/1260 Truth: right of    Model: on top of   with 0.9641   confidence: False
#  355/1260 Truth: right of    Model: right of    with 0.9767   confidence: True
#  356/1260 Truth: right of    Model: right of    with 0.9712   confidence: True
#  357/1260 Truth: right of    Model: right of    with 0.9661   confidence: True
#  358/1260 Truth: right of    Model: on top of   with 0.9492   confidence: False
#  359/1260 Truth: right of    Model: right of    with 0.9695   confidence: True
#  360/1260 Truth: right of    Model: right of    with 0.9738   confidence: True
#  361/1260 Truth: right of    Model: right of    with 0.9730   confidence: True
#  362/1260 Truth: right of    Model: right of    with 0.9645   confidence: True
#  363/1260 Truth: right of    Model: right of    with 0.9645   confidence: True
#  364/1260 Truth: right of    Model: right of    with 0.8365   confidence: True
#  365/1260 Truth: right of    Model: left of     with 0.9734   confidence: False
#  366/1260 Truth: right of    Model: right of    with 0.9733   confidence: True
#  367/1260 Truth: right of    Model: right of    with 0.9636   confidence: True
#  368/1260 Truth: right of    Model: on top of   with 0.9697   confidence: False
#  369/1260 Truth: right of    Model: right of    with 0.9748   confidence: True
#  370/1260 Truth: right of    Model: right of    with 0.9693   confidence: True
#  371/1260 Truth: right of    Model: right of    with 0.9715   confidence: True
#  372/1260 Truth: right of    Model: on top of   with 0.9614   confidence: False
#  373/1260 Truth: right of    Model: on top of   with 0.9699   confidence: False
#  374/1260 Truth: right of    Model: right of    with 0.9452   confidence: True
#  375/1260 Truth: right of    Model: right of    with 0.9470   confidence: True
#  376/1260 Truth: right of    Model: underneath  with 0.9776   confidence: False
#  377/1260 Truth: right of    Model: right of    with 0.9399   confidence: True
#  378/1260 Truth: right of    Model: right of    with 0.9722   confidence: True
#  379/1260 Truth: right of    Model: right of    with 0.9706   confidence: True
#  380/1260 Truth: right of    Model: right of    with 0.9712   confidence: True
#  381/1260 Truth: right of    Model: left of     with 0.9724   confidence: False
#  382/1260 Truth: right of    Model: right of    with 0.9462   confidence: True
#  383/1260 Truth: right of    Model: on top of   with 0.9620   confidence: False
#  384/1260 Truth: right of    Model: right of    with 0.9470   confidence: True
#  385/1260 Truth: right of    Model: right of    with 0.9476   confidence: True
#  386/1260 Truth: right of    Model: on top of   with 0.9317   confidence: False
#  387/1260 Truth: right of    Model: on top of   with 0.9636   confidence: False
#  388/1260 Truth: right of    Model: right of    with 0.9759   confidence: True
#  389/1260 Truth: right of    Model: right of    with 0.9224   confidence: True
#  390/1260 Truth: right of    Model: right of    with 0.9596   confidence: True
#  391/1260 Truth: right of    Model: right of    with 0.9463   confidence: True
#  392/1260 Truth: right of    Model: right of    with 0.9700   confidence: True
#  393/1260 Truth: right of    Model: right of    with 0.9691   confidence: True
#  394/1260 Truth: right of    Model: right of    with 0.9475   confidence: True
#  395/1260 Truth: right of    Model: right of    with 0.9618   confidence: True
#  396/1260 Truth: right of    Model: right of    with 0.9679   confidence: True
#  397/1260 Truth: right of    Model: right of    with 0.9694   confidence: True
#  398/1260 Truth: right of    Model: left of     with 0.9724   confidence: False
#  399/1260 Truth: right of    Model: right of    with 0.8833   confidence: True
#  400/1260 Truth: right of    Model: right of    with 0.9673   confidence: True
#  401/1260 Truth: right of    Model: right of    with 0.8647   confidence: True
#  402/1260 Truth: right of    Model: left of     with 0.9739   confidence: False
#  403/1260 Truth: right of    Model: right of    with 0.9326   confidence: True
#  404/1260 Truth: right of    Model: right of    with 0.9706   confidence: True
#  405/1260 Truth: right of    Model: right of    with 0.9500   confidence: True
#  406/1260 Truth: right of    Model: right of    with 0.9685   confidence: True
#  407/1260 Truth: right of    Model: right of    with 0.9703   confidence: True
#  408/1260 Truth: right of    Model: right of    with 0.9706   confidence: True
#  409/1260 Truth: right of    Model: right of    with 0.9579   confidence: True
#  410/1260 Truth: right of    Model: right of    with 0.9626   confidence: True
#  411/1260 Truth: on top of   Model: on top of   with 0.9430   confidence: True
#  412/1260 Truth: on top of   Model: left of     with 0.9657   confidence: False
#  413/1260 Truth: on top of   Model: on top of   with 0.9260   confidence: True
#  414/1260 Truth: on top of   Model: on top of   with 0.9195   confidence: True
#  415/1260 Truth: on top of   Model: on top of   with 0.9765   confidence: True
#  416/1260 Truth: on top of   Model: on top of   with 0.9562   confidence: True
#  417/1260 Truth: on top of   Model: on top of   with 0.8157   confidence: True
#  418/1260 Truth: on top of   Model: on top of   with 0.9368   confidence: True
#  419/1260 Truth: on top of   Model: on top of   with 0.9739   confidence: True
#  420/1260 Truth: on top of   Model: on top of   with 0.9255   confidence: True
#  421/1260 Truth: on top of   Model: on top of   with 0.8966   confidence: True
#  422/1260 Truth: on top of   Model: on top of   with 0.9752   confidence: True
#  423/1260 Truth: on top of   Model: left of     with 0.9667   confidence: False
#  424/1260 Truth: on top of   Model: on top of   with 0.9408   confidence: True
#  425/1260 Truth: on top of   Model: on top of   with 0.9446   confidence: True
#  426/1260 Truth: on top of   Model: left of     with 0.9551   confidence: False
#  427/1260 Truth: on top of   Model: on top of   with 0.9678   confidence: True
#  428/1260 Truth: on top of   Model: on top of   with 0.9616   confidence: True
#  429/1260 Truth: on top of   Model: on top of   with 0.9791   confidence: True
#  430/1260 Truth: on top of   Model: on top of   with 0.9252   confidence: True
#  431/1260 Truth: on top of   Model: on top of   with 0.8865   confidence: True
#  432/1260 Truth: on top of   Model: on top of   with 0.9317   confidence: True
#  433/1260 Truth: on top of   Model: on top of   with 0.9742   confidence: True
#  434/1260 Truth: on top of   Model: on top of   with 0.9797   confidence: True
#  435/1260 Truth: on top of   Model: on top of   with 0.9654   confidence: True
#  436/1260 Truth: on top of   Model: on top of   with 0.9740   confidence: True
#  437/1260 Truth: on top of   Model: on top of   with 0.9721   confidence: True
#  438/1260 Truth: on top of   Model: left of     with 0.9660   confidence: False
#  439/1260 Truth: on top of   Model: left of     with 0.7836   confidence: False
#  440/1260 Truth: on top of   Model: left of     with 0.9695   confidence: False
#  441/1260 Truth: on top of   Model: on top of   with 0.9540   confidence: True
#  442/1260 Truth: on top of   Model: left of     with 0.9682   confidence: False
#  443/1260 Truth: on top of   Model: on top of   with 0.9235   confidence: True
#  444/1260 Truth: on top of   Model: on top of   with 0.9654   confidence: True
#  445/1260 Truth: on top of   Model: on top of   with 0.9608   confidence: True
#  446/1260 Truth: on top of   Model: on top of   with 0.8138   confidence: True
#  447/1260 Truth: on top of   Model: on top of   with 0.9216   confidence: True
#  448/1260 Truth: on top of   Model: on top of   with 0.9403   confidence: True
#  449/1260 Truth: on top of   Model: left of     with 0.9606   confidence: False
#  450/1260 Truth: on top of   Model: on top of   with 0.9769   confidence: True
#  451/1260 Truth: on top of   Model: on top of   with 0.9767   confidence: True
#  452/1260 Truth: on top of   Model: on top of   with 0.7632   confidence: True
#  453/1260 Truth: on top of   Model: on top of   with 0.9303   confidence: True
#  454/1260 Truth: on top of   Model: on top of   with 0.9676   confidence: True
#  455/1260 Truth: on top of   Model: on top of   with 0.9179   confidence: True
#  456/1260 Truth: on top of   Model: left of     with 0.9710   confidence: False
#  457/1260 Truth: on top of   Model: left of     with 0.9683   confidence: False
#  458/1260 Truth: on top of   Model: on top of   with 0.9302   confidence: True
#  459/1260 Truth: on top of   Model: left of     with 0.8009   confidence: False
#  460/1260 Truth: on top of   Model: on top of   with 0.9642   confidence: True
#  461/1260 Truth: on top of   Model: on top of   with 0.9754   confidence: True
#  462/1260 Truth: on top of   Model: on top of   with 0.8146   confidence: True
#  463/1260 Truth: on top of   Model: on top of   with 0.9307   confidence: True
#  464/1260 Truth: on top of   Model: on top of   with 0.9197   confidence: True
#  465/1260 Truth: on top of   Model: on top of   with 0.9088   confidence: True
#  466/1260 Truth: on top of   Model: on top of   with 0.9598   confidence: True
#  467/1260 Truth: on top of   Model: on top of   with 0.9527   confidence: True
#  468/1260 Truth: on top of   Model: left of     with 0.9552   confidence: False
#  469/1260 Truth: on top of   Model: on top of   with 0.9300   confidence: True
#  470/1260 Truth: on top of   Model: on top of   with 0.9470   confidence: True
#  471/1260 Truth: on top of   Model: on top of   with 0.9753   confidence: True
#  472/1260 Truth: on top of   Model: on top of   with 0.9735   confidence: True
#  473/1260 Truth: on top of   Model: on top of   with 0.9182   confidence: True
#  474/1260 Truth: on top of   Model: on top of   with 0.8964   confidence: True
#  475/1260 Truth: on top of   Model: right of    with 0.8356   confidence: False
#  476/1260 Truth: on top of   Model: left of     with 0.9722   confidence: False
#  477/1260 Truth: on top of   Model: on top of   with 0.9160   confidence: True
#  478/1260 Truth: on top of   Model: on top of   with 0.9740   confidence: True
#  479/1260 Truth: on top of   Model: on top of   with 0.9768   confidence: True
#  480/1260 Truth: on top of   Model: on top of   with 0.9771   confidence: True
#  481/1260 Truth: on top of   Model: on top of   with 0.8039   confidence: True
#  482/1260 Truth: on top of   Model: on top of   with 0.9622   confidence: True
#  483/1260 Truth: on top of   Model: on top of   with 0.9380   confidence: True
#  484/1260 Truth: on top of   Model: on top of   with 0.9792   confidence: True
#  485/1260 Truth: on top of   Model: on top of   with 0.9534   confidence: True
#  486/1260 Truth: on top of   Model: on top of   with 0.9671   confidence: True
#  487/1260 Truth: on top of   Model: left of     with 0.9701   confidence: False
#  488/1260 Truth: on top of   Model: right of    with 0.8807   confidence: False
#  489/1260 Truth: on top of   Model: on top of   with 0.9256   confidence: True
#  490/1260 Truth: on top of   Model: on top of   with 0.8959   confidence: True
#  491/1260 Truth: on top of   Model: on top of   with 0.9284   confidence: True
#  492/1260 Truth: on top of   Model: on top of   with 0.9506   confidence: True
#  493/1260 Truth: on top of   Model: on top of   with 0.9011   confidence: True
#  494/1260 Truth: on top of   Model: on top of   with 0.9323   confidence: True
#  495/1260 Truth: on top of   Model: left of     with 0.9629   confidence: False
#  496/1260 Truth: on top of   Model: on top of   with 0.9639   confidence: True
#  497/1260 Truth: on top of   Model: left of     with 0.9611   confidence: False
#  498/1260 Truth: on top of   Model: on top of   with 0.9396   confidence: True
#  499/1260 Truth: on top of   Model: on top of   with 0.9758   confidence: True
#  500/1260 Truth: on top of   Model: on top of   with 0.9144   confidence: True
#  501/1260 Truth: on top of   Model: on top of   with 0.8130   confidence: True
#  502/1260 Truth: on top of   Model: on top of   with 0.9426   confidence: True
#  503/1260 Truth: on top of   Model: on top of   with 0.9759   confidence: True
#  504/1260 Truth: on top of   Model: on top of   with 0.9075   confidence: True
#  505/1260 Truth: on top of   Model: on top of   with 0.9766   confidence: True
#  506/1260 Truth: on top of   Model: on top of   with 0.9410   confidence: True
#  507/1260 Truth: on top of   Model: right of    with 0.8413   confidence: False
#  508/1260 Truth: on top of   Model: right of    with 0.8076   confidence: False
#  509/1260 Truth: on top of   Model: on top of   with 0.9477   confidence: True
#  510/1260 Truth: on top of   Model: on top of   with 0.9161   confidence: True
#  511/1260 Truth: on top of   Model: on top of   with 0.8078   confidence: True
#  512/1260 Truth: on top of   Model: on top of   with 0.9209   confidence: True
#  513/1260 Truth: on top of   Model: on top of   with 0.9748   confidence: True
#  514/1260 Truth: on top of   Model: on top of   with 0.9305   confidence: True
#  515/1260 Truth: on top of   Model: left of     with 0.9687   confidence: False
#  516/1260 Truth: on top of   Model: on top of   with 0.9734   confidence: True
#  517/1260 Truth: on top of   Model: left of     with 0.9626   confidence: False
#  518/1260 Truth: on top of   Model: on top of   with 0.9770   confidence: True
#  519/1260 Truth: on top of   Model: on top of   with 0.9771   confidence: True
#  520/1260 Truth: on top of   Model: left of     with 0.9566   confidence: False
#  521/1260 Truth: on top of   Model: on top of   with 0.9126   confidence: True
#  522/1260 Truth: on top of   Model: on top of   with 0.9787   confidence: True
#  523/1260 Truth: on top of   Model: on top of   with 0.9316   confidence: True
#  524/1260 Truth: on top of   Model: on top of   with 0.9187   confidence: True
#  525/1260 Truth: on top of   Model: left of     with 0.9697   confidence: False
#  526/1260 Truth: on top of   Model: on top of   with 0.8975   confidence: True
#  527/1260 Truth: on top of   Model: on top of   with 0.9628   confidence: True
#  528/1260 Truth: on top of   Model: on top of   with 0.9776   confidence: True
#  529/1260 Truth: on top of   Model: on top of   with 0.9565   confidence: True
#  530/1260 Truth: on top of   Model: on top of   with 0.9694   confidence: True
#  531/1260 Truth: on top of   Model: on top of   with 0.9750   confidence: True
#  532/1260 Truth: on top of   Model: on top of   with 0.9727   confidence: True
#  533/1260 Truth: on top of   Model: on top of   with 0.9767   confidence: True
#  534/1260 Truth: on top of   Model: on top of   with 0.9580   confidence: True
#  535/1260 Truth: on top of   Model: on top of   with 0.9785   confidence: True
#  536/1260 Truth: on top of   Model: left of     with 0.9694   confidence: False
#  537/1260 Truth: on top of   Model: on top of   with 0.9386   confidence: True
#  538/1260 Truth: on top of   Model: left of     with 0.8039   confidence: False
#  539/1260 Truth: on top of   Model: left of     with 0.9630   confidence: False
#  540/1260 Truth: on top of   Model: on top of   with 0.9749   confidence: True
# ...
# 1058/1260 Truth: in front of Model: in front of with 0.9731   confidence: True
# 1059/1260 Truth: behind      Model: on top of   with 0.9812   confidence: False
# 1060/1260 Truth: behind      Model: behind      with 0.9753   confidence: True
# 1061/1260 Truth: behind      Model: behind      with 0.9617   confidence: True
# 1062/1260 Truth: behind      Model: behind      with 0.5209   confidence: True
# 1063/1260 Truth: behind      Model: behind      with 0.9619   confidence: True
# 1064/1260 Truth: behind      Model: behind      with 0.9703   confidence: True
# 1065/1260 Truth: behind      Model: behind      with 0.9479   confidence: True
# 1066/1260 Truth: behind      Model: behind      with 0.9744   confidence: True
# 1067/1260 Truth: behind      Model: behind      with 0.9686   confidence: True
# 1068/1260 Truth: behind      Model: behind      with 0.9314   confidence: True
# 1069/1260 Truth: behind      Model: behind      with 0.9729   confidence: True
# 1070/1260 Truth: behind      Model: behind      with 0.9690   confidence: True
# 1071/1260 Truth: behind      Model: behind      with 0.7794   confidence: True
# 1072/1260 Truth: behind      Model: behind      with 0.7715   confidence: True
# 1073/1260 Truth: behind      Model: behind      with 0.9598   confidence: True
# 1074/1260 Truth: behind      Model: behind      with 0.4851   confidence: True
# 1075/1260 Truth: behind      Model: behind      with 0.9505   confidence: True
# 1076/1260 Truth: behind      Model: behind      with 0.9505   confidence: True
# 1077/1260 Truth: behind      Model: behind      with 0.9696   confidence: True
# 1078/1260 Truth: behind      Model: behind      with 0.9562   confidence: True
# 1079/1260 Truth: behind      Model: behind      with 0.9616   confidence: True
# 1080/1260 Truth: behind      Model: behind      with 0.9414   confidence: True
# 1081/1260 Truth: behind      Model: behind      with 0.9414   confidence: True
# 1082/1260 Truth: behind      Model: behind      with 0.9700   confidence: True
# 1083/1260 Truth: behind      Model: behind      with 0.9718   confidence: True
# 1084/1260 Truth: behind      Model: behind      with 0.6521   confidence: True
# 1085/1260 Truth: behind      Model: behind      with 0.9496   confidence: True
# 1086/1260 Truth: behind      Model: behind      with 0.5894   confidence: True
# 1087/1260 Truth: behind      Model: behind      with 0.9720   confidence: True
# 1088/1260 Truth: behind      Model: behind      with 0.9529   confidence: True
# 1089/1260 Truth: behind      Model: behind      with 0.9529   confidence: True
# 1090/1260 Truth: behind      Model: right of    with 0.9772   confidence: False
# 1091/1260 Truth: behind      Model: behind      with 0.9650   confidence: True
# 1092/1260 Truth: behind      Model: on top of   with 0.9740   confidence: False
# 1093/1260 Truth: behind      Model: behind      with 0.9758   confidence: True
# 1094/1260 Truth: behind      Model: behind      with 0.9593   confidence: True
# 1095/1260 Truth: behind      Model: behind      with 0.9633   confidence: True
# 1096/1260 Truth: behind      Model: left of     with 0.8417   confidence: False
# 1097/1260 Truth: behind      Model: behind      with 0.4855   confidence: True
# 1098/1260 Truth: behind      Model: behind      with 0.7497   confidence: True
# 1099/1260 Truth: behind      Model: behind      with 0.9718   confidence: True
# 1100/1260 Truth: behind      Model: behind      with 0.9730   confidence: True
# 1101/1260 Truth: behind      Model: behind      with 0.8745   confidence: True
# 1102/1260 Truth: behind      Model: behind      with 0.9699   confidence: True
# 1103/1260 Truth: behind      Model: behind      with 0.9627   confidence: True
# 1104/1260 Truth: behind      Model: behind      with 0.8018   confidence: True
# 1105/1260 Truth: behind      Model: behind      with 0.9582   confidence: True
# 1106/1260 Truth: behind      Model: behind      with 0.8420   confidence: True
# 1107/1260 Truth: behind      Model: behind      with 0.9605   confidence: True
# 1108/1260 Truth: behind      Model: behind      with 0.7165   confidence: True
# 1109/1260 Truth: behind      Model: behind      with 0.9058   confidence: True
# 1110/1260 Truth: behind      Model: behind      with 0.9567   confidence: True
# 1111/1260 Truth: behind      Model: behind      with 0.6692   confidence: True
# 1112/1260 Truth: behind      Model: behind      with 0.8866   confidence: True
# 1113/1260 Truth: behind      Model: behind      with 0.9688   confidence: True
# 1114/1260 Truth: behind      Model: behind      with 0.8280   confidence: True
# 1115/1260 Truth: behind      Model: behind      with 0.5945   confidence: True
# 1116/1260 Truth: behind      Model: on top of   with 0.9782   confidence: False
# 1117/1260 Truth: behind      Model: behind      with 0.9604   confidence: True
# 1118/1260 Truth: behind      Model: behind      with 0.9607   confidence: True
# 1119/1260 Truth: behind      Model: on top of   with 0.9759   confidence: False
# 1120/1260 Truth: behind      Model: behind      with 0.9743   confidence: True
# 1121/1260 Truth: behind      Model: behind      with 0.9712   confidence: True
# 1122/1260 Truth: behind      Model: behind      with 0.8434   confidence: True
# 1123/1260 Truth: behind      Model: behind      with 0.9678   confidence: True
# 1124/1260 Truth: behind      Model: right of    with 0.9772   confidence: False
# 1125/1260 Truth: behind      Model: on top of   with 0.9758   confidence: False
# 1126/1260 Truth: behind      Model: behind      with 0.9338   confidence: True
# 1127/1260 Truth: behind      Model: behind      with 0.8090   confidence: True
# 1128/1260 Truth: behind      Model: behind      with 0.9741   confidence: True
# 1129/1260 Truth: behind      Model: behind      with 0.9741   confidence: True
# 1130/1260 Truth: behind      Model: behind      with 0.9520   confidence: True
# 1131/1260 Truth: behind      Model: left of     with 0.8211   confidence: False
# 1132/1260 Truth: behind      Model: behind      with 0.9506   confidence: True
# 1133/1260 Truth: behind      Model: behind      with 0.9670   confidence: True
# 1134/1260 Truth: behind      Model: behind      with 0.6357   confidence: True
# 1135/1260 Truth: behind      Model: behind      with 0.9589   confidence: True
# 1136/1260 Truth: behind      Model: behind      with 0.9635   confidence: True
# 1137/1260 Truth: behind      Model: on top of   with 0.9803   confidence: False
# 1138/1260 Truth: behind      Model: behind      with 0.8876   confidence: True
# 1139/1260 Truth: behind      Model: behind      with 0.9689   confidence: True
# 1140/1260 Truth: behind      Model: behind      with 0.9696   confidence: True
# 1141/1260 Truth: behind      Model: behind      with 0.9500   confidence: True
# 1142/1260 Truth: behind      Model: behind      with 0.9692   confidence: True
# 1143/1260 Truth: behind      Model: behind      with 0.9499   confidence: True
# 1144/1260 Truth: behind      Model: behind      with 0.8637   confidence: True
# 1145/1260 Truth: behind      Model: behind      with 0.9721   confidence: True
# 1146/1260 Truth: behind      Model: on top of   with 0.9748   confidence: False
# 1147/1260 Truth: behind      Model: behind      with 0.9504   confidence: True
# 1148/1260 Truth: behind      Model: behind      with 0.8699   confidence: True
# 1149/1260 Truth: behind      Model: right of    with 0.9764   confidence: False
# 1150/1260 Truth: behind      Model: behind      with 0.8783   confidence: True
# 1151/1260 Truth: behind      Model: right of    with 0.9762   confidence: False
# 1152/1260 Truth: behind      Model: behind      with 0.9603   confidence: True
# 1153/1260 Truth: behind      Model: behind      with 0.9652   confidence: True
# 1154/1260 Truth: behind      Model: on top of   with 0.9749   confidence: False
# 1155/1260 Truth: behind      Model: behind      with 0.7120   confidence: True
# 1156/1260 Truth: behind      Model: behind      with 0.5039   confidence: True
# 1157/1260 Truth: behind      Model: behind      with 0.9649   confidence: True
# 1158/1260 Truth: behind      Model: on top of   with 0.9766   confidence: False
# 1159/1260 Truth: behind      Model: underneath  with 0.9767   confidence: False
# 1160/1260 Truth: behind      Model: behind      with 0.9468   confidence: True
# 1161/1260 Truth: behind      Model: behind      with 0.9632   confidence: True
# 1162/1260 Truth: behind      Model: behind      with 0.9124   confidence: True
# 1163/1260 Truth: behind      Model: behind      with 0.9643   confidence: True
# 1164/1260 Truth: behind      Model: behind      with 0.8640   confidence: True
# 1165/1260 Truth: behind      Model: behind      with 0.9404   confidence: True
# 1166/1260 Truth: behind      Model: behind      with 0.9344   confidence: True
# 1167/1260 Truth: behind      Model: right of    with 0.9756   confidence: False
# 1168/1260 Truth: behind      Model: on top of   with 0.9753   confidence: False
# 1169/1260 Truth: behind      Model: behind      with 0.8947   confidence: True
# 1170/1260 Truth: behind      Model: on top of   with 0.9732   confidence: False
# 1171/1260 Truth: behind      Model: behind      with 0.9629   confidence: True
# 1172/1260 Truth: behind      Model: on top of   with 0.9744   confidence: False
# 1173/1260 Truth: behind      Model: behind      with 0.9692   confidence: True
# 1174/1260 Truth: behind      Model: behind      with 0.5458   confidence: True
# 1175/1260 Truth: behind      Model: behind      with 0.6581   confidence: True
# 1176/1260 Truth: behind      Model: behind      with 0.9506   confidence: True
# 1177/1260 Truth: behind      Model: left of     with 0.6680   confidence: False
# 1178/1260 Truth: behind      Model: behind      with 0.9725   confidence: True
# 1179/1260 Truth: behind      Model: behind      with 0.9202   confidence: True
# 1180/1260 Truth: behind      Model: behind      with 0.9677   confidence: True
# 1181/1260 Truth: behind      Model: on top of   with 0.9815   confidence: False
# 1182/1260 Truth: behind      Model: behind      with 0.8540   confidence: True
# 1183/1260 Truth: behind      Model: behind      with 0.9579   confidence: True
# 1184/1260 Truth: behind      Model: on top of   with 0.9746   confidence: False
# 1185/1260 Truth: behind      Model: behind      with 0.5707   confidence: True
# 1186/1260 Truth: behind      Model: behind      with 0.8407   confidence: True
# 1187/1260 Truth: behind      Model: behind      with 0.9596   confidence: True
# 1188/1260 Truth: behind      Model: behind      with 0.9719   confidence: True
# 1189/1260 Truth: behind      Model: behind      with 0.9500   confidence: True
# 1190/1260 Truth: behind      Model: behind      with 0.8510   confidence: True
# 1191/1260 Truth: behind      Model: on top of   with 0.9815   confidence: False
# 1192/1260 Truth: behind      Model: behind      with 0.5267   confidence: True
# 1193/1260 Truth: behind      Model: behind      with 0.9743   confidence: True
# 1194/1260 Truth: behind      Model: on top of   with 0.9743   confidence: False
# 1195/1260 Truth: behind      Model: behind      with 0.9531   confidence: True
# 1196/1260 Truth: behind      Model: behind      with 0.9686   confidence: True
# 1197/1260 Truth: behind      Model: behind      with 0.7582   confidence: True
# 1198/1260 Truth: behind      Model: behind      with 0.8564   confidence: True
# 1199/1260 Truth: behind      Model: behind      with 0.9707   confidence: True
# 1200/1260 Truth: behind      Model: underneath  with 0.9709   confidence: False
# 1201/1260 Truth: behind      Model: behind      with 0.9533   confidence: True
# 1202/1260 Truth: behind      Model: behind      with 0.6699   confidence: True
# 1203/1260 Truth: behind      Model: behind      with 0.9713   confidence: True
# 1204/1260 Truth: behind      Model: behind      with 0.9541   confidence: True
# 1205/1260 Truth: behind      Model: behind      with 0.6563   confidence: True
# 1206/1260 Truth: behind      Model: underneath  with 0.9748   confidence: False
# 1207/1260 Truth: behind      Model: behind      with 0.9709   confidence: True
# 1208/1260 Truth: behind      Model: behind      with 0.7669   confidence: True
# 1209/1260 Truth: behind      Model: behind      with 0.9122   confidence: True
# 1210/1260 Truth: behind      Model: behind      with 0.9628   confidence: True
# 1211/1260 Truth: behind      Model: behind      with 0.9618   confidence: True
# 1212/1260 Truth: behind      Model: right of    with 0.9766   confidence: False
# 1213/1260 Truth: behind      Model: on top of   with 0.9752   confidence: False
# 1214/1260 Truth: behind      Model: behind      with 0.7751   confidence: True
# 1215/1260 Truth: behind      Model: behind      with 0.9681   confidence: True
# 1216/1260 Truth: behind      Model: behind      with 0.4642   confidence: True
# 1217/1260 Truth: behind      Model: behind      with 0.9277   confidence: True
# 1218/1260 Truth: behind      Model: behind      with 0.8042   confidence: True
# 1219/1260 Truth: behind      Model: behind      with 0.9735   confidence: True
# 1220/1260 Truth: behind      Model: behind      with 0.5943   confidence: True
# 1221/1260 Truth: behind      Model: behind      with 0.7627   confidence: True
# 1222/1260 Truth: behind      Model: behind      with 0.8677   confidence: True
# 1223/1260 Truth: behind      Model: on top of   with 0.9736   confidence: False
# 1224/1260 Truth: behind      Model: behind      with 0.9661   confidence: True
# 1225/1260 Truth: behind      Model: on top of   with 0.9732   confidence: False
# 1226/1260 Truth: behind      Model: behind      with 0.9519   confidence: True
# 1227/1260 Truth: behind      Model: behind      with 0.8737   confidence: True
# 1228/1260 Truth: behind      Model: right of    with 0.9766   confidence: False
# 1229/1260 Truth: behind      Model: behind      with 0.7796   confidence: True
# 1230/1260 Truth: behind      Model: behind      with 0.9550   confidence: True
# 1231/1260 Truth: behind      Model: behind      with 0.9051   confidence: True
# 1232/1260 Truth: behind      Model: behind      with 0.9685   confidence: True
# 1233/1260 Truth: behind      Model: behind      with 0.9601   confidence: True
# 1234/1260 Truth: behind      Model: behind      with 0.9698   confidence: True
# 1235/1260 Truth: behind      Model: behind      with 0.8100   confidence: True
# 1236/1260 Truth: behind      Model: behind      with 0.9690   confidence: True
# 1237/1260 Truth: behind      Model: behind      with 0.9656   confidence: True
# 1238/1260 Truth: behind      Model: behind      with 0.9712   confidence: True
# 1239/1260 Truth: behind      Model: behind      with 0.9545   confidence: True
# 1240/1260 Truth: behind      Model: on top of   with 0.9761   confidence: False
# 1241/1260 Truth: behind      Model: behind      with 0.8359   confidence: True
# 1242/1260 Truth: behind      Model: behind      with 0.9672   confidence: True
# 1243/1260 Truth: behind      Model: behind      with 0.9348   confidence: True
# 1244/1260 Truth: behind      Model: behind      with 0.7752   confidence: True
# 1245/1260 Truth: behind      Model: behind      with 0.9737   confidence: True
# 1246/1260 Truth: behind      Model: behind      with 0.9736   confidence: True
# 1247/1260 Truth: behind      Model: behind      with 0.9700   confidence: True
# 1248/1260 Truth: behind      Model: behind      with 0.9746   confidence: True
# 1249/1260 Truth: behind      Model: right of    with 0.9755   confidence: False
# 1250/1260 Truth: behind      Model: behind      with 0.8713   confidence: True
# 1251/1260 Truth: behind      Model: right of    with 0.9767   confidence: False
# 1252/1260 Truth: behind      Model: behind      with 0.8110   confidence: True
# 1253/1260 Truth: behind      Model: behind      with 0.6817   confidence: True
# 1254/1260 Truth: behind      Model: behind      with 0.9727   confidence: True
# 1255/1260 Truth: behind      Model: behind      with 0.9717   confidence: True
# 1256/1260 Truth: behind      Model: behind      with 0.8167   confidence: True
# 1257/1260 Truth: behind      Model: behind      with 0.9586   confidence: True
# 1258/1260 Truth: behind      Model: behind      with 0.8692   confidence: True
# 1259/1260 Truth: behind      Model: behind      with 0.8250   confidence: True

# %%
confMatLabels = copy.deepcopy(staticPoseModel.textLabels)
confMatLabels.sort()

from sklearn.metrics import confusion_matrix
h = confusion_matrix(Lsample, ss)
print h
plot_confusion_matrix(h, confMatLabels)
# Out:
# [[166   0   3  20   9   3]
#  [  0 171   4   2   0  32]
#  [  3  23 133  39   5  15]
#  [  0   0  33 170   9   0]
#  [  0   1  14  24 149   5]
#  [  0  17  23   0  12 175]]

# %%
percCorect = 100*np.diag(h.astype(np.float)).sum()/numItems

normConf = h / h.astype(np.float).sum(axis=0)
normConf = np.nan_to_num(normConf)
print
print 'Nomalised Confusion Matrix = '
print normConf
print 

print str(percCorect)[:5].ljust(7) + " % correct for training data"

for i in range(cmSize):
    for j in range(cmSize):
        print str(normConf[i,j]*100)[:5].ljust(7) + '% of ' + str(staticPoseModel.textLabels[i]) + ' classified as ' + str(staticPoseModel.textLabels[j])
    print

print
# Out:
# Nomalised Confusion Matrix =
# [[ 0.98224852  0.          0.01428571  0.07843137  0.04891304  0.01304348]
#  [ 0.          0.80660377  0.01904762  0.00784314  0.          0.13913043]
#  [ 0.01775148  0.10849057  0.63333333  0.15294118  0.02717391  0.06521739]
#  [ 0.          0.          0.15714286  0.66666667  0.04891304  0.        ]
#  [ 0.          0.00471698  0.06666667  0.09411765  0.80978261  0.02173913]
#  [ 0.          0.08018868  0.10952381  0.          0.06521739  0.76086957]]
#
# 76.50   % correct for training data
# 98.22  % of left of classified as left of
# 0.0    % of left of classified as right of
# 1.428  % of left of classified as on top of
# 7.843  % of left of classified as underneath
# 4.891  % of left of classified as in front of
# 1.304  % of left of classified as behind
#
# 0.0    % of right of classified as left of
# 80.66  % of right of classified as right of
# 1.904  % of right of classified as on top of
# 0.784  % of right of classified as underneath
# 0.0    % of right of classified as in front of
# 13.91  % of right of classified as behind
#
# 1.775  % of on top of classified as left of
# 10.84  % of on top of classified as right of
# 63.33  % of on top of classified as on top of
# 15.29  % of on top of classified as underneath
# 2.717  % of on top of classified as in front of
# 6.521  % of on top of classified as behind
#
# 0.0    % of underneath classified as left of
# 0.0    % of underneath classified as right of
# 15.71  % of underneath classified as on top of
# 66.66  % of underneath classified as underneath
# 4.891  % of underneath classified as in front of
# 0.0    % of underneath classified as behind
#
# 0.0    % of in front of classified as left of
# 0.471  % of in front of classified as right of
# 6.666  % of in front of classified as on top of
# 9.411  % of in front of classified as underneath
# 80.97  % of in front of classified as in front of
# 2.173  % of in front of classified as behind
#
# 0.0    % of behind classified as left of
# 8.018  % of behind classified as right of
# 10.95  % of behind classified as on top of
# 0.0    % of behind classified as underneath
# 6.521  % of behind classified as in front of
# 76.08  % of behind classified as behind

# %%
# allCount = Yall.shape[0]
# factor = 40
# numItems = int(allCount/factor)
cmSize = len(staticPoseModel.textLabels)
confMatrixTest = np.zeros((cmSize, cmSize))
numItems = YtestAll.shape[0]

off3 = len(str(numItems))

print 'estimated time: ' + str(numItems/60) + 'mins for ' + str(numItems) + ' items'
#format training data

yTrainingData = formatDataFunc(YtestAll)
YsampleIdx = [ i for i in sorted(random.sample(xrange(len(yTrainingData)),numItems)) ]

Ysample = [yTrainingData[i] for i in YsampleIdx]
Lsample = [staticPoseModel.textLabels[int(LtestAll[i])] for i in YsampleIdx]

# %time syn = dview.map_async(testFunc, Ysample, Lsample)
wait_watching_stdout(syn, dt=1, truncate=1000)
ret = syn.get()
clear_output()
for i in range(len(ret)):

    currLabel = Lsample[i]

    if(currLabel == ret[i][0]):
        result = True
    else:
        result = False
    print str(i).rjust(off3) + '/' + str(numItems) + ' Truth: ' + currLabel.ljust(off1) + ' Model: ' + ret[i][0].ljust(off1) + ' with ' + str(1-ret[i][1])[:6].ljust(off2) + ' confidence: ' + str(result)
    sstest.append(ret[i][0])
# Out:
#   0/540 Truth: left of     Model: left of     with 0.9684   confidence: True
#   1/540 Truth: left of     Model: on top of   with 0.9744   confidence: False
#   2/540 Truth: left of     Model: left of     with 0.9658   confidence: True
#   3/540 Truth: left of     Model: on top of   with 0.9760   confidence: False
#   4/540 Truth: left of     Model: left of     with 0.9149   confidence: True
#   5/540 Truth: left of     Model: left of     with 0.9651   confidence: True
#   6/540 Truth: left of     Model: left of     with 0.9518   confidence: True
#   7/540 Truth: left of     Model: left of     with 0.9468   confidence: True
#   8/540 Truth: left of     Model: left of     with 0.9600   confidence: True
#   9/540 Truth: left of     Model: left of     with 0.9139   confidence: True
#  10/540 Truth: left of     Model: left of     with 0.6499   confidence: True
#  11/540 Truth: left of     Model: in front of with 0.9758   confidence: False
#  12/540 Truth: left of     Model: left of     with 0.9452   confidence: True
#  13/540 Truth: left of     Model: left of     with 0.9636   confidence: True
#  14/540 Truth: left of     Model: right of    with 0.9705   confidence: False
#  15/540 Truth: left of     Model: left of     with 0.9573   confidence: True
#  16/540 Truth: left of     Model: underneath  with 0.9586   confidence: False
#  17/540 Truth: left of     Model: on top of   with 0.9716   confidence: False
#  18/540 Truth: left of     Model: left of     with 0.9680   confidence: True
#  19/540 Truth: left of     Model: right of    with 0.9655   confidence: False
#  20/540 Truth: left of     Model: left of     with 0.9508   confidence: True
#  21/540 Truth: left of     Model: on top of   with 0.9770   confidence: False
#  22/540 Truth: left of     Model: in front of with 0.9436   confidence: False
#  23/540 Truth: left of     Model: on top of   with 0.9733   confidence: False
#  24/540 Truth: left of     Model: left of     with 0.3152   confidence: True
#  25/540 Truth: left of     Model: left of     with 0.9688   confidence: True
#  26/540 Truth: left of     Model: in front of with 0.9769   confidence: False
#  27/540 Truth: left of     Model: in front of with 0.9796   confidence: False
#  28/540 Truth: left of     Model: left of     with 0.9621   confidence: True
#  29/540 Truth: left of     Model: left of     with 0.9694   confidence: True
#  30/540 Truth: left of     Model: left of     with 0.8916   confidence: True
#  31/540 Truth: left of     Model: right of    with 0.9415   confidence: False
#  32/540 Truth: left of     Model: in front of with 0.9385   confidence: False
#  33/540 Truth: left of     Model: in front of with 0.9375   confidence: False
#  34/540 Truth: left of     Model: in front of with 0.9514   confidence: False
#  35/540 Truth: left of     Model: on top of   with 0.9231   confidence: False
#  36/540 Truth: left of     Model: underneath  with 0.9305   confidence: False
#  37/540 Truth: left of     Model: on top of   with 0.9093   confidence: False
#  38/540 Truth: left of     Model: on top of   with 0.9531   confidence: False
#  39/540 Truth: left of     Model: left of     with 0.9716   confidence: True
#  40/540 Truth: left of     Model: left of     with 0.7587   confidence: True
#  41/540 Truth: left of     Model: left of     with 0.9626   confidence: True
#  42/540 Truth: left of     Model: left of     with 0.9584   confidence: True
#  43/540 Truth: left of     Model: left of     with 0.9627   confidence: True
#  44/540 Truth: left of     Model: left of     with 0.9683   confidence: True
#  45/540 Truth: left of     Model: underneath  with 0.8898   confidence: False
#  46/540 Truth: left of     Model: left of     with 0.6853   confidence: True
#  47/540 Truth: left of     Model: left of     with 0.9649   confidence: True
#  48/540 Truth: left of     Model: left of     with 0.9641   confidence: True
#  49/540 Truth: left of     Model: on top of   with 0.9783   confidence: False
#  50/540 Truth: left of     Model: on top of   with 0.9786   confidence: False
#  51/540 Truth: left of     Model: left of     with 0.9662   confidence: True
#  52/540 Truth: left of     Model: left of     with 0.9649   confidence: True
#  53/540 Truth: left of     Model: left of     with 0.9649   confidence: True
#  54/540 Truth: left of     Model: left of     with 0.9683   confidence: True
#  55/540 Truth: left of     Model: left of     with 0.9676   confidence: True
#  56/540 Truth: left of     Model: left of     with 0.8772   confidence: True
#  57/540 Truth: left of     Model: in front of with 0.9777   confidence: False
#  58/540 Truth: left of     Model: left of     with 0.9528   confidence: True
#  59/540 Truth: left of     Model: left of     with 0.9678   confidence: True
#  60/540 Truth: left of     Model: left of     with 0.6916   confidence: True
#  61/540 Truth: left of     Model: in front of with 0.9800   confidence: False
#  62/540 Truth: left of     Model: right of    with 0.8875   confidence: False
#  63/540 Truth: left of     Model: on top of   with 0.9262   confidence: False
#  64/540 Truth: left of     Model: in front of with 0.9767   confidence: False
#  65/540 Truth: left of     Model: left of     with 0.9647   confidence: True
#  66/540 Truth: left of     Model: underneath  with 0.2220   confidence: False
#  67/540 Truth: left of     Model: left of     with 0.5727   confidence: True
#  68/540 Truth: left of     Model: right of    with 0.9622   confidence: False
#  69/540 Truth: left of     Model: underneath  with 0.9599   confidence: False
#  70/540 Truth: left of     Model: left of     with 0.9202   confidence: True
#  71/540 Truth: left of     Model: left of     with 0.9493   confidence: True
#  72/540 Truth: left of     Model: in front of with 0.9765   confidence: False
#  73/540 Truth: left of     Model: left of     with 0.9639   confidence: True
#  74/540 Truth: left of     Model: left of     with 0.9683   confidence: True
#  75/540 Truth: left of     Model: on top of   with 0.9801   confidence: False
#  76/540 Truth: left of     Model: left of     with 0.9528   confidence: True
#  77/540 Truth: left of     Model: left of     with 0.8204   confidence: True
#  78/540 Truth: left of     Model: left of     with 0.9559   confidence: True
#  79/540 Truth: left of     Model: in front of with 0.9762   confidence: False
#  80/540 Truth: left of     Model: left of     with 0.9699   confidence: True
#  81/540 Truth: left of     Model: left of     with 0.9618   confidence: True
#  82/540 Truth: right of    Model: right of    with 0.9726   confidence: True
#  83/540 Truth: right of    Model: right of    with 0.9556   confidence: True
#  84/540 Truth: right of    Model: right of    with 0.9702   confidence: True
#  85/540 Truth: right of    Model: right of    with 0.9766   confidence: True
#  86/540 Truth: right of    Model: right of    with 0.9634   confidence: True
#  87/540 Truth: right of    Model: right of    with 0.9674   confidence: True
#  88/540 Truth: right of    Model: right of    with 0.9679   confidence: True
#  89/540 Truth: right of    Model: right of    with 0.9610   confidence: True
#  90/540 Truth: right of    Model: on top of   with 0.9617   confidence: False
#  91/540 Truth: right of    Model: right of    with 0.9763   confidence: True
#  92/540 Truth: right of    Model: right of    with 0.9375   confidence: True
#  93/540 Truth: right of    Model: right of    with 0.9772   confidence: True
#  94/540 Truth: right of    Model: right of    with 0.9734   confidence: True
#  95/540 Truth: right of    Model: right of    with 0.9764   confidence: True
#  96/540 Truth: right of    Model: right of    with 0.9375   confidence: True
#  97/540 Truth: right of    Model: right of    with 0.9514   confidence: True
#  98/540 Truth: right of    Model: right of    with 0.9741   confidence: True
#  99/540 Truth: right of    Model: right of    with 0.9417   confidence: True
# 100/540 Truth: right of    Model: right of    with 0.9620   confidence: True
# 101/540 Truth: right of    Model: right of    with 0.9478   confidence: True
# 102/540 Truth: right of    Model: right of    with 0.9759   confidence: True
# 103/540 Truth: right of    Model: right of    with 0.8915   confidence: True
# 104/540 Truth: right of    Model: right of    with 0.9526   confidence: True
# 105/540 Truth: right of    Model: right of    with 0.9709   confidence: True
# 106/540 Truth: right of    Model: right of    with 0.9757   confidence: True
# 107/540 Truth: right of    Model: right of    with 0.9316   confidence: True
# 108/540 Truth: right of    Model: on top of   with 0.9547   confidence: False
# 109/540 Truth: right of    Model: right of    with 0.9355   confidence: True
# 110/540 Truth: right of    Model: right of    with 0.9172   confidence: True
# 111/540 Truth: right of    Model: right of    with 0.9699   confidence: True
# 112/540 Truth: right of    Model: right of    with 0.9653   confidence: True
# 113/540 Truth: right of    Model: right of    with 0.9513   confidence: True
# 114/540 Truth: right of    Model: right of    with 0.9720   confidence: True
# 115/540 Truth: right of    Model: right of    with 0.9189   confidence: True
# 116/540 Truth: right of    Model: right of    with 0.9394   confidence: True
# 117/540 Truth: right of    Model: right of    with 0.9610   confidence: True
# 118/540 Truth: right of    Model: left of     with 0.9724   confidence: False
# 119/540 Truth: right of    Model: right of    with 0.9698   confidence: True
# 120/540 Truth: right of    Model: right of    with 0.9422   confidence: True
# 121/540 Truth: right of    Model: right of    with 0.9610   confidence: True
# 122/540 Truth: right of    Model: right of    with 0.9418   confidence: True
# 123/540 Truth: right of    Model: right of    with 0.9696   confidence: True
# 124/540 Truth: right of    Model: on top of   with 0.9338   confidence: False
# 125/540 Truth: right of    Model: right of    with 0.9648   confidence: True
# 126/540 Truth: right of    Model: right of    with 0.9692   confidence: True
# 127/540 Truth: right of    Model: right of    with 0.9709   confidence: True
# 128/540 Truth: right of    Model: on top of   with 0.9603   confidence: False
# 129/540 Truth: right of    Model: left of     with 0.9742   confidence: False
# 130/540 Truth: right of    Model: right of    with 0.9670   confidence: True
# 131/540 Truth: right of    Model: right of    with 0.9735   confidence: True
# 132/540 Truth: right of    Model: right of    with 0.9747   confidence: True
# 133/540 Truth: right of    Model: right of    with 0.9618   confidence: True
# 134/540 Truth: right of    Model: right of    with 0.9767   confidence: True
# 135/540 Truth: right of    Model: right of    with 0.9282   confidence: True
# 136/540 Truth: right of    Model: right of    with 0.9608   confidence: True
# 137/540 Truth: right of    Model: right of    with 0.9620   confidence: True
# 138/540 Truth: right of    Model: right of    with 0.9724   confidence: True
# 139/540 Truth: right of    Model: right of    with 0.9611   confidence: True
# 140/540 Truth: right of    Model: right of    with 0.9733   confidence: True
# 141/540 Truth: right of    Model: right of    with 0.9774   confidence: True
# 142/540 Truth: right of    Model: right of    with 0.9532   confidence: True
# 143/540 Truth: right of    Model: right of    with 0.9466   confidence: True
# 144/540 Truth: right of    Model: right of    with 0.9711   confidence: True
# 145/540 Truth: right of    Model: right of    with 0.9501   confidence: True
# 146/540 Truth: right of    Model: right of    with 0.9673   confidence: True
# 147/540 Truth: right of    Model: on top of   with 0.9650   confidence: False
# 148/540 Truth: right of    Model: right of    with 0.9700   confidence: True
# 149/540 Truth: right of    Model: right of    with 0.9596   confidence: True
# 150/540 Truth: right of    Model: on top of   with 0.9460   confidence: False
# 151/540 Truth: right of    Model: right of    with 0.9751   confidence: True
# 152/540 Truth: right of    Model: right of    with 0.9417   confidence: True
# 153/540 Truth: right of    Model: right of    with 0.9745   confidence: True
# 154/540 Truth: right of    Model: right of    with 0.9669   confidence: True
# 155/540 Truth: right of    Model: right of    with 0.9696   confidence: True
# 156/540 Truth: right of    Model: right of    with 0.9700   confidence: True
# 157/540 Truth: right of    Model: left of     with 0.9728   confidence: False
# 158/540 Truth: right of    Model: right of    with 0.9744   confidence: True
# 159/540 Truth: right of    Model: on top of   with 0.9497   confidence: False
# 160/540 Truth: right of    Model: right of    with 0.9640   confidence: True
# 161/540 Truth: right of    Model: right of    with 0.9409   confidence: True
# 162/540 Truth: right of    Model: right of    with 0.9245   confidence: True
# 163/540 Truth: right of    Model: on top of   with 0.9445   confidence: False
# 164/540 Truth: right of    Model: right of    with 0.9678   confidence: True
# 165/540 Truth: right of    Model: right of    with 0.9768   confidence: True
# 166/540 Truth: right of    Model: right of    with 0.9623   confidence: True
# 167/540 Truth: right of    Model: right of    with 0.9720   confidence: True
# 168/540 Truth: right of    Model: right of    with 0.9535   confidence: True
# 169/540 Truth: right of    Model: right of    with 0.9764   confidence: True
# 170/540 Truth: right of    Model: on top of   with 0.9634   confidence: False
# 171/540 Truth: right of    Model: right of    with 0.9367   confidence: True
# 172/540 Truth: right of    Model: on top of   with 0.9454   confidence: False
# 173/540 Truth: right of    Model: underneath  with 0.9769   confidence: False
# 174/540 Truth: right of    Model: on top of   with 0.9716   confidence: False
# 175/540 Truth: right of    Model: underneath  with 0.9777   confidence: False
# 176/540 Truth: right of    Model: right of    with 0.9740   confidence: True
# 177/540 Truth: right of    Model: right of    with 0.9665   confidence: True
# 178/540 Truth: right of    Model: right of    with 0.9739   confidence: True
# 179/540 Truth: right of    Model: right of    with 0.9236   confidence: True
# 180/540 Truth: right of    Model: right of    with 0.9739   confidence: True
# 181/540 Truth: right of    Model: right of    with 0.9669   confidence: True
# 182/540 Truth: right of    Model: right of    with 0.9649   confidence: True
# 183/540 Truth: right of    Model: left of     with 0.9741   confidence: False
# 184/540 Truth: right of    Model: right of    with 0.9755   confidence: True
# 185/540 Truth: right of    Model: on top of   with 0.9476   confidence: False
# 186/540 Truth: right of    Model: right of    with 0.9321   confidence: True
# 187/540 Truth: right of    Model: right of    with 0.9626   confidence: True
# 188/540 Truth: right of    Model: left of     with 0.9727   confidence: False
# 189/540 Truth: on top of   Model: left of     with 0.9632   confidence: False
# 190/540 Truth: on top of   Model: on top of   with 0.8165   confidence: True
# 191/540 Truth: on top of   Model: on top of   with 0.9316   confidence: True
# 192/540 Truth: on top of   Model: on top of   with 0.8980   confidence: True
# 193/540 Truth: on top of   Model: left of     with 0.9724   confidence: False
# 194/540 Truth: on top of   Model: on top of   with 0.9251   confidence: True
# 195/540 Truth: on top of   Model: on top of   with 0.9703   confidence: True
# 196/540 Truth: on top of   Model: left of     with 0.8199   confidence: False
# 197/540 Truth: on top of   Model: left of     with 0.9681   confidence: False
# 198/540 Truth: on top of   Model: on top of   with 0.8840   confidence: True
# 199/540 Truth: on top of   Model: on top of   with 0.9382   confidence: True
# 200/540 Truth: on top of   Model: left of     with 0.8372   confidence: False
# 201/540 Truth: on top of   Model: on top of   with 0.9607   confidence: True
# 202/540 Truth: on top of   Model: left of     with 0.9506   confidence: False
# 203/540 Truth: on top of   Model: on top of   with 0.9678   confidence: True
# 204/540 Truth: on top of   Model: on top of   with 0.9771   confidence: True
# 205/540 Truth: on top of   Model: left of     with 0.9643   confidence: False
# 206/540 Truth: on top of   Model: on top of   with 0.9784   confidence: True
# 207/540 Truth: on top of   Model: on top of   with 0.8386   confidence: True
# 208/540 Truth: on top of   Model: on top of   with 0.7816   confidence: True
# 209/540 Truth: on top of   Model: on top of   with 0.9185   confidence: True
# 210/540 Truth: on top of   Model: on top of   with 0.9300   confidence: True
# 211/540 Truth: on top of   Model: on top of   with 0.8919   confidence: True
# 212/540 Truth: on top of   Model: on top of   with 0.9746   confidence: True
# 213/540 Truth: on top of   Model: on top of   with 0.9367   confidence: True
# 214/540 Truth: on top of   Model: on top of   with 0.7692   confidence: True
# 215/540 Truth: on top of   Model: left of     with 0.9683   confidence: False
# 216/540 Truth: on top of   Model: left of     with 0.9608   confidence: False
# 217/540 Truth: on top of   Model: on top of   with 0.9613   confidence: True
# 218/540 Truth: on top of   Model: on top of   with 0.9740   confidence: True
# 219/540 Truth: on top of   Model: on top of   with 0.9743   confidence: True
# 220/540 Truth: on top of   Model: on top of   with 0.9798   confidence: True
# 221/540 Truth: on top of   Model: on top of   with 0.9381   confidence: True
# 222/540 Truth: on top of   Model: on top of   with 0.9755   confidence: True
# 223/540 Truth: on top of   Model: on top of   with 0.9241   confidence: True
# 224/540 Truth: on top of   Model: on top of   with 0.9789   confidence: True
# 225/540 Truth: on top of   Model: on top of   with 0.9516   confidence: True
# 226/540 Truth: on top of   Model: on top of   with 0.8149   confidence: True
# 227/540 Truth: on top of   Model: on top of   with 0.9563   confidence: True
# 228/540 Truth: on top of   Model: on top of   with 0.9758   confidence: True
# 229/540 Truth: on top of   Model: left of     with 0.9550   confidence: False
# 230/540 Truth: on top of   Model: on top of   with 0.9624   confidence: True
# 231/540 Truth: on top of   Model: on top of   with 0.8248   confidence: True
# 232/540 Truth: on top of   Model: on top of   with 0.9673   confidence: True
# 233/540 Truth: on top of   Model: on top of   with 0.7687   confidence: True
# 234/540 Truth: on top of   Model: on top of   with 0.9573   confidence: True
# 235/540 Truth: on top of   Model: on top of   with 0.9531   confidence: True
# 236/540 Truth: on top of   Model: on top of   with 0.7807   confidence: True
# 237/540 Truth: on top of   Model: on top of   with 0.9772   confidence: True
# 238/540 Truth: on top of   Model: on top of   with 0.9471   confidence: True
# 239/540 Truth: on top of   Model: on top of   with 0.9744   confidence: True
# 240/540 Truth: on top of   Model: on top of   with 0.9686   confidence: True
# 241/540 Truth: on top of   Model: on top of   with 0.9057   confidence: True
# 242/540 Truth: on top of   Model: on top of   with 0.9654   confidence: True
# 243/540 Truth: on top of   Model: on top of   with 0.9120   confidence: True
# 244/540 Truth: on top of   Model: on top of   with 0.9774   confidence: True
# 245/540 Truth: on top of   Model: on top of   with 0.9647   confidence: True
# 246/540 Truth: on top of   Model: on top of   with 0.9645   confidence: True
# 247/540 Truth: on top of   Model: on top of   with 0.9763   confidence: True
# 248/540 Truth: on top of   Model: left of     with 0.9664   confidence: False
# 249/540 Truth: on top of   Model: on top of   with 0.9001   confidence: True
# 250/540 Truth: on top of   Model: on top of   with 0.9787   confidence: True
# 251/540 Truth: on top of   Model: on top of   with 0.9780   confidence: True
# 252/540 Truth: on top of   Model: on top of   with 0.9753   confidence: True
# 253/540 Truth: on top of   Model: on top of   with 0.9747   confidence: True
# 254/540 Truth: on top of   Model: on top of   with 0.9556   confidence: True
# 255/540 Truth: on top of   Model: on top of   with 0.9739   confidence: True
# 256/540 Truth: on top of   Model: on top of   with 0.9165   confidence: True
# 257/540 Truth: on top of   Model: on top of   with 0.9759   confidence: True
# 258/540 Truth: on top of   Model: on top of   with 0.9050   confidence: True
# 259/540 Truth: on top of   Model: on top of   with 0.9794   confidence: True
# 260/540 Truth: on top of   Model: on top of   with 0.9794   confidence: True
# 261/540 Truth: on top of   Model: left of     with 0.9717   confidence: False
# 262/540 Truth: on top of   Model: on top of   with 0.9316   confidence: True
# 263/540 Truth: on top of   Model: left of     with 0.9470   confidence: False
# 264/540 Truth: on top of   Model: left of     with 0.9713   confidence: False
# 265/540 Truth: on top of   Model: on top of   with 0.9780   confidence: True
# 266/540 Truth: on top of   Model: on top of   with 0.9367   confidence: True
# 267/540 Truth: on top of   Model: on top of   with 0.9697   confidence: True
# 268/540 Truth: on top of   Model: right of    with 0.8303   confidence: False
# 269/540 Truth: on top of   Model: on top of   with 0.9161   confidence: True
# 270/540 Truth: on top of   Model: on top of   with 0.9712   confidence: True
# 271/540 Truth: on top of   Model: on top of   with 0.9800   confidence: True
# 272/540 Truth: on top of   Model: on top of   with 0.9779   confidence: True
# 273/540 Truth: on top of   Model: left of     with 0.9676   confidence: False
# 274/540 Truth: on top of   Model: on top of   with 0.9268   confidence: True
# 275/540 Truth: on top of   Model: on top of   with 0.9765   confidence: True
# 276/540 Truth: on top of   Model: on top of   with 0.8116   confidence: True
# 277/540 Truth: underneath  Model: left of     with 0.9742   confidence: False
# 278/540 Truth: underneath  Model: underneath  with 0.9679   confidence: True
# 279/540 Truth: underneath  Model: underneath  with 0.9488   confidence: True
# 280/540 Truth: underneath  Model: underneath  with 0.8987   confidence: True
# 281/540 Truth: underneath  Model: underneath  with 0.9051   confidence: True
# 282/540 Truth: underneath  Model: underneath  with 0.9343   confidence: True
# 283/540 Truth: underneath  Model: underneath  with 0.8713   confidence: True
# 284/540 Truth: underneath  Model: underneath  with 0.9166   confidence: True
# 285/540 Truth: underneath  Model: underneath  with 0.9687   confidence: True
# 286/540 Truth: underneath  Model: in front of with 0.9576   confidence: False
# 287/540 Truth: underneath  Model: in front of with 0.9532   confidence: False
# 288/540 Truth: underneath  Model: left of     with 0.9486   confidence: False
# 289/540 Truth: underneath  Model: underneath  with 0.9740   confidence: True
# 290/540 Truth: underneath  Model: underneath  with 0.8240   confidence: True
# 291/540 Truth: underneath  Model: underneath  with 0.8727   confidence: True
# 292/540 Truth: underneath  Model: right of    with 0.9753   confidence: False
# 293/540 Truth: underneath  Model: underneath  with 0.9620   confidence: True
# 294/540 Truth: underneath  Model: underneath  with 0.9675   confidence: True
# 295/540 Truth: underneath  Model: underneath  with 0.8157   confidence: True
# 296/540 Truth: underneath  Model: underneath  with 0.9673   confidence: True
# 297/540 Truth: underneath  Model: underneath  with 0.9652   confidence: True
# 298/540 Truth: underneath  Model: underneath  with 0.9651   confidence: True
# 299/540 Truth: underneath  Model: underneath  with 0.9754   confidence: True
# 300/540 Truth: underneath  Model: underneath  with 0.9701   confidence: True
# 301/540 Truth: underneath  Model: underneath  with 0.9595   confidence: True
# 302/540 Truth: underneath  Model: underneath  with 0.9470   confidence: True
# 303/540 Truth: underneath  Model: underneath  with 0.9682   confidence: True
# 304/540 Truth: underneath  Model: underneath  with 0.8690   confidence: True
# 305/540 Truth: underneath  Model: underneath  with 0.9589   confidence: True
# 306/540 Truth: underneath  Model: right of    with 0.9620   confidence: False
# 307/540 Truth: underneath  Model: underneath  with 0.9725   confidence: True
# 308/540 Truth: underneath  Model: underneath  with 0.9761   confidence: True
# 309/540 Truth: underneath  Model: underneath  with 0.8270   confidence: True
# 310/540 Truth: underneath  Model: underneath  with 0.9423   confidence: True
# 311/540 Truth: underneath  Model: underneath  with 0.8991   confidence: True
# 312/540 Truth: underneath  Model: underneath  with 0.9345   confidence: True
# 313/540 Truth: underneath  Model: left of     with 0.9503   confidence: False
# 314/540 Truth: underneath  Model: underneath  with 0.9409   confidence: True
# 315/540 Truth: underneath  Model: underneath  with 0.9159   confidence: True
# 316/540 Truth: underneath  Model: underneath  with 0.9450   confidence: True
# 317/540 Truth: underneath  Model: underneath  with 0.9262   confidence: True
# 318/540 Truth: underneath  Model: left of     with 0.9753   confidence: False
# 319/540 Truth: underneath  Model: right of    with 0.9775   confidence: False
# 320/540 Truth: underneath  Model: underneath  with 0.9352   confidence: True
# 321/540 Truth: underneath  Model: underneath  with 0.9697   confidence: True
# 322/540 Truth: underneath  Model: underneath  with 0.9700   confidence: True
# 323/540 Truth: underneath  Model: underneath  with 0.9000   confidence: True
# 324/540 Truth: underneath  Model: underneath  with 0.9149   confidence: True
# 325/540 Truth: underneath  Model: underneath  with 0.8931   confidence: True
# 326/540 Truth: underneath  Model: underneath  with 0.8893   confidence: True
# 327/540 Truth: underneath  Model: in front of with 0.9492   confidence: False
# 328/540 Truth: underneath  Model: underneath  with 0.9624   confidence: True
# 329/540 Truth: underneath  Model: underneath  with 0.8045   confidence: True
# 330/540 Truth: underneath  Model: underneath  with 0.8520   confidence: True
# 331/540 Truth: underneath  Model: underneath  with 0.9622   confidence: True
# 332/540 Truth: underneath  Model: underneath  with 0.9385   confidence: True
# 333/540 Truth: underneath  Model: underneath  with 0.8903   confidence: True
# 334/540 Truth: underneath  Model: underneath  with 0.9622   confidence: True
# 335/540 Truth: underneath  Model: underneath  with 0.9522   confidence: True
# 336/540 Truth: underneath  Model: right of    with 0.9780   confidence: False
# 337/540 Truth: underneath  Model: in front of with 0.9569   confidence: False
# 338/540 Truth: underneath  Model: underneath  with 0.9528   confidence: True
# 339/540 Truth: underneath  Model: underneath  with 0.9725   confidence: True
# 340/540 Truth: underneath  Model: underneath  with 0.9716   confidence: True
# 341/540 Truth: underneath  Model: underneath  with 0.9684   confidence: True
# 342/540 Truth: underneath  Model: underneath  with 0.9682   confidence: True
# 343/540 Truth: underneath  Model: underneath  with 0.9016   confidence: True
# 344/540 Truth: underneath  Model: right of    with 0.9719   confidence: False
# 345/540 Truth: underneath  Model: underneath  with 0.7945   confidence: True
# 346/540 Truth: underneath  Model: left of     with 0.9744   confidence: False
# 347/540 Truth: underneath  Model: left of     with 0.9554   confidence: False
# 348/540 Truth: underneath  Model: underneath  with 0.8236   confidence: True
# 349/540 Truth: underneath  Model: in front of with 0.9528   confidence: False
# 350/540 Truth: in front of Model: underneath  with 0.9741   confidence: False
# 351/540 Truth: in front of Model: in front of with 0.9634   confidence: True
# 352/540 Truth: in front of Model: underneath  with 0.9556   confidence: False
# 353/540 Truth: in front of Model: in front of with 0.9445   confidence: True
# 354/540 Truth: in front of Model: in front of with 0.9582   confidence: True
# 355/540 Truth: in front of Model: in front of with 0.9785   confidence: True
# 356/540 Truth: in front of Model: in front of with 0.9470   confidence: True
# 357/540 Truth: in front of Model: in front of with 0.9513   confidence: True
# 358/540 Truth: in front of Model: underneath  with 0.9656   confidence: False
# 359/540 Truth: in front of Model: in front of with 0.9638   confidence: True
# 360/540 Truth: in front of Model: in front of with 0.9496   confidence: True
# 361/540 Truth: in front of Model: in front of with 0.9740   confidence: True
# 362/540 Truth: in front of Model: in front of with 0.9747   confidence: True
# 363/540 Truth: in front of Model: on top of   with 0.9195   confidence: False
# 364/540 Truth: in front of Model: in front of with 0.9588   confidence: True
# 365/540 Truth: in front of Model: in front of with 0.9740   confidence: True
# 366/540 Truth: in front of Model: in front of with 0.9706   confidence: True
# 367/540 Truth: in front of Model: in front of with 0.9507   confidence: True
# 368/540 Truth: in front of Model: in front of with 0.9461   confidence: True
# 369/540 Truth: in front of Model: in front of with 0.9379   confidence: True
# 370/540 Truth: in front of Model: in front of with 0.9128   confidence: True
# 371/540 Truth: in front of Model: in front of with 0.9337   confidence: True
# 372/540 Truth: in front of Model: left of     with 0.9690   confidence: False
# 373/540 Truth: in front of Model: in front of with 0.9338   confidence: True
# 374/540 Truth: in front of Model: in front of with 0.9045   confidence: True
# 375/540 Truth: in front of Model: in front of with 0.9557   confidence: True
# 376/540 Truth: in front of Model: in front of with 0.9539   confidence: True
# 377/540 Truth: in front of Model: in front of with 0.9678   confidence: True
# 378/540 Truth: in front of Model: in front of with 0.9753   confidence: True
# 379/540 Truth: in front of Model: in front of with 0.9722   confidence: True
# 380/540 Truth: in front of Model: in front of with 0.9473   confidence: True
# 381/540 Truth: in front of Model: left of     with 0.9713   confidence: False
# 382/540 Truth: in front of Model: in front of with 0.8938   confidence: True
# 383/540 Truth: in front of Model: in front of with 0.9372   confidence: True
# 384/540 Truth: in front of Model: in front of with 0.9101   confidence: True
# 385/540 Truth: in front of Model: left of     with 0.9735   confidence: False
# 386/540 Truth: in front of Model: in front of with 0.9543   confidence: True
# 387/540 Truth: in front of Model: in front of with 0.9470   confidence: True
# 388/540 Truth: in front of Model: in front of with 0.9377   confidence: True
# 389/540 Truth: in front of Model: in front of with 0.9402   confidence: True
# 390/540 Truth: in front of Model: in front of with 0.9798   confidence: True
# 391/540 Truth: in front of Model: in front of with 0.9438   confidence: True
# 392/540 Truth: in front of Model: in front of with 0.9665   confidence: True
# 393/540 Truth: in front of Model: in front of with 0.9339   confidence: True
# 394/540 Truth: in front of Model: in front of with 0.9591   confidence: True
# 395/540 Truth: in front of Model: in front of with 0.9461   confidence: True
# 396/540 Truth: in front of Model: in front of with 0.9636   confidence: True
# 397/540 Truth: in front of Model: on top of   with 0.9181   confidence: False
# 398/540 Truth: in front of Model: in front of with 0.9703   confidence: True
# 399/540 Truth: in front of Model: in front of with 0.9576   confidence: True
# 400/540 Truth: in front of Model: in front of with 0.9572   confidence: True
# 401/540 Truth: in front of Model: in front of with 0.9070   confidence: True
# 402/540 Truth: in front of Model: in front of with 0.9675   confidence: True
# 403/540 Truth: in front of Model: in front of with 0.9760   confidence: True
# 404/540 Truth: in front of Model: in front of with 0.9389   confidence: True
# 405/540 Truth: in front of Model: in front of with 0.9421   confidence: True
# 406/540 Truth: in front of Model: in front of with 0.9226   confidence: True
# 407/540 Truth: in front of Model: in front of with 0.9718   confidence: True
# 408/540 Truth: in front of Model: in front of with 0.9616   confidence: True
# 409/540 Truth: in front of Model: in front of with 0.9458   confidence: True
# 410/540 Truth: in front of Model: in front of with 0.9754   confidence: True
# 411/540 Truth: in front of Model: underneath  with 0.9482   confidence: False
# 412/540 Truth: in front of Model: in front of with 0.9462   confidence: True
# 413/540 Truth: in front of Model: in front of with 0.9189   confidence: True
# 414/540 Truth: in front of Model: in front of with 0.9740   confidence: True
# 415/540 Truth: in front of Model: in front of with 0.9454   confidence: True
# 416/540 Truth: in front of Model: in front of with 0.9501   confidence: True
# 417/540 Truth: in front of Model: in front of with 0.9551   confidence: True
# 418/540 Truth: in front of Model: in front of with 0.9575   confidence: True
# 419/540 Truth: in front of Model: underneath  with 0.9423   confidence: False
# 420/540 Truth: in front of Model: in front of with 0.9737   confidence: True
# 421/540 Truth: in front of Model: in front of with 0.9633   confidence: True
# 422/540 Truth: in front of Model: in front of with 0.9606   confidence: True
# 423/540 Truth: in front of Model: in front of with 0.9565   confidence: True
# 424/540 Truth: in front of Model: underneath  with 0.9435   confidence: False
# 425/540 Truth: in front of Model: in front of with 0.9753   confidence: True
# 426/540 Truth: in front of Model: in front of with 0.9428   confidence: True
# 427/540 Truth: in front of Model: in front of with 0.9700   confidence: True
# 428/540 Truth: in front of Model: in front of with 0.9164   confidence: True
# 429/540 Truth: in front of Model: in front of with 0.9391   confidence: True
# 430/540 Truth: in front of Model: in front of with 0.9542   confidence: True
# 431/540 Truth: in front of Model: in front of with 0.9438   confidence: True
# 432/540 Truth: in front of Model: in front of with 0.9452   confidence: True
# 433/540 Truth: in front of Model: in front of with 0.9611   confidence: True
# 434/540 Truth: in front of Model: in front of with 0.9632   confidence: True
# 435/540 Truth: in front of Model: in front of with 0.9576   confidence: True
# 436/540 Truth: in front of Model: in front of with 0.9679   confidence: True
# 437/540 Truth: in front of Model: in front of with 0.9051   confidence: True
# 438/540 Truth: in front of Model: in front of with 0.9635   confidence: True
# 439/540 Truth: in front of Model: in front of with 0.9366   confidence: True
# 440/540 Truth: in front of Model: in front of with 0.9764   confidence: True
# 441/540 Truth: behind      Model: behind      with 0.5750   confidence: True
# 442/540 Truth: behind      Model: on top of   with 0.9817   confidence: False
# 443/540 Truth: behind      Model: on top of   with 0.9781   confidence: False
# 444/540 Truth: behind      Model: behind      with 0.9584   confidence: True
# 445/540 Truth: behind      Model: behind      with 0.9705   confidence: True
# 446/540 Truth: behind      Model: behind      with 0.8162   confidence: True
# 447/540 Truth: behind      Model: behind      with 0.9673   confidence: True
# 448/540 Truth: behind      Model: behind      with 0.9716   confidence: True
# 449/540 Truth: behind      Model: on top of   with 0.9809   confidence: False
# 450/540 Truth: behind      Model: right of    with 0.9763   confidence: False
# 451/540 Truth: behind      Model: on top of   with 0.9763   confidence: False
# 452/540 Truth: behind      Model: behind      with 0.4977   confidence: True
# 453/540 Truth: behind      Model: behind      with 0.9323   confidence: True
# 454/540 Truth: behind      Model: behind      with 0.9655   confidence: True
# 455/540 Truth: behind      Model: underneath  with 0.9774   confidence: False
# 456/540 Truth: behind      Model: behind      with 0.8380   confidence: True
# 457/540 Truth: behind      Model: behind      with 0.9415   confidence: True
# 458/540 Truth: behind      Model: behind      with 0.9723   confidence: True
# 459/540 Truth: behind      Model: behind      with 0.9742   confidence: True
# 460/540 Truth: behind      Model: behind      with 0.9334   confidence: True
# 461/540 Truth: behind      Model: behind      with 0.9644   confidence: True
# 462/540 Truth: behind      Model: behind      with 0.9560   confidence: True
# 463/540 Truth: behind      Model: behind      with 0.9432   confidence: True
# 464/540 Truth: behind      Model: behind      with 0.7677   confidence: True
# 465/540 Truth: behind      Model: behind      with 0.9749   confidence: True
# 466/540 Truth: behind      Model: behind      with 0.9589   confidence: True
# 467/540 Truth: behind      Model: underneath  with 0.9722   confidence: False
# 468/540 Truth: behind      Model: behind      with 0.9640   confidence: True
# 469/540 Truth: behind      Model: behind      with 0.9740   confidence: True
# 470/540 Truth: behind      Model: behind      with 0.9699   confidence: True
# 471/540 Truth: behind      Model: behind      with 0.9632   confidence: True
# 472/540 Truth: behind      Model: behind      with 0.7367   confidence: True
# 473/540 Truth: behind      Model: behind      with 0.9713   confidence: True
# 474/540 Truth: behind      Model: behind      with 0.9540   confidence: True
# 475/540 Truth: behind      Model: behind      with 0.9663   confidence: True
# 476/540 Truth: behind      Model: behind      with 0.8655   confidence: True
# 477/540 Truth: behind      Model: behind      with 0.9489   confidence: True
# 478/540 Truth: behind      Model: behind      with 0.9753   confidence: True
# 479/540 Truth: behind      Model: behind      with 0.9580   confidence: True
# 480/540 Truth: behind      Model: behind      with 0.8838   confidence: True
# 481/540 Truth: behind      Model: behind      with 0.8418   confidence: True
# 482/540 Truth: behind      Model: behind      with 0.9677   confidence: True
# 483/540 Truth: behind      Model: behind      with 0.9380   confidence: True
# 484/540 Truth: behind      Model: behind      with 0.6874   confidence: True
# 485/540 Truth: behind      Model: on top of   with 0.9744   confidence: False
# 486/540 Truth: behind      Model: behind      with 0.9505   confidence: True
# 487/540 Truth: behind      Model: behind      with 0.7448   confidence: True
# 488/540 Truth: behind      Model: on top of   with 0.9815   confidence: False
# 489/540 Truth: behind      Model: behind      with 0.5017   confidence: True
# 490/540 Truth: behind      Model: behind      with 0.8313   confidence: True
# 491/540 Truth: behind      Model: behind      with 0.9704   confidence: True
# 492/540 Truth: behind      Model: on top of   with 0.9753   confidence: False
# 493/540 Truth: behind      Model: behind      with 0.9694   confidence: True
# 494/540 Truth: behind      Model: behind      with 0.9660   confidence: True
# 495/540 Truth: behind      Model: behind      with 0.9500   confidence: True
# 496/540 Truth: behind      Model: behind      with 0.7450   confidence: True
# 497/540 Truth: behind      Model: underneath  with 0.9772   confidence: False
# 498/540 Truth: behind      Model: behind      with 0.8053   confidence: True
# 499/540 Truth: behind      Model: behind      with 0.9749   confidence: True
# 500/540 Truth: behind      Model: behind      with 0.7179   confidence: True
# 501/540 Truth: behind      Model: left of     with 0.5346   confidence: False
# 502/540 Truth: behind      Model: behind      with 0.8944   confidence: True
# 503/540 Truth: behind      Model: behind      with 0.9662   confidence: True
# 504/540 Truth: behind      Model: behind      with 0.7061   confidence: True
# 505/540 Truth: behind      Model: behind      with 0.9655   confidence: True
# 506/540 Truth: behind      Model: behind      with 0.9734   confidence: True
# 507/540 Truth: behind      Model: behind      with 0.9739   confidence: True
# 508/540 Truth: behind      Model: behind      with 0.8983   confidence: True
# 509/540 Truth: behind      Model: behind      with 0.8215   confidence: True
# 510/540 Truth: behind      Model: behind      with 0.9460   confidence: True
# 511/540 Truth: behind      Model: behind      with 0.8740   confidence: True
# 512/540 Truth: behind      Model: behind      with 0.9642   confidence: True
# 513/540 Truth: behind      Model: behind      with 0.8900   confidence: True
# 514/540 Truth: behind      Model: behind      with 0.8537   confidence: True
# 515/540 Truth: behind      Model: behind      with 0.9628   confidence: True
# 516/540 Truth: behind      Model: behind      with 0.9654   confidence: True
# 517/540 Truth: behind      Model: behind      with 0.9214   confidence: True
# 518/540 Truth: behind      Model: behind      with 0.8569   confidence: True
# 519/540 Truth: behind      Model: behind      with 0.8684   confidence: True
# 520/540 Truth: behind      Model: behind      with 0.8768   confidence: True
# 521/540 Truth: behind      Model: behind      with 0.9749   confidence: True
# 522/540 Truth: behind      Model: behind      with 0.5381   confidence: True
# 523/540 Truth: behind      Model: on top of   with 0.9809   confidence: False
# 524/540 Truth: behind      Model: behind      with 0.9455   confidence: True
# 525/540 Truth: behind      Model: behind      with 0.9620   confidence: True
# 526/540 Truth: behind      Model: behind      with 0.7215   confidence: True
# 527/540 Truth: behind      Model: behind      with 0.7470   confidence: True
# 528/540 Truth: behind      Model: right of    with 0.9767   confidence: False
# 529/540 Truth: behind      Model: behind      with 0.9723   confidence: True
# 530/540 Truth: behind      Model: behind      with 0.8950   confidence: True
# 531/540 Truth: behind      Model: behind      with 0.8859   confidence: True
# 532/540 Truth: behind      Model: underneath  with 0.9773   confidence: False
# 533/540 Truth: behind      Model: behind      with 0.9695   confidence: True
# 534/540 Truth: behind      Model: underneath  with 0.9771   confidence: False
# 535/540 Truth: behind      Model: behind      with 0.7418   confidence: True
# 536/540 Truth: behind      Model: underneath  with 0.9733   confidence: False
# 537/540 Truth: behind      Model: behind      with 0.9722   confidence: True
# 538/540 Truth: behind      Model: on top of   with 0.9756   confidence: False
# 539/540 Truth: behind      Model: behind      with 0.8172   confidence: True

# %%
confMatrixTest = confusion_matrix(sstest, Lsample)
print confMatrixTest
plot_confusion_matrix(confMatrixTest, confMatLabels)
# Out:
# [[81  0  0  0  0  0]
#  [ 0 80 12  0  0  5]
#  [ 1  3 48 15  5  6]
#  [ 9  2 12 72 12  0]
#  [ 2  0  5  1 88  5]
#  [ 6  6  5  0  2 57]]

# %%
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix

percCorect = 100*np.diag(confMatrixTest.astype(np.float)).sum()/numItems

normConf = confMatrixTest / confMatrixTest.astype(np.float).sum(axis=0)
normConf = np.nan_to_num(normConf)
print
print 'Nomalised Confusion Matrix = '
print normConf
print 

print str(percCorect)[:5].ljust(7) + " % correct for testing data"

for i in range(cmSize):
    for j in range(cmSize):
        print str(normConf[i,j]*100)[:5].ljust(7)  + '% of ' + str(staticPoseModel.textLabels[i]) + ' classified as ' + str(staticPoseModel.textLabels[j])
    print

print
# Out:
# Nomalised Confusion Matrix =
# [[ 0.81818182  0.          0.          0.          0.          0.        ]
#  [ 0.          0.87912088  0.14634146  0.          0.          0.06849315]
#  [ 0.01010101  0.03296703  0.58536585  0.17045455  0.04672897  0.08219178]
#  [ 0.09090909  0.02197802  0.14634146  0.81818182  0.11214953  0.        ]
#  [ 0.02020202  0.          0.06097561  0.01136364  0.82242991  0.06849315]
#  [ 0.06060606  0.06593407  0.06097561  0.          0.01869159  0.78082192]]
#
# 78.88   % correct for testing data
# 81.81  % of left of classified as left of
# 0.0    % of left of classified as right of
# 0.0    % of left of classified as on top of
# 0.0    % of left of classified as underneath
# 0.0    % of left of classified as in front of
# 0.0    % of left of classified as behind
#
# 0.0    % of right of classified as left of
# 87.91  % of right of classified as right of
# 14.63  % of right of classified as on top of
# 0.0    % of right of classified as underneath
# 0.0    % of right of classified as in front of
# 6.849  % of right of classified as behind
#
# 1.010  % of on top of classified as left of
# 3.296  % of on top of classified as right of
# 58.53  % of on top of classified as on top of
# 17.04  % of on top of classified as underneath
# 4.672  % of on top of classified as in front of
# 8.219  % of on top of classified as behind
#
# 9.090  % of underneath classified as left of
# 2.197  % of underneath classified as right of
# 14.63  % of underneath classified as on top of
# 81.81  % of underneath classified as underneath
# 11.21  % of underneath classified as in front of
# 0.0    % of underneath classified as behind
#
# 2.020  % of in front of classified as left of
# 0.0    % of in front of classified as right of
# 6.097  % of in front of classified as on top of
# 1.136  % of in front of classified as underneath
# 82.24  % of in front of classified as in front of
# 6.849  % of in front of classified as behind
#
# 6.060  % of behind classified as left of
# 6.593  % of behind classified as right of
# 6.097  % of behind classified as on top of
# 0.0    % of behind classified as underneath
# 1.869  % of behind classified as in front of
# 78.08  % of behind classified as behind
